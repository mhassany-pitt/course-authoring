# %%
import json

new_catalog = json.load(open('new-catalog.json'))
old_catalog = json.load(open('old-catalog.json'))

# %%
new_catalog = {item['identity']['id']: item for item in new_catalog}
old_catalog = {item['short_name']: item for item in old_catalog}

# %%
len(set(old_catalog.keys()).intersection(set(new_catalog.keys())))
# Out:
# 2934
