# %%
import polars as pl

gavin = pl.concat([
    pl.read_csv('filtered_pcex_example_with_kcs.csv'),
    pl.read_csv('filtered_pcex_problem_with_kcs.csv')
])

gavin
# Out:
# shape: (159, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ set_id    ┆ set_name  ┆ item_name ┆ item_type ┆ … ┆ item_tags ┆ item_desc ┆ item_code ┆ generate │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ription   ┆ ---       ┆ d_kcs    │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ str       ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 664e50d09 ┆ py_if_els ┆ Calculati ┆ example   ┆ … ┆ null      ┆ Construct ┆ #Step 1:  ┆ ['Variab │
# │ 1363872f0 ┆ e_wage    ┆ ng the    ┆           ┆   ┆           ┆ a program ┆ Assign    ┆ le assig │
# │ ba390d    ┆           ┆ Employee' ┆           ┆   ┆           ┆ for the   ┆ initial   ┆ nment',  │
# │           ┆           ┆ s Wag…    ┆           ┆   ┆           ┆ pa…       ┆ values…   ┆ 'Input…  │
# │ 664e50499 ┆ py_list_m ┆ Finding   ┆ example   ┆ … ┆ null      ┆ Write a   ┆ #Step 1:  ┆ ['Indexi │
# │ 1363872f0 ┆ in_max    ┆ the       ┆           ┆   ┆           ┆ program   ┆ Define    ┆ ng opera │
# │ ba38f0    ┆           ┆ Maximum   ┆           ┆   ┆           ┆ that      ┆ and initi ┆ tion',   │
# │           ┆           ┆ Value in  ┆           ┆   ┆           ┆ finds     ┆ alize…    ┆ 'For lo… │
# │           ┆           ┆ a…        ┆           ┆   ┆           ┆ the…      ┆           ┆          │
# │ 664e50239 ┆ py_f_to_c ┆ Celsius   ┆ example   ┆ … ┆ null      ┆ Construct ┆ #Step 1:  ┆ ['Multip │
# │ 1363872f0 ┆ _conversi ┆ To Fahren ┆           ┆   ┆           ┆ a program ┆ Assign    ┆ lication │
# │ ba38dd    ┆ on        ┆ heit      ┆           ┆   ┆           ┆ that      ┆ initial   ┆ operatio │
# │           ┆           ┆ Conversi… ┆           ┆   ┆           ┆ compu…    ┆ values…   ┆ n', '…   │
# │ 664e500f9 ┆ py_queue_ ┆ Queue Imp ┆ example   ┆ … ┆ null      ┆ Implement ┆ # Define  ┆ ['Class  │
# │ 1363872f0 ┆ queue     ┆ lementati ┆           ┆   ┆           ┆ ing       ┆ a Queue   ┆ definiti │
# │ ba38d0    ┆           ┆ on        ┆           ┆   ┆           ┆ Queue.    ┆ Class     ┆ on', 'Co │
# │           ┆           ┆           ┆           ┆   ┆           ┆ Using     ┆ class Q…  ┆ nstruc…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆ Clas…     ┆           ┆          │
# │ 664e50089 ┆ py_char_d ┆ Creating  ┆ example   ┆ … ┆ null      ┆ Construct ┆ #Step 1:  ┆ ['Functi │
# │ 1363872f0 ┆ ict       ┆ a Diction ┆           ┆   ┆           ┆ a program ┆ Define    ┆ on defin │
# │ ba38c8    ┆           ┆ ary of    ┆           ┆   ┆           ┆ that has  ┆ the       ┆ ition',  │
# │           ┆           ┆ Chara…    ┆           ┆   ┆           ┆ a…        ┆ function  ┆ 'Dicti…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ d…        ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 664e24ba9 ┆ py_soda_s ┆ Determini ┆ challenge ┆ … ┆ null      ┆ Suppose a ┆ #Step 1:  ┆ ['Two-di │
# │ 1363872f0 ┆ urvey     ┆ ng the    ┆           ┆   ┆           ┆ soda manu ┆ Define a  ┆ mensiona │
# │ ba331f    ┆           ┆ Average   ┆           ┆   ┆           ┆ facturer  ┆ 4x10      ┆ l list   │
# │           ┆           ┆ Rating…   ┆           ┆   ┆           ┆ he…       ┆ two-dim…  ┆ usage',… │
# │ 664e24289 ┆ py_double ┆ Doubly    ┆ challenge ┆ … ┆ null      ┆ Create    ┆ # Step 1: ┆ ['Class  │
# │ 1363872f0 ┆ _linked_l ┆ Linked    ┆           ┆   ┆           ┆ the       ┆ Define    ┆ definiti │
# │ ba3309    ┆ ist       ┆ List      ┆           ┆   ┆           ┆ necessary ┆ Node      ┆ on', 'Co │
# │           ┆           ┆           ┆           ┆   ┆           ┆ classes   ┆ class     ┆ nstruc…  │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f…        ┆ cl…       ┆          │
# │ 664e241c9 ┆ py_search ┆ Binary    ┆ challenge ┆ … ┆ null      ┆ Binary    ┆ # Define  ┆ ['While  │
# │ 1363872f0 ┆ _binary_s ┆ search    ┆           ┆   ┆           ┆ Search    ┆ a binary  ┆ loop',   │
# │ ba32fc    ┆ earch     ┆           ┆           ┆   ┆           ┆ operates  ┆ search    ┆ 'Less-th │
# │           ┆           ┆           ┆           ┆   ┆           ┆ by divi…  ┆ funct…    ┆ an-or-e… │
# │ 664e24129 ┆ py_time_c ┆ Convertin ┆ challenge ┆ … ┆ null      ┆ Construct ┆ #Step 1:  ┆ ['Input  │
# │ 1363872f0 ┆ onversion ┆ g Millise ┆           ┆   ┆           ┆ a program ┆ Read the  ┆ operatio │
# │ ba32f4    ┆           ┆ conds to  ┆           ┆   ┆           ┆ that      ┆ milliseco ┆ n',      │
# │           ┆           ┆ Hou…      ┆           ┆   ┆           ┆ obtai…    ┆ nds…      ┆ 'Type    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ conv…    │
# │ 664e23fd9 ┆ py_pythag ┆ Pythagore ┆ challenge ┆ … ┆ null      ┆ Suppose   ┆ #Step 1:  ┆ ['Float  │
# │ 1363872f0 ┆ orean_the ┆ an        ┆           ┆   ┆           ┆ that the  ┆ Receive   ┆ conversi │
# │ ba32ea    ┆ orem      ┆ Theorem   ┆           ┆   ┆           ┆ user      ┆ the       ┆ on',     │
# │           ┆           ┆ (Case 2)  ┆           ┆   ┆           ┆ provides… ┆ values    ┆ 'Input   │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ fo…       ┆ fu…      │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
muntasir = pl.read_csv('Muntasir_Gavin -- 2025-12-17 __ PCEX Dataset - pcex_final+kcs.csv')
muntasir = muntasir.filter(pl.col('item_language') == 'PYTHON')
muntasir
# Out:
# shape: (177, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ item_lang ┆ set_name  ┆ item_name ┆ item_type ┆ … ┆ item_code ┆ item_url  ┆ item_kcs  ┆ python_p │
# │ uage      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ arser_kc │
# │ ---       ┆ str       ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆ s        │
# │ str       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ PYTHON    ┆ objects_c ┆ py_accoun ┆ PCEX Set  ┆ … ┆ #Step 1:  ┆ http://pa ┆ CallingOb ┆ int,__ac │
# │           ┆ lasses_ac ┆ t1        ┆           ┆   ┆ Define    ┆ wscomp2.s ┆ jectMetho ┆ ct_name, │
# │           ┆ count     ┆           ┆           ┆   ┆ the class ┆ is.pitt.e ┆ d,Subtrac ┆ deposit, │
# │           ┆           ┆           ┆           ┆   ┆ clas…     ┆ du/…      ┆ tio…      ┆ __bala…  │
# │ PYTHON    ┆ objects_c ┆ py_accoun ┆ PCEX      ┆ … ┆ #Step 1:  ┆ http://pa ┆ CallingOb ┆ int,__ac │
# │           ┆ lasses_ac ┆ t2        ┆ Challenge ┆   ┆ Define    ┆ wscomp2.s ┆ jectMetho ┆ ct_name, │
# │           ┆ count     ┆           ┆           ┆   ┆ the class ┆ is.pitt.e ┆ d,Subtrac ┆ __balanc │
# │           ┆           ┆           ┆           ┆   ┆ clas…     ┆ du/…      ┆ tio…      ┆ e,str-…  │
# │ PYTHON    ┆ objects_c ┆ py_loan1  ┆ PCEX Set  ┆ … ┆ #Step 1:  ┆ http://pa ┆ CallingOb ┆ int,type │
# │           ┆ lasses_lo ┆           ┆           ┆   ┆ Define    ┆ wscomp2.s ┆ jectMetho ┆ cast-int │
# │           ┆ an        ┆           ┆           ┆   ┆ the class ┆ is.pitt.e ┆ d,Power,S ┆ ,str-or- │
# │           ┆           ┆           ┆           ┆   ┆ clas…     ┆ du/…      ┆ ubt…      ┆ num-ad…  │
# │ PYTHON    ┆ objects_c ┆ py_loan2  ┆ PCEX      ┆ … ┆ #Step 1:  ┆ http://pa ┆ CallingOb ┆ int,type │
# │           ┆ lasses_lo ┆           ┆ Challenge ┆   ┆ Define    ┆ wscomp2.s ┆ jectMetho ┆ cast-int │
# │           ┆ an        ┆           ┆           ┆   ┆ the class ┆ is.pitt.e ┆ d,Power,P ┆ ,str-or- │
# │           ┆           ┆           ┆           ┆   ┆ clas…     ┆ du/…      ┆ rin…      ┆ num-ad…  │
# │ PYTHON    ┆ objects_c ┆ py_point1 ┆ PCEX Set  ┆ … ┆ #Step 1:  ┆ http://pa ┆ CallingOb ┆ int,set_ │
# │           ┆ lasses_po ┆           ┆           ┆   ┆ Define    ┆ wscomp2.s ┆ jectMetho ┆ x,str-or │
# │           ┆ int       ┆           ┆           ┆   ┆ the class ┆ is.pitt.e ┆ d,Printin ┆ -num-add │
# │           ┆           ┆           ┆           ┆   ┆ clas…     ┆ du/…      ┆ g,C…      ┆ -op,re…  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ PYTHON    ┆ py_win_pe ┆ py_win_pe ┆ PCEX Set  ┆ … ┆ #Step 1:  ┆ http://pa ┆ Printing, ┆ int,whil │
# │           ┆ rcentage  ┆ rcentage  ┆           ┆   ┆ Assign    ┆ wscomp2.s ┆ CallingLi ┆ e,compar │
# │           ┆           ┆           ┆           ┆   ┆ initial   ┆ is.pitt.e ┆ braryFunc ┆ e-lessth │
# │           ┆           ┆           ┆           ┆   ┆ values…   ┆ du/…      ┆ tio…      ┆ an,str…  │
# │ PYTHON    ┆ py_win_pe ┆ py_win_pe ┆ PCEX      ┆ … ┆ #Step 1:  ┆ http://pa ┆ Printing, ┆ int,whil │
# │           ┆ rcentage  ┆ rcentage_ ┆ Challenge ┆   ┆ Read the  ┆ wscomp2.s ┆ CallingLi ┆ e,compar │
# │           ┆           ┆ input     ┆           ┆   ┆ number of ┆ is.pitt.e ┆ braryFunc ┆ e-lessth │
# │           ┆           ┆           ┆           ┆   ┆ ga…       ┆ du/…      ┆ tio…      ┆ an,com…  │
# │ PYTHON    ┆ py_win_pe ┆ py_win_pe ┆ PCEX      ┆ … ┆ #Step 1:  ┆ http://pa ┆ Printing, ┆ int,whil │
# │           ┆ rcentage  ┆ rcentage_ ┆ Challenge ┆   ┆ Assign    ┆ wscomp2.s ┆ CallingLi ┆ e,compar │
# │           ┆           ┆ won_equal ┆           ┆   ┆ initial   ┆ is.pitt.e ┆ braryFunc ┆ e-lessth │
# │           ┆           ┆           ┆           ┆   ┆ values…   ┆ du/…      ┆ tio…      ┆ an,str…  │
# │ PYTHON    ┆ py_work_h ┆ py_work_h ┆ PCEX Set  ┆ … ┆ #Step 1:  ┆ http://pa ┆ ForLoopWi ┆ int,nest │
# │           ┆ ours      ┆ ours1     ┆           ┆   ┆ Define    ┆ wscomp2.s ┆ thListInd ┆ ed-for,s │
# │           ┆           ┆           ┆           ┆   ┆ the       ┆ is.pitt.e ┆ exing,Nes ┆ tr-or-nu │
# │           ┆           ┆           ┆           ┆   ┆ function  ┆ du/…      ┆ ted…      ┆ m-add-…  │
# │           ┆           ┆           ┆           ┆   ┆ d…        ┆           ┆           ┆          │
# │ PYTHON    ┆ py_work_h ┆ py_work_h ┆ PCEX      ┆ … ┆ #Step 1:  ┆ http://pa ┆ ForLoopWi ┆ int,nest │
# │           ┆ ours      ┆ ours2     ┆ Challenge ┆   ┆ Define    ┆ wscomp2.s ┆ thListInd ┆ ed-for,t │
# │           ┆           ┆           ┆           ┆   ┆ the       ┆ is.pitt.e ┆ exing,Nes ┆ ypecast- │
# │           ┆           ┆           ┆           ┆   ┆ function  ┆ du/…      ┆ ted…      ┆ int,st…  │
# │           ┆           ┆           ┆           ┆   ┆ d…        ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
items[['set_name', 'item_name']].unique()
# Out:
# shape: (144, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ set_name                        ┆ item_name                       │
# │ ---                             ┆ ---                             │
# │ str                             ┆ str                             │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ py_list_change                  ┆ Modifying a List (Case 1)       │
# │ py_str_count                    ┆ Counting the Occurrences of On… │
# │ py_if_else_wage                 ┆ Calculating the Wage of an Emp… │
# │ py_functions_multiple_paramete… ┆ Multiple Parameters             │
# │ py_phone_age                    ┆ Determining When to Buy a New … │
# │ …                               ┆ …                               │
# │ objects_classes_point           ┆ The Class for Representing a P… │
# │ objects_classes_loan            ┆ The Class for Representing a L… │
# │ py_soda_survey                  ┆ Determining the Maximum Rating… │
# │ py_squares                      ┆ Printing the Squares of Number… │
# │ py_hot_dry                      ┆ Determining the Weather Condit… │
# └─────────────────────────────────┴─────────────────────────────────┘
