# %%
tofix = {
    "q_py___eq__1_es",
    "q_py___eq__2_es",
    "q_py___gt__1_es",
    "q_py_2d_arrays1_es",
    "q_py_2d_arrays2_es",
    "q_py_2d_arrays3_es",
    "q_py_2d_arrays4_es",
    "q_py_account_logic1_es",
    "q_py_add_two_lists1_es",
    "q_py_aliasing1_es",
    "q_py_aliasing2_es",
    "q_py_aliasing3_es",
    "q_py_arithmetic1_es",
    "q_py_arithmetic2_es",
    "q_py_comparison_logic1_es",
    "q_py_concat_strings1_es",
    "q_py_data_types_functions_es",
    "q_py_data_types_module_es",
    "q_py_data_types2_es",
    "q_py_dict_access1_es",
    "q_py_dict_access2_es",
    "q_py_dict_square_es",
    "q_py_dlinkedlist1_es",
    "q_py_dlinkedlist3_es",
    "q_py_exception_asE_es",
    "q_py_exception_assertion_es",
    "q_py_exceptions_addarr_es",
    "q_py_exchange1_es",
    "q_py_exchange2_es",
    "q_py_file1_es",
    "q_py_file2_es",
    "q_py_file3_es",
    "q_py_for_loop1_es",
    "q_py_fstring_format_1_es",
    "q_py_fstring_format_2_es",
    "q_py_fstring_format_3_es",
    "q_py_fstring_format_4_es",
    "q_py_fun_car1_es",
    "q_py_fun_car2_es",
    "q_py_function_pass_es",
    "q_py_if_elif1_es",
    "q_py_Inheritance_person1_es",
    "q_py_inheritance_person2_es",
    "q_py_int_ref1_es",
    "q_py_interest_if_elif1_es",
    "q_py_interest_if_else1_es",
    "q_py_list_access1_es",
    "q_py_list_access2_es",
    "q_py_list_append1_es",
    "q_py_list_except1_es",
    "q_py_list_int_ref1_es",
    "q_py_list_remove1_es",
    "q_py_list_str_ref1_es",
    "q_py_max_index_search_es",
    "q_py_nested_for_while_es",
    "q_py_nested_if_elif1_es",
    "q_py_nested_if_elif2_es",
    "q_py_nested_if1_es",
    "q_py_nested_while1_es",
    "q_py_obj_account1_es",
    "q_py_obj_car1_es",
    "q_py_obj_car2_es",
    "q_py_obj_point1_es",
    "q_py_output1_es",
    "q_py_output2_es",
    "q_py_output3_es",
    "q_py_output4_es",
    "q_py_q_py_datatype1_es",
    "q_py_q_py_string_formatting1_es",
    "q_py_q_py_string_formatting2_es",
    "q_py_queue_es",
    "q_py_recursion_pascal_es",
    "q_py_recursion1_es",
    "q_py_reference_list1_es",
    "q_py_reference_reverse_es",
    "q_py_rw_file1_es",
    "q_py_rw_file2_es",
    "q_py_sequential_search_es",
    "q_py_slinkedlist1_es",
    "q_py_str_ref1_es",
    "q_py_substring1_es",
    "q_py_swap1_es",
    "q_py_tree_inorder_traverse_es",
    "q_py_tree_preorder_traverse_es",
    "q_py_tuple_es",
    "q_py_value_except1_es",
    "q_py_while_loop1_es",
    "q_py_while_loop2_es",
    "Desplazando los Valores de la Lista a la Derecha Dos Posiciones",
    "Desplazando los Valores de la Lista a la Derecha una Posicion",
    "Desplazando los Valores de la Lista a la Izquierda Dos Posiciones",
    "Determinando Cuando Comprar un Nuevo Telefono (Caso 2)",
    "Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 2)",
    "Encontrar el Mayor Divisor de un Numero Positivo",
    "Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo Invertido",
    "Informacion de Herencia de Persona y Empleado",
    "Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 2)",
    "La Clase para Representar un Prestamo (Caso 2)",
    "Maquina Expendedora Con Monedas de diferentes centavos",
    "Pasar Valores",
}

# %%
import os
import json

for file in os.listdir('./items'):
    if not file.endswith('.json'):
        continue
    item = json.load(open(os.path.join('./items', file)))
    if item['identity']['title'] not in tofix:
        continue
    item['languages']['content_language'] = 'es'
    json.dump(item, open(os.path.join('./items', file), 'w'), indent=2)
    print(f"Fixed {item['identity']['title']}")
# Out:
# Fixed q_py_add_two_lists1_es
# Fixed q_py_2d_arrays1_es
# Fixed q_py_rw_file1_es
# Fixed q_py_q_py_string_formatting2_es
# Fixed q_py_nested_if1_es
# Fixed q_py_file2_es
# Fixed q_py_dict_access1_es
# Fixed q_py_str_ref1_es
# Fixed q_py_aliasing2_es
# Fixed Pasar Valores
# Fixed Desplazando los Valores de la Lista a la Derecha Dos Posiciones
# Fixed Maquina Expendedora Con Monedas de diferentes centavos
# Fixed q_py_sequential_search_es
# Fixed q_py_list_str_ref1_es
# Fixed Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 2)
# Fixed q_py_file3_es
# Fixed q_py_interest_if_else1_es
# Fixed q_py_file1_es
# Fixed q_py_nested_for_while_es
# Fixed q_py_rw_file2_es
# Fixed q_py_obj_point1_es
# Fixed q_py_list_remove1_es
# Fixed q_py_output3_es
# Fixed q_py_if_elif1_es
# Fixed q_py_int_ref1_es
# Fixed q_py_tuple_es
# Fixed q_py_fstring_format_3_es
# Fixed q_py_for_loop1_es
# Fixed q_py_output4_es
# Fixed q_py_2d_arrays3_es
# Fixed q_py_recursion_pascal_es
# ...
