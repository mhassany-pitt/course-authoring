# %%
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()

# %%
# api_token = open('api_token.txt').read().strip()
# for index, item in enumerate(catalog):
#     provider = item['attribution']['provider']
#     if provider != 'WebEx' or not item['links']['demo_url'].startswith('https://acos.cs.vt.edu/html/annotated/acos-annex-'):
#         continue
#     item = requests.get(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}",
#         headers={'api-token': api_token}
#     ).json()
#     item['attribution']['provider'] = 'AnnEx'
#     response = requests.patch(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{item['id']}",
#         json=item,
#         headers={'api-token': api_token}
#     )
#     print(f'{index}/{len(catalog)}:[{response.status_code}]', item['identity']['title'])
# Out:
# 567/2934:[200] Linked List 1
# 992/2934:[200] LeftJoin1_version_1
# 993/2934:[200] Left Join 1
# 1333/2934:[200] (Strings) Change case - CSEdPad
# 1334/2934:[200] (LogicalOperators) Compare numbers - CSEdPad
# 1335/2934:[200] (Math class) Math example 3 - CSEdPad
# 1336/2934:[200] (Searching) Binary search - CSEdPad
# 1337/2934:[200] (Sorting) Bubble sort - CSEdPad
# 1338/2934:[200] (Methods) Adding numbers - CSEdPad
# 1339/2934:[200] (Do while)  Find high & low scores - CSEdPad
# 1340/2934:[200] (Arraylists) Ex1 - CsEdPad
# 1341/2934:[200] (Exception Handling) Arithmetic - CSEdPad
# 1342/2934:[200] (Recursion) Recursive is palindrome - CSEdPad
# 1343/2934:[200] (Nested Loops) Grid of stars - CSEdPad
# 1344/2934:[200] (Switch) Convert dress size number - CSEdPad
# 1345/2934:[200] (Two-dim arrays) Matrix multiply - CSEdPad
# 1346/2934:[200] (If) Positive - CSEdPad
# 1347/2934:[200] (Inheritance) Physics teacher - CSEdPad
# 1348/2934:[200] (Classes & Objects) Rectangle - CSEdPad
# 1349/2934:[200] (Arrays) Grade scores - CSEdPad
# 1350/2934:[200] (LogicalOperators) Leap year - CSEdPad
# 1351/2934:[200] (MathClass) MathExample1 - CSEdPad
# 1352/2934:[200] (Input) Employee Detail - CSEdPad
# 1353/2934:[200] (Strings) String length - CSEdPad
# 1354/2934:[200] (Preliminary)AverageSpeedInMarathon-CSEdPad
# 1355/2934:[200] (If else) Temperature Conversion - CSEdPad
# 1356/2934:[200] (While loops) While Loops Ex 1 - CSEdPad
# 1357/2934:[200] (For loops) Sum of odd numbers - CSEdPad
# 1398/2934:[200] memp_variables_1
# 1399/2934:[200] Constants_Memphis_02
# 1400/2934:[200] Constants_Memphis_01
# 1432/2934:[200] SwapExample
# 1456/2934:[200] 2-19_CompoundInterest
# 1457/2934:[200] 3-21_ParamPassing
# 1458/2934:[200] 2-21_StringDemos
# 1459/2934:[200] 4-02_TicTacToe
# 1460/2934:[200] 4-02_Arrays2D
# 1461/2934:[200] 4-11_AnimalClient
# 1462/2934:[200] 4-11_Animal
# 1463/2934:[200] 3-19_PizzaPrices
# 1464/2934:[200] 3-19_MoreMethods
# 1465/2934:[200] 2-19_PrimeChecker
# 1466/2934:[200] 3-19_ShowBackwards
# 1467/2934:[200] 3-19_ArrayDemos
# 1468/2934:[200] While (Memphis)
# 1469/2934:[200] While 1 (Memphis)
# 1470/2934:[200] Char Strings (Memphis)
# 1471/2934:[200] Math class 2 random (Memphis)
# 1472/2934:[200] Math class 1 (Memphis)
# 1473/2934:[200] Switch (Memphis)
# 1474/2934:[200] Modulus (Memphis)
# 1475/2934:[200] If else nested (Memphis)
# 1476/2934:[200] Boolean expressions (Memphis)
# 1477/2934:[200] Expressions within print (Memphis)
# 1478/2934:[200] Casting data types (Memphis)
# 1479/2934:[200] Expressions (Memphis)
# 1480/2934:[200] Variables assignment (Memphis)
# 1481/2934:[200] Scanner input (Memphis)
# 1482/2934:[200] Scanner input
# 1737/2934:[200] HKC array testing 1
# 1742/2934:[200] VariablePrint
# 1743/2934:[200] VariablePrintPrintln
# 1744/2934:[200] PrintPrintln
# 1745/2934:[200] SimpleNestedLoop
# 1851/2934:[200] IS17_ArrayList2_6
# 1852/2934:[200] IS17_ArrayList2_7
# 1853/2934:[200] IS17_ArrayList3_5
# 1854/2934:[200] IS17_ArrayList3_6
# 1855/2934:[200] IS17_ArrayList3_7
# 1856/2934:[200] IS17_ArrayList3_8
# 1857/2934:[200] Static Method
# 1858/2934:[200] Package declaration
# 1859/2934:[200] Importing Package
# 1860/2934:[200] Inner Classes
# 1861/2934:[200] Standard Input
# 1862/2934:[200] JavaTutorial_4_1_8
# 1863/2934:[200] JavaTutorial_4_4_4
# 1864/2934:[200] DEPRECATED_String Comparison
# 1865/2934:[200] DEPRECATED_Substring
# 1866/2934:[200] DEPRECATED_String Length
# 1867/2934:[200] DEPRECATED_If Else
# 1868/2934:[200] DEPRECATED_Decision If
# 1869/2934:[200] DEPRECATED_Nested Loops
# 1870/2934:[200] DEPRECATED_Nested Loops2
# 1871/2934:[200] DEPRECATED_Array Declaration
# 1872/2934:[200] DEPRECATED_Using an Array1
# 1873/2934:[200] DEPRECATED_Using an Array2
# 1874/2934:[200] DEPRECATED_Create ArrayList
# 1875/2934:[200] DEPRECATED_ArrayList Demo
# 1876/2934:[200] DEPRECATED_Wrapper Classes
# 1877/2934:[200] DEPRECATED_Create 2D Array
# 1878/2934:[200] DEPRECATED_Use 2D Array
# 1879/2934:[200] IS17_inheritance1
# 1880/2934:[200] IS17_inheritance2
# 1881/2934:[200] IS17_interface1
# 1882/2934:[200] IS17_interface2
# 1883/2934:[200] IS17_override1
# 1884/2934:[200] IS17_inheritance3
# 1885/2934:[200] IS17_abstract1
# 1886/2934:[200] IS17_this_and_super
# 1887/2934:[200] IS17_ArrayList1
# 1888/2934:[200] IS17_ArrayList2
# 1889/2934:[200] IS17_ArrayList3
# 1890/2934:[200] IS17_interface3
# 1891/2934:[200] DEPRECATED_Interface
# 1892/2934:[200] DEPRECATED_Inheritance
# 1893/2934:[200] DEPRECATED_Override
# 1894/2934:[200] DEPRECATED_MultiInterfaces
# 1895/2934:[200] IS17_inheritance1_1
# 1896/2934:[200] IS17_inheritance1_2
# 1897/2934:[200] IS17_inheritance1_3
# 1898/2934:[200] IS17_inheritance2_1
# 1899/2934:[200] IS17_inheritance2_2
# 1900/2934:[200] IS17_inheritance2_3
# 1901/2934:[200] IS17_inheritance2_4
# 1902/2934:[200] IS17_inheritance3_1
# 1903/2934:[200] IS17_inheritance3_2
# 1904/2934:[200] IS17_inheritance3_3
# 1905/2934:[200] IS17_inheritance3_4
# 1906/2934:[200] IS17_interface1_1
# 1907/2934:[200] IS17_interface1_2
# 1908/2934:[200] IS17_interface1_3
# 1909/2934:[200] IS17_interface2_1
# 1910/2934:[200] IS17_interface2_2
# 1911/2934:[200] IS17_interface2_3
# 1912/2934:[200] IS17_interface2_4
# 1913/2934:[200] IS17_interface3_1
# 1914/2934:[200] IS17_interface3_2
# 1915/2934:[200] IS17_interface3_3
# 1916/2934:[200] IS17_interface3_4
# 1917/2934:[200] IS17_ArrayList1_1
# 1918/2934:[200] IS17_ArrayList1_2
# 1919/2934:[200] IS17_ArrayList1_3
# 1920/2934:[200] IS17_ArrayList2_1
# 1921/2934:[200] IS17_ArrayList2_2
# 1922/2934:[200] IS17_ArrayList2_3
# 1923/2934:[200] IS17_ArrayList2_4
# 1924/2934:[200] IS17_ArrayList3_1
# 1925/2934:[200] IS17_ArrayList3_2
# 1926/2934:[200] IS17_ArrayList3_3
# 1927/2934:[200] IS17_ArrayList3_4
# 1928/2934:[200] IS17_inheritance1_4
# 1929/2934:[200] IS17_inheritance1_5
# 1930/2934:[200] IS17_inheritance1_6
# 1931/2934:[200] IS17_inheritance1_7
# 1932/2934:[200] IS17_inheritance2_5
# 1933/2934:[200] IS17_inheritance2_6
# 1934/2934:[200] IS17_inheritance2_7
# 1935/2934:[200] IS17_inheritance3_5
# 1936/2934:[200] IS17_inheritance3_6
# 1937/2934:[200] IS17_inheritance3_7
# 1938/2934:[200] IS17_inheritance3_8
# 1939/2934:[200] IS17_interface1_4
# 1940/2934:[200] IS17_interface1_5
# 1941/2934:[200] IS17_interface1_6
# 1942/2934:[200] IS17_interface1_7
# 1943/2934:[200] IS17_interface2_5
# 1944/2934:[200] IS17_interface2_6
# 1945/2934:[200] IS17_interface2_7
# 1946/2934:[200] IS17_interface3_5
# 1947/2934:[200] IS17_interface3_6
# 1948/2934:[200] IS17_interface3_7
# 1949/2934:[200] IS17_interface3_8
# 1950/2934:[200] IS17_ArrayList1_4
# 1951/2934:[200] IS17_ArrayList1_5
# 1952/2934:[200] IS17_ArrayList1_6
# 1953/2934:[200] IS17_ArrayList1_7
# 1954/2934:[200] IS17_ArrayList2_5
# 1955/2934:[200] ISD:: WelcomeApplet2.java
# 1956/2934:[200] ISD:: AdditionApplet.java
# 1957/2934:[200] ISD::ShowColors.java
# 1958/2934:[200] ISD::Fonts.java
# 1959/2934:[200] ISD::Metrics.java
# 1960/2934:[200] ISD::LinesRectsOvals.java
# 1961/2934:[200] ISD::HTTPGetServlet.java
# 1962/2934:[200] ISD::HTTPPostServlet.java
# 1963/2934:[200] ISD::WelcomeLines.java
# 1964/2934:[200] ISD::DrawArcs.java
# 1965/2934:[200] ISD::DrawPolygons.java
# 1966/2934:[200] ISD::Shapes.java
# 1967/2934:[200] ISD::Shapes2.java
# 1968/2934:[200] ISD::ButtonTest.java
# 1969/2934:[200] ISD::LabelTest.java
# 1970/2934:[200] ISD::ShowColors2.java
# 1971/2934:[200] ISD::TextFieldTest.java
# 1972/2934:[200] ISD::CheckBoxTest.java
# 1973/2934:[200] ISD::RadioButtonTest.java
# 1974/2934:[200] ISD::ComboBoxTest.java
# 1975/2934:[200] ISD::ListTest.java
# 1976/2934:[200] ISD::MultipleSelection.java
# 1977/2934:[200] ISD::TextAreaDemo.java
# 1978/2934:[200] ISD::FlowLayoutDemo.java
# 1979/2934:[200] ISD::BorderLayoutDemo.java
# 1980/2934:[200] ISD::GridLayoutDemo.java
# 1981/2934:[200] ISD::PanelDemo.java
# 1982/2934:[200] ISD::KeyDemo.java
# 1983/2934:[200] ISD::CookieExample.java
# 1984/2934:[200] ISD::SessionExample.java
# 1985/2934:[200] ISD:: GetRequestExample.java
# 1986/2934:[200] ISD:: Post Request Example.java
# 1987/2934:[200] DEPRECATED_variable declaration
# 1988/2934:[200] DEPRECATED_variable initialization
# 1989/2934:[200] DEPRECATED_if-else
# 1990/2934:[200] DEPRECATED_increment
# 1991/2934:[200] DEPRECATED_arithmetic operations
# 1992/2934:[200] DEPRECATED_comparison operators
# 1993/2934:[200] DEPRECATED_conditional operators
# 1994/2934:[200] DEPRECATED_relational operators
# 1995/2934:[200] DEPRECATED_logical operators
# 1996/2934:[200] DEPRECATED_While
# 1997/2934:[200] DEPRECATED_dowhile
# 1998/2934:[200] DEPRECATED_WhileCounter
# 1999/2934:[200] DEPRECATED_switch
# 2000/2934:[200] DEPRECATED_SwitchDemo2
# 2001/2934:[200] DEPRECATED_Bicycle
# 2002/2934:[200] DEPRECATED_CreateObjectDemo
# 2003/2934:[200] DEPRECATED_Point
# 2004/2934:[200] DEPRECATED_Rectangle
# 2005/2934:[200] DEPRECATED_HelloWorld
# 2006/2934:[200] DEPRECATED_Primitive Data Types
# 2007/2934:[200] DEPRECATED_StringExample
# 2008/2934:[200] DEPRECATED_Constants
# 2009/2934:[200] DEPRECATED_Math Functions
# 2010/2934:[200] DEPRECATED_Operator
# 2011/2934:[200] DEPRECATED_Type Casting
# 2012/2934:[200] DEPRECATED_Creating String
# 2013/2934:[200] DEPRECATED_boolean declaration
# 2014/2934:[200] DEPRECATED_Boolean Expression
# 2015/2934:[200] DEPRECATED_Boolean Operators
# 2016/2934:[200] View Creation (2) pt
# 2017/2934:[200] Retrieving data from view pt
# 2018/2934:[200] View Creation (1) pt
# 2019/2934:[200] Aggregating Derived Relations pt
# 2020/2934:[200] Derived Relations pt
# 2021/2934:[200] Nested Subqueries (2) pt
# 2022/2934:[200] Nested Subqueries (1) pt
# 2023/2934:[200] Grouping and aggregating (3) pt
# 2024/2934:[200] Grouping and aggregating (2) pt
# 2025/2934:[200] Grouping and aggregating (1) pt
# 2026/2934:[200] Aggregating Subquery pt
# 2027/2934:[200] Grouped Queries with Condition pt
# 2028/2934:[200] Grouped Queries pt
# 2029/2934:[200] Checking Null Values pt
# 2030/2934:[200] Comparing Subquery Results (2) pt
# 2031/2934:[200] Comparing Subquery Results (1) pt
# 2032/2934:[200] Combining Query Results (3) pt
# 2033/2934:[200] Combining Query Results (2) pt
# 2034/2934:[200] Combining Query Results (1) pt
# 2035/2934:[200] Alphabetic Order pt
# 2036/2934:[200] Multiple Table Selection (2) pt
# 2037/2934:[200] Multiple Table Selection (1) pt
# 2038/2934:[200] String Operation pt
# 2039/2934:[200] Range Test (2) pt
# 2040/2934:[200] Range Test (1) pt
# 2041/2934:[200] Multiple Comparisons (2) pt
# 2042/2934:[200] Multiple Comparisons (1) pt
# 2043/2934:[200] Comparison Condition (3) pt
# 2044/2934:[200] Comparison Condition (2) pt
# 2045/2934:[200] Comparison Condition (1) pt
# 2046/2934:[200] Arithmetic Expression pt
# 2047/2934:[200] Skipping Duplicates pt
# 2048/2934:[200] Selection Condition pt
# 2049/2934:[200] Selecting One Attribute pt
# 2050/2934:[200] Selecting Multiple Attributes pt
# 2051/2934:[200] Selecting All Attributes pt
# 2052/2934:[200] Updating with subquery pt
# 2053/2934:[200] Updating with condition pt
# 2054/2934:[200] Updating Data (3) pt
# 2055/2934:[200] Updating Data (2) pt
# 2056/2934:[200] Updating Data (1) pt
# 2057/2934:[200] Deleting with Condition (2) pt
# 2058/2934:[200] Deleting with Condition (1) pt
# 2059/2934:[200] Deleting Data pt
# 2060/2934:[200] Inserting Data (4) pt
# 2061/2934:[200] Inserting Data (3) pt
# 2062/2934:[200] Inserting Data (2) pt
# 2063/2934:[200] Inserting Data (1) pt
# 2064/2934:[200] Check Constraint (2) pt
# 2065/2934:[200] Check Constraint (1) pt
# 2066/2934:[200] Assertion Creation (2) pt
# 2067/2934:[200] Assertion Creation (1) pt
# 2068/2934:[200] Foreign Key pt
# 2069/2934:[200] Primary Key and Unique Key pt
# 2070/2934:[200] PrimaryKeyandUniqueKeypt
# 2071/2934:[200] Primary Key(2) pt
# 2072/2934:[200] Primary Key(1) pt
# 2073/2934:[200] Column Drop pt
# 2074/2934:[200] Column Addition pt
# 2075/2934:[200] Table Drop pt
# 2076/2934:[200] Table Creation pt
# 2077/2934:[200] Aggregate Functions (4) pt
# 2078/2934:[200] Aggregate Functions (3) pt
# 2079/2934:[200] Aggregate Functions (2) pt
# 2080/2934:[200] Aggregate Functions (1) pt
# 2081/2934:[200] AggregateFunctions(1)_version_1
# 2186/2934:[200] Simple Printing
# 2368/2934:[200] Operations with Variables
# 2369/2934:[200] All Variables Together
# 2370/2934:[200] Initializing Variables
# 2371/2934:[200] Size of Variables
# 2372/2934:[200] Boolean Variables
# 2373/2934:[200] Ctring Variables
# 2374/2934:[200] Character Numbers ASCII
# 2375/2934:[200] Char Variables
# 2376/2934:[200] Float and Double Variables
# 2377/2934:[200] Variable Types
# 2378/2934:[200] Change the Value of a Variable
# 2379/2934:[200] Using Variables
# 2380/2934:[200] Using End of Line Statement
# 2381/2934:[200] Multiline cout
# 2382/2934:[200] Simple cout
# 2383/2934:[200] Cash Register Tester (Constant Field)
# 2391/2934:[200] Strings (equalsIgnoreCase)
# 2392/2934:[200] Converting between Class and Interface Types
# 2393/2934:[200] Interface Polymorphism
# 2394/2934:[200] Measure
# 2395/2934:[200] Overriding Object Methods
# 2396/2934:[200] Tic-Tac-Toe
# 2397/2934:[200] Bank
# 2398/2934:[200] Grade Book
# 2399/2934:[200] ArrayList Tester
# 2401/2934:[200] Enhanced For Loop Demo
# 2403/2934:[200] This Reference
# 2404/2934:[200] Cash Register Tester
# 2405/2934:[200] Bank Account Tester
# 2406/2934:[200] Counter Demo
# 2407/2934:[200] Copy Demo
# 2408/2934:[200] Accessor Mutator Demo
# 2409/2934:[200] Constructor Demo
# 2410/2934:[200] Method Demo
# 2412/2934:[200] String Equals
# 2414/2934:[200] Testing for null
# 2415/2934:[200] Object Equality
# 2422/2934:[200] Strings (Concatenation)
# 2423/2934:[200] Strings (parse)
# 2424/2934:[200] Strings (replace)
# 2425/2934:[200] Strings (charAt)
# 2432/2934:[200] Combining Assignment and Arithmetic
# 2433/2934:[200] Decrement
# 2438/2934:[200] Print Tester
# 2439/2934:[200] Variable Demo
# 2440/2934:[200] Hello Printer
# 2441/2934:[200] check_file2
# 2442/2934:[200] count_occur
# 2443/2934:[200] pointer_seq_file
# 2444/2934:[200] pointer_seq_file2
# 2445/2934:[200] create_seq_file
# 2446/2934:[200] read_seq_file
# 2447/2934:[200] update_credit_prog
# 2448/2934:[200] pass_file
# 2449/2934:[200] structs1
# 2450/2934:[200] rand_access_file
# 2451/2934:[200] write_info_rand_file
# 2512/2934:[200] IfElse_Structure
# 2513/2934:[200] private
# 2565/2934:[200] Table Creation
# 2567/2934:[200] Primary Key (1)
# 2569/2934:[200] Primary Key and Unique Key
# 2571/2934:[200] Foriegn Key
# 2573/2934:[200] Table Drop
# 2575/2934:[200] Column Addition
# 2577/2934:[200] Column Drop
# 2579/2934:[200] Inserting Data (1)
# 2581/2934:[200] Deleting Data
# 2582/2934:[200] Binary_Expressions
# 2583/2934:[200] Selecting One Attribute
# 2584/2934:[200] precedence_expression
# 2585/2934:[200] Selecting Multiple Attributes
# 2586/2934:[200] precedence_expr
# 2587/2934:[200] Selecting All Attributes
# 2588/2934:[200] complex_expr
# 2589/2934:[200] Skipping Duplicates
# 2590/2934:[200] IncDec_Oper
# 2591/2934:[200] Aggregate Functions (1)
# 2592/2934:[200] compound_assign
# 2593/2934:[200] Selection Condition
# 2594/2934:[200] casting_num
# 2595/2934:[200] Comparison Condition (1)
# 2596/2934:[200] 1stprogram
# 2597/2934:[200] Comparison Condition (2)
# 2598/2934:[200] printf
# 2599/2934:[200] Comparison Condition (3)
# 2600/2934:[200] input_print
# 2601/2934:[200] Multiple Table Selection (1)
# 2602/2934:[200] decimal_value
# 2603/2934:[200] Multiple Comparisons (1)
# 2604/2934:[200] avg_score
# 2605/2934:[200] Check Constraint (1)
# 2606/2934:[200] CH3_printf1
# 2607/2934:[200] Check Constraint (2)
# 2608/2934:[200] CH3_printf2
# 2609/2934:[200] Assertion Creation (1)
# 2610/2934:[200] CH3_printf3
# 2611/2934:[200] Inserting Data (2)
# 2612/2934:[200] Inserting Data (3)
# 2613/2934:[200] Coin_Values
# 2614/2934:[200] Inserting Data (4)
# 2615/2934:[200] IncDec
# 2616/2934:[200] Updating Data (2)
# 2617/2934:[200] If
# 2618/2934:[200] Updating Data (3)
# 2619/2934:[200] while_structure
# 2620/2934:[200] Updating Data (1)
# 2621/2934:[200] Sentinel_value
# 2622/2934:[200] Updating with condition
# 2623/2934:[200] Sales
# 2624/2934:[200] Updating with subquery
# 2625/2934:[200] Payroll
# 2626/2934:[200] Deleting with Condition (1)
# 2627/2934:[200] Cwhile_counter
# 2628/2934:[200] Deleting with Condition (2)
# 2629/2934:[200] Whileloop
# 2630/2934:[200] Arithmetic Expression
# 2631/2934:[200] ForLoop
# 2632/2934:[200] Multiple Comparisons (2)
# 2633/2934:[200] ForLoop2
# 2634/2934:[200] Range Test (1)
# 2635/2934:[200] ForStatement
# 2636/2934:[200] Range Test (2)
# 2637/2934:[200] Usage
# 2638/2934:[200] Multiple Table Selection (2)
# 2639/2934:[200] WhileStatement
# 2640/2934:[200] String Operation
# 2641/2934:[200] BreakStatement
# 2642/2934:[200] Alphabetic Order
# 2643/2934:[200] Continue
# 2644/2934:[200] Combining Query Results (1)
# 2645/2934:[200] SwitchStatement
# 2646/2934:[200] Combining Query Results (2)
# 2647/2934:[200] SwitchStatement2
# 2648/2934:[200] Combining Query Results (3)
# 2649/2934:[200] IF2
# 2650/2934:[200] Aggregate Functions (2)
# 2651/2934:[200] Rand
# 2652/2934:[200] Aggregate Functions (3)
# 2653/2934:[200] Srand
# 2654/2934:[200] Aggregate Functions (4)
# 2655/2934:[200] rand function
# 2656/2934:[200] Grouped Queries
# 2657/2934:[200] defined function
# 2658/2934:[200] Grouped Queries with Condition
# 2659/2934:[200] Multiple Return
# 2660/2934:[200] Checking Null Values
# 2661/2934:[200] Assign Return
# 2662/2934:[200] Nested Subqueries (1)
# 2663/2934:[200] Do Switch Function
# 2664/2934:[200] Nested Subqueries (2)
# 2665/2934:[200] Defined Function2
# 2666/2934:[200] Comparing Subquery Results (1)
# 2667/2934:[200] No Argument Functions
# 2668/2934:[200] Comparing Subquery Results (2)
# 2669/2934:[200] Function CallByValue
# 2670/2934:[200] Aggregating Subquery
# 2671/2934:[200] Call By Reference
# 2672/2934:[200] Derived Relations
# 2673/2934:[200] Call By Reference2
# 2674/2934:[200] View Creation (1)
# 2675/2934:[200] Block Scope
# 2676/2934:[200] View Creation (2)
# 2677/2934:[200] Recursion
# 2678/2934:[200] Grouping and aggregating (1)
# 2680/2934:[200] Grouping and aggregating (2)
# 2682/2934:[200] Grouping and aggregating (3)
# 2683/2934:[200] One Dim Arrays
# 2684/2934:[200] Assertion Creation (2)
# 2685/2934:[200] Retrieving data from view
# 2686/2934:[200] Static Arrays
# 2687/2934:[200] Aggregating Derived Relations
# 2688/2934:[200] Using Arrays
# 2689/2934:[200] Primary Key (2)
# 2690/2934:[200] Encryption Program
# 2691/2934:[200] Variable Declaration
# 2692/2934:[200] comparison operators
# 2693/2934:[200] Using Const
# 2694/2934:[200] Variable Initialization
# 2695/2934:[200] boolean operators
# 2696/2934:[200] Using 2D Arrays
# 2697/2934:[200] HelloWorld
# 2698/2934:[200] if-else-if
# 2699/2934:[200] BubbleSort
# 2700/2934:[200] Object Creation and Method Calls
# 2701/2934:[200] Exceptions
# 2702/2934:[200] SortAlgorithm
# 2703/2934:[200] Rectangle
# 2704/2934:[200] Multiple Variables
# 2705/2934:[200] InsertSortAlgo
# 2706/2934:[200] Bicycle
# 2707/2934:[200] Multiple Variables 2
# 2708/2934:[200] BubbleSortAlgo
# 2709/2934:[200] Funcion mismo valor absoluto (ES)
# 2710/2934:[200] If with complex condition
# 2711/2934:[200] CallbyValue
# 2712/2934:[200] Primitive Data Types
# 2713/2934:[200] If Statement
# 2714/2934:[200] CallbyReference
# 2715/2934:[200] Type Casting
# 2716/2934:[200] Else Clause
# 2717/2934:[200] deferencing
# 2718/2934:[200] Constants
# 2719/2934:[200] Nested if
# 2720/2934:[200] PointerNotation
# 2721/2934:[200] Constant2
# 2722/2934:[200] Using &&
# 2723/2934:[200] ArraysSubscript
# 2724/2934:[200] Arithmetic Operations
# 2725/2934:[200] Using ||
# 2726/2934:[200] PointerArrays
# 2727/2934:[200] Increment
# 2728/2934:[200] Switch Statement
# 2729/2934:[200] PointerArrays2
# 2730/2934:[200] Math Functions
# 2731/2934:[200] Free Flow Switch
# 2732/2934:[200] ArrayAddresses
# 2733/2934:[200] Operator
# 2734/2934:[200] Nested Switch
# 2735/2934:[200] ArrayPointers
# 2736/2934:[200] Creating String
# 2737/2934:[200] Switch with Enum
# 2738/2934:[200] NonConstant
# 2739/2934:[200] Substring
# 2740/2934:[200] Sum using While
# 2741/2934:[200] NonConstPointer
# 2742/2934:[200] String Length
# 2743/2934:[200] While with double
# 2744/2934:[200] ConstPointer
# 2745/2934:[200] Decision If
# 2746/2934:[200] Nested For Loop
# 2747/2934:[200] ConstPointer2
# 2748/2934:[200] If Else
# 2749/2934:[200] Print Out a Diamond
# 2750/2934:[200] BubbleSortPF
# 2751/2934:[200] String Comparison
# 2752/2934:[200] Infinite For
# 2753/2934:[200] PrintAddress
# 2754/2934:[200] Logical Operators
# 2755/2934:[200] For with Multiple Variables 2
# 2756/2934:[200] Boolean Declaration
# 2757/2934:[200] For with Multiple Variables
# 2758/2934:[200] CopyString
# 2759/2934:[200] Boolean Expression
# 2760/2934:[200] For with Multiple Variables 3
# 2761/2934:[200] CreateFile
# 2762/2934:[200] Boolean Operators
# 2763/2934:[200] For omitting elements
# 2764/2934:[200] ReadFromFile
# 2765/2934:[200] While
# 2766/2934:[200] For-Each 2
# 2767/2934:[200] DoWhile
# 2768/2934:[200] For-Each with ArrayList
# 2769/2934:[200] atof_atoi_atol
# 2770/2934:[200] For Loop
# 2771/2934:[200] For-Each
# 2772/2934:[200] strtod
# 2773/2934:[200] Nested Loops
# 2774/2934:[200] For-each with char array
# 2775/2934:[200] gets_puts
# 2776/2934:[200] Nested Loops2
# 2777/2934:[200] Multidimensional Array Iteration
# 2778/2934:[200] Array Declaration
# 2779/2934:[200] For-each with break
# 2780/2934:[200] strcy_strncpy
# 2781/2934:[200] Using an Array1
# 2782/2934:[200] relational operators
# 2783/2934:[200] strcat_strncat
# 2784/2934:[200] Using an Array2
# 2785/2934:[200] String Example
# 2786/2934:[200] strcmp_strncmp
# 2787/2934:[200] Create ArrayList
# 2788/2934:[200] switch
# 2789/2934:[200] strlen
# 2790/2934:[200] ArrayList Demo
# 2791/2934:[200] Polymorphism and Inheritance 1
# 2792/2934:[200] search_func
# 2793/2934:[200] Wrapper Classes
# 2794/2934:[200] Casting subclass
# 2795/2934:[200] strtok
# 2796/2934:[200] Create 2D Array
# 2797/2934:[200] Polymorphism and Inheritance 2
# 2798/2934:[200] upper_lower_case
# 2799/2934:[200] Use 2D Array
# 2800/2934:[200] A Dog is also a Pet
# 2801/2934:[200] string_to_integer
# 2802/2934:[200] Interface
# 2803/2934:[200] Inheritance and Constructors 1
# 2804/2934:[200] string_compare
# 2805/2934:[200] MultiInterfaces
# 2806/2934:[200] Simple Inheritance
# 2807/2934:[200] tokenize1
# 2808/2934:[200] Inheritance
# 2809/2934:[200] search_occur
# 2810/2934:[200] Override
# 2811/2934:[200] word_count
# 2812/2934:[200] find_string
# 2813/2934:[200] defined_func1
# 2814/2934:[200] defined_func2
# 2815/2934:[200] string_lib_func1
# 2816/2934:[200] fgetc_fputc
# 2817/2934:[200] check_file
# 2922/2934:[200] Calculate_profit
# 2923/2934:[200] Array of Char
# 2924/2934:[200] CharReferencing
# 2925/2934:[200] character_functions
# 2926/2934:[200] getchar()
# 2927/2934:[200] ascII_char
