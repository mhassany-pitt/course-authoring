# %%
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()

api_token = open('api_token.txt').read().strip()
for index, item in enumerate(catalog):
    print(f'{index}/{len(catalog)} setting MIT as the license ->', item['identity']['title'])
    if not item['rights']['license']:
        item = requests.get(f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}").json()
        item['rights']['license'] = "MIT"
        response = requests.patch(
            f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{item['id']}",
            json=item,
            headers={'api-token': api_token}
        )
        print('status_code:', response.status_code)
# Out:
# 0/2884 setting MIT as the license -> Seconds to Minutes Conversion
# 1/2884 setting MIT as the license -> Converting Milliseconds to Hours-Minutes- and Seconds
# 2/2884 setting MIT as the license -> Seconds to Minutes Conversion
# 3/2884 setting MIT as the license -> Converting Milliseconds to Hours-Minutes- and Seconds
# 4/2884 setting MIT as the license -> Seconds to Minutes Conversion
# 5/2884 setting MIT as the license -> Converting Milliseconds to Hours-Minutes- and Seconds.
# 6/2884 setting MIT as the license -> Vending Machine With Dollars and Quarters
# 7/2884 setting MIT as the license -> Vending Machine With Quarters-Dimes- and Nickels
# 8/2884 setting MIT as the license -> Vending Machine With Dollars and Quarters
# 9/2884 setting MIT as the license -> Vending Machine With Quarters-Dimes- and Nickels
# 10/2884 setting MIT as the license -> Printing Common Elements in Two Arrays
# 11/2884 setting MIT as the license -> Printing the Total Number of Times Elements of One Array Appear in Another Array
# 12/2884 setting MIT as the license -> Creating an array that Contains the Numbers of Times Each Element of One Array Appears in Another Array
# 13/2884 setting MIT as the license -> Determining When to Buy a New Phone (Case 1)
# 14/2884 setting MIT as the license -> Determining When to Buy a New Phone (Case 2)
# 15/2884 setting MIT as the license -> Printing Consecutive Numbers Starting from Zero (Case 1)
# 16/2884 setting MIT as the license -> Printing Consecutive Numbers Starting from Zero (Case 2)
# 17/2884 setting MIT as the license -> Pythagorean Theorem (Case 1)
# 18/2884 setting MIT as the license -> Pythagorean Theorem (Case 2)
# 19/2884 setting MIT as the license -> Finding the Smallest Divisor of a Positive Number
# 20/2884 setting MIT as the license -> Finding the Largest Divisor of a Positive Number
# 21/2884 setting MIT as the license -> Accessing String Characters (Case 1)
# 22/2884 setting MIT as the license -> Accessing String Characters (Case 2)
# 23/2884 setting MIT as the license -> The Class for Representing a Bank Account (Case 1)
# 24/2884 setting MIT as the license -> The Class for Representing a Bank Account (Case 2)
# 25/2884 setting MIT as the license -> The Class for Representing a TV (Case 1)
# 26/2884 setting MIT as the license -> The Class for Representing a TV (Case 2)
# 27/2884 setting MIT as the license -> The Class for Representing a Loan (Case 1)
# 28/2884 setting MIT as the license -> The Class for Representing a Loan (Case 2)
# 29/2884 setting MIT as the license -> Creating a List of Words from a File
# 30/2884 setting MIT as the license -> Comparing the List of Words from Two Files
# 31/2884 setting MIT as the license -> Creating an Array of Odd Numbers
# 32/2884 setting MIT as the license -> Creating an Array of User Inputs
# 33/2884 setting MIT as the license -> Increment/Decrement Operators (Case 1)
# 34/2884 setting MIT as the license -> Increment/Decrement Operators (Case 2)
# 35/2884 setting MIT as the license -> Increment/Decrement Operators (Case 3)
# 36/2884 setting MIT as the license -> String Concatenation (Case 1)
# 37/2884 setting MIT as the license -> String Concatenation (Case 2)
# 38/2884 setting MIT as the license -> Determining When a Customer Could Rent a Car (Case 1)
# 39/2884 setting MIT as the license -> Determining When a Customer Could Rent a Car (Case 2)
# 40/2884 setting MIT as the license -> Determining When a Customer Could Rent a Car (Case 3)
# 41/2884 setting MIT as the license -> String Comparison (Case 1)
# 42/2884 setting MIT as the license -> String Comparison (Case 2)
# 43/2884 setting MIT as the license -> Calculating the Sum of the Values in an Array
# 44/2884 setting MIT as the license -> Calculating the Average of the Values in the Array
# 45/2884 setting MIT as the license -> Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 1)
# 46/2884 setting MIT as the license -> Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 2)
# 47/2884 setting MIT as the license -> Calculating the Winning Percentage of a Sports Team (Case 1)
# 48/2884 setting MIT as the license -> Calculating the Winning Percentage of a Sports Team (Case 2)
# 49/2884 setting MIT as the license -> Calculating the Winning Percentage of a Sports Team (Case 3)
# 50/2884 setting MIT as the license -> Updating an Element in the Array (Case 1)
# 51/2884 setting MIT as the license -> Updating an Element in the Array (Case 2)
# 52/2884 setting MIT as the license -> Updating an Element in the Array (Case 3)
# 53/2884 setting MIT as the license -> Modifying an Array (Case 1)
# 54/2884 setting MIT as the license -> Modifying an Array (Case 2)
# 55/2884 setting MIT as the license -> Printing Name Initials
# 56/2884 setting MIT as the license -> Printing Full Name with Middle Initial
# 57/2884 setting MIT as the license -> Printing Name in APA Style
# 58/2884 setting MIT as the license -> Warning the User about the Changes in the Temperature
# 59/2884 setting MIT as the license -> Warning the User about the Changes in the Temperature and Humidity
# 60/2884 setting MIT as the license -> Determining the Smallest of the Three Integers
# 61/2884 setting MIT as the license -> Determining the Largest of the Three Integers
# 62/2884 setting MIT as the license -> Printing Table of Medal Winner Counts with Row Totals
# 63/2884 setting MIT as the license -> Printing Table of Medal Winner Counts with Row and Column Totals
# 64/2884 setting MIT as the license -> Vending Machine With Dollars and Quarters
# 65/2884 setting MIT as the license -> Vending Machine With Quarters-Dimes- and Nickels
# 66/2884 setting MIT as the license -> Celsius To Fahrenheit Conversion
# 67/2884 setting MIT as the license -> Fahrenheit to Celsius Conversion
# 68/2884 setting MIT as the license -> Determining When at Least One of the Three Boolean Variables is True
# 69/2884 setting MIT as the license -> Determining When at Least One of the Three Boolean Variables is False
# 70/2884 setting MIT as the license -> Determining When All Three Boolean Variables Are Equal
# 71/2884 setting MIT as the license -> Determining the Letter Grade Of a Student
# 72/2884 setting MIT as the license -> Converting the Letter Grade of a Student to Its Numeric Range
# 73/2884 setting MIT as the license -> The Class for Representing a Point in the Euclidean Plane (Case 1)
# 74/2884 setting MIT as the license -> The Class for Representing a Point in the Euclidean Plane (Case 2)
# 75/2884 setting MIT as the license -> Printing the Squares of Numbers Within a Specified Range (Case 1)
# 76/2884 setting MIT as the license -> Printing the Squares of Numbers Within a Specified Range (Case 2)
# 77/2884 setting MIT as the license -> Printing the Squares of Numbers Within a Specified Range (Case 3)
# 78/2884 setting MIT as the license -> Calculating the Employees Wage Based on the Hours That the Employee Has Worked and an Hourly Pay Rate
# 79/2884 setting MIT as the license -> Calculating the Wage of an Employee at the Customer Service Call Center
# 80/2884 setting MIT as the license -> Counting the Number of Valid and Banned Product Codes (Case 1)
# 81/2884 setting MIT as the license -> Counting the Number of Valid and Banned Product Codes (Case 2)
# 82/2884 setting MIT as the license -> Determining Whether One is a Teenager (Case 1)
# 83/2884 setting MIT as the license -> Determining Whether One is a Teenager (Case 2)
# 84/2884 setting MIT as the license -> Printing A Right Triangle Star Pattern
# 85/2884 setting MIT as the license -> Printing an Inverted Right Triangle Star Pattern
# 86/2884 setting MIT as the license -> Point Class Hierarchy (Case 1)
# 87/2884 setting MIT as the license -> Point Class Hierarchy (Case 2)
# 88/2884 setting MIT as the license -> Animal Class Hierarchy (Case 1)
# 89/2884 setting MIT as the license ->  Animal Class Hierarchy (Case 2)
# 90/2884 setting MIT as the license -> Finding the Number of Days Above the Average Temperature
# 91/2884 setting MIT as the license -> Displaying the Days That are Above 32 Degrees Fahrenheit
# 92/2884 setting MIT as the license -> Reporting File Information (Case 1)
# 93/2884 setting MIT as the license -> Reporting File Information (Case 2)
# 94/2884 setting MIT as the license -> Calculating the Average of Input Integers
# 95/2884 setting MIT as the license -> Calculating the Average of the Input Integers that are an Even Number
# 96/2884 setting MIT as the license -> Calculating the Average of Floating-Point Numbers
# 97/2884 setting MIT as the license -> Determining When a Student Fails a Course (Case 1)
# 98/2884 setting MIT as the license -> Determining When a Student Fails a Course (Case 2)
# 99/2884 setting MIT as the license -> Determining When a Student Fails a Course (Case 3)
# 100/2884 setting MIT as the license -> Printing Digits of an Integer from Right to Left
# 101/2884 setting MIT as the license -> The Digit Sum of an Integer
# 102/2884 setting MIT as the license -> Reversing the Digits of an Integer
# 103/2884 setting MIT as the license -> Finding Adjacent Duplicates in a Sequence of Numbers
# 104/2884 setting MIT as the license -> Finding Adjacent Consecutive Numbers in a Sequence of Integers
# 105/2884 setting MIT as the license -> Finding Adjacent Numbers in Ascending Order in a Sequence of Numbers
# 106/2884 setting MIT as the license -> Rotating the Array Values to the Left by One Position
# 107/2884 setting MIT as the license -> Rotating the Array Values to the Left by Two Position
# 108/2884 setting MIT as the license -> Rotating the Array Values to the Right by One Position
# 109/2884 setting MIT as the license -> Rotating the List Values to the Right by Two Position
# 110/2884 setting MIT as the license -> Calculating Body Mass Index (BMI)
# 111/2884 setting MIT as the license -> Calculating and Rounding Up Body Mass Index (BMI) To the Nearest Integer
# 112/2884 setting MIT as the license -> Updating Two-Dimensional Array (Case 1)
# 113/2884 setting MIT as the license -> Updating Two-Dimensional Array (Case 2)
# 114/2884 setting MIT as the license -> Updating Two-Dimensional Array (Case 3)
# 115/2884 setting MIT as the license -> Determining the Sign of an Integer
# 116/2884 setting MIT as the license -> Determining Whether an Integer is Even or Odd
# 117/2884 setting MIT as the license -> Receiving Input Integers Until a Certain Condition is Met (Case 1)
# 118/2884 setting MIT as the license -> Receiving Input Integers Until a Certain Condition is Met (Case 2)
# 119/2884 setting MIT as the license -> Receiving Input Integers Until a Certain Condition is Met (Case 3)
# 120/2884 setting MIT as the license -> Receiving Input Integers Until a Certain Condition is Met (Case 4)
# 121/2884 setting MIT as the license -> String With Escape Characters (Case 1)
# 122/2884 setting MIT as the license -> String With Escape Characters (Case 2)
# 123/2884 setting MIT as the license -> String With Escape Characters (Case 3)
# 124/2884 setting MIT as the license -> Determining the Weather Condition (Case 1)
# 125/2884 setting MIT as the license -> Determining the Weather Condition (Case 2)
# 126/2884 setting MIT as the license -> Determining the Weather Condition (Case 3)
# 127/2884 setting MIT as the license -> Determining the Weather Condition (Case 4)
# 128/2884 setting MIT as the license -> Determining the Maximum Rating for Each Soda in The Survey
# 129/2884 setting MIT as the license -> Determining the Average Rating for Each Soda in The Survey
# 130/2884 setting MIT as the license -> Determining the Average Ratings of each Respondent and Average Ratings Given to Each Soda in the Survey
# 131/2884 setting MIT as the license -> Printing Consecutive Numbers Within a Specified Range (Case 1)
# 132/2884 setting MIT as the license -> Printing Consecutive Numbers Within a Specified Range (Case 2)
# 133/2884 setting MIT as the license -> Seconds to Minutes Conversion
# 134/2884 setting MIT as the license -> Converting Milliseconds to Hours-Minutes- and Seconds
# 135/2884 setting MIT as the license -> Finding the Minimum Value in an Array
# 136/2884 setting MIT as the license -> Finding the Maximum Value in an Array
# 137/2884 setting MIT as the license -> Printing A Sequence of Repeated Numbers (Case 1)
# 138/2884 setting MIT as the license -> Printing A Sequence of Repeated Numbers (Case 2)
# 139/2884 setting MIT as the license -> Reporting the Total Hours Each Employee Worked (Case 1)
# 140/2884 setting MIT as the license -> Reporting the Total Hours Each Employee Worked (Case 2)
# 141/2884 setting MIT as the license -> Herencia de Persona y Empleado
# 142/2884 setting MIT as the license -> Informacion de Herencia de Persona y Empleado
# 143/2884 setting MIT as the license -> Mostrando los Dias que Estan por Sobre el Promedio de Temperatura
# 144/2884 setting MIT as the license -> Mostrando los Dias que Estan por Sobre 32 Grados Fahrenheit
# 145/2884 setting MIT as the license -> Concatenando Caracteres de Dos Strings (Caso 1)
# 146/2884 setting MIT as the license -> Concatenando Caracteres de Dos Strings (Caso 2).
# 147/2884 setting MIT as the license -> Imprimir Tabla de Conteo de Medallas con Totales por Fila
# 148/2884 setting MIT as the license -> Imprimir Tabla de Conteo de Medallas con Totales por Fila y por Columna
# 149/2884 setting MIT as the license -> Determinando Si Uno Es Adolescente (Caso 1)
# 150/2884 setting MIT as the license -> Determinando Si Uno Es Adolescente (Caso 2)
# 151/2884 setting MIT as the license -> Creando un Diccionario de Pares Estudiante-Puntajes (Caso 1)
# 152/2884 setting MIT as the license -> Creando un Diccionario de Pares Estudiante-Puntajes (Caso 2)
# 153/2884 setting MIT as the license -> Informe de Informacion del Archivo (Caso 1)
# 154/2884 setting MIT as the license -> Informar Informacion del Archivo (Caso 2)
# 155/2884 setting MIT as the license -> Contando las Ocurrencias de un String en Otro (Caso 1)
# 156/2884 setting MIT as the license -> Contando las Ocurrencias de un String en Otro (Caso 2).
# 157/2884 setting MIT as the license -> Calculo del Indice de Masa Corporal (IMC)
# 158/2884 setting MIT as the license -> Calculo y Redondeo del Indice de Masa Corporal (IMC) al Entero Mas Cercano.
# 159/2884 setting MIT as the license -> La Clase para Representar un Prestamo (Caso 1)
# 160/2884 setting MIT as the license -> La Clase para Representar un Prestamo (Caso 2)
# 161/2884 setting MIT as the license -> Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 1)
# 162/2884 setting MIT as the license -> Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 2)
# 163/2884 setting MIT as the license -> Determinando Cuando Comprar un Nuevo Telefono (Caso 1)
# 164/2884 setting MIT as the license -> Determinando Cuando Comprar un Nuevo Telefono (Caso 2)
# 165/2884 setting MIT as the license -> Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 1)
# 166/2884 setting MIT as the license -> Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 2)
# 167/2884 setting MIT as the license -> Creando un Diccionario de Pares Caracteres-Frecuencia
# 168/2884 setting MIT as the license -> Creando un Diccionario de Pares Caracteres-Palabras
# 169/2884 setting MIT as the license -> Desplazando los Valores de la Lista a la Izquierda Una Posicion
# 170/2884 setting MIT as the license -> Desplazando los Valores de la Lista a la Izquierda Dos Posiciones
# 171/2884 setting MIT as the license -> Desplazando los Valores de la Lista a la Derecha una Posicion
# 172/2884 setting MIT as the license -> Desplazando los Valores de la Lista a la Derecha Dos Posiciones
# 173/2884 setting MIT as the license -> Pasar Valores
# 174/2884 setting MIT as the license -> Pasar Valores
# 175/2884 setting MIT as the license -> Maquina Expendedora Con Dolares y Monedas de Veinticinco
# 176/2884 setting MIT as the license -> Maquina Expendedora Con Monedas de diferentes centavos
# 177/2884 setting MIT as the license -> Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo
# 178/2884 setting MIT as the license -> Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo Invertido
# 179/2884 setting MIT as the license -> Encontrar el Divisor Mas Pequeno de un Numero Positivo
# 180/2884 setting MIT as the license -> Encontrar el Mayor Divisor de un Numero Positivo
# 181/2884 setting MIT as the license -> testing_um2_student_average_arun_ch
# 182/2884 setting MIT as the license -> JSON ITERATION 1
# 183/2884 setting MIT as the license -> Calculando el Porcentaje de Victorias de un Equipo (Caso 1)
# 184/2884 setting MIT as the license -> Calculando el Porcentaje de Victorias de un Equipo (Caso 2)
# 185/2884 setting MIT as the license -> Calculando el Porcentaje de Victorias de un Equipo (Caso 3)
# 186/2884 setting MIT as the license -> Advertir al Usuario sobre los Cambios en la Temperatura
# 187/2884 setting MIT as the license -> Advertir al Usuario sobre los Cambios en la Temperatura y Humedad.
# 188/2884 setting MIT as the license -> Funcion con Multiples Parametros
# 189/2884 setting MIT as the license -> Funcion con Multiples Parametros Llamando Otra
# 190/2884 setting MIT as the license -> Pythagorean Theorem (Case 1)
# 191/2884 setting MIT as the license -> Pythagorean Theorem (Case 2)
# 192/2884 setting MIT as the license -> testing_um2_student_average_arun_ch
# 193/2884 setting MIT as the license -> testing_um2_student_average_arun_ex
# 194/2884 setting MIT as the license -> testing_um2_arun_java_SLR_weat_ex
# 195/2884 setting MIT as the license -> testing_um2_arun_java_SLR_weat_ch
# 196/2884 setting MIT as the license -> CopyFileTo
# 197/2884 setting MIT as the license -> PrintFileContent
# 198/2884 setting MIT as the license -> Calcular promedio de dos numeros enteros (ES)
# 199/2884 setting MIT as the license -> Calcular factura mensual (ES)
# 200/2884 setting MIT as the license -> Calcular los segundos en n dias (ES)
# 201/2884 setting MIT as the license -> Condicion: es impar (ES)
# 202/2884 setting MIT as the license -> Contar Mayusculas (ES)
# 203/2884 setting MIT as the license -> Mayusculas o Minusculas (ES)
# 204/2884 setting MIT as the license -> Contar no digitos (ES)
# 205/2884 setting MIT as the license -> Todo Esponjoso (ES)
# 206/2884 setting MIT as the license -> Indice Menor (ES)
# 207/2884 setting MIT as the license -> Primer Par (ES)
# 208/2884 setting MIT as the license -> Triangulo Ascii (ES)
# 209/2884 setting MIT as the license -> Contar Digitos (ES)
# 210/2884 setting MIT as the license -> Factor menor (ES)
# 211/2884 setting MIT as the license -> Contar Pasos Collatz (ES)
# 212/2884 setting MIT as the license -> Solo Dos Verdaderos (p2-4-ES)
# 213/2884 setting MIT as the license -> Solo Uno Verdadero (p1-4-ES)
# 214/2884 setting MIT as the license -> Listas de enteros pares (ES)
# 215/2884 setting MIT as the license -> Encontrar el indice de el string mas largo (ES)
# 216/2884 setting MIT as the license -> Intercambiar primero y ultimo
# 217/2884 setting MIT as the license -> Contar el numero de valores que estan por encima del promedio (ES)
# 218/2884 setting MIT as the license -> Suma digital (ES)
# 219/2884 setting MIT as the license -> Programa usual primero (CC)
# 220/2884 setting MIT as the license -> Ciclo for anidado
# 221/2884 setting MIT as the license -> Calculo rebanadas de pizza (ES)
# 222/2884 setting MIT as the license -> Condicion: es adolescente (ES)
# 223/2884 setting MIT as the license -> Dia siguiente
# 224/2884 setting MIT as the license -> Maximo de tres enteros (ES)
# 225/2884 setting MIT as the license -> Calculo galletas necesarias (ES)
# 226/2884 setting MIT as the license -> Calcular su suma y producto
# 227/2884 setting MIT as the license -> Practicar el uso de la biblioteca math y comprobar el tipo de una variable
# 228/2884 setting MIT as the license -> Practicar la manipulación de variables y verificar sus tipos
# 229/2884 setting MIT as the license -> Practicar ciclos while anidados
# 230/2884 setting MIT as the license -> Practicar el uso de ciclos while y for anidados
# 231/2884 setting MIT as the license -> Practicar herencia de clases
# 232/2884 setting MIT as the license -> Manipulación de diccionarios
# 233/2884 setting MIT as the license -> Cálculos con diccionarios
# 234/2884 setting MIT as the license -> Valores y referencias en listas
# 235/2884 setting MIT as the license -> Practicar la búsqueda del índice del elemento mínimo
# 236/2884 setting MIT as the license -> Practicar la búsqueda del índice de los elementos mínimo y máximo
# 237/2884 setting MIT as the license -> Construir un programa que cree una estructura de pila (Stack)
# 238/2884 setting MIT as the license -> Construir una función que use una estructura de cola (Queue)
# 239/2884 setting MIT as the license -> Construir una función que recorra una lista enlazada
# 240/2884 setting MIT as the license -> Construir una función que verifique el tamaño de una lista enlazada
# 241/2884 setting MIT as the license -> Construir una función que ordene un arreglo numérico usando Merge Sort
# 242/2884 setting MIT as the license -> Practicar el algoritmo de ordenación rápida (Quick Sort)
# 243/2884 setting MIT as the license -> Construir una función de recorrido inorder (inorden)
# 244/2884 setting MIT as the license -> Imprimir hola mundo
# 245/2884 setting MIT as the license -> Crear una función que imprima hola mundo
# 246/2884 setting MIT as the license -> Crear una función que reciba un número, le sume dos y lo devuelva
# 247/2884 setting MIT as the license -> Crear una función que devuelva el mayor de dos números
# 248/2884 setting MIT as the license -> Practicar el orden de líneas para obtener el número correcto
# 249/2884 setting MIT as the license -> Crear un programa con un ciclo while
# 250/2884 setting MIT as the license -> Crear un programa que compare un valor en un ciclo
# 251/2884 setting MIT as the license -> Crear y llamar a una función
# 252/2884 setting MIT as the license -> Crear múltiples funciones y llamadas de función anidadas
# 253/2884 setting MIT as the license -> Crear una función recursiva
# 254/2884 setting MIT as the license -> Crear una clase y utilizarla
# 255/2884 setting MIT as the license -> Crear una función y usar el operador módulo
# 256/2884 setting MIT as the license -> Iterar sobre una lista
# 257/2884 setting MIT as the license -> Practicar indexación de listas
# 258/2884 setting MIT as the license -> Practicar el corte de cadenas (slicing)
# 259/2884 setting MIT as the license -> Iterar sobre un diccionario
# 260/2884 setting MIT as the license -> Acceder a los valores de un diccionario
# 261/2884 setting MIT as the license -> Convertir una lista de tuplas en un diccionario
# 262/2884 setting MIT as the license -> Iterar sobre elementos (items) de un diccionario
# 263/2884 setting MIT as the license -> Usar expresiones booleanas como parámetros de una función
# 264/2884 setting MIT as the license -> Practicar sentencias if...elif...else
# 265/2884 setting MIT as the license -> Practicar leer un archivo e imprimir su contenido
# 266/2884 setting MIT as the license -> Practicar el manejo de excepciones
# 267/2884 setting MIT as the license -> Practicar sentencias if anidadas
# 268/2884 setting MIT as the license -> Practicar el uso de comparaciones
# 269/2884 setting MIT as the license -> Practicar indexación y modificación de listas
# 270/2884 setting MIT as the license -> Practicar la asignación de variables
# 271/2884 setting MIT as the license -> Crear una compuerta XOR usando sentencias if...elif
# 272/2884 setting MIT as the license -> Practicar iterar sobre una lista y usar módulo
# 273/2884 setting MIT as the license -> Practicar métodos de cadenas
# 274/2884 setting MIT as the license -> Practicar el manejo de excepciones
# 275/2884 setting MIT as the license -> Crear una clase y usar sus métodos
# 276/2884 setting MIT as the license -> Construir un programa que trabaje con listas
# 277/2884 setting MIT as the license -> Construir un problema con ciclos anidados
# 278/2884 setting MIT as the license -> Construir un programa que genere combinaciones únicas de 3 dígitos
# 279/2884 setting MIT as the license -> Construir un programa que genere combinaciones únicas de 3 dígitos
# 280/2884 setting MIT as the license -> Construir un programa con múltiples sentencias if-elif
# 281/2884 setting MIT as the license -> Construir un programa con múltiples sentencias if-elif
# 282/2884 setting MIT as the license -> Construir un programa con múltiples sentencias if-elif
# 283/2884 setting MIT as the license -> Frecuencia de letras
# 284/2884 setting MIT as the license -> Frecuencia de letras
# 285/2884 setting MIT as the license -> Crear una función que verifique si una cadena es un palíndromo o no
# 286/2884 setting MIT as the license -> Crear una función que verifique si una cadena es un palíndromo o no
# 287/2884 setting MIT as the license -> Crear una función que verifique si una cadena es un palíndromo o no
# 288/2884 setting MIT as the license -> Construir una función que determine si una cadena dada como parámetro es un palíndromo
# 289/2884 setting MIT as the license -> Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 290/2884 setting MIT as the license -> Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 291/2884 setting MIT as the license -> Invertir la lista
# 292/2884 setting MIT as the license -> Invertir la lista
# 293/2884 setting MIT as the license -> Invertir la lista
# 294/2884 setting MIT as the license -> Invertir la lista
# 295/2884 setting MIT as the license -> Invertir la lista
# 296/2884 setting MIT as the license -> Invertir la lista
# 297/2884 setting MIT as the license -> Invertir la lista
# 298/2884 setting MIT as the license -> Invertir la lista
# 299/2884 setting MIT as the license -> Verificar si la suma de dos enteros es igual al tercer entero
# 300/2884 setting MIT as the license -> Verificar si la suma de dos enteros es igual al tercer entero
# 301/2884 setting MIT as the license -> Actualizar elementos en una nueva lista
# 302/2884 setting MIT as the license -> Actualizar elementos necesarios en una nueva lista
# 303/2884 setting MIT as the license -> Actualizar los elementos en una nueva lista
# 304/2884 setting MIT as the license -> Actualizar los elementos en una nueva lista
# 305/2884 setting MIT as the license -> Actualizar elementos necesarios en una nueva lista
# 306/2884 setting MIT as the license -> Actualizar elementos necesarios en una nueva lista
# 307/2884 setting MIT as the license -> Cálculo de potencias
# 308/2884 setting MIT as the license -> Cálculo de potencias
# 309/2884 setting MIT as the license -> Calcular una potencia
# 310/2884 setting MIT as the license -> Calcular una potencia
# 311/2884 setting MIT as the license -> Calcular una potencia
# 312/2884 setting MIT as the license -> Calcular una potencia
# 313/2884 setting MIT as the license -> Eliminar duplicados de una lista
# 314/2884 setting MIT as the license -> Eliminar duplicados de una lista
# 315/2884 setting MIT as the license -> Reorganizar la lista
# 316/2884 setting MIT as the license -> Reorganizar la lista
# 317/2884 setting MIT as the license -> Reorganizar la lista
# 318/2884 setting MIT as the license -> Reorganizar la lista
# 319/2884 setting MIT as the license -> Practicar la lectura de archivos e imprimir el tercer elemento de cada línea
# 320/2884 setting MIT as the license -> Binary Search Algorithm Slideshow
# 321/2884 setting MIT as the license -> Binary Search recurrence slideshow
# 322/2884 setting MIT as the license -> BST Search Slideshow
# 323/2884 setting MIT as the license -> BST Insert Slideshow
# 324/2884 setting MIT as the license -> BST deletemax Slideshow
# 325/2884 setting MIT as the license -> BST remove Slideshow
# 326/2884 setting MIT as the license -> PosetCON
# 327/2884 setting MIT as the license -> Binary Search Proficiency Exercise
# 328/2884 setting MIT as the license -> BST Search Proficiency Exercise
# 329/2884 setting MIT as the license -> BST Question Summary
# 330/2884 setting MIT as the license -> Self-organizing List Move-to-front Proficiency Exercise
# 331/2884 setting MIT as the license -> Insertion Sort Slideshow
# 332/2884 setting MIT as the license -> Insertion Sort Worst Case Slideshow
# 333/2884 setting MIT as the license -> Insertion Sort Best Case Slideshow
# 334/2884 setting MIT as the license -> Insertion Sort Average Case Slideshow
# 335/2884 setting MIT as the license -> Bubble Sort Slideshow 1
# 336/2884 setting MIT as the license -> Bubble Sort Slideshow 2
# 337/2884 setting MIT as the license -> Bubble Sort Analysis Slideshow
# 338/2884 setting MIT as the license -> Selection Sort Slideshow 1
# 339/2884 setting MIT as the license -> Selection Sort Slideshow 2
# 340/2884 setting MIT as the license -> Selection Sort Analysis Slideshow
# 341/2884 setting MIT as the license -> Exchange Sort Analysis Slideshow
# 342/2884 setting MIT as the license -> Shellsort Slideshow 1
# 343/2884 setting MIT as the license -> Shellsort Slideshow 2
# 344/2884 setting MIT as the license -> Shellsort Slideshow 3
# 345/2884 setting MIT as the license -> Shellsort Slideshow 4
# 346/2884 setting MIT as the license -> Shellsort Slideshow 5
# 347/2884 setting MIT as the license -> Shellsort Slideshow 6
# 348/2884 setting MIT as the license -> Merging Slideshow
# 349/2884 setting MIT as the license -> Mergesort Analysis Slideshow
# 350/2884 setting MIT as the license -> Mergesort Implementation Slideshow 1
# 351/2884 setting MIT as the license -> Mergesort Implementation Slideshow 2
# 352/2884 setting MIT as the license -> Quicksort Partition Slideshow
# 353/2884 setting MIT as the license -> Quicksort Partition Analysis Slideshow
# 354/2884 setting MIT as the license -> Quicksort Worst Case Analysis Slideshow
# 355/2884 setting MIT as the license -> Quicksort Best Case Analysis Slideshow
# 356/2884 setting MIT as the license -> Quicksort Average Case Analysis Slideshow
# 357/2884 setting MIT as the license -> Heapsort Slideshow
# 358/2884 setting MIT as the license -> Heapsort Analysis Slideshow
# 359/2884 setting MIT as the license -> Binsort Slideshow 1
# 360/2884 setting MIT as the license -> Binsort Slideshow 2
# 361/2884 setting MIT as the license -> Radix Sort Analysis Slideshow
# 362/2884 setting MIT as the license -> Sorting Lower Bound Slideshow
# 363/2884 setting MIT as the license -> Selection Sort Pointer Swap
# 364/2884 setting MIT as the license -> Sorting Terminology and Notation Slideshow 1
# 365/2884 setting MIT as the license -> Sorting Problem
# 366/2884 setting MIT as the license -> Pair to Sorting Reduction Slideshow
# 367/2884 setting MIT as the license -> Sorting to Pairing Reduction Slideshow
# 368/2884 setting MIT as the license -> Record Comparison Summary Exercise
# 369/2884 setting MIT as the license -> Sorting Intro Summary
# 370/2884 setting MIT as the license -> Insertion Sort Proficiency Exercise
# 371/2884 setting MIT as the license -> Insertion Sort Summary Exercise
# 372/2884 setting MIT as the license -> Bubble Sort Proficiency Exercise
# 373/2884 setting MIT as the license -> Bubble Sort Summary Exercise
# 374/2884 setting MIT as the license -> Selection Sort Proficiency Exercise
# 375/2884 setting MIT as the license -> Selection Sort Summary Exercise
# 376/2884 setting MIT as the license -> Inversions Proficiency Exercise
# 377/2884 setting MIT as the license -> Exchange Sorting Summary Exercise
# 378/2884 setting MIT as the license -> Shellsort Sublist Proficency Exercise
# 379/2884 setting MIT as the license -> Shellsort Series Exercise
# 380/2884 setting MIT as the license -> Shellsort Summary Exercise
# 381/2884 setting MIT as the license -> Mergesort Merging Proficiency Exercise
# 382/2884 setting MIT as the license -> Mergesort Summary Exercise
# 383/2884 setting MIT as the license -> Quicksort Pivot Proficiency Exercise
# 384/2884 setting MIT as the license -> Quicksort Partition Proficiency Exercise
# 385/2884 setting MIT as the license -> Quicksort Summary Exercise
# 386/2884 setting MIT as the license -> Heapsort RemoveMax Proficiency Exercise
# 387/2884 setting MIT as the license -> Heapsort Summary Exercise
# 388/2884 setting MIT as the license -> Radix Sort Proficiency Exercise
# 389/2884 setting MIT as the license -> Radix Sort Summary Exercise
# 390/2884 setting MIT as the license -> Sort Comparison Summary Exercise
# 391/2884 setting MIT as the license -> Lower Bounds Summary Exercise
# 392/2884 setting MIT as the license -> Sorting Chapter Summary Exercise
# 393/2884 setting MIT as the license -> JLinkedListUtil Challenge
# 394/2884 setting MIT as the license -> JLinkedListUtil
# 395/2884 setting MIT as the license ->  Recursively calculate the power of a number Challenge
# 396/2884 setting MIT as the license ->  Recursively calculate the power of a number
# 397/2884 setting MIT as the license -> Recursively calculate the sum of all numbers from 1 to n Challenge
# 398/2884 setting MIT as the license -> Recursively calculate the sum of all numbers from 1 to n
# 399/2884 setting MIT as the license -> q_java_q_py_slinkedlist1
# 400/2884 setting MIT as the license -> q_java_q_py_dlinkedlist1
# 401/2884 setting MIT as the license -> Merge LinkList - NFB
# 402/2884 setting MIT as the license -> (Recursion) Power calculation - NFB
# 403/2884 setting MIT as the license -> (Recursion) Sum from 1 to n - NFB
# 404/2884 setting MIT as the license -> Recursive addition of characters - NFB
# 405/2884 setting MIT as the license -> Traverse LinkedList - NFB
# 406/2884 setting MIT as the license -> LinkedList repeated two lists - NFB
# 407/2884 setting MIT as the license -> Compare Two LinkedList - NFB
# 408/2884 setting MIT as the license -> Compare Two LinkedList
# 409/2884 setting MIT as the license -> Linked List 1
# 410/2884 setting MIT as the license -> Use Recursion to calculate power
# 411/2884 setting MIT as the license -> Use Recursion to calculate total sum of all numbers from 1 to N.
# 412/2884 setting MIT as the license -> PCRS C3-PL Reverse dictionary
# 413/2884 setting MIT as the license -> PCRS C3-PL Recursive counting
# 414/2884 setting MIT as the license -> PCRS C3-PL Bracket validation
# 415/2884 setting MIT as the license -> PCRS C3-PL  Find N Letters
# 416/2884 setting MIT as the license -> PCRS C3-PL  Event Class
# 417/2884 setting MIT as the license -> PCRS C3-PL  Total Slices
# 418/2884 setting MIT as the license -> PCRS C3-PL  List Insert
# 419/2884 setting MIT as the license -> PCRS C3-PL  Reverse Lookup
# 420/2884 setting MIT as the license -> PCRS C3-PL  Realestate Class
# 421/2884 setting MIT as the license -> PCRS C3-PL  Ipod Class
# 422/2884 setting MIT as the license -> PCRS C3-PL  Rectangle Class
# 423/2884 setting MIT as the license -> PCRS C3-PL  Special List Class
# 424/2884 setting MIT as the license -> PCRS C3-PL  Can Pay With Two Coins
# 425/2884 setting MIT as the license -> PCRS C3-PL  Add Underscores
# 426/2884 setting MIT as the license -> PCRS C3-PL  Class Day Calendar
# 427/2884 setting MIT as the license -> PCRS C3-PL  Double
# 428/2884 setting MIT as the license -> PCRS C3-PL  Our Maximum
# 429/2884 setting MIT as the license -> PCRS C3-PL  Max Of Min
# 430/2884 setting MIT as the license -> PCRS C3-PL  Caculate Tax
# 431/2884 setting MIT as the license -> PCRS C3-PL  Same Abs
# 432/2884 setting MIT as the license -> PCRS C3-PL  Upper Lower
# 433/2884 setting MIT as the license -> PCRS C3-PL  Overdue Fees
# 434/2884 setting MIT as the license -> PCRS C3-PL  Different Types
# 435/2884 setting MIT as the license -> PCRS C3-PL  Every Second Line
# 436/2884 setting MIT as the license -> PCRS C3-PL  Get Words
# 437/2884 setting MIT as the license -> PCRS C3-PL  Context To Next Words
# 438/2884 setting MIT as the license -> PCRS C3-PL  Calendar Event3
# 439/2884 setting MIT as the license -> PCRS C3-PL  User Class1
# 440/2884 setting MIT as the license -> PCRS C3-PL  User Day
# 441/2884 setting MIT as the license -> PCRS C3-PL  Adjacent Match
# 442/2884 setting MIT as the license -> PCRS C3-PL  Duplicate Cut
# 443/2884 setting MIT as the license -> PCRS C3-PL  Student By Degree
# 444/2884 setting MIT as the license -> PCRS C3-PL  Has Last Token
# 445/2884 setting MIT as the license -> PCRS C3-PL  Context Not Unique Hashtags
# 446/2884 setting MIT as the license -> PCRS C3-PL  Non Intersecting
# 447/2884 setting MIT as the license -> PCRS C3-PL  Eligible
# 448/2884 setting MIT as the license -> PCRS C3-PL  Return Indices
# 449/2884 setting MIT as the license -> PCRS C3-PL  Reorganize
# 450/2884 setting MIT as the license -> PCRS C3-PL  Reorder By Hashtag
# 451/2884 setting MIT as the license -> PCRS C3-PL  Valid
# 452/2884 setting MIT as the license -> PCRS C3-PL  Valid Dna
# 453/2884 setting MIT as the license -> PCRS C3-PL  Item Catalog Class
# 454/2884 setting MIT as the license -> PCRS C3-PL  Somecode
# 455/2884 setting MIT as the license -> PCRS C3-PL  My Max
# 456/2884 setting MIT as the license -> PCRS C3-PL  Compute Sum
# 457/2884 setting MIT as the license -> PCRS C3-PL  Unique Integer
# 458/2884 setting MIT as the license -> PCRS C3-PL  Compute Product
# 459/2884 setting MIT as the license -> PCRS C3-PL  Hello World
# 460/2884 setting MIT as the license -> PCRS C3-PL  Hello World Name
# 461/2884 setting MIT as the license -> PCRS C3-PL  Shift Char
# 462/2884 setting MIT as the license -> PCRS C3-PL  Unshift Char
# 463/2884 setting MIT as the license -> PCRS C3-PL  A Before B
# 464/2884 setting MIT as the license -> PCRS C3-PL  Less Than Ten
# 465/2884 setting MIT as the license -> PCRS C3-PL  Positive Less Than Ten
# 466/2884 setting MIT as the license -> PCRS C3-PL  In Between
# 467/2884 setting MIT as the license -> PCRS C3-PL  Sum Twenty
# 468/2884 setting MIT as the license -> PCRS C3-PL  Exactly One Positive
# 469/2884 setting MIT as the license -> PCRS C3-PL  Exactly One Positive2
# 470/2884 setting MIT as the license -> PCRS C3-PL  Is Prime
# 471/2884 setting MIT as the license -> PCRS C3-PL  Max In Group
# 472/2884 setting MIT as the license -> PCRS C3-PL  Counta
# 473/2884 setting MIT as the license -> PCRS C3-PL  Countx
# 474/2884 setting MIT as the license -> PCRS C3-PL  Replace1
# 475/2884 setting MIT as the license -> PCRS C3-PL  Replacec
# 476/2884 setting MIT as the license -> PCRS C3-PL  Replacex
# 477/2884 setting MIT as the license -> PCRS C3-PL  Replace Between Index
# 478/2884 setting MIT as the license -> PCRS C3-PL  Is In
# 479/2884 setting MIT as the license -> PCRS C3-PL  Is Not In
# 480/2884 setting MIT as the license -> PCRS C3-PL  Dna Pairs
# 481/2884 setting MIT as the license -> PCRS C3-PL  Dna Base Pairs
# 482/2884 setting MIT as the license -> PCRS C3-PL  Count Genes
# 483/2884 setting MIT as the license -> PCRS C3-PL  Between Two Genes
# 484/2884 setting MIT as the license -> PCRS C3-PL  Sum List
# 485/2884 setting MIT as the license -> PCRS C3-PL  List Average
# 486/2884 setting MIT as the license -> PCRS C3-PL  Max In List
# 487/2884 setting MIT as the license -> PCRS C3-PL  Greater Than Ten
# 488/2884 setting MIT as the license -> PCRS C3-PL  Sum Greater Than N
# 489/2884 setting MIT as the license -> PCRS C3-PL  Return Max Index
# 490/2884 setting MIT as the license -> PCRS C3-PL  Longest String
# 491/2884 setting MIT as the license -> PCRS C3-PL  Count Longer
# 492/2884 setting MIT as the license -> PCRS C3-PL  Num Above Average
# 493/2884 setting MIT as the license -> PCRS C3-PL  Count Number Seven
# 494/2884 setting MIT as the license -> PCRS C3-PL  Count Nm
# 495/2884 setting MIT as the license -> PCRS C3-PL  Count Nmmn
# 496/2884 setting MIT as the license -> PCRS C3-PL  Count Nums
# 497/2884 setting MIT as the license -> PCRS C3-PL  Num Greater At Index
# 498/2884 setting MIT as the license -> PCRS C3-PL  Is Sorted
# 499/2884 setting MIT as the license -> PCRS C3-PL  Postfix
# 500/2884 setting MIT as the license -> PCRS C3-PL  Closed Interval
# 501/2884 setting MIT as the license -> PCRS C3-PL  Merge Sort
# 502/2884 setting MIT as the license -> PCRS C3-PL  Recurse Converge
# 503/2884 setting MIT as the license -> PCRS C3-PL  Alert Weekend
# 504/2884 setting MIT as the license -> PCRS C3-PL  Positive Two Digits
# 505/2884 setting MIT as the license -> PCRS C3-PL  Two Params True One
# 506/2884 setting MIT as the license -> PCRS C3-PL  Negative If Zero
# 507/2884 setting MIT as the license -> PCRS C3-PL  Continent
# 508/2884 setting MIT as the license -> PCRS C3-PL  Avocados
# 509/2884 setting MIT as the license -> PCRS C3-PL  Two Params True
# 510/2884 setting MIT as the license -> PCRS C3-PL Simple int comparison
# 511/2884 setting MIT as the license -> PCRS C3-PL Is char half alphabet
# 512/2884 setting MIT as the license -> PCRS C3-PL Is char lowercase
# 513/2884 setting MIT as the license ->  PCRS C3-PL Is teenager
# 514/2884 setting MIT as the license -> PCRS C3-PL If can drink
# 515/2884 setting MIT as the license -> PCRS C3-PL Is candyshop open
# 516/2884 setting MIT as the license -> PCRS C3-PL Within five
# 517/2884 setting MIT as the license -> PCRS C3-PL  Loan
# 518/2884 setting MIT as the license -> PCRS C3-PL  Utilties
# 519/2884 setting MIT as the license -> PCRS C3-PL  List Insert
# 520/2884 setting MIT as the license -> Busqueda Inversa de Telefono (ES)
# 521/2884 setting MIT as the license -> PCRS C3-PL  Realestate Class
# 522/2884 setting MIT as the license -> PCRS C3-PL  Ipod Class
# 523/2884 setting MIT as the license -> PCRS C3-PL  Rectangle Class
# 524/2884 setting MIT as the license -> PCRS C3-PL  Special List Class
# 525/2884 setting MIT as the license -> PCRS C3-PL  Can Pay With Two Coins
# 526/2884 setting MIT as the license -> Agregar guiones bajos a string (ES)
# 527/2884 setting MIT as the license -> PCRS C3-PL  Class Day Calendar
# 528/2884 setting MIT as the license -> PCRS C3-PL  Double
# 529/2884 setting MIT as the license -> PCRS C3-PL  Our Maximum
# 530/2884 setting MIT as the license -> Funcion maximo de los minimos valores (ES)
# 531/2884 setting MIT as the license -> Funcion calculo impuesto (ES)
# 532/2884 setting MIT as the license -> PCRS C3-PL  Same Abs
# 533/2884 setting MIT as the license -> PCRS C3-PL  Different Types
# 534/2884 setting MIT as the license -> Cada segunda linea en archivo (ES)
# 535/2884 setting MIT as the license -> PCRS C3-PL  Calendar Event3
# 536/2884 setting MIT as the license -> PCRS C3-PL  User Class1
# 537/2884 setting MIT as the license -> PCRS C3-PL  User Day
# 538/2884 setting MIT as the license -> PCRS C3-PL  Duplicate Cut
# 539/2884 setting MIT as the license -> PCRS C3-PL  Has Last Token
# 540/2884 setting MIT as the license -> PCRS C3-PL  Context Not Unique Hashtags
# 541/2884 setting MIT as the license -> PCRS C3-PL  Non Intersecting
# 542/2884 setting MIT as the license -> PCRS C3-PL  Return Indices
# 543/2884 setting MIT as the license -> Reorganizar diccionario (ES)
# 544/2884 setting MIT as the license -> PCRS C3-PL  Item Catalog Class
# 545/2884 setting MIT as the license -> PCRS C3-PL  Somecode
# 546/2884 setting MIT as the license -> PCRS C3-PL  My Max
# 547/2884 setting MIT as the license -> PCRS C3-PL  Compute Sum
# 548/2884 setting MIT as the license -> PCRS C3-PL  Unique Integer
# 549/2884 setting MIT as the license -> PCRS C3-PL  Compute Product
# 550/2884 setting MIT as the license -> PCRS C3-PL  Hello World
# 551/2884 setting MIT as the license -> Desplazar caracter en string (ES)
# 552/2884 setting MIT as the license -> Desplazar caracter hacia atras en string (ES)
# 553/2884 setting MIT as the license -> String A antes que String B (ES)
# 554/2884 setting MIT as the license -> Condicion: menor que 10 (ES)
# 555/2884 setting MIT as the license -> Condicion: positivo menor que 10 (ES)
# 556/2884 setting MIT as the license -> PCRS C3-PL  Exactly One Positive2
# 557/2884 setting MIT as the license -> PCRS C3-PL  Is In
# 558/2884 setting MIT as the license -> PCRS C3-PL  Is Not In
# 559/2884 setting MIT as the license -> PCRS C3-PL  Dna Pairs
# 560/2884 setting MIT as the license -> PCRS C3-PL  Dna Base Pairs
# 561/2884 setting MIT as the license -> PCRS C3-PL  Count Genes
# 562/2884 setting MIT as the license -> PCRS C3-PL  Between Two Genes
# 563/2884 setting MIT as the license -> Suma elementos lista (ES)
# 564/2884 setting MIT as the license -> Promedio en lista (ES)
# 565/2884 setting MIT as the license -> Maximo en lista (ES)
# 566/2884 setting MIT as the license -> PCRS C3-PL  Return Max Index
# 567/2884 setting MIT as the license -> PCRS C3-PL  Count Longer
# 568/2884 setting MIT as the license -> PCRS C3-PL  Count Number Seven
# 569/2884 setting MIT as the license -> PCRS C3-PL  Count Nm
# 570/2884 setting MIT as the license -> PCRS C3-PL  Count Nmmn
# 571/2884 setting MIT as the license -> PCRS C3-PL  Is Sorted
# 572/2884 setting MIT as the license -> PCRS C3-PL If can drink
# 573/2884 setting MIT as the license -> PCRS C3-PL Is char lowercase
# 574/2884 setting MIT as the license -> PCRS C3-PL  Hidden
# 575/2884 setting MIT as the license -> PCRS C3-PL  Closed Interval
# 576/2884 setting MIT as the license -> PCRS C3-PL Within five
# 577/2884 setting MIT as the license -> PCRS C3-PL  Merge Sort
# 578/2884 setting MIT as the license -> PCRS C3-PL Is candyshop open
# 579/2884 setting MIT as the license -> Convergencia recursiva (ES)
# 580/2884 setting MIT as the license -> PCRS C3-PL Is char half alphabet
# 581/2884 setting MIT as the license -> PCRS C3-PL  Positive Two Digits
# 582/2884 setting MIT as the license ->  PCRS C3-PL Is teenager
# 583/2884 setting MIT as the license -> PCRS C3-PL  Continent
# 584/2884 setting MIT as the license -> PCRS C3-PL  Avocados
# 585/2884 setting MIT as the license -> PCRS C3-PL  If Perishable Num
# 586/2884 setting MIT as the license -> PCRS C3-PL  Simple Sum
# 587/2884 setting MIT as the license -> PCRS C3-PL  Loan
# 588/2884 setting MIT as the license -> Revertir diccionario (ES)
# 589/2884 setting MIT as the license -> Conteo votos en diccionario (ES)
# 590/2884 setting MIT as the license -> Ortografia correcta (diccionario desde archivo) (ES)
# 591/2884 setting MIT as the license -> Busqueda inversa telefono diccionario (ES)
# 592/2884 setting MIT as the license -> Cantidades de comida en diccionario (ES)
# 593/2884 setting MIT as the license -> Es matriz diagonal (lista 2D) (ES)
# 594/2884 setting MIT as the license -> Encontrar palabra en sopa de letras simple (lista 2D) (ES)
# 595/2884 setting MIT as the license -> Solo caracteres de un cierto alfabeto (ES)
# 596/2884 setting MIT as the license -> Cada enesimo caracter con while (ES)
# 597/2884 setting MIT as the license -> Encontrar letra n veces con while (ES)
# 598/2884 setting MIT as the license -> Generar string de numeros repetidos con for (ES)
# 599/2884 setting MIT as the license -> Generar lista rápida de reproduccion valida (excepciones) (ES)
# 600/2884 setting MIT as the license -> Calculo: costo alojamiento (ES)
# 601/2884 setting MIT as the license -> Calculo: containers y botellas en lecheria (ES)
# 602/2884 setting MIT as the license -> Condicion: es negativo (ES)
# 603/2884 setting MIT as the license -> Condicion: es dia de fin de semana (ES)
# 604/2884 setting MIT as the license -> Condicion: nota de aprobacion (ES)
# 605/2884 setting MIT as the license -> Condicion: numero entre otros (ES)
# 606/2884 setting MIT as the license -> Condicion: pares que sumen 20 (ES)
# 607/2884 setting MIT as the license -> Condicion: al menos un numero positivo (ES)
# 608/2884 setting MIT as the license -> Determinar si numero es primo (while) (ES)
# 609/2884 setting MIT as the license -> Obtener lista de palabras desde archivo (ES)
# 610/2884 setting MIT as the license -> Calculo: Cuociente y Resto (ES)
# 611/2884 setting MIT as the license -> Caja rapida (diccionario) (ES)
# 612/2884 setting MIT as the license -> Suma segura de productos en pedido (excepciones) (ES)
# 613/2884 setting MIT as the license -> Es sopa de letras (ES)
# 614/2884 setting MIT as the license -> PCRS C3-PL  Assignment
# 615/2884 setting MIT as the license -> Estirar String (ES)
# 616/2884 setting MIT as the license -> Calculo diferencia absoluta mayor lista (ES)
# 617/2884 setting MIT as the license -> Recolectar bajo rendimiento lista (ES)
# 618/2884 setting MIT as the license -> Escalar lista notas (ES)
# 619/2884 setting MIT as the license -> PCRS C3-PL  Lastname Firstname
# 620/2884 setting MIT as the license -> PCRS C3-PL  Lastname Firstname Phonenumber
# 621/2884 setting MIT as the license -> Condicion: puede votar (ES)
# 622/2884 setting MIT as the license -> PCRS C3-PL  Name Sort
# 623/2884 setting MIT as the license -> PCRS C3-PL  Mononym
# 624/2884 setting MIT as the license -> PCRS C3-PL  Class Day
# 625/2884 setting MIT as the license -> PCRS C3-PL  Event Class
# 626/2884 setting MIT as the license -> PCRS C3-PL  Ascii Isoceles
# 627/2884 setting MIT as the license -> Obtener lineas archivo (ES)
# ...
# 2605/2884 setting MIT as the license -> Exceptions
# 2606/2884 setting MIT as the license -> SortAlgorithm
# 2607/2884 setting MIT as the license -> Rectangle
# 2608/2884 setting MIT as the license -> Multiple Variables
# 2609/2884 setting MIT as the license -> InsertSortAlgo
# 2610/2884 setting MIT as the license -> Bicycle
# 2611/2884 setting MIT as the license -> Multiple Variables 2
# 2612/2884 setting MIT as the license -> BubbleSortAlgo
# 2613/2884 setting MIT as the license -> Funcion mismo valor absoluto (ES)
# 2614/2884 setting MIT as the license -> If with complex condition
# 2615/2884 setting MIT as the license -> CallbyValue
# 2616/2884 setting MIT as the license -> Primitive Data Types
# 2617/2884 setting MIT as the license -> If Statement
# 2618/2884 setting MIT as the license -> CallbyReference
# 2619/2884 setting MIT as the license -> Type Casting
# 2620/2884 setting MIT as the license -> Else Clause
# 2621/2884 setting MIT as the license -> deferencing
# 2622/2884 setting MIT as the license -> Constants
# 2623/2884 setting MIT as the license -> Nested if
# 2624/2884 setting MIT as the license -> PointerNotation
# 2625/2884 setting MIT as the license -> Constant2
# 2626/2884 setting MIT as the license -> Using &&
# 2627/2884 setting MIT as the license -> ArraysSubscript
# 2628/2884 setting MIT as the license -> Arithmetic Operations
# 2629/2884 setting MIT as the license -> Using ||
# 2630/2884 setting MIT as the license -> PointerArrays
# 2631/2884 setting MIT as the license -> Increment
# 2632/2884 setting MIT as the license -> Switch Statement
# 2633/2884 setting MIT as the license -> PointerArrays2
# 2634/2884 setting MIT as the license -> Math Functions
# 2635/2884 setting MIT as the license -> Free Flow Switch
# 2636/2884 setting MIT as the license -> ArrayAddresses
# 2637/2884 setting MIT as the license -> Operator
# 2638/2884 setting MIT as the license -> Nested Switch
# 2639/2884 setting MIT as the license -> ArrayPointers
# 2640/2884 setting MIT as the license -> Creating String
# 2641/2884 setting MIT as the license -> Switch with Enum
# 2642/2884 setting MIT as the license -> NonConstant
# 2643/2884 setting MIT as the license -> Substring
# 2644/2884 setting MIT as the license -> Sum using While
# 2645/2884 setting MIT as the license -> NonConstPointer
# 2646/2884 setting MIT as the license -> String Length
# 2647/2884 setting MIT as the license -> While with double
# 2648/2884 setting MIT as the license -> ConstPointer
# 2649/2884 setting MIT as the license -> Decision If
# 2650/2884 setting MIT as the license -> Nested For Loop
# 2651/2884 setting MIT as the license -> ConstPointer2
# 2652/2884 setting MIT as the license -> If Else
# 2653/2884 setting MIT as the license -> Print Out a Diamond
# 2654/2884 setting MIT as the license -> BubbleSortPF
# 2655/2884 setting MIT as the license -> String Comparison
# 2656/2884 setting MIT as the license -> Infinite For
# 2657/2884 setting MIT as the license -> PrintAddress
# 2658/2884 setting MIT as the license -> Logical Operators
# 2659/2884 setting MIT as the license -> For with Multiple Variables 2
# 2660/2884 setting MIT as the license -> Boolean Declaration
# 2661/2884 setting MIT as the license -> For with Multiple Variables
# 2662/2884 setting MIT as the license -> CopyString
# 2663/2884 setting MIT as the license -> Boolean Expression
# 2664/2884 setting MIT as the license -> For with Multiple Variables 3
# 2665/2884 setting MIT as the license -> CreateFile
# 2666/2884 setting MIT as the license -> Boolean Operators
# 2667/2884 setting MIT as the license -> For omitting elements
# 2668/2884 setting MIT as the license -> ReadFromFile
# 2669/2884 setting MIT as the license -> While
# 2670/2884 setting MIT as the license -> For-Each 2
# 2671/2884 setting MIT as the license -> DoWhile
# 2672/2884 setting MIT as the license -> For-Each with ArrayList
# 2673/2884 setting MIT as the license -> atof_atoi_atol
# 2674/2884 setting MIT as the license -> For Loop
# 2675/2884 setting MIT as the license -> For-Each
# 2676/2884 setting MIT as the license -> strtod
# 2677/2884 setting MIT as the license -> Nested Loops
# 2678/2884 setting MIT as the license -> For-each with char array
# 2679/2884 setting MIT as the license -> gets_puts
# 2680/2884 setting MIT as the license -> Nested Loops2
# 2681/2884 setting MIT as the license -> Multidimensional Array Iteration
# 2682/2884 setting MIT as the license -> Array Declaration
# 2683/2884 setting MIT as the license -> For-each with break
# 2684/2884 setting MIT as the license -> strcy_strncpy
# 2685/2884 setting MIT as the license -> Using an Array1
# 2686/2884 setting MIT as the license -> relational operators
# 2687/2884 setting MIT as the license -> strcat_strncat
# 2688/2884 setting MIT as the license -> Using an Array2
# 2689/2884 setting MIT as the license -> String Example
# 2690/2884 setting MIT as the license -> strcmp_strncmp
# 2691/2884 setting MIT as the license -> Create ArrayList
# 2692/2884 setting MIT as the license -> switch
# 2693/2884 setting MIT as the license -> strlen
# 2694/2884 setting MIT as the license -> ArrayList Demo
# 2695/2884 setting MIT as the license -> Polymorphism and Inheritance 1
# 2696/2884 setting MIT as the license -> search_func
# 2697/2884 setting MIT as the license -> Wrapper Classes
# 2698/2884 setting MIT as the license -> Casting subclass
# 2699/2884 setting MIT as the license -> strtok
# 2700/2884 setting MIT as the license -> Create 2D Array
# 2701/2884 setting MIT as the license -> Polymorphism and Inheritance 2
# 2702/2884 setting MIT as the license -> upper_lower_case
# 2703/2884 setting MIT as the license -> Use 2D Array
# 2704/2884 setting MIT as the license -> A Dog is also a Pet
# 2705/2884 setting MIT as the license -> string_to_integer
# 2706/2884 setting MIT as the license -> Interface
# 2707/2884 setting MIT as the license -> Inheritance and Constructors 1
# 2708/2884 setting MIT as the license -> string_compare
# 2709/2884 setting MIT as the license -> MultiInterfaces
# 2710/2884 setting MIT as the license -> Simple Inheritance
# 2711/2884 setting MIT as the license -> tokenize1
# 2712/2884 setting MIT as the license -> Inheritance
# 2713/2884 setting MIT as the license -> search_occur
# 2714/2884 setting MIT as the license -> Override
# 2715/2884 setting MIT as the license -> word_count
# 2716/2884 setting MIT as the license -> find_string
# 2717/2884 setting MIT as the license -> defined_func1
# 2718/2884 setting MIT as the license -> defined_func2
# 2719/2884 setting MIT as the license -> string_lib_func1
# 2720/2884 setting MIT as the license -> fgetc_fputc
# 2721/2884 setting MIT as the license -> check_file
# 2722/2884 setting MIT as the license -> Objects 3 (Rectangle)
# 2723/2884 setting MIT as the license -> Objects 4 (String)
# 2724/2884 setting MIT as the license -> Objects 5 (String)
# 2725/2884 setting MIT as the license -> Class 1 (BankAccount)
# 2726/2884 setting MIT as the license -> Class 2 (BankAccount)
# 2727/2884 setting MIT as the license -> Class 3 (BankAccount)
# 2728/2884 setting MIT as the license -> Class 4 (CashRegister)
# 2729/2884 setting MIT as the license -> Class 5 (Point)
# 2730/2884 setting MIT as the license -> Using int
# 2731/2884 setting MIT as the license -> Using double
# 2732/2884 setting MIT as the license -> Using double and Math class
# 2733/2884 setting MIT as the license -> Using float
# 2734/2884 setting MIT as the license -> Converting String to int
# 2735/2884 setting MIT as the license -> Converting String to double
# 2736/2884 setting MIT as the license -> Constants 1
# 2737/2884 setting MIT as the license -> Constants 2
# 2738/2884 setting MIT as the license -> Operations with int
# 2739/2884 setting MIT as the license -> Using Math class 1
# 2740/2884 setting MIT as the license -> Using Math class 2
# 2741/2884 setting MIT as the license -> Modulus Operator
# 2742/2884 setting MIT as the license -> Increment Operator
# 2743/2884 setting MIT as the license -> Strings 1
# 2744/2884 setting MIT as the license -> Strings 2
# 2745/2884 setting MIT as the license -> Strings 3
# 2746/2884 setting MIT as the license -> Strings 4
# 2747/2884 setting MIT as the license -> Strings 5
# 2748/2884 setting MIT as the license -> Strings 6
# 2749/2884 setting MIT as the license -> if-else 1
# 2750/2884 setting MIT as the license -> if-else 2
# 2751/2884 setting MIT as the license -> if-else 3
# 2752/2884 setting MIT as the license -> if-else 4
# 2753/2884 setting MIT as the license -> if-else 5
# 2754/2884 setting MIT as the license -> Using boolean
# 2755/2884 setting MIT as the license -> Comparing Strings
# 2756/2884 setting MIT as the license -> Boolean Operations (AND)
# 2757/2884 setting MIT as the license -> Comparisons
# 2758/2884 setting MIT as the license -> Comparisons 2
# 2759/2884 setting MIT as the license -> Switch 1
# 2760/2884 setting MIT as the license -> Switch 2
# 2761/2884 setting MIT as the license -> Switch 3
# 2762/2884 setting MIT as the license -> Loop While 1
# 2763/2884 setting MIT as the license -> Loop While 2
# 2764/2884 setting MIT as the license -> Loop While 3
# 2765/2884 setting MIT as the license -> Problem 1
# 2766/2884 setting MIT as the license -> Loop While 5
# 2767/2884 setting MIT as the license -> Loop Do-While 1
# 2768/2884 setting MIT as the license -> Loop Do-While 2
# 2769/2884 setting MIT as the license -> Loop Do-While 3
# 2770/2884 setting MIT as the license -> Loop Do-While 4
# 2771/2884 setting MIT as the license -> Problem 2
# 2772/2884 setting MIT as the license -> Problem 3
# 2773/2884 setting MIT as the license -> Loop For 1
# 2774/2884 setting MIT as the license -> Loop For 2
# 2775/2884 setting MIT as the license -> Loop For 3
# 2776/2884 setting MIT as the license -> Loop For 4
# 2777/2884 setting MIT as the license -> Loop For 5
# 2778/2884 setting MIT as the license -> Nested Loops 1
# 2779/2884 setting MIT as the license -> Problem 4
# 2780/2884 setting MIT as the license -> Nested Loops 3
# 2781/2884 setting MIT as the license -> Problem 5
# 2782/2884 setting MIT as the license -> Problem 6
# 2783/2884 setting MIT as the license -> Arrays 3
# 2784/2884 setting MIT as the license -> Arrays 4
# 2785/2884 setting MIT as the license -> Arrays 5
# 2786/2884 setting MIT as the license -> ArrayList 1
# 2787/2884 setting MIT as the license -> ArrayList 2
# 2788/2884 setting MIT as the license -> ArrayList 3
# 2789/2884 setting MIT as the license -> Wrapper Classes 1
# 2790/2884 setting MIT as the license -> Wrapper Classes 2
# 2791/2884 setting MIT as the license -> Wrapper Classes 3
# 2792/2884 setting MIT as the license -> 2D Arrays 1
# 2793/2884 setting MIT as the license -> 2D Arrays 2
# 2794/2884 setting MIT as the license -> Problem 7
# 2795/2884 setting MIT as the license -> 2D Arrays 4
# 2796/2884 setting MIT as the license -> ArrayList 4
# 2797/2884 setting MIT as the license -> ArrayList 5
# 2798/2884 setting MIT as the license -> Wrapper Classes 4
# 2799/2884 setting MIT as the license -> Interfaces 1
# 2800/2884 setting MIT as the license -> Interfaces 2
# 2801/2884 setting MIT as the license -> Interfaces 3
# 2802/2884 setting MIT as the license -> Interfaces 4
# 2803/2884 setting MIT as the license -> Interfaces 5
# 2804/2884 setting MIT as the license -> Inheritance 1
# 2805/2884 setting MIT as the license -> Inheritance 2
# 2806/2884 setting MIT as the license -> Inheritance 3
# 2807/2884 setting MIT as the license -> Inheritance 4
# 2808/2884 setting MIT as the license -> Inheritance 5
# 2809/2884 setting MIT as the license -> Inheritance 6
# 2810/2884 setting MIT as the license -> Exceptions 1
# 2811/2884 setting MIT as the license -> Exceptions 2
# 2812/2884 setting MIT as the license -> Exceptions 3
# 2813/2884 setting MIT as the license -> Exceptions 4
# 2814/2884 setting MIT as the license -> Exceptions 5
# 2815/2884 setting MIT as the license -> Constants in Math class
# 2816/2884 setting MIT as the license -> Constants in CashRegister class 1
# 2817/2884 setting MIT as the license -> Constants in CashRegister class 2
# 2818/2884 setting MIT as the license -> int Variables 1
# 2819/2884 setting MIT as the license -> int Variables 2
# 2820/2884 setting MIT as the license -> int Variables 3
# 2821/2884 setting MIT as the license -> int Variables 4
# 2822/2884 setting MIT as the license -> String Variables
# 2823/2884 setting MIT as the license -> Objects 1 (Rectangle)
# 2824/2884 setting MIT as the license -> Objects 2 (Rectangle)
# 2825/2884 setting MIT as the license -> SELECT-FROM question1
# 2826/2884 setting MIT as the license -> SELECT-FROM question2
# 2827/2884 setting MIT as the license -> SELECT-FROM question3
# 2828/2884 setting MIT as the license -> SELECT-FROM question4
# 2829/2884 setting MIT as the license -> SELECT-FROM question5
# 2830/2884 setting MIT as the license -> SELECT-DISTINCT question6
# 2831/2884 setting MIT as the license -> Arithmetic Expressions question1
# 2832/2884 setting MIT as the license -> Arithmetic Expressions question2
# 2833/2884 setting MIT as the license -> Arithmetic Expressions question3
# 2834/2884 setting MIT as the license -> Arithmetic Expressions question4
# 2835/2884 setting MIT as the license -> Arithmetic Expressions question5
# 2836/2884 setting MIT as the license -> SELECT-FROM-WHERE question1
# 2837/2884 setting MIT as the license -> SELECT-FROM-WHERE question2
# 2838/2884 setting MIT as the license -> SELECT-FROM-WHERE question3
# 2839/2884 setting MIT as the license -> SELECT-FROM-WHERE question4
# 2840/2884 setting MIT as the license -> SELECT-FROM-WHERE question5
# 2841/2884 setting MIT as the license -> Pattern Matching question1
# 2842/2884 setting MIT as the license -> Pattern Matching question2
# 2843/2884 setting MIT as the license -> Pattern Matching question3
# 2844/2884 setting MIT as the license -> Pattern Matching question4
# 2845/2884 setting MIT as the license -> Pattern Matching question5
# 2846/2884 setting MIT as the license -> Multiple Table question1
# 2847/2884 setting MIT as the license -> Multiple Table question2
# 2848/2884 setting MIT as the license -> Multiple Table question3
# 2849/2884 setting MIT as the license -> Multiple Table question4
# 2850/2884 setting MIT as the license -> Multiple Table question5
# 2851/2884 setting MIT as the license -> Order-By question1
# 2852/2884 setting MIT as the license -> Order-By question2
# 2853/2884 setting MIT as the license -> Order-By question3
# 2854/2884 setting MIT as the license -> Order-By question4
# 2855/2884 setting MIT as the license -> Set Operations question1
# 2856/2884 setting MIT as the license -> Aggregate Functions question1
# 2857/2884 setting MIT as the license -> Aggregate Functions question2
# 2858/2884 setting MIT as the license -> Aggregate Functions question3
# 2859/2884 setting MIT as the license -> Aggregate Functions question4
# 2860/2884 setting MIT as the license -> Aggregate Functions question5
# 2861/2884 setting MIT as the license -> Group-By & Having question1
# 2862/2884 setting MIT as the license -> Group-By & Having question2
# 2863/2884 setting MIT as the license -> Group-By & Having question3
# 2864/2884 setting MIT as the license -> Group-By & Having question4
# 2865/2884 setting MIT as the license -> Group-By & Having question5
# 2866/2884 setting MIT as the license -> Sub-Queries question1
# 2867/2884 setting MIT as the license -> Sub-Queries question2
# 2868/2884 setting MIT as the license -> Sub-Queries question3
# 2869/2884 setting MIT as the license -> Sub-Queries question4
# 2870/2884 setting MIT as the license -> Sub-Queries question5
# 2871/2884 setting MIT as the license -> fig04_05.c
# 2872/2884 setting MIT as the license -> Calculate_profit
# 2873/2884 setting MIT as the license -> Array of Char
# 2874/2884 setting MIT as the license -> CharReferencing
# 2875/2884 setting MIT as the license -> character_functions
# 2876/2884 setting MIT as the license -> getchar()
# 2877/2884 setting MIT as the license -> ascII_char
# 2878/2884 setting MIT as the license -> IS12:: f2c_table.c (4.5)
# 2879/2884 setting MIT as the license -> IS12:: nicer_f2c_table.c (4.6)
# 2880/2884 setting MIT as the license -> IS12:: capitaltable.c (4.9)
# 2881/2884 setting MIT as the license -> IS12:: count_char.c (6.1)
# 2882/2884 setting MIT as the license -> IS12:: char_codes.c (6.2)
# 2883/2884 setting MIT as the license -> IS12:: starchart.c (12.1)
