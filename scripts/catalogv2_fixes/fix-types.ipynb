# %%
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()

# %%
# api_token = open('api_token.txt').read().strip()
# for index, item in enumerate(catalog):
#     type = item['identity']['type'].strip()
#     old_type = type
#     provider = item['attribution']['provider']
#     if (
#         type == 'Question' and provider in ['PCRS','CodeWorkout','CodeCheck','CodeOcean','CodeLab','SQL-Knot']
#     ) or (type in ['PCRS','SQL-Knot']):
#         type = 'FreeCodingProblems'
#     elif type == 'Question' and provider in ['QuizJET','QuizPET']:
#         type = 'PredictingFinalResult'
#     elif type in ['Question','Parsons Problem'] and provider in ['jsParsons']:
#         type = 'ParsonsProblem'
#     elif type == 'PCEX Challenge':
#         type = 'CodeCompletionProblem'
#     elif type == 'PCEX Set':
#         type = 'CodeConstruction'
#     elif provider == 'WebEx' and item['content']['prompt']:
#         type = 'CodeConstruction'
#     elif provider == 'WebEx' and not item['content']['prompt']:
#         type = 'BehaviorExample'
#     elif type == 'Animated Example' and provider in ['JSVEE','DBQA']:
#         type = 'CodeVisualization'

#     if type == old_type:
#         continue

#     item = requests.get(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}",
#         headers={'api-token': api_token}
#     ).json()
#     item['identity']['type'] = type

#     response = requests.patch(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{item['id']}",
#         json=item,
#         headers={'api-token': api_token}
#     )
#     print(f'{index}/{len(catalog)}:[{response.status_code}]', item['identity']['title'])
# Out:
# 0/2934:[200] Sub-Queries question5
# 1/2934:[200] Sub-Queries question4
# 2/2934:[200] Sub-Queries question3
# 3/2934:[200] Sub-Queries question2
# 4/2934:[200] Sub-Queries question1
# 5/2934:[200] Group-By & Having question5
# 6/2934:[200] Group-By & Having question4
# 7/2934:[200] Group-By & Having question3
# 8/2934:[200] Group-By & Having question2
# 9/2934:[200] Group-By & Having question1
# 10/2934:[200] Aggregate Functions question5
# 11/2934:[200] Aggregate Functions question4
# 12/2934:[200] Aggregate Functions question3
# 13/2934:[200] Aggregate Functions question2
# 14/2934:[200] Aggregate Functions question1
# 15/2934:[200] Set Operations question1
# 16/2934:[200] Order-By question4
# 17/2934:[200] Order-By question3
# 18/2934:[200] Order-By question2
# 19/2934:[200] Order-By question1
# 20/2934:[200] Multiple Table question5
# 21/2934:[200] Multiple Table question4
# 22/2934:[200] Multiple Table question3
# 23/2934:[200] Multiple Table question2
# ...
