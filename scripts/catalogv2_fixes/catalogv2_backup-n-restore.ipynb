# %%
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()
for index, item in enumerate(catalog):
    print(f'{index}/{len(catalog)}:', item['identity']['title'])
    item = requests.get(f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}").json()
    json.dump(item, open(f"items/{item['id']}.json", 'w'), indent=2)
# Out:
# 0/3404: c_max_number
# 1/3404: c_grading
# 2/3404: c_pritisak
# 3/3404: c_mjeseci
# 4/3404: Kontrola toka programa
# 5/3404: c_faktorijeli (while petlja)
# 6/3404: c_ispis_unazad (while petlja)
# 7/3404: While petlja
# 8/3404: c_puni_kvadrat
# 9/3404: c_faktorijeli (for petlja)
# 10/3404: c_ispis_unazad (for petlja)
# 11/3404: For petlja
# 12/3404: c_decimalni_ispis
# 13/3404: c_ispisi_sa_sirinom_preciznosti_i_vodecim_nulama
# 14/3404: c_ispisi
# 15/3404: c_ispisi_sa_sirinom_i_preciznosti
# 16/3404: Formatirani ispisi
# 17/3404: c_hello_world_redovi
# 18/3404: c_hello_world
# 19/3404: Uvod
# 20/3404: c_ostatak_pri_dijeljenju
# 21/3404: c_dijeljenje
# 22/3404: c_farenhajt_celzijus_konverzija
# 23/3404: c_celzijus_farenhajt_konverzija
# 24/3404: c_polovine
# 25/3404: Izrazi
# 26/3404: Executing statements sequentially
# 27/3404: Print using variables
# 28/3404: Sequential Execution
# 29/3404: c_selection_sort
# 30/3404: Selection sort
# 31/3404: c_prebacivanje_u_drugi_niz
# 32/3404: c_unos_niza_while
# 33/3404: c_unos_niza_s_prekidom
# 34/3404: Unos i prebacivanje elemenata niza
# 35/3404: c_ispis_sporedna_dijagonala
# 36/3404: c_max_array
# 37/3404: c_unos_matrice
# 38/3404: c_min_array
# 39/3404: c_ispis_glavna_dijagonala
# 40/3404: Unos i obrada nizova i matrica
# 41/3404: c_funkcija_suma_kolicnika
# 42/3404: c_funkcija_stepenuj
# 43/3404: c_funkcija_pozdrav
# 44/3404: c_kubiraj
# 45/3404: Funkcije i izrazi
# 46/3404: c_funkcija_djeljiv_sa
# 47/3404: c_funkcija_djeljiv_sa_3
# 48/3404: c_funkcija_djelitelji
# 49/3404: Funkcije i djeljivost
# 50/3404: c_proizvod_elemenata_na_dijagonalama_neparan
# 51/3404: c_proizvod_elemenata_na_dijagonalama
# 52/3404: c_elementi_ispod_glavne_dijagonale
# 53/3404: c_ispis_iznad_glavne_dijagonale
# 54/3404: c_ispis_ispod_sporedne_dijagonale
# 55/3404: Rad sa dijagonalama matrica
# 56/3404: c_mnozenje_reda_iznad
# 57/3404: c_sabiranje_kolona
# 58/3404: c_dijeljenje_reda
# 59/3404: Aritmeticke operacije nad redovima i kolonama matrice
# 60/3404: c_max_elementi_kolona
# 61/3404: c_zbir_elemenata_u_kolonama
# 62/3404: c_zbir_elemenata_u_redovima
# 63/3404: c_srednja_vrijednost_matrice
# 64/3404: Operacije nad elementima matrice
# 65/3404: c_zamjena_kolona_dva_mjesta_dalje
# 66/3404: c_zamjena_redova
# 67/3404: c_zamjena_dva_reda
# 68/3404: c_zamjena_dvije_kolone
# 69/3404: Zamjena redova i kolona
# 70/3404: c_pokazivaci_min_max
# 71/3404: c_zamjena_pomocu_pokazivaca
# 72/3404: Pokazivaci kao parametri u funkcijama
# 73/3404: c_pokazivaci_dodjela_i_ispis
# 74/3404: c_vrijednosti_u_pokazivacima_int
# 75/3404: c_vrijednosti_u_pokazivacima
# 76/3404: Adrese i dodjela vrijednosti pokazivacima
# 77/3404: c_promjena_vrijednosti_preko_pokazivaca_2
# 78/3404: c_pokazivaci_dereferenciranje_int
# 79/3404: c_promjena_vrijednosti_preko_pokazivaca
# 80/3404: Dereferenciranje pokazivaca
# 81/3404: c_pokazivaci_pomjeranje_kroz_niz_i_manipulacija
# 82/3404: c_pokazivaci_pomjeranje_kroz_niz
# 83/3404: c_pokazivaci_manipulacija_clanova_niza
# 84/3404: Pokazivacka aritmetika
# 85/3404: c_unos_broja_i_karaktera
# 86/3404: c_unos_karaktera_za_karakterom
# 87/3404: c_unos_karaktera_getchar
# 88/3404: Unos karaktera
# 89/3404: c_trazenje_karaktera_u_stringu
# 90/3404: c_unos_niza_karaktera
# 91/3404: c_niz_karaktera_brojanje_samoglasnika
# 92/3404: Nizovi karaktera
# 93/3404: c_trazenje_karaktera_u_stringu_pokazivaci
# 94/3404: c_pokazivaci_na_karaktere_brojanje_samoglasnika
# 95/3404: Pokazivaci na karaktere
# 96/3404: c_brojanje_rijeci_s_velikim_pocetnim_slovom
# 97/3404: c_brojanje_rijeci_razmaci
# 98/3404: c_brojanje_rijeci_alfanumericki
# 99/3404: Detektovanje granica unutar stringa
# 100/3404: c_zamjena_svakog_drugog_znaka
# 101/3404: c_pretvaranje_broja_u_slovo
# 102/3404: Mijenjanje karaktera u stringu
# 103/3404: c_brisanje_samoglasnika
# 104/3404: c_izbacivanje_nte_rijeci
# 105/3404: c_izbacivanje_svakog_ntog_karaktera
# 106/3404: Brisanje dijelova stringa
# 107/3404: c_spajanje_dva_stringa
# 108/3404: c_ubacivanje_rijeci
# 109/3404: Ubacivanje karaktera u string
# 110/3404: c_funkcija_nadji_rijec
# 111/3404: c_funkcija_prebroji_znak
# 112/3404: c_funkcija_uporedi_stringove
# 113/3404: Slanje stringova u funkcije
# 114/3404: c_funkcija_ukloni_razmake
# 115/3404: c_funkcija_podstring
# 116/3404: Vracanje pokazivaca na karaktere iz funkcija
# 117/3404: Linked List Operations - Size 2
# 118/3404: Linked List Operations - Size 1
# 119/3404: Linked List Implementation
# 120/3404: Linked List Implementation - 1
# 121/3404: Linked List Operations - Contains
# 122/3404: Linked List Implementation
# 123/3404: Linked List Implementation - 2
# 124/3404: Queue Class - Check if Element Exists
# 125/3404: Queue Class - Check if Element Exists
# 126/3404: Queue
# 127/3404: Binary Search - 1
# 128/3404: Binary Search - 1
# 129/3404: Binary Search
# 130/3404: Binary Search - 2
# 131/3404: Binary Search - 2
# 132/3404: Binary Search - Recursive
# 133/3404: c_datoteke_brojanje_rijeci_s_velikim_pocetnim_slovom
# 134/3404: c_datoteke_brojanje_redova_rijeci_znakova
# 135/3404: Citanje sadrzaja tekstualnih datoteka karakter po karakter
# 136/3404: c_upis_stringa_u_datoteku
# 137/3404: c_kopiranje_karaktera_u_datoteku
# 138/3404: Upis u tekstualne datoteke karakter po karakter
# 139/3404: c_formatirane_datoteke_citanje_brojeva_i_stringa
# 140/3404: c_formatirane_datoteke_citanje_broja_i_stringa
# 141/3404: Citanje sadrzaja formatiranih tekstualnih datoteka
# 142/3404: c_formatirane_datoteke_upis_sa_decimalama
# 143/3404: c_formatirane_datoteke_upis_broja_i_stringa
# 144/3404: Upis u formatirane tekstualne datoteke
# 145/3404: c_makro_max_broj
# 146/3404: c_makro_kvadrat_broja
# 147/3404: Makro naredbe
# 148/3404: c_upis_reda_na_kraj_datoteke
# 149/3404: c_upis_na_kraj_datoteke
# 150/3404: c_upis_broja_karaktera_na_kraj_datoteke
# 151/3404: Izmjena tekstualnih datoteka
# 152/3404: c_citanje_iz_txt_challenge
# 153/3404: c_citanje_struktura_iz_datoteka
# 154/3404: Citanje struktura iz tekstualnih datoteka
# 155/3404: c_citanje_iz_bin_datoteke_challenge
# 156/3404: c_citanje_podatka_iz_bin_datoteke
# 157/3404: c_citanje_iz_bin_datoteke
# 158/3404: Citanje iz binarnih datoteka
# 159/3404: c_pisanje_u_datoteke_challenge
# 160/3404: c_pisanje_u_datoteke
# 161/3404: Unos struktura u tekstualne datoteke
# 162/3404: c_pisanje_u_binarne_datoteke_challenge
# 163/3404: c_pisanje_podatka_u_binarnu_datoteku
# 164/3404: c_pisanje_u_binarne_datoteke
# 165/3404: Pisanje u binarne datoteke
# 166/3404: c_citanja_izmjena_koristenjem_kursora_challenge
# 167/3404: c_citanje_izmjena_datoteka_koristenjem_kursora
# 168/3404: Rad s kursorom u tekstualnim datotekama
# 169/3404: c_izmjena_binarnih_datoteka_challenge
# 170/3404: c_izmjena_binarnih_datoteka
# 171/3404: Append i read-update mod za binarne datoteke
# 172/3404: c_strukture_i_nizovi_challenge
# 173/3404: c_strukture_i_nizovi_pokazivaci
# 174/3404: c_strukture_i_nizovi
# 175/3404: Nizovi u strukturama i nizovi struktura
# 176/3404: c_strukture_unos_ispis_studenta_challenge
# 177/3404: c_unos_i_ispis_proizvoda
# 178/3404: c_unos_i_ispis_datuma
# 179/3404: c_strukture
# 180/3404: Unos i ispis struktura
# 181/3404: c_strukture_funkcija_pravougaonik
# 182/3404: c_strukture_funkcije_sredina_tacaka
# 183/3404: Funkcije i strukture
# 184/3404: c_strukture_funkcija_pravougaonik_pokazivaci
# 185/3404: c_strukture_funkcije_sredina_tacaka_s_pokazivacima
# 186/3404: c_strukture_s_pokazivacima
# 187/3404: Funkcije i strukture s pokazivacima
# 188/3404: c_dinamicka_alokacija_varijabli_challenge
# 189/3404: c_dinamicka_alokacija_varijable_malloc
# 190/3404: c_dinamicka_alokacija_varijable_calloc
# 191/3404: Dinamicka alokacija obicnih varijabli
# 192/3404: c_dinamicka_alokacija_nizova_challenge
# 193/3404: c_dinamicka_alokacija_niza_malloc
# 194/3404: c_dinamicka_alokacija_niza_calloc
# 195/3404: Dinamicka alokacija nizova
# 196/3404: codecheck-python-StringsNumbersInStrings-1
# 197/3404: codecheck-python-StringsNumbersInStrings-3
# 198/3404: codecheck-python-StringsNumbersInStrings-2
# 199/3404: codecheck-python-LoopingOvertheEntireArray-12
# 200/3404: codecheck-python-LoopingOvertheEntireArray-9
# 201/3404: codecheck-python-LoopingOvertheEntireArray-1
# 202/3404: codecheck-python-LoopingOvertheEntireArray-11
# 203/3404: codecheck-python-LoopingOvertheEntireArray-3
# 204/3404: codecheck-python-LoopingOvertheEntireArray-4
# 205/3404: codecheck-python-LoopingOvertheEntireArray-5
# 206/3404: codecheck-python-LoopingOvertheEntireArray-13
# 207/3404: codecheck-python-LoopingOvertheEntireArray-6
# 208/3404: codecheck-python-LoopingOvertheEntireArray-2
# 209/3404: codecheck-python-LoopingOvertheEntireArray-10
# 210/3404: codecheck-python-LoopingOvertheEntireArray-8
# 211/3404: codecheck-python-LoopingOvertheEntireArray-7
# 212/3404: codecheck-python-StringWords-1
# 213/3404: codecheck-python-StringWords-3
# 214/3404: codecheck-python-StringWords-4
# 215/3404: codecheck-python-StringWords-2
# 216/3404: codecheck-python-MaximumandMinimum-1
# 217/3404: codecheck-python-MaximumandMinimum-3
# 218/3404: codecheck-python-MaximumandMinimum-4
# 219/3404: codecheck-python-MaximumandMinimum-5
# 220/3404: codecheck-python-MaximumandMinimum-6
# 221/3404: codecheck-python-MaximumandMinimum-2
# 222/3404: codecheck-python-MaximumandMinimum-7
# 223/3404: codecheck-python-ComplexLoops-1
# 224/3404: codecheck-python-ComplexLoops-3
# 225/3404: codecheck-python-ComplexLoops-4
# 226/3404: codecheck-python-ComplexLoops-5
# 227/3404: codecheck-python-ComplexLoops-6
# 228/3404: codecheck-python-ComplexLoops-2
# 229/3404: codecheck-python-LoopingoverNeighbors-1
# 230/3404: codecheck-python-LoopingoverNeighbors-3
# 231/3404: codecheck-python-LoopingoverNeighbors-4
# 232/3404: codecheck-python-LoopingoverNeighbors-5
# 233/3404: codecheck-python-LoopingoverNeighbors-2
# 234/3404: codecheck-python-StringsNoLoops-1
# 235/3404: codecheck-python-StringsNoLoops-3
# 236/3404: codecheck-python-StringsNoLoops-4
# 237/3404: codecheck-python-StringsNoLoops-5
# 238/3404: codecheck-python-StringsNoLoops-2
# 239/3404: codecheck-python-ArraysNoLoops-1
# 240/3404: codecheck-python-ArraysNoLoops-3
# 241/3404: codecheck-python-ArraysNoLoops-4
# 242/3404: codecheck-python-ArraysNoLoops-2
# 243/3404: codecheck-python-SumsAveragesProducts-14
# 244/3404: codecheck-python-SumsAveragesProducts-12
# 245/3404: codecheck-python-SumsAveragesProducts-9
# 246/3404: codecheck-python-SumsAveragesProducts-1
# 247/3404: codecheck-python-SumsAveragesProducts-11
# 248/3404: codecheck-python-SumsAveragesProducts-3
# 249/3404: codecheck-python-SumsAveragesProducts-4
# 250/3404: codecheck-python-SumsAveragesProducts-5
# 251/3404: codecheck-python-SumsAveragesProducts-13
# 252/3404: codecheck-python-SumsAveragesProducts-6
# 253/3404: codecheck-python-SumsAveragesProducts-2
# 254/3404: codecheck-python-SumsAveragesProducts-10
# 255/3404: codecheck-python-SumsAveragesProducts-8
# 256/3404: codecheck-python-SumsAveragesProducts-7
# 257/3404: codecheck-python-Producing2DArrays-1
# 258/3404: codecheck-python-Producing2DArrays-3
# 259/3404: codecheck-python-Producing2DArrays-4
# 260/3404: codecheck-python-Producing2DArrays-5
# 261/3404: codecheck-python-Producing2DArrays-6
# 262/3404: codecheck-python-Producing2DArrays-2
# 263/3404: codecheck-python-Producing2DArrays-7
# 264/3404: codecheck-python-OtherStringOperations-9
# 265/3404: codecheck-python-OtherStringOperations-1
# 266/3404: codecheck-python-OtherStringOperations-3
# 267/3404: codecheck-python-OtherStringOperations-4
# 268/3404: codecheck-python-OtherStringOperations-5
# 269/3404: codecheck-python-OtherStringOperations-6
# 270/3404: codecheck-python-OtherStringOperations-2
# 271/3404: codecheck-python-OtherStringOperations-8
# 272/3404: codecheck-python-OtherStringOperations-7
# 273/3404: codecheck-python-FunctionsWithDecisions-9
# 274/3404: codecheck-python-FunctionsWithDecisions-1
# 275/3404: codecheck-python-FunctionsWithDecisions-3
# 276/3404: codecheck-python-FunctionsWithDecisions-4
# 277/3404: codecheck-python-FunctionsWithDecisions-5
# 278/3404: codecheck-python-FunctionsWithDecisions-6
# 279/3404: codecheck-python-FunctionsWithDecisions-2
# 280/3404: codecheck-python-FunctionsWithDecisions-8
# 281/3404: codecheck-python-FunctionsWithDecisions-7
# 282/3404: codecheck-python-TwoAnswers-1
# 283/3404: codecheck-python-TwoAnswers-3
# 284/3404: codecheck-python-TwoAnswers-4
# 285/3404: codecheck-python-TwoAnswers-5
# 286/3404: codecheck-python-TwoAnswers-2
# 287/3404: codecheck-python-FillingArrays-1
# 288/3404: codecheck-python-FillingArrays-3
# 289/3404: codecheck-python-FillingArrays-4
# 290/3404: codecheck-python-FillingArrays-5
# 291/3404: codecheck-python-FillingArrays-2
# 292/3404: codecheck-python-Branches-12
# 293/3404: codecheck-python-Branches-9
# 294/3404: codecheck-python-Branches-1
# 295/3404: codecheck-python-Branches-11
# 296/3404: codecheck-python-Branches-3
# 297/3404: codecheck-python-Branches-4
# 298/3404: codecheck-python-Branches-5
# 299/3404: codecheck-python-Branches-13
# 300/3404: codecheck-python-Branches-6
# 301/3404: codecheck-python-Branches-2
# 302/3404: codecheck-python-Branches-10
# 303/3404: codecheck-python-Branches-8
# 304/3404: codecheck-python-Branches-7
# 305/3404: codecheck-python-MovingorRemovingElements-1
# 306/3404: codecheck-python-MovingorRemovingElements-3
# 307/3404: codecheck-python-MovingorRemovingElements-4
# 308/3404: codecheck-python-MovingorRemovingElements-5
# 309/3404: codecheck-python-MovingorRemovingElements-6
# 310/3404: codecheck-python-MovingorRemovingElements-2
# 311/3404: codecheck-python-LoopsAlongaRoworColumn-9
# 312/3404: codecheck-python-LoopsAlongaRoworColumn-1
# 313/3404: codecheck-python-LoopsAlongaRoworColumn-11
# 314/3404: codecheck-python-LoopsAlongaRoworColumn-3
# 315/3404: codecheck-python-LoopsAlongaRoworColumn-4
# 316/3404: codecheck-python-LoopsAlongaRoworColumn-5
# 317/3404: codecheck-python-LoopsAlongaRoworColumn-6
# 318/3404: codecheck-python-LoopsAlongaRoworColumn-2
# 319/3404: codecheck-python-LoopsAlongaRoworColumn-10
# 320/3404: codecheck-python-LoopsAlongaRoworColumn-8
# 321/3404: codecheck-python-LoopsAlongaRoworColumn-7
# 322/3404: codecheck-python-FindingElements-1
# 323/3404: codecheck-python-FindingElements-3
# 324/3404: codecheck-python-FindingElements-4
# 325/3404: codecheck-python-FindingElements-5
# 326/3404: codecheck-python-FindingElements-6
# 327/3404: codecheck-python-FindingElements-2
# 328/3404: codecheck-python-DoubleLoops-1
# 329/3404: codecheck-python-DoubleLoops-3
# 330/3404: codecheck-python-DoubleLoops-4
# 331/3404: codecheck-python-DoubleLoops-5
# 332/3404: codecheck-python-DoubleLoops-6
# 333/3404: codecheck-python-DoubleLoops-2
# 334/3404: codecheck-python-DoubleLoops-8
# 335/3404: codecheck-python-DoubleLoops-7
# 336/3404: codecheck-python-StringsFindingSubstrings-1
# 337/3404: codecheck-python-StringsFindingSubstrings-3
# 338/3404: codecheck-python-StringsFindingSubstrings-4
# 339/3404: codecheck-python-StringsFindingSubstrings-5
# 340/3404: codecheck-python-StringsFindingSubstrings-2
# 341/3404: codecheck-python-2DArraysNoLoops-1
# 342/3404: codecheck-python-2DArraysNoLoops-3
# 343/3404: codecheck-python-2DArraysNoLoops-4
# 344/3404: codecheck-python-2DArraysNoLoops-5
# 345/3404: codecheck-python-2DArraysNoLoops-6
# 346/3404: codecheck-python-2DArraysNoLoops-2
# 347/3404: codecheck-python-2DArraysNoLoops-8
# 348/3404: codecheck-python-2DArraysNoLoops-7
# 349/3404: codecheck-python-StringsComparingStrings-1
# 350/3404: codecheck-python-StringsComparingStrings-3
# 351/3404: codecheck-python-StringsComparingStrings-2
# 352/3404: codecheck-python-CountingElements-9
# 353/3404: codecheck-python-CountingElements-1
# 354/3404: codecheck-python-CountingElements-3
# 355/3404: codecheck-python-CountingElements-4
# 356/3404: codecheck-python-CountingElements-5
# 357/3404: codecheck-python-CountingElements-6
# 358/3404: codecheck-python-CountingElements-2
# 359/3404: codecheck-python-CountingElements-10
# 360/3404: codecheck-python-CountingElements-8
# 361/3404: codecheck-python-CountingElements-7
# 362/3404: Sub-Queries question5
# 363/3404: Sub-Queries question4
# 364/3404: Sub-Queries question3
# 365/3404: Sub-Queries question2
# 366/3404: Sub-Queries question1
# 367/3404: Group-By & Having question5
# 368/3404: Group-By & Having question4
# 369/3404: Group-By & Having question3
# 370/3404: Group-By & Having question2
# 371/3404: Group-By & Having question1
# 372/3404: Aggregate Functions question5
# 373/3404: Aggregate Functions question4
# 374/3404: Aggregate Functions question3
# 375/3404: Aggregate Functions question2
# 376/3404: Aggregate Functions question1
# 377/3404: Set Operations question1
# 378/3404: Order-By question4
# 379/3404: Order-By question3
# 380/3404: Order-By question2
# 381/3404: Order-By question1
# 382/3404: Multiple Table question5
# 383/3404: Multiple Table question4
# 384/3404: Multiple Table question3
# 385/3404: Multiple Table question2
# 386/3404: Multiple Table question1
# 387/3404: Pattern Matching question5
# 388/3404: Pattern Matching question4
# 389/3404: Pattern Matching question3
# 390/3404: Pattern Matching question2
# 391/3404: Pattern Matching question1
# 392/3404: SELECT-FROM-WHERE question5
# 393/3404: SELECT-FROM-WHERE question4
# 394/3404: SELECT-FROM-WHERE question3
# 395/3404: SELECT-FROM-WHERE question2
# 396/3404: SELECT-FROM-WHERE question1
# 397/3404: Arithmetic Expressions question5
# 398/3404: Arithmetic Expressions question4
# 399/3404: Arithmetic Expressions question3
# 400/3404: Arithmetic Expressions question2
# 401/3404: Arithmetic Expressions question1
# 402/3404: SELECT-DISTINCT question6
# 403/3404: SELECT-FROM question5
# 404/3404: SELECT-FROM question4
# 405/3404: SELECT-FROM question3
# 406/3404: SELECT-FROM question2
# 407/3404: SELECT-FROM question1
# 408/3404: SELECT-FROM-WHERE question6
# 409/3404: SELECT-FROM-WHERE question9
# 410/3404: SELECT-FROM-WHERE question8
# 411/3404: SELECT-FROM-WHERE question7
# 412/3404: Arithmetic Expressions question3
# 413/3404: Arithmetic Expressions question2
# 414/3404: Arithmetic Expressions question1
# 415/3404: SELECT-DISTINCT question6
# 416/3404: SELECT-FROM question5
# 417/3404: SELECT-FROM question4
# 418/3404: SELECT-FROM question3
# 419/3404: SELECT-FROM question2
# 420/3404: SELECT-FROM question1
# 421/3404: Multiple Table question4
# 422/3404: Multiple Table question3
# 423/3404: Multiple Table question2
# 424/3404: Multiple Table question1
# 425/3404: Pattern Matching question5
# 426/3404: Pattern Matching question4
# 427/3404: Pattern Matching question3
# 428/3404: Pattern Matching question2
# 429/3404: Pattern Matching question1
# 430/3404: SELECT-FROM-WHERE question5
# 431/3404: SELECT-FROM-WHERE question4
# 432/3404: SELECT-FROM-WHERE question3
# 433/3404: SELECT-FROM-WHERE question2
# 434/3404: SELECT-FROM-WHERE question1
# 435/3404: Arithmetic Expressions question5
# 436/3404: Arithmetic Expressions question4
# 437/3404: Group-By & Having question4
# 438/3404: Group-By & Having question3
# 439/3404: Group-By & Having question2
# 440/3404: Group-By & Having question1
# 441/3404: Aggregate Functions question5
# 442/3404: Aggregate Functions question4
# 443/3404: Aggregate Functions question3
# 444/3404: Aggregate Functions question2
# 445/3404: Aggregate Functions question1
# 446/3404: Set Operations question1
# 447/3404: Order-By question4
# 448/3404: Order-By question3
# 449/3404: Order-By question2
# 450/3404: Order-By question1
# 451/3404: Multiple Table question5
# 452/3404: SELECT-FROM-WHERE question9
# 453/3404: SELECT-FROM-WHERE question8
# 454/3404: SELECT-FROM-WHERE question7
# 455/3404: SELECT-FROM-WHERE question6
# 456/3404: Sub-Queries question5
# 457/3404: Sub-Queries question4
# 458/3404: Sub-Queries question3
# 459/3404: Sub-Queries question2
# 460/3404: Sub-Queries question1
# 461/3404: Group-By & Having question5
# 462/3404: Set Operations question3
# 463/3404: Set Operations question2
# 464/3404: Set Operations question5
# 465/3404: Set Operations question4
# 466/3404: Arithmetic-expressions query execution 1
# 467/3404: Subqueries query execution 1
# 468/3404: Group-by-having query execution 1
# 469/3404: Aggregate-functions query execution 1
# 470/3404: Order-by query execution 1
# 471/3404: Pattern-matching query execution 1
# 472/3404: Select-from query execution 1
# 473/3404: Multiple-table-queries execution 1
# 474/3404: Select-from-where query execution 1
# 475/3404: Group-by-having query execution 4
# 476/3404: Group-by-having query execution 3
# 477/3404: Group-by-having query execution 2
# 478/3404: Aggregate-functions query execution 4
# 479/3404: Aggregate-functions query execution 3
# 480/3404: Aggregate-functions query execution 2
# 481/3404: Order-by query execution 4
# 482/3404: Order-by query execution 3
# 483/3404: Order-by query execution 2
# 484/3404: Pattern-matching query execution 4
# 485/3404: Pattern-matching query execution 3
# 486/3404: Pattern-matching query execution 2
# 487/3404: Select-from query execution 4
# 488/3404: Select-from query execution 3
# 489/3404: Select-from query execution 2
# 490/3404: Multiple-table-queries execution 4
# 491/3404: Multiple-table-queries execution 3
# 492/3404: Multiple-table-queries execution 2
# 493/3404: Select-from-where query execution 4
# 494/3404: Select-from-where query execution 3
# 495/3404: Select-from-where query execution 2
# 496/3404: Arithmetic-expressions query execution 4
# 497/3404: Arithmetic-expressions query execution 3
# 498/3404: Arithmetic-expressions query execution 2
# 499/3404: Subqueries query execution 4
# 500/3404: Subqueries query execution 3
# 501/3404: Subqueries query execution 2
# 502/3404: Join query execution 1
# 503/3404: Join query execution 4
# 504/3404: Join query execution 3
# 505/3404: Join query execution 2
# 506/3404: Arithmetic-expressions query execution 6
# 507/3404: Arithmetic-expressions query execution 5
# 508/3404: Join question1
# 509/3404: Join question2
# 510/3404: LEFT-JOIN question2
# 511/3404: LEFT-JOIN question1
# 512/3404: Inner-join query execution 1
# 513/3404: Left-join query execution 1
# 514/3404: Left-join query execution 4
# 515/3404: Left-join query execution 3
# 516/3404: Left-join query execution 2
# 517/3404: Inner-join query execution 4
# 518/3404: Inner-join query execution 3
# 519/3404: Inner-join query execution 2
# 520/3404: Seconds to Minutes Conversion
# 521/3404: Converting Milliseconds to Hours-Minutes- and Seconds
# 522/3404: Seconds to Minutes Conversion
# 523/3404: Converting Milliseconds to Hours-Minutes- and Seconds
# 524/3404: Seconds to Minutes Conversion
# 525/3404: Converting Milliseconds to Hours-Minutes- and Seconds.
# 526/3404: Vending Machine With Dollars and Quarters
# 527/3404: Vending Machine With Quarters-Dimes- and Nickels
# 528/3404: Vending Machine With Dollars and Quarters
# 529/3404: Vending Machine With Quarters-Dimes- and Nickels
# 530/3404: Printing Common Elements in Two Arrays
# 531/3404: Printing the Total Number of Times Elements of One Array Appear in Another Array
# 532/3404: Creating an array that Contains the Numbers of Times Each Element of One Array Appears in Another Array
# 533/3404: Determining When to Buy a New Phone (Case 1)
# 534/3404: Determining When to Buy a New Phone (Case 2)
# 535/3404: Printing Consecutive Numbers Starting from Zero (Case 1)
# 536/3404: Printing Consecutive Numbers Starting from Zero (Case 2)
# 537/3404: Pythagorean Theorem (Case 1)
# 538/3404: Pythagorean Theorem (Case 2)
# 539/3404: Finding the Smallest Divisor of a Positive Number
# 540/3404: Finding the Largest Divisor of a Positive Number
# 541/3404: Accessing String Characters (Case 1)
# 542/3404: Accessing String Characters (Case 2)
# 543/3404: The Class for Representing a Bank Account (Case 1)
# 544/3404: The Class for Representing a Bank Account (Case 2)
# 545/3404: The Class for Representing a TV (Case 1)
# 546/3404: The Class for Representing a TV (Case 2)
# 547/3404: The Class for Representing a Loan (Case 1)
# 548/3404: The Class for Representing a Loan (Case 2)
# 549/3404: Creating a List of Words from a File
# 550/3404: Comparing the List of Words from Two Files
# 551/3404: Creating an Array of Odd Numbers
# 552/3404: Creating an Array of User Inputs
# 553/3404: Increment/Decrement Operators (Case 1)
# 554/3404: Increment/Decrement Operators (Case 2)
# 555/3404: Increment/Decrement Operators (Case 3)
# 556/3404: String Concatenation (Case 1)
# 557/3404: String Concatenation (Case 2)
# 558/3404: Determining When a Customer Could Rent a Car (Case 1)
# 559/3404: Determining When a Customer Could Rent a Car (Case 2)
# 560/3404: Determining When a Customer Could Rent a Car (Case 3)
# 561/3404: String Comparison (Case 1)
# 562/3404: String Comparison (Case 2)
# 563/3404: Calculating the Sum of the Values in an Array
# 564/3404: Calculating the Average of the Values in the Array
# 565/3404: Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 1)
# 566/3404: Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 2)
# 567/3404: Calculating the Winning Percentage of a Sports Team (Case 1)
# 568/3404: Calculating the Winning Percentage of a Sports Team (Case 2)
# 569/3404: Calculating the Winning Percentage of a Sports Team (Case 3)
# 570/3404: Updating an Element in the Array (Case 1)
# 571/3404: Updating an Element in the Array (Case 2)
# 572/3404: Updating an Element in the Array (Case 3)
# 573/3404: Modifying an Array (Case 1)
# 574/3404: Modifying an Array (Case 2)
# 575/3404: Printing Name Initials
# 576/3404: Printing Full Name with Middle Initial
# 577/3404: Printing Name in APA Style
# 578/3404: Warning the User about the Changes in the Temperature
# 579/3404: Warning the User about the Changes in the Temperature and Humidity
# 580/3404: Determining the Smallest of the Three Integers
# 581/3404: Determining the Largest of the Three Integers
# 582/3404: Printing Table of Medal Winner Counts with Row Totals
# 583/3404: Printing Table of Medal Winner Counts with Row and Column Totals
# 584/3404: Vending Machine With Dollars and Quarters
# 585/3404: Vending Machine With Quarters-Dimes- and Nickels
# 586/3404: Celsius To Fahrenheit Conversion
# 587/3404: Fahrenheit to Celsius Conversion
# 588/3404: Determining When at Least One of the Three Boolean Variables is True
# 589/3404: Determining When at Least One of the Three Boolean Variables is False
# 590/3404: Determining When All Three Boolean Variables Are Equal
# 591/3404: Determining the Letter Grade Of a Student
# 592/3404: Converting the Letter Grade of a Student to Its Numeric Range
# 593/3404: The Class for Representing a Point in the Euclidean Plane (Case 1)
# 594/3404: The Class for Representing a Point in the Euclidean Plane (Case 2)
# 595/3404: Printing the Squares of Numbers Within a Specified Range (Case 1)
# 596/3404: Printing the Squares of Numbers Within a Specified Range (Case 2)
# 597/3404: Printing the Squares of Numbers Within a Specified Range (Case 3)
# 598/3404: Calculating the Employees Wage Based on the Hours That the Employee Has Worked and an Hourly Pay Rate
# 599/3404: Calculating the Wage of an Employee at the Customer Service Call Center
# 600/3404: Counting the Number of Valid and Banned Product Codes (Case 1)
# 601/3404: Counting the Number of Valid and Banned Product Codes (Case 2)
# 602/3404: Determining Whether One is a Teenager (Case 1)
# 603/3404: Determining Whether One is a Teenager (Case 2)
# 604/3404: Printing A Right Triangle Star Pattern
# 605/3404: Printing an Inverted Right Triangle Star Pattern
# 606/3404: Point Class Hierarchy (Case 1)
# 607/3404: Point Class Hierarchy (Case 2)
# 608/3404: Animal Class Hierarchy (Case 1)
# 609/3404:  Animal Class Hierarchy (Case 2)
# 610/3404: Finding the Number of Days Above the Average Temperature
# 611/3404: Displaying the Days That are Above 32 Degrees Fahrenheit
# 612/3404: Reporting File Information (Case 1)
# 613/3404: Reporting File Information (Case 2)
# 614/3404: Calculating the Average of Input Integers
# 615/3404: Calculating the Average of the Input Integers that are an Even Number
# 616/3404: Calculating the Average of Floating-Point Numbers
# 617/3404: Determining When a Student Fails a Course (Case 1)
# 618/3404: Determining When a Student Fails a Course (Case 2)
# 619/3404: Determining When a Student Fails a Course (Case 3)
# 620/3404: Printing Digits of an Integer from Right to Left
# 621/3404: The Digit Sum of an Integer
# 622/3404: Reversing the Digits of an Integer
# 623/3404: Finding Adjacent Duplicates in a Sequence of Numbers
# 624/3404: Finding Adjacent Consecutive Numbers in a Sequence of Integers
# 625/3404: Finding Adjacent Numbers in Ascending Order in a Sequence of Numbers
# 626/3404: Rotating the Array Values to the Left by One Position
# 627/3404: Rotating the Array Values to the Left by Two Position
# 628/3404: Rotating the Array Values to the Right by One Position
# 629/3404: Rotating the List Values to the Right by Two Position
# 630/3404: Calculating Body Mass Index (BMI)
# 631/3404: Calculating and Rounding Up Body Mass Index (BMI) To the Nearest Integer
# 632/3404: Updating Two-Dimensional Array (Case 1)
# 633/3404: Updating Two-Dimensional Array (Case 2)
# 634/3404: Updating Two-Dimensional Array (Case 3)
# 635/3404: Determining the Sign of an Integer
# 636/3404: Determining Whether an Integer is Even or Odd
# 637/3404: Receiving Input Integers Until a Certain Condition is Met (Case 1)
# 638/3404: Receiving Input Integers Until a Certain Condition is Met (Case 2)
# 639/3404: Receiving Input Integers Until a Certain Condition is Met (Case 3)
# 640/3404: Receiving Input Integers Until a Certain Condition is Met (Case 4)
# 641/3404: String With Escape Characters (Case 1)
# 642/3404: String With Escape Characters (Case 2)
# 643/3404: String With Escape Characters (Case 3)
# 644/3404: Determining the Weather Condition (Case 1)
# 645/3404: Determining the Weather Condition (Case 2)
# 646/3404: Determining the Weather Condition (Case 3)
# 647/3404: Determining the Weather Condition (Case 4)
# 648/3404: Determining the Maximum Rating for Each Soda in The Survey
# 649/3404: Determining the Average Rating for Each Soda in The Survey
# 650/3404: Determining the Average Ratings of each Respondent and Average Ratings Given to Each Soda in the Survey
# 651/3404: Printing Consecutive Numbers Within a Specified Range (Case 1)
# 652/3404: Printing Consecutive Numbers Within a Specified Range (Case 2)
# 653/3404: Seconds to Minutes Conversion
# 654/3404: Converting Milliseconds to Hours-Minutes- and Seconds
# 655/3404: Finding the Minimum Value in an Array
# 656/3404: Finding the Maximum Value in an Array
# 657/3404: Printing A Sequence of Repeated Numbers (Case 1)
# 658/3404: Printing A Sequence of Repeated Numbers (Case 2)
# 659/3404: Reporting the Total Hours Each Employee Worked (Case 1)
# 660/3404: Reporting the Total Hours Each Employee Worked (Case 2)
# 661/3404: Herencia de Persona y Empleado
# 662/3404: Informacion de Herencia de Persona y Empleado
# 663/3404: Mostrando los Dias que Estan por Sobre el Promedio de Temperatura
# 664/3404: Mostrando los Dias que Estan por Sobre 32 Grados Fahrenheit
# 665/3404: Concatenando Caracteres de Dos Strings (Caso 1)
# 666/3404: Concatenando Caracteres de Dos Strings (Caso 2).
# 667/3404: Imprimir Tabla de Conteo de Medallas con Totales por Fila
# 668/3404: Imprimir Tabla de Conteo de Medallas con Totales por Fila y por Columna
# 669/3404: Determinando Si Uno Es Adolescente (Caso 1)
# 670/3404: Determinando Si Uno Es Adolescente (Caso 2)
# 671/3404: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 1)
# 672/3404: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 2)
# 673/3404: Informe de Informacion del Archivo (Caso 1)
# 674/3404: Informar Informacion del Archivo (Caso 2)
# 675/3404: Contando las Ocurrencias de un String en Otro (Caso 1)
# 676/3404: Contando las Ocurrencias de un String en Otro (Caso 2).
# 677/3404: Calculo del Indice de Masa Corporal (IMC)
# 678/3404: Calculo y Redondeo del Indice de Masa Corporal (IMC) al Entero Mas Cercano.
# 679/3404: La Clase para Representar un Prestamo (Caso 1)
# 680/3404: La Clase para Representar un Prestamo (Caso 2)
# 681/3404: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 1)
# 682/3404: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 2)
# 683/3404: Determinando Cuando Comprar un Nuevo Telefono (Caso 1)
# 684/3404: Determinando Cuando Comprar un Nuevo Telefono (Caso 2)
# 685/3404: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 1)
# 686/3404: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 2)
# 687/3404: Creando un Diccionario de Pares Caracteres-Frecuencia
# 688/3404: Creando un Diccionario de Pares Caracteres-Palabras
# 689/3404: Desplazando los Valores de la Lista a la Izquierda Una Posicion
# 690/3404: Desplazando los Valores de la Lista a la Izquierda Dos Posiciones
# 691/3404: Desplazando los Valores de la Lista a la Derecha una Posicion
# 692/3404: Desplazando los Valores de la Lista a la Derecha Dos Posiciones
# 693/3404: Pasar Valores
# 694/3404: Pasar Valores
# 695/3404: Maquina Expendedora Con Dolares y Monedas de Veinticinco
# 696/3404: Maquina Expendedora Con Monedas de diferentes centavos
# 697/3404: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo
# 698/3404: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo Invertido
# 699/3404: Encontrar el Divisor Mas Pequeno de un Numero Positivo
# 700/3404: Encontrar el Mayor Divisor de un Numero Positivo
# 701/3404: testing_um2_student_average_arun_ch
# 702/3404: JSON ITERATION 1
# 703/3404: Calculando el Porcentaje de Victorias de un Equipo (Caso 1)
# 704/3404: Calculando el Porcentaje de Victorias de un Equipo (Caso 2)
# 705/3404: Calculando el Porcentaje de Victorias de un Equipo (Caso 3)
# 706/3404: Advertir al Usuario sobre los Cambios en la Temperatura
# 707/3404: Advertir al Usuario sobre los Cambios en la Temperatura y Humedad.
# 708/3404: Funcion con Multiples Parametros
# 709/3404: Funcion con Multiples Parametros Llamando Otra
# 710/3404: Pythagorean Theorem (Case 1)
# 711/3404: Pythagorean Theorem (Case 2)
# 712/3404: testing_um2_student_average_arun_ch
# 713/3404: testing_um2_student_average_arun_ex
# 714/3404: testing_um2_arun_java_SLR_weat_ex
# 715/3404: testing_um2_arun_java_SLR_weat_ch
# 716/3404: CopyFileTo
# 717/3404: PrintFileContent
# 718/3404: Calcular promedio de dos numeros enteros (ES)
# 719/3404: Calcular factura mensual (ES)
# 720/3404: Calcular los segundos en n dias (ES)
# 721/3404: Condicion: es impar (ES)
# 722/3404: Contar Mayusculas (ES)
# 723/3404: Mayusculas o Minusculas (ES)
# 724/3404: Contar no digitos (ES)
# 725/3404: Todo Esponjoso (ES)
# 726/3404: Indice Menor (ES)
# 727/3404: Primer Par (ES)
# 728/3404: Triangulo Ascii (ES)
# 729/3404: Contar Digitos (ES)
# 730/3404: Factor menor (ES)
# 731/3404: Contar Pasos Collatz (ES)
# 732/3404: Solo Dos Verdaderos (p2-4-ES)
# 733/3404: Solo Uno Verdadero (p1-4-ES)
# 734/3404: Listas de enteros pares (ES)
# 735/3404: Encontrar el indice de el string mas largo (ES)
# 736/3404: Intercambiar primero y ultimo
# 737/3404: Contar el numero de valores que estan por encima del promedio (ES)
# 738/3404: Suma digital (ES)
# 739/3404: Programa usual primero (CC)
# 740/3404: Ciclo for anidado
# 741/3404: Calculo rebanadas de pizza (ES)
# 742/3404: Condicion: es adolescente (ES)
# 743/3404: Dia siguiente
# 744/3404: Maximo de tres enteros (ES)
# 745/3404: Calculo galletas necesarias (ES)
# 746/3404: Calcular su suma y producto
# 747/3404: Practicar el uso de la biblioteca math y comprobar el tipo de una variable
# 748/3404: Practicar la manipulación de variables y verificar sus tipos
# 749/3404: Practicar ciclos while anidados
# 750/3404: Practicar el uso de ciclos while y for anidados
# 751/3404: Practicar herencia de clases
# 752/3404: Manipulación de diccionarios
# 753/3404: Cálculos con diccionarios
# 754/3404: Valores y referencias en listas
# 755/3404: Practicar la búsqueda del índice del elemento mínimo
# 756/3404: Practicar la búsqueda del índice de los elementos mínimo y máximo
# 757/3404: Construir un programa que cree una estructura de pila (Stack)
# 758/3404: Construir una función que use una estructura de cola (Queue)
# 759/3404: Construir una función que recorra una lista enlazada
# 760/3404: Construir una función que verifique el tamaño de una lista enlazada
# 761/3404: Construir una función que ordene un arreglo numérico usando Merge Sort
# 762/3404: Practicar el algoritmo de ordenación rápida (Quick Sort)
# 763/3404: Construir una función de recorrido inorder (inorden)
# 764/3404: Imprimir hola mundo
# 765/3404: Crear una función que imprima hola mundo
# 766/3404: Crear una función que reciba un número, le sume dos y lo devuelva
# 767/3404: Crear una función que devuelva el mayor de dos números
# 768/3404: Practicar el orden de líneas para obtener el número correcto
# 769/3404: Crear un programa con un ciclo while
# 770/3404: Crear un programa que compare un valor en un ciclo
# 771/3404: Crear y llamar a una función
# 772/3404: Crear múltiples funciones y llamadas de función anidadas
# 773/3404: Crear una función recursiva
# 774/3404: Crear una clase y utilizarla
# 775/3404: Crear una función y usar el operador módulo
# 776/3404: Iterar sobre una lista
# 777/3404: Practicar indexación de listas
# 778/3404: Practicar el corte de cadenas (slicing)
# 779/3404: Iterar sobre un diccionario
# 780/3404: Acceder a los valores de un diccionario
# 781/3404: Convertir una lista de tuplas en un diccionario
# 782/3404: Iterar sobre elementos (items) de un diccionario
# 783/3404: Usar expresiones booleanas como parámetros de una función
# 784/3404: Practicar sentencias if...elif...else
# 785/3404: Practicar leer un archivo e imprimir su contenido
# 786/3404: Practicar el manejo de excepciones
# 787/3404: Practicar sentencias if anidadas
# 788/3404: Practicar el uso de comparaciones
# 789/3404: Practicar indexación y modificación de listas
# 790/3404: Practicar la asignación de variables
# 791/3404: Crear una compuerta XOR usando sentencias if...elif
# 792/3404: Practicar iterar sobre una lista y usar módulo
# 793/3404: Practicar métodos de cadenas
# 794/3404: Practicar el manejo de excepciones
# 795/3404: Crear una clase y usar sus métodos
# 796/3404: Construir un programa que trabaje con listas
# 797/3404: Construir un problema con ciclos anidados
# 798/3404: Construir un programa que genere combinaciones únicas de 3 dígitos
# 799/3404: Construir un programa que genere combinaciones únicas de 3 dígitos
# 800/3404: Construir un programa con múltiples sentencias if-elif
# 801/3404: Construir un programa con múltiples sentencias if-elif
# 802/3404: Construir un programa con múltiples sentencias if-elif
# 803/3404: Frecuencia de letras
# 804/3404: Frecuencia de letras
# 805/3404: Crear una función que verifique si una cadena es un palíndromo o no
# 806/3404: Crear una función que verifique si una cadena es un palíndromo o no
# 807/3404: Crear una función que verifique si una cadena es un palíndromo o no
# 808/3404: Construir una función que determine si una cadena dada como parámetro es un palíndromo
# 809/3404: Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 810/3404: Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 811/3404: Invertir la lista
# 812/3404: Invertir la lista
# 813/3404: Invertir la lista
# 814/3404: Invertir la lista
# 815/3404: Invertir la lista
# 816/3404: Invertir la lista
# 817/3404: Invertir la lista
# 818/3404: Invertir la lista
# 819/3404: Verificar si la suma de dos enteros es igual al tercer entero
# 820/3404: Verificar si la suma de dos enteros es igual al tercer entero
# 821/3404: Actualizar elementos en una nueva lista
# 822/3404: Actualizar elementos necesarios en una nueva lista
# 823/3404: Actualizar los elementos en una nueva lista
# 824/3404: Actualizar los elementos en una nueva lista
# 825/3404: Actualizar elementos necesarios en una nueva lista
# 826/3404: Actualizar elementos necesarios en una nueva lista
# 827/3404: Cálculo de potencias
# 828/3404: Cálculo de potencias
# 829/3404: Calcular una potencia
# 830/3404: Calcular una potencia
# 831/3404: Calcular una potencia
# 832/3404: Calcular una potencia
# 833/3404: Eliminar duplicados de una lista
# 834/3404: Eliminar duplicados de una lista
# 835/3404: Reorganizar la lista
# 836/3404: Reorganizar la lista
# 837/3404: Reorganizar la lista
# 838/3404: Reorganizar la lista
# 839/3404: Practicar la lectura de archivos e imprimir el tercer elemento de cada línea
# 840/3404: Binary Search Algorithm Slideshow
# 841/3404: Binary Search recurrence slideshow
# 842/3404: BST Search Slideshow
# 843/3404: BST Insert Slideshow
# 844/3404: BST deletemax Slideshow
# 845/3404: BST remove Slideshow
# 846/3404: PosetCON
# 847/3404: Binary Search Proficiency Exercise
# 848/3404: BST Search Proficiency Exercise
# 849/3404: BST Question Summary
# 850/3404: Self-organizing List Move-to-front Proficiency Exercise
# 851/3404: Insertion Sort Slideshow
# 852/3404: Insertion Sort Worst Case Slideshow
# 853/3404: Insertion Sort Best Case Slideshow
# 854/3404: Insertion Sort Average Case Slideshow
# 855/3404: Bubble Sort Slideshow 1
# 856/3404: Bubble Sort Slideshow 2
# 857/3404: Bubble Sort Analysis Slideshow
# 858/3404: Selection Sort Slideshow 1
# 859/3404: Selection Sort Slideshow 2
# 860/3404: Selection Sort Analysis Slideshow
# 861/3404: Exchange Sort Analysis Slideshow
# 862/3404: Shellsort Slideshow 1
# 863/3404: Shellsort Slideshow 2
# 864/3404: Shellsort Slideshow 3
# 865/3404: Shellsort Slideshow 4
# 866/3404: Shellsort Slideshow 5
# 867/3404: Shellsort Slideshow 6
# 868/3404: Merging Slideshow
# 869/3404: Mergesort Analysis Slideshow
# 870/3404: Mergesort Implementation Slideshow 1
# 871/3404: Mergesort Implementation Slideshow 2
# 872/3404: Quicksort Partition Slideshow
# 873/3404: Quicksort Partition Analysis Slideshow
# 874/3404: Quicksort Worst Case Analysis Slideshow
# 875/3404: Quicksort Best Case Analysis Slideshow
# 876/3404: Quicksort Average Case Analysis Slideshow
# 877/3404: Heapsort Slideshow
# 878/3404: Heapsort Analysis Slideshow
# 879/3404: Binsort Slideshow 1
# 880/3404: Binsort Slideshow 2
# 881/3404: Radix Sort Analysis Slideshow
# 882/3404: Sorting Lower Bound Slideshow
# 883/3404: Selection Sort Pointer Swap
# 884/3404: Sorting Terminology and Notation Slideshow 1
# 885/3404: Sorting Problem
# 886/3404: Pair to Sorting Reduction Slideshow
# 887/3404: Sorting to Pairing Reduction Slideshow
# 888/3404: Record Comparison Summary Exercise
# 889/3404: Sorting Intro Summary
# 890/3404: Insertion Sort Proficiency Exercise
# 891/3404: Insertion Sort Summary Exercise
# 892/3404: Bubble Sort Proficiency Exercise
# 893/3404: Bubble Sort Summary Exercise
# 894/3404: Selection Sort Proficiency Exercise
# 895/3404: Selection Sort Summary Exercise
# 896/3404: Inversions Proficiency Exercise
# 897/3404: Exchange Sorting Summary Exercise
# 898/3404: Shellsort Sublist Proficency Exercise
# 899/3404: Shellsort Series Exercise
# 900/3404: Shellsort Summary Exercise
# 901/3404: Mergesort Merging Proficiency Exercise
# 902/3404: Mergesort Summary Exercise
# 903/3404: Quicksort Pivot Proficiency Exercise
# 904/3404: Quicksort Partition Proficiency Exercise
# 905/3404: Quicksort Summary Exercise
# 906/3404: Heapsort RemoveMax Proficiency Exercise
# 907/3404: Heapsort Summary Exercise
# 908/3404: Radix Sort Proficiency Exercise
# 909/3404: Radix Sort Summary Exercise
# 910/3404: Sort Comparison Summary Exercise
# 911/3404: Lower Bounds Summary Exercise
# 912/3404: Sorting Chapter Summary Exercise
# 913/3404: JLinkedListUtil Challenge
# 914/3404: JLinkedListUtil
# 915/3404:  Recursively calculate the power of a number Challenge
# 916/3404:  Recursively calculate the power of a number
# 917/3404: Recursively calculate the sum of all numbers from 1 to n Challenge
# 918/3404: Recursively calculate the sum of all numbers from 1 to n
# 919/3404: q_java_q_py_slinkedlist1
# 920/3404: q_java_q_py_dlinkedlist1
# 921/3404: Merge LinkList - NFB
# 922/3404: (Recursion) Power calculation - NFB
# 923/3404: (Recursion) Sum from 1 to n - NFB
# 924/3404: Recursive addition of characters - NFB
# 925/3404: Traverse LinkedList - NFB
# 926/3404: LinkedList repeated two lists - NFB
# 927/3404: Compare Two LinkedList - NFB
# 928/3404: Compare Two LinkedList
# 929/3404: Linked List 1
# 930/3404: Use Recursion to calculate power
# 931/3404: Use Recursion to calculate total sum of all numbers from 1 to N.
# 932/3404: PCRS C3-PL Reverse dictionary
# 933/3404: PCRS C3-PL Recursive counting
# 934/3404: PCRS C3-PL Bracket validation
# 935/3404: PCRS C3-PL  Find N Letters
# 936/3404: PCRS C3-PL  Event Class
# 937/3404: PCRS C3-PL  Total Slices
# 938/3404: PCRS C3-PL  List Insert
# 939/3404: PCRS C3-PL  Reverse Lookup
# 940/3404: PCRS C3-PL  Realestate Class
# 941/3404: PCRS C3-PL  Ipod Class
# 942/3404: PCRS C3-PL  Rectangle Class
# 943/3404: PCRS C3-PL  Special List Class
# 944/3404: PCRS C3-PL  Can Pay With Two Coins
# 945/3404: PCRS C3-PL  Add Underscores
# 946/3404: PCRS C3-PL  Class Day Calendar
# 947/3404: PCRS C3-PL  Double
# 948/3404: PCRS C3-PL  Our Maximum
# 949/3404: PCRS C3-PL  Max Of Min
# 950/3404: PCRS C3-PL  Caculate Tax
# 951/3404: PCRS C3-PL  Same Abs
# 952/3404: PCRS C3-PL  Upper Lower
# 953/3404: PCRS C3-PL  Overdue Fees
# 954/3404: PCRS C3-PL  Different Types
# 955/3404: PCRS C3-PL  Every Second Line
# 956/3404: PCRS C3-PL  Get Words
# 957/3404: PCRS C3-PL  Context To Next Words
# 958/3404: PCRS C3-PL  Calendar Event3
# 959/3404: PCRS C3-PL  User Class1
# 960/3404: PCRS C3-PL  User Day
# 961/3404: PCRS C3-PL  Adjacent Match
# 962/3404: PCRS C3-PL  Duplicate Cut
# 963/3404: PCRS C3-PL  Student By Degree
# 964/3404: PCRS C3-PL  Has Last Token
# 965/3404: PCRS C3-PL  Context Not Unique Hashtags
# 966/3404: PCRS C3-PL  Non Intersecting
# 967/3404: PCRS C3-PL  Eligible
# 968/3404: PCRS C3-PL  Return Indices
# 969/3404: PCRS C3-PL  Reorganize
# 970/3404: PCRS C3-PL  Reorder By Hashtag
# 971/3404: PCRS C3-PL  Valid
# 972/3404: PCRS C3-PL  Valid Dna
# 973/3404: PCRS C3-PL  Item Catalog Class
# 974/3404: PCRS C3-PL  Somecode
# 975/3404: PCRS C3-PL  My Max
# 976/3404: PCRS C3-PL  Compute Sum
# 977/3404: PCRS C3-PL  Unique Integer
# 978/3404: PCRS C3-PL  Compute Product
# 979/3404: PCRS C3-PL  Hello World
# 980/3404: PCRS C3-PL  Hello World Name
# 981/3404: PCRS C3-PL  Shift Char
# 982/3404: PCRS C3-PL  Unshift Char
# 983/3404: PCRS C3-PL  A Before B
# 984/3404: PCRS C3-PL  Less Than Ten
# 985/3404: PCRS C3-PL  Positive Less Than Ten
# 986/3404: PCRS C3-PL  In Between
# 987/3404: PCRS C3-PL  Sum Twenty
# 988/3404: PCRS C3-PL  Exactly One Positive
# 989/3404: PCRS C3-PL  Exactly One Positive2
# 990/3404: PCRS C3-PL  Is Prime
# 991/3404: PCRS C3-PL  Max In Group
# 992/3404: PCRS C3-PL  Counta
# 993/3404: PCRS C3-PL  Countx
# 994/3404: PCRS C3-PL  Replace1
# 995/3404: PCRS C3-PL  Replacec
# 996/3404: PCRS C3-PL  Replacex
# 997/3404: PCRS C3-PL  Replace Between Index
# 998/3404: PCRS C3-PL  Is In
# 999/3404: PCRS C3-PL  Is Not In
# 1000/3404: PCRS C3-PL  Dna Pairs
# 1001/3404: PCRS C3-PL  Dna Base Pairs
# 1002/3404: PCRS C3-PL  Count Genes
# 1003/3404: PCRS C3-PL  Between Two Genes
# 1004/3404: PCRS C3-PL  Sum List
# 1005/3404: PCRS C3-PL  List Average
# 1006/3404: PCRS C3-PL  Max In List
# 1007/3404: PCRS C3-PL  Greater Than Ten
# 1008/3404: PCRS C3-PL  Sum Greater Than N
# 1009/3404: PCRS C3-PL  Return Max Index
# 1010/3404: PCRS C3-PL  Longest String
# 1011/3404: PCRS C3-PL  Count Longer
# 1012/3404: PCRS C3-PL  Num Above Average
# 1013/3404: PCRS C3-PL  Count Number Seven
# 1014/3404: PCRS C3-PL  Count Nm
# 1015/3404: PCRS C3-PL  Count Nmmn
# 1016/3404: PCRS C3-PL  Count Nums
# 1017/3404: PCRS C3-PL  Num Greater At Index
# 1018/3404: PCRS C3-PL  Is Sorted
# 1019/3404: PCRS C3-PL  Postfix
# 1020/3404: PCRS C3-PL  Closed Interval
# 1021/3404: PCRS C3-PL  Merge Sort
# 1022/3404: PCRS C3-PL  Recurse Converge
# 1023/3404: PCRS C3-PL  Alert Weekend
# 1024/3404: PCRS C3-PL  Positive Two Digits
# 1025/3404: PCRS C3-PL  Two Params True One
# 1026/3404: PCRS C3-PL  Negative If Zero
# 1027/3404: PCRS C3-PL  Continent
# 1028/3404: PCRS C3-PL  Avocados
# 1029/3404: PCRS C3-PL  Two Params True
# 1030/3404: PCRS C3-PL Simple int comparison
# 1031/3404: PCRS C3-PL Is char half alphabet
# 1032/3404: PCRS C3-PL Is char lowercase
# 1033/3404:  PCRS C3-PL Is teenager
# 1034/3404: PCRS C3-PL If can drink
# 1035/3404: PCRS C3-PL Is candyshop open
# 1036/3404: PCRS C3-PL Within five
# 1037/3404: PCRS C3-PL  Loan
# 1038/3404: PCRS C3-PL  Utilties
# 1039/3404: PCRS C3-PL  List Insert
# 1040/3404: Busqueda Inversa de Telefono (ES)
# 1041/3404: PCRS C3-PL  Realestate Class
# 1042/3404: PCRS C3-PL  Ipod Class
# 1043/3404: PCRS C3-PL  Rectangle Class
# 1044/3404: PCRS C3-PL  Special List Class
# 1045/3404: PCRS C3-PL  Can Pay With Two Coins
# 1046/3404: Agregar guiones bajos a string (ES)
# 1047/3404: PCRS C3-PL  Class Day Calendar
# 1048/3404: PCRS C3-PL  Double
# 1049/3404: PCRS C3-PL  Our Maximum
# 1050/3404: Funcion maximo de los minimos valores (ES)
# 1051/3404: Funcion calculo impuesto (ES)
# 1052/3404: PCRS C3-PL  Same Abs
# 1053/3404: PCRS C3-PL  Different Types
# 1054/3404: Cada segunda linea en archivo (ES)
# 1055/3404: PCRS C3-PL  Calendar Event3
# 1056/3404: PCRS C3-PL  User Class1
# 1057/3404: PCRS C3-PL  User Day
# 1058/3404: PCRS C3-PL  Duplicate Cut
# 1059/3404: PCRS C3-PL  Has Last Token
# 1060/3404: PCRS C3-PL  Context Not Unique Hashtags
# 1061/3404: PCRS C3-PL  Non Intersecting
# 1062/3404: PCRS C3-PL  Return Indices
# 1063/3404: Reorganizar diccionario (ES)
# 1064/3404: PCRS C3-PL  Item Catalog Class
# 1065/3404: PCRS C3-PL  Somecode
# 1066/3404: PCRS C3-PL  My Max
# 1067/3404: PCRS C3-PL  Compute Sum
# ...
# 2845/3404: String Concat
# 2846/3404: Strings (Concatenation)
# 2847/3404: Strings (parse)
# 2848/3404: Strings (replace)
# 2849/3404: Strings (charAt)
# 2850/3404: Using Math Class (ceil)
# 2851/3404: Using Math Class (abs)
# 2852/3404: Pre Decrement
# 2853/3404: Post Decrement
# 2854/3404: Post Increment
# 2855/3404: Compound Assignment
# 2856/3404: Combining Assignment and Arithmetic
# 2857/3404: Decrement
# 2858/3404: Simple Variable Test
# 2859/3404: println Test
# 2860/3404: int Variables 4
# 2861/3404: int Variable 1
# 2862/3404: Print Tester
# 2863/3404: Variable Demo
# 2864/3404: Hello Printer
# 2865/3404: check_file2
# 2866/3404: count_occur
# 2867/3404: pointer_seq_file
# 2868/3404: pointer_seq_file2
# 2869/3404: create_seq_file
# 2870/3404: read_seq_file
# 2871/3404: update_credit_prog
# 2872/3404: pass_file
# 2873/3404: structs1
# 2874/3404: rand_access_file
# 2875/3404: write_info_rand_file
# 2876/3404: IS12:: helloworld.c (1.1)
# 2877/3404: IS12:: printing.c (2)
# 2878/3404: IS12:: printing1.c (2.1)
# 2879/3404: IS12:: printing2.c (2.2)
# 2880/3404: IS12:: calculating1.c (2.3)
# 2881/3404: IS12:: calculating2.c (2.4)
# 2882/3404: IS12:: variables.c (3.1)
# 2883/3404: IS12:: exchange_kiosk.c (3.11)
# 2884/3404: IS12:: better_kiosk.c (3.2)
# 2885/3404: IS12:: capital.c (3.3)
# 2886/3404: IS12:: fahr_input.c (3.4)
# 2887/3404: IS12:: countdown1.c (4.1)
# 2888/3404: IS12:: countdown2.c (4.2)
# 2889/3404: IS12:: capitalyears.c (4.3)
# 2890/3404: IS12:: factorial.c (4.4)
# 2891/3404: IS12:: accumulator.c (4.7)
# 2892/3404: IS12:: apples_kids.c (4.8)
# 2893/3404: IS12:: max2.c (5.1)
# 2894/3404: IS12:: max1.c (5.2)
# 2895/3404: IS12:: rate2.c (5.3)
# 2896/3404: IS12:: maxloop.c (5.4)
# 2897/3404: IS12:: max3.c (5.5)
# 2898/3404: IS12:: line_count.c (6.4)
# 2899/3404: IS12:: better_copycat.c (6.5)
# 2900/3404: IS12:: copycat.c (6.6)
# 2901/3404: IS12:: arraysum.c (9.1)
# 2902/3404: IS12:: arraymax.c (9.2)
# 2903/3404: IS12:: arraymin.c (9.3)
# 2904/3404: IS12:: babyweighting.c (9.4)
# 2905/3404: IS12:: digcount.c (10.1)
# 2906/3404: IS12:: sumarfunc.c (10.2)
# 2907/3404: IS12:: power.c (10.3)
# 2908/3404: IS12:: longestline.c (12.2)
# 2909/3404: IS12:: patternsearch.c (12.3)
# 2910/3404: IS12:: str2int.c (12.4)
# 2911/3404: IS12:: goodswap.c (14.1)
# 2912/3404: IS12:: strcomp.c (14.2)
# 2913/3404: IS12:: battleship.c (15.1)
# 2914/3404: IS12:: yearday.c (15.2)
# 2915/3404: IS12:: printback.c (15.3)
# 2916/3404: IS12:: betterbattle.c (15.4)
# 2917/3404: IS12:: recfactorial.c (24.1)
# 2918/3404: IS12:: recpower.c (24.2)
# 2919/3404: IS12:: insummax.c (111.1)
# 2920/3404: IS12:: parampass.c (111.2)
# 2921/3404: IS12:: palindrome.c (111.3)
# 2922/3404: IS12:: qpa.c (117.1)
# 2923/3404: IS12:: rate3.c (117.2)
# 2924/3404: IS12:: encrypt.c (117.3)
# 2925/3404: IS12:: qpa_or.c (117.4)
# 2926/3404: IS12:: qpa_and.c (117.5)
# 2927/3404: IS12:: av_line_while.c (118.1)
# 2928/3404: IS12:: av_line_for.c (118.2)
# 2929/3404: IS12:: f2c_for.c (118.3)
# 2930/3404: IS12:: abcounting.c (118.4)
# 2931/3404: IS12:: abcounting_case.c (118.5)
# 2932/3404: IS12:: wc.c (118.6)
# 2933/3404: IS12:: nondigits.c (118.7)
# 2934/3404: IS12:: arrayio.c (119.1)
# 2935/3404: IS12:: arrayiofor.c (119.2)
# 2936/3404: IfElse_Structure
# 2937/3404: private
# 2938/3404: fig02_01.c
# 2939/3404: fig02_03.c
# 2940/3404: fig02_04.c
# 2941/3404: fig02_05.c
# 2942/3404: fig02_13.c
# 2943/3404: fig03_06.c
# 2944/3404: fig03_08.c
# 2945/3404: fig03_10.c
# 2946/3404: fig03_13.c
# 2947/3404: fig04_01.c
# 2948/3404: fig04_02.c
# 2949/3404: fig04_06.c
# 2950/3404: fig04_07.c
# 2951/3404: fig04_09.c
# 2952/3404: fig04_11.c
# 2953/3404: fig04_12.c
# 2954/3404: fig05_03.c
# 2955/3404: fig05_04.c
# 2956/3404: fig05_07.c
# 2957/3404: fig05_08.c
# 2958/3404: fig05_09.c
# 2959/3404: fig05_10.c
# 2960/3404: fig05_12.c
# 2961/3404: fig05_14.c
# 2962/3404: fig05_15.c
# 2963/3404: fig06_03.c
# 2964/3404: fig06_04.c
# 2965/3404: fig06_05.c
# 2966/3404: fig06_06.c
# 2967/3404: fig06_07.c
# 2968/3404: fig06_08.c
# 2969/3404: fig06_09.c
# 2970/3404: fig06_10.c
# 2971/3404: fig06_11.c
# 2972/3404: fig06_12.c
# 2973/3404: fig06_13.c
# 2974/3404: fig06_14.c
# 2975/3404: fig06_15.c
# 2976/3404: fig06_16.c
# 2977/3404: fig06_18.c
# 2978/3404: fig06_19.c
# 2979/3404: fig06_21.c
# 2980/3404: fig06_22.c
# 2981/3404: fig07_04.c
# 2982/3404: fig07_06.c
# 2983/3404: fig07_07.c
# 2984/3404: fig07_10.c
# 2985/3404: fig07_11.c
# 2986/3404: fig07_12.c
# 2987/3404: fig07_13.c
# 2988/3404: fig07_14.c
# 2989/3404: Table Creation
# 2990/3404: fig07_15.c
# 2991/3404: Primary Key (1)
# 2992/3404: fig07_16.c
# 2993/3404: Primary Key and Unique Key
# 2994/3404: fig07_17.c
# 2995/3404: Foriegn Key
# 2996/3404: fig07_20.cpp
# 2997/3404: Table Drop
# 2998/3404: fig07_21.c
# 2999/3404: Column Addition
# 3000/3404: fig07_24.c
# 3001/3404: Column Drop
# 3002/3404: fig07_26.c
# 3003/3404: Inserting Data (1)
# 3004/3404: fig07_28.c
# 3005/3404: Deleting Data
# 3006/3404: Binary_Expressions
# 3007/3404: Selecting One Attribute
# 3008/3404: precedence_expression
# 3009/3404: Selecting Multiple Attributes
# 3010/3404: precedence_expr
# 3011/3404: Selecting All Attributes
# 3012/3404: complex_expr
# 3013/3404: Skipping Duplicates
# 3014/3404: IncDec_Oper
# 3015/3404: Aggregate Functions (1)
# 3016/3404: compound_assign
# 3017/3404: Selection Condition
# 3018/3404: casting_num
# 3019/3404: Comparison Condition (1)
# 3020/3404: 1stprogram
# 3021/3404: Comparison Condition (2)
# 3022/3404: printf
# 3023/3404: Comparison Condition (3)
# 3024/3404: input_print
# 3025/3404: Multiple Table Selection (1)
# 3026/3404: decimal_value
# 3027/3404: Multiple Comparisons (1)
# 3028/3404: avg_score
# 3029/3404: Check Constraint (1)
# 3030/3404: CH3_printf1
# 3031/3404: Check Constraint (2)
# 3032/3404: CH3_printf2
# 3033/3404: Assertion Creation (1)
# 3034/3404: CH3_printf3
# 3035/3404: Inserting Data (2)
# 3036/3404: Inserting Data (3)
# 3037/3404: Coin_Values
# 3038/3404: Inserting Data (4)
# 3039/3404: IncDec
# 3040/3404: Updating Data (2)
# 3041/3404: If
# 3042/3404: Updating Data (3)
# 3043/3404: while_structure
# 3044/3404: Updating Data (1)
# 3045/3404: Sentinel_value
# 3046/3404: Updating with condition
# 3047/3404: Sales
# 3048/3404: Updating with subquery
# 3049/3404: Payroll
# 3050/3404: Deleting with Condition (1)
# 3051/3404: Cwhile_counter
# 3052/3404: Deleting with Condition (2)
# 3053/3404: Whileloop
# 3054/3404: Arithmetic Expression
# 3055/3404: ForLoop
# 3056/3404: Multiple Comparisons (2)
# 3057/3404: ForLoop2
# 3058/3404: Range Test (1)
# 3059/3404: ForStatement
# 3060/3404: Range Test (2)
# 3061/3404: Usage
# 3062/3404: Multiple Table Selection (2)
# 3063/3404: WhileStatement
# 3064/3404: String Operation
# 3065/3404: BreakStatement
# 3066/3404: Alphabetic Order
# 3067/3404: Continue
# 3068/3404: Combining Query Results (1)
# 3069/3404: SwitchStatement
# 3070/3404: Combining Query Results (2)
# 3071/3404: SwitchStatement2
# 3072/3404: Combining Query Results (3)
# 3073/3404: IF2
# 3074/3404: Aggregate Functions (2)
# 3075/3404: Rand
# 3076/3404: Aggregate Functions (3)
# 3077/3404: Srand
# 3078/3404: Aggregate Functions (4)
# 3079/3404: rand function
# 3080/3404: Grouped Queries
# 3081/3404: defined function
# 3082/3404: Grouped Queries with Condition
# 3083/3404: Multiple Return
# 3084/3404: Checking Null Values
# 3085/3404: Assign Return
# 3086/3404: Nested Subqueries (1)
# 3087/3404: Do Switch Function
# 3088/3404: Nested Subqueries (2)
# 3089/3404: Defined Function2
# 3090/3404: Comparing Subquery Results (1)
# 3091/3404: No Argument Functions
# 3092/3404: Comparing Subquery Results (2)
# 3093/3404: Function CallByValue
# 3094/3404: Aggregating Subquery
# 3095/3404: Call By Reference
# 3096/3404: Derived Relations
# 3097/3404: Call By Reference2
# 3098/3404: View Creation (1)
# 3099/3404: Block Scope
# 3100/3404: View Creation (2)
# 3101/3404: Recursion
# 3102/3404: Grouping and aggregating (1)
# 3103/3404: calculate_Functions.c
# 3104/3404: Grouping and aggregating (2)
# 3105/3404: calculate_Main.c
# 3106/3404: Grouping and aggregating (3)
# 3107/3404: One Dim Arrays
# 3108/3404: Assertion Creation (2)
# 3109/3404: Retrieving data from view
# 3110/3404: Static Arrays
# 3111/3404: Aggregating Derived Relations
# 3112/3404: Using Arrays
# 3113/3404: Primary Key (2)
# 3114/3404: Encryption Program
# 3115/3404: Variable Declaration
# 3116/3404: comparison operators
# 3117/3404: Using Const
# 3118/3404: Variable Initialization
# 3119/3404: boolean operators
# 3120/3404: Using 2D Arrays
# 3121/3404: HelloWorld
# 3122/3404: if-else-if
# 3123/3404: BubbleSort
# 3124/3404: Object Creation and Method Calls
# 3125/3404: Exceptions
# 3126/3404: SortAlgorithm
# 3127/3404: Rectangle
# 3128/3404: Multiple Variables
# 3129/3404: InsertSortAlgo
# 3130/3404: Bicycle
# 3131/3404: Multiple Variables 2
# 3132/3404: BubbleSortAlgo
# 3133/3404: Funcion mismo valor absoluto (ES)
# 3134/3404: If with complex condition
# 3135/3404: CallbyValue
# 3136/3404: Primitive Data Types
# 3137/3404: If Statement
# 3138/3404: CallbyReference
# 3139/3404: Type Casting
# 3140/3404: Else Clause
# 3141/3404: deferencing
# 3142/3404: Constants
# 3143/3404: Nested if
# 3144/3404: PointerNotation
# 3145/3404: Constant2
# 3146/3404: Using &&
# 3147/3404: ArraysSubscript
# 3148/3404: Arithmetic Operations
# 3149/3404: Using ||
# 3150/3404: PointerArrays
# 3151/3404: Increment
# 3152/3404: Switch Statement
# 3153/3404: PointerArrays2
# 3154/3404: Math Functions
# 3155/3404: Free Flow Switch
# 3156/3404: ArrayAddresses
# 3157/3404: Operator
# 3158/3404: Nested Switch
# 3159/3404: ArrayPointers
# 3160/3404: Creating String
# 3161/3404: Switch with Enum
# 3162/3404: NonConstant
# 3163/3404: Substring
# 3164/3404: Sum using While
# 3165/3404: NonConstPointer
# 3166/3404: String Length
# 3167/3404: While with double
# 3168/3404: ConstPointer
# 3169/3404: Decision If
# 3170/3404: Nested For Loop
# 3171/3404: ConstPointer2
# 3172/3404: If Else
# 3173/3404: Print Out a Diamond
# 3174/3404: BubbleSortPF
# 3175/3404: String Comparison
# 3176/3404: Infinite For
# 3177/3404: PrintAddress
# 3178/3404: Logical Operators
# 3179/3404: For with Multiple Variables 2
# 3180/3404: Boolean Declaration
# 3181/3404: For with Multiple Variables
# 3182/3404: CopyString
# 3183/3404: Boolean Expression
# 3184/3404: For with Multiple Variables 3
# 3185/3404: CreateFile
# 3186/3404: Boolean Operators
# 3187/3404: For omitting elements
# 3188/3404: ReadFromFile
# 3189/3404: While
# 3190/3404: For-Each 2
# 3191/3404: DoWhile
# 3192/3404: For-Each with ArrayList
# 3193/3404: atof_atoi_atol
# 3194/3404: For Loop
# 3195/3404: For-Each
# 3196/3404: strtod
# 3197/3404: Nested Loops
# 3198/3404: For-each with char array
# 3199/3404: gets_puts
# 3200/3404: Nested Loops2
# 3201/3404: Multidimensional Array Iteration
# 3202/3404: Array Declaration
# 3203/3404: For-each with break
# 3204/3404: strcy_strncpy
# 3205/3404: Using an Array1
# 3206/3404: relational operators
# 3207/3404: strcat_strncat
# 3208/3404: Using an Array2
# 3209/3404: String Example
# 3210/3404: strcmp_strncmp
# 3211/3404: Create ArrayList
# 3212/3404: switch
# 3213/3404: strlen
# 3214/3404: ArrayList Demo
# 3215/3404: Polymorphism and Inheritance 1
# 3216/3404: search_func
# 3217/3404: Wrapper Classes
# 3218/3404: Casting subclass
# 3219/3404: strtok
# 3220/3404: Create 2D Array
# 3221/3404: Polymorphism and Inheritance 2
# 3222/3404: upper_lower_case
# 3223/3404: Use 2D Array
# 3224/3404: A Dog is also a Pet
# 3225/3404: string_to_integer
# 3226/3404: Interface
# 3227/3404: Inheritance and Constructors 1
# 3228/3404: string_compare
# 3229/3404: MultiInterfaces
# 3230/3404: Simple Inheritance
# 3231/3404: tokenize1
# 3232/3404: Inheritance
# 3233/3404: search_occur
# 3234/3404: Override
# 3235/3404: word_count
# 3236/3404: find_string
# 3237/3404: defined_func1
# 3238/3404: defined_func2
# 3239/3404: string_lib_func1
# 3240/3404: fgetc_fputc
# 3241/3404: check_file
# 3242/3404: Objects 3 (Rectangle)
# 3243/3404: Objects 4 (String)
# 3244/3404: Objects 5 (String)
# 3245/3404: Class 1 (BankAccount)
# 3246/3404: Class 2 (BankAccount)
# 3247/3404: Class 3 (BankAccount)
# 3248/3404: Class 4 (CashRegister)
# 3249/3404: Class 5 (Point)
# 3250/3404: Using int
# 3251/3404: Using double
# 3252/3404: Using double and Math class
# 3253/3404: Using float
# 3254/3404: Converting String to int
# 3255/3404: Converting String to double
# 3256/3404: Constants 1
# 3257/3404: Constants 2
# 3258/3404: Operations with int
# 3259/3404: Using Math class 1
# 3260/3404: Using Math class 2
# 3261/3404: Modulus Operator
# 3262/3404: Increment Operator
# 3263/3404: Strings 1
# 3264/3404: Strings 2
# 3265/3404: Strings 3
# 3266/3404: Strings 4
# 3267/3404: Strings 5
# 3268/3404: Strings 6
# 3269/3404: if-else 1
# 3270/3404: if-else 2
# 3271/3404: if-else 3
# 3272/3404: if-else 4
# 3273/3404: if-else 5
# 3274/3404: Using boolean
# 3275/3404: Comparing Strings
# 3276/3404: Boolean Operations (AND)
# 3277/3404: Comparisons
# 3278/3404: Comparisons 2
# 3279/3404: Switch 1
# 3280/3404: Switch 2
# 3281/3404: Switch 3
# 3282/3404: Loop While 1
# 3283/3404: Loop While 2
# 3284/3404: Loop While 3
# 3285/3404: Problem 1
# 3286/3404: Loop While 5
# 3287/3404: Loop Do-While 1
# 3288/3404: Loop Do-While 2
# 3289/3404: Loop Do-While 3
# 3290/3404: Loop Do-While 4
# 3291/3404: Problem 2
# 3292/3404: Problem 3
# 3293/3404: Loop For 1
# 3294/3404: Loop For 2
# 3295/3404: Loop For 3
# 3296/3404: Loop For 4
# 3297/3404: Loop For 5
# 3298/3404: Nested Loops 1
# 3299/3404: Problem 4
# 3300/3404: Nested Loops 3
# 3301/3404: Problem 5
# 3302/3404: Problem 6
# 3303/3404: Arrays 3
# 3304/3404: Arrays 4
# 3305/3404: Arrays 5
# 3306/3404: ArrayList 1
# 3307/3404: ArrayList 2
# 3308/3404: ArrayList 3
# 3309/3404: Wrapper Classes 1
# 3310/3404: Wrapper Classes 2
# 3311/3404: Wrapper Classes 3
# 3312/3404: 2D Arrays 1
# 3313/3404: 2D Arrays 2
# 3314/3404: Problem 7
# 3315/3404: 2D Arrays 4
# 3316/3404: ArrayList 4
# 3317/3404: ArrayList 5
# 3318/3404: Wrapper Classes 4
# 3319/3404: Interfaces 1
# 3320/3404: Interfaces 2
# 3321/3404: Interfaces 3
# 3322/3404: Interfaces 4
# 3323/3404: Interfaces 5
# 3324/3404: Inheritance 1
# 3325/3404: Inheritance 2
# 3326/3404: Inheritance 3
# 3327/3404: Inheritance 4
# 3328/3404: Inheritance 5
# 3329/3404: Inheritance 6
# 3330/3404: Exceptions 1
# 3331/3404: Exceptions 2
# 3332/3404: Exceptions 3
# 3333/3404: Exceptions 4
# 3334/3404: Exceptions 5
# 3335/3404: Constants in Math class
# 3336/3404: Constants in CashRegister class 1
# 3337/3404: Constants in CashRegister class 2
# 3338/3404: int Variables 1
# 3339/3404: int Variables 2
# 3340/3404: int Variables 3
# 3341/3404: int Variables 4
# 3342/3404: String Variables
# 3343/3404: Objects 1 (Rectangle)
# 3344/3404: Objects 2 (Rectangle)
# 3345/3404: SELECT-FROM question1
# 3346/3404: SELECT-FROM question2
# 3347/3404: SELECT-FROM question3
# 3348/3404: SELECT-FROM question4
# 3349/3404: SELECT-FROM question5
# 3350/3404: SELECT-DISTINCT question6
# 3351/3404: Arithmetic Expressions question1
# 3352/3404: Arithmetic Expressions question2
# 3353/3404: Arithmetic Expressions question3
# 3354/3404: Arithmetic Expressions question4
# 3355/3404: Arithmetic Expressions question5
# 3356/3404: SELECT-FROM-WHERE question1
# 3357/3404: SELECT-FROM-WHERE question2
# 3358/3404: SELECT-FROM-WHERE question3
# 3359/3404: SELECT-FROM-WHERE question4
# 3360/3404: SELECT-FROM-WHERE question5
# 3361/3404: Pattern Matching question1
# 3362/3404: Pattern Matching question2
# 3363/3404: Pattern Matching question3
# 3364/3404: Pattern Matching question4
# 3365/3404: Pattern Matching question5
# 3366/3404: Multiple Table question1
# 3367/3404: Multiple Table question2
# 3368/3404: Multiple Table question3
# 3369/3404: Multiple Table question4
# 3370/3404: Multiple Table question5
# 3371/3404: Order-By question1
# 3372/3404: Order-By question2
# 3373/3404: Order-By question3
# 3374/3404: Order-By question4
# 3375/3404: Set Operations question1
# 3376/3404: Aggregate Functions question1
# 3377/3404: Aggregate Functions question2
# 3378/3404: Aggregate Functions question3
# 3379/3404: Aggregate Functions question4
# 3380/3404: Aggregate Functions question5
# 3381/3404: Group-By & Having question1
# 3382/3404: Group-By & Having question2
# 3383/3404: Group-By & Having question3
# 3384/3404: Group-By & Having question4
# 3385/3404: Group-By & Having question5
# 3386/3404: Sub-Queries question1
# 3387/3404: Sub-Queries question2
# 3388/3404: Sub-Queries question3
# 3389/3404: Sub-Queries question4
# 3390/3404: Sub-Queries question5
# 3391/3404: fig04_05.c
# 3392/3404: Calculate_profit
# 3393/3404: Array of Char
# 3394/3404: CharReferencing
# 3395/3404: character_functions
# 3396/3404: getchar()
# 3397/3404: ascII_char
# 3398/3404: IS12:: f2c_table.c (4.5)
# 3399/3404: IS12:: nicer_f2c_table.c (4.6)
# 3400/3404: IS12:: capitaltable.c (4.9)
# 3401/3404: IS12:: count_char.c (6.1)
# 3402/3404: IS12:: char_codes.c (6.2)
# 3403/3404: IS12:: starchart.c (12.1)

# %%
# import os
# import requests
# import json

# api_token = open('api_token.txt').read().strip()
# items = os.listdir('items')

# for index, id in enumerate(items):
#     if not id.endswith('.json'):
#         continue
#     item = json.load(open(f'items/{id}'))
#     response = requests.patch(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id.replace('.json', '')}",
#         json=item,
#         headers={'api-token': api_token}
#     )
#     print(f'[{index}/{len(items)}:{response.status_code}] restored item id:', id.replace('.json', ''))
