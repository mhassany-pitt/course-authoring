# %%
# ------- BACKUP ITEMS -------
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()
for index, item in enumerate(catalog):
    print(f'{index}/{len(catalog)}:', item['identity']['title'])
    item = requests.get(f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}").json()
    del item['updated_at']
    json.dump(item, open(f"items/{item['id']}.json", 'w'), indent=2)
# Out:
# 0/3298: Insertion Sort
# 1/3298: Insertion Sort
# 2/3298: c_max_number
# 3/3298: c_grading
# 4/3298: c_pritisak
# 5/3298: c_mjeseci
# 6/3298: Kontrola toka programa
# 7/3298: c_faktorijeli (while petlja)
# 8/3298: c_ispis_unazad (while petlja)
# 9/3298: While petlja
# 10/3298: c_puni_kvadrat
# 11/3298: c_faktorijeli (for petlja)
# 12/3298: c_ispis_unazad (for petlja)
# 13/3298: For petlja
# 14/3298: c_decimalni_ispis
# 15/3298: c_ispisi_sa_sirinom_preciznosti_i_vodecim_nulama
# 16/3298: c_ispisi
# 17/3298: c_ispisi_sa_sirinom_i_preciznosti
# 18/3298: Formatirani ispisi
# 19/3298: c_hello_world_redovi
# 20/3298: c_hello_world
# 21/3298: Uvod
# 22/3298: c_ostatak_pri_dijeljenju
# 23/3298: c_dijeljenje
# 24/3298: c_farenhajt_celzijus_konverzija
# 25/3298: c_celzijus_farenhajt_konverzija
# 26/3298: c_polovine
# 27/3298: Izrazi
# 28/3298: Executing statements sequentially
# 29/3298: Print using variables
# 30/3298: Sequential Execution
# 31/3298: c_selection_sort
# 32/3298: Selection sort
# 33/3298: c_prebacivanje_u_drugi_niz
# 34/3298: c_unos_niza_while
# 35/3298: c_unos_niza_s_prekidom
# 36/3298: Unos i prebacivanje elemenata niza
# 37/3298: c_ispis_sporedna_dijagonala
# 38/3298: c_max_array
# 39/3298: c_unos_matrice
# 40/3298: c_min_array
# 41/3298: c_ispis_glavna_dijagonala
# 42/3298: Unos i obrada nizova i matrica
# 43/3298: c_funkcija_suma_kolicnika
# 44/3298: c_funkcija_stepenuj
# 45/3298: c_funkcija_pozdrav
# 46/3298: c_kubiraj
# 47/3298: Funkcije i izrazi
# 48/3298: c_funkcija_djeljiv_sa
# 49/3298: c_funkcija_djeljiv_sa_3
# 50/3298: c_funkcija_djelitelji
# 51/3298: Funkcije i djeljivost
# 52/3298: c_proizvod_elemenata_na_dijagonalama_neparan
# 53/3298: c_proizvod_elemenata_na_dijagonalama
# 54/3298: c_elementi_ispod_glavne_dijagonale
# 55/3298: c_ispis_iznad_glavne_dijagonale
# 56/3298: c_ispis_ispod_sporedne_dijagonale
# 57/3298: Rad sa dijagonalama matrica
# 58/3298: c_mnozenje_reda_iznad
# 59/3298: c_sabiranje_kolona
# 60/3298: c_dijeljenje_reda
# 61/3298: Aritmeticke operacije nad redovima i kolonama matrice
# 62/3298: c_max_elementi_kolona
# 63/3298: c_zbir_elemenata_u_kolonama
# 64/3298: c_zbir_elemenata_u_redovima
# 65/3298: c_srednja_vrijednost_matrice
# 66/3298: Operacije nad elementima matrice
# 67/3298: c_zamjena_kolona_dva_mjesta_dalje
# 68/3298: c_zamjena_redova
# 69/3298: c_zamjena_dva_reda
# 70/3298: c_zamjena_dvije_kolone
# 71/3298: Zamjena redova i kolona
# 72/3298: c_pokazivaci_min_max
# 73/3298: c_zamjena_pomocu_pokazivaca
# 74/3298: Pokazivaci kao parametri u funkcijama
# 75/3298: c_pokazivaci_dodjela_i_ispis
# 76/3298: c_vrijednosti_u_pokazivacima_int
# 77/3298: c_vrijednosti_u_pokazivacima
# 78/3298: Adrese i dodjela vrijednosti pokazivacima
# 79/3298: c_promjena_vrijednosti_preko_pokazivaca_2
# 80/3298: c_pokazivaci_dereferenciranje_int
# 81/3298: c_promjena_vrijednosti_preko_pokazivaca
# 82/3298: Dereferenciranje pokazivaca
# 83/3298: c_pokazivaci_pomjeranje_kroz_niz_i_manipulacija
# 84/3298: c_pokazivaci_pomjeranje_kroz_niz
# 85/3298: c_pokazivaci_manipulacija_clanova_niza
# 86/3298: Pokazivacka aritmetika
# 87/3298: c_unos_broja_i_karaktera
# 88/3298: c_unos_karaktera_za_karakterom
# 89/3298: c_unos_karaktera_getchar
# 90/3298: Unos karaktera
# 91/3298: c_trazenje_karaktera_u_stringu
# 92/3298: c_unos_niza_karaktera
# 93/3298: c_niz_karaktera_brojanje_samoglasnika
# 94/3298: Nizovi karaktera
# 95/3298: c_trazenje_karaktera_u_stringu_pokazivaci
# 96/3298: c_pokazivaci_na_karaktere_brojanje_samoglasnika
# 97/3298: Pokazivaci na karaktere
# 98/3298: c_brojanje_rijeci_s_velikim_pocetnim_slovom
# 99/3298: c_brojanje_rijeci_razmaci
# 100/3298: c_brojanje_rijeci_alfanumericki
# 101/3298: Detektovanje granica unutar stringa
# 102/3298: c_zamjena_svakog_drugog_znaka
# 103/3298: c_pretvaranje_broja_u_slovo
# 104/3298: Mijenjanje karaktera u stringu
# 105/3298: c_brisanje_samoglasnika
# 106/3298: c_izbacivanje_nte_rijeci
# 107/3298: c_izbacivanje_svakog_ntog_karaktera
# 108/3298: Brisanje dijelova stringa
# 109/3298: c_spajanje_dva_stringa
# 110/3298: c_ubacivanje_rijeci
# 111/3298: Ubacivanje karaktera u string
# 112/3298: c_funkcija_nadji_rijec
# 113/3298: c_funkcija_prebroji_znak
# 114/3298: c_funkcija_uporedi_stringove
# 115/3298: Slanje stringova u funkcije
# 116/3298: c_funkcija_ukloni_razmake
# 117/3298: c_funkcija_podstring
# 118/3298: Vracanje pokazivaca na karaktere iz funkcija
# 119/3298: Linked List Operations - Size 2
# 120/3298: Linked List Operations - Size 1
# 121/3298: Linked List Implementation
# 122/3298: Linked List Implementation - 1
# 123/3298: Linked List Operations - Contains
# 124/3298: Linked List Implementation
# 125/3298: Linked List Implementation - 2
# 126/3298: Queue Class - Check if Element Exists
# 127/3298: Queue Class - Check if Element Exists
# 128/3298: Queue
# 129/3298: Binary Search - 1
# 130/3298: Binary Search - 1
# 131/3298: Binary Search
# 132/3298: Binary Search - 2
# 133/3298: Binary Search - 2
# 134/3298: Binary Search - Recursive
# 135/3298: c_datoteke_brojanje_rijeci_s_velikim_pocetnim_slovom
# 136/3298: c_datoteke_brojanje_redova_rijeci_znakova
# 137/3298: Citanje sadrzaja tekstualnih datoteka karakter po karakter
# 138/3298: c_upis_stringa_u_datoteku
# 139/3298: c_kopiranje_karaktera_u_datoteku
# 140/3298: Upis u tekstualne datoteke karakter po karakter
# 141/3298: c_formatirane_datoteke_citanje_brojeva_i_stringa
# 142/3298: c_formatirane_datoteke_citanje_broja_i_stringa
# 143/3298: Citanje sadrzaja formatiranih tekstualnih datoteka
# 144/3298: c_formatirane_datoteke_upis_sa_decimalama
# 145/3298: c_formatirane_datoteke_upis_broja_i_stringa
# 146/3298: Upis u formatirane tekstualne datoteke
# 147/3298: c_makro_max_broj
# 148/3298: c_makro_kvadrat_broja
# 149/3298: Makro naredbe
# 150/3298: c_upis_reda_na_kraj_datoteke
# 151/3298: c_upis_na_kraj_datoteke
# 152/3298: c_upis_broja_karaktera_na_kraj_datoteke
# 153/3298: Izmjena tekstualnih datoteka
# 154/3298: c_citanje_iz_txt_challenge
# 155/3298: c_citanje_struktura_iz_datoteka
# 156/3298: Citanje struktura iz tekstualnih datoteka
# 157/3298: c_citanje_iz_bin_datoteke_challenge
# 158/3298: c_citanje_podatka_iz_bin_datoteke
# 159/3298: c_citanje_iz_bin_datoteke
# 160/3298: Citanje iz binarnih datoteka
# 161/3298: c_pisanje_u_datoteke_challenge
# 162/3298: c_pisanje_u_datoteke
# 163/3298: Unos struktura u tekstualne datoteke
# 164/3298: c_pisanje_u_binarne_datoteke_challenge
# 165/3298: c_pisanje_podatka_u_binarnu_datoteku
# 166/3298: c_pisanje_u_binarne_datoteke
# 167/3298: Pisanje u binarne datoteke
# 168/3298: c_citanja_izmjena_koristenjem_kursora_challenge
# 169/3298: c_citanje_izmjena_datoteka_koristenjem_kursora
# 170/3298: Rad s kursorom u tekstualnim datotekama
# 171/3298: c_izmjena_binarnih_datoteka_challenge
# 172/3298: c_izmjena_binarnih_datoteka
# 173/3298: Append i read-update mod za binarne datoteke
# 174/3298: c_strukture_i_nizovi_challenge
# 175/3298: c_strukture_i_nizovi_pokazivaci
# 176/3298: c_strukture_i_nizovi
# 177/3298: Nizovi u strukturama i nizovi struktura
# 178/3298: c_strukture_unos_ispis_studenta_challenge
# 179/3298: c_unos_i_ispis_proizvoda
# 180/3298: c_unos_i_ispis_datuma
# 181/3298: c_strukture
# 182/3298: Unos i ispis struktura
# 183/3298: c_strukture_funkcija_pravougaonik
# 184/3298: c_strukture_funkcije_sredina_tacaka
# 185/3298: Funkcije i strukture
# 186/3298: c_strukture_funkcija_pravougaonik_pokazivaci
# 187/3298: c_strukture_funkcije_sredina_tacaka_s_pokazivacima
# 188/3298: c_strukture_s_pokazivacima
# 189/3298: Funkcije i strukture s pokazivacima
# 190/3298: c_dinamicka_alokacija_varijabli_challenge
# 191/3298: c_dinamicka_alokacija_varijable_malloc
# 192/3298: c_dinamicka_alokacija_varijable_calloc
# 193/3298: Dinamicka alokacija obicnih varijabli
# 194/3298: c_dinamicka_alokacija_nizova_challenge
# 195/3298: c_dinamicka_alokacija_niza_malloc
# 196/3298: c_dinamicka_alokacija_niza_calloc
# 197/3298: Dinamicka alokacija nizova
# 198/3298: codecheck-python-StringsNumbersInStrings-1
# 199/3298: codecheck-python-StringsNumbersInStrings-3
# 200/3298: codecheck-python-StringsNumbersInStrings-2
# 201/3298: codecheck-python-LoopingOvertheEntireArray-12
# 202/3298: codecheck-python-LoopingOvertheEntireArray-9
# 203/3298: codecheck-python-LoopingOvertheEntireArray-1
# 204/3298: codecheck-python-LoopingOvertheEntireArray-11
# 205/3298: codecheck-python-LoopingOvertheEntireArray-3
# 206/3298: codecheck-python-LoopingOvertheEntireArray-4
# 207/3298: codecheck-python-LoopingOvertheEntireArray-5
# 208/3298: codecheck-python-LoopingOvertheEntireArray-13
# 209/3298: codecheck-python-LoopingOvertheEntireArray-6
# 210/3298: codecheck-python-LoopingOvertheEntireArray-2
# 211/3298: codecheck-python-LoopingOvertheEntireArray-10
# 212/3298: codecheck-python-LoopingOvertheEntireArray-8
# 213/3298: codecheck-python-LoopingOvertheEntireArray-7
# 214/3298: codecheck-python-StringWords-1
# 215/3298: codecheck-python-StringWords-3
# 216/3298: codecheck-python-StringWords-4
# 217/3298: codecheck-python-StringWords-2
# 218/3298: codecheck-python-MaximumandMinimum-1
# 219/3298: codecheck-python-MaximumandMinimum-3
# 220/3298: codecheck-python-MaximumandMinimum-4
# 221/3298: codecheck-python-MaximumandMinimum-5
# 222/3298: codecheck-python-MaximumandMinimum-6
# 223/3298: codecheck-python-MaximumandMinimum-2
# 224/3298: codecheck-python-MaximumandMinimum-7
# 225/3298: codecheck-python-ComplexLoops-1
# 226/3298: codecheck-python-ComplexLoops-3
# 227/3298: codecheck-python-ComplexLoops-4
# 228/3298: codecheck-python-ComplexLoops-5
# 229/3298: codecheck-python-ComplexLoops-6
# 230/3298: codecheck-python-ComplexLoops-2
# 231/3298: codecheck-python-LoopingoverNeighbors-1
# 232/3298: codecheck-python-LoopingoverNeighbors-3
# 233/3298: codecheck-python-LoopingoverNeighbors-4
# 234/3298: codecheck-python-LoopingoverNeighbors-5
# 235/3298: codecheck-python-LoopingoverNeighbors-2
# 236/3298: codecheck-python-StringsNoLoops-1
# 237/3298: codecheck-python-StringsNoLoops-3
# 238/3298: codecheck-python-StringsNoLoops-4
# 239/3298: codecheck-python-StringsNoLoops-5
# 240/3298: codecheck-python-StringsNoLoops-2
# 241/3298: codecheck-python-ArraysNoLoops-1
# 242/3298: codecheck-python-ArraysNoLoops-3
# 243/3298: codecheck-python-ArraysNoLoops-4
# 244/3298: codecheck-python-ArraysNoLoops-2
# 245/3298: codecheck-python-SumsAveragesProducts-14
# 246/3298: codecheck-python-SumsAveragesProducts-12
# 247/3298: codecheck-python-SumsAveragesProducts-9
# 248/3298: codecheck-python-SumsAveragesProducts-1
# 249/3298: codecheck-python-SumsAveragesProducts-11
# 250/3298: codecheck-python-SumsAveragesProducts-3
# 251/3298: codecheck-python-SumsAveragesProducts-4
# 252/3298: codecheck-python-SumsAveragesProducts-5
# 253/3298: codecheck-python-SumsAveragesProducts-13
# 254/3298: codecheck-python-SumsAveragesProducts-6
# 255/3298: codecheck-python-SumsAveragesProducts-2
# 256/3298: codecheck-python-SumsAveragesProducts-10
# 257/3298: codecheck-python-SumsAveragesProducts-8
# 258/3298: codecheck-python-SumsAveragesProducts-7
# 259/3298: codecheck-python-Producing2DArrays-1
# 260/3298: codecheck-python-Producing2DArrays-3
# 261/3298: codecheck-python-Producing2DArrays-4
# 262/3298: codecheck-python-Producing2DArrays-5
# 263/3298: codecheck-python-Producing2DArrays-6
# 264/3298: codecheck-python-Producing2DArrays-2
# 265/3298: codecheck-python-Producing2DArrays-7
# 266/3298: codecheck-python-OtherStringOperations-9
# 267/3298: codecheck-python-OtherStringOperations-1
# 268/3298: codecheck-python-OtherStringOperations-3
# 269/3298: codecheck-python-OtherStringOperations-4
# 270/3298: codecheck-python-OtherStringOperations-5
# 271/3298: codecheck-python-OtherStringOperations-6
# 272/3298: codecheck-python-OtherStringOperations-2
# 273/3298: codecheck-python-OtherStringOperations-8
# 274/3298: codecheck-python-OtherStringOperations-7
# 275/3298: codecheck-python-FunctionsWithDecisions-9
# 276/3298: codecheck-python-FunctionsWithDecisions-1
# 277/3298: codecheck-python-FunctionsWithDecisions-3
# 278/3298: codecheck-python-FunctionsWithDecisions-4
# 279/3298: codecheck-python-FunctionsWithDecisions-5
# 280/3298: codecheck-python-FunctionsWithDecisions-6
# 281/3298: codecheck-python-FunctionsWithDecisions-2
# 282/3298: codecheck-python-FunctionsWithDecisions-8
# 283/3298: codecheck-python-FunctionsWithDecisions-7
# 284/3298: codecheck-python-TwoAnswers-1
# 285/3298: codecheck-python-TwoAnswers-3
# 286/3298: codecheck-python-TwoAnswers-4
# 287/3298: codecheck-python-TwoAnswers-5
# 288/3298: codecheck-python-TwoAnswers-2
# 289/3298: codecheck-python-FillingArrays-1
# 290/3298: codecheck-python-FillingArrays-3
# 291/3298: codecheck-python-FillingArrays-4
# 292/3298: codecheck-python-FillingArrays-5
# 293/3298: codecheck-python-FillingArrays-2
# 294/3298: codecheck-python-Branches-12
# 295/3298: codecheck-python-Branches-9
# 296/3298: codecheck-python-Branches-1
# 297/3298: codecheck-python-Branches-11
# 298/3298: codecheck-python-Branches-3
# 299/3298: codecheck-python-Branches-4
# 300/3298: codecheck-python-Branches-5
# 301/3298: codecheck-python-Branches-13
# 302/3298: codecheck-python-Branches-6
# 303/3298: codecheck-python-Branches-2
# 304/3298: codecheck-python-Branches-10
# 305/3298: codecheck-python-Branches-8
# 306/3298: codecheck-python-Branches-7
# 307/3298: codecheck-python-MovingorRemovingElements-1
# 308/3298: codecheck-python-MovingorRemovingElements-3
# 309/3298: codecheck-python-MovingorRemovingElements-4
# 310/3298: codecheck-python-MovingorRemovingElements-5
# 311/3298: codecheck-python-MovingorRemovingElements-6
# 312/3298: codecheck-python-MovingorRemovingElements-2
# 313/3298: codecheck-python-LoopsAlongaRoworColumn-9
# 314/3298: codecheck-python-LoopsAlongaRoworColumn-1
# 315/3298: codecheck-python-LoopsAlongaRoworColumn-11
# 316/3298: codecheck-python-LoopsAlongaRoworColumn-3
# 317/3298: codecheck-python-LoopsAlongaRoworColumn-4
# 318/3298: codecheck-python-LoopsAlongaRoworColumn-5
# 319/3298: codecheck-python-LoopsAlongaRoworColumn-6
# 320/3298: codecheck-python-LoopsAlongaRoworColumn-2
# 321/3298: codecheck-python-LoopsAlongaRoworColumn-10
# 322/3298: codecheck-python-LoopsAlongaRoworColumn-8
# 323/3298: codecheck-python-LoopsAlongaRoworColumn-7
# 324/3298: codecheck-python-FindingElements-1
# 325/3298: codecheck-python-FindingElements-3
# 326/3298: codecheck-python-FindingElements-4
# 327/3298: codecheck-python-FindingElements-5
# 328/3298: codecheck-python-FindingElements-6
# 329/3298: codecheck-python-FindingElements-2
# 330/3298: codecheck-python-DoubleLoops-1
# 331/3298: codecheck-python-DoubleLoops-3
# 332/3298: codecheck-python-DoubleLoops-4
# 333/3298: codecheck-python-DoubleLoops-5
# 334/3298: codecheck-python-DoubleLoops-6
# 335/3298: codecheck-python-DoubleLoops-2
# 336/3298: codecheck-python-DoubleLoops-8
# 337/3298: codecheck-python-DoubleLoops-7
# 338/3298: codecheck-python-StringsFindingSubstrings-1
# 339/3298: codecheck-python-StringsFindingSubstrings-3
# 340/3298: codecheck-python-StringsFindingSubstrings-4
# 341/3298: codecheck-python-StringsFindingSubstrings-5
# 342/3298: codecheck-python-StringsFindingSubstrings-2
# 343/3298: codecheck-python-2DArraysNoLoops-1
# 344/3298: codecheck-python-2DArraysNoLoops-3
# 345/3298: codecheck-python-2DArraysNoLoops-4
# 346/3298: codecheck-python-2DArraysNoLoops-5
# 347/3298: codecheck-python-2DArraysNoLoops-6
# 348/3298: codecheck-python-2DArraysNoLoops-2
# 349/3298: codecheck-python-2DArraysNoLoops-8
# 350/3298: codecheck-python-2DArraysNoLoops-7
# 351/3298: codecheck-python-StringsComparingStrings-1
# 352/3298: codecheck-python-StringsComparingStrings-3
# 353/3298: codecheck-python-StringsComparingStrings-2
# 354/3298: codecheck-python-CountingElements-9
# 355/3298: codecheck-python-CountingElements-1
# 356/3298: codecheck-python-CountingElements-3
# 357/3298: codecheck-python-CountingElements-4
# 358/3298: codecheck-python-CountingElements-5
# 359/3298: codecheck-python-CountingElements-6
# 360/3298: codecheck-python-CountingElements-2
# 361/3298: codecheck-python-CountingElements-10
# 362/3298: codecheck-python-CountingElements-8
# 363/3298: codecheck-python-CountingElements-7
# 364/3298: Sub-Queries question5
# 365/3298: Sub-Queries question4
# 366/3298: Sub-Queries question3
# 367/3298: Sub-Queries question2
# 368/3298: Sub-Queries question1
# 369/3298: Group-By & Having question5
# 370/3298: Group-By & Having question4
# 371/3298: Group-By & Having question3
# 372/3298: Group-By & Having question2
# 373/3298: Group-By & Having question1
# 374/3298: Aggregate Functions question5
# 375/3298: Aggregate Functions question4
# 376/3298: Aggregate Functions question3
# 377/3298: Aggregate Functions question2
# 378/3298: Aggregate Functions question1
# 379/3298: Set Operations question1
# 380/3298: Order-By question4
# 381/3298: Order-By question3
# 382/3298: Order-By question2
# 383/3298: Order-By question1
# 384/3298: Multiple Table question5
# 385/3298: Multiple Table question4
# 386/3298: Multiple Table question3
# 387/3298: Multiple Table question2
# 388/3298: Multiple Table question1
# 389/3298: Pattern Matching question5
# 390/3298: Pattern Matching question4
# 391/3298: Pattern Matching question3
# 392/3298: Pattern Matching question2
# 393/3298: Pattern Matching question1
# 394/3298: SELECT-FROM-WHERE question5
# 395/3298: SELECT-FROM-WHERE question4
# 396/3298: SELECT-FROM-WHERE question3
# 397/3298: SELECT-FROM-WHERE question2
# 398/3298: SELECT-FROM-WHERE question1
# 399/3298: Arithmetic Expressions question5
# 400/3298: Arithmetic Expressions question4
# 401/3298: Arithmetic Expressions question3
# 402/3298: Arithmetic Expressions question2
# 403/3298: Arithmetic Expressions question1
# 404/3298: SELECT-DISTINCT question6
# 405/3298: SELECT-FROM question5
# 406/3298: SELECT-FROM question4
# 407/3298: SELECT-FROM question3
# 408/3298: SELECT-FROM question2
# 409/3298: SELECT-FROM question1
# 410/3298: SELECT-FROM-WHERE question6
# 411/3298: SELECT-FROM-WHERE question9
# 412/3298: SELECT-FROM-WHERE question8
# 413/3298: SELECT-FROM-WHERE question7
# 414/3298: Arithmetic Expressions question3
# 415/3298: Arithmetic Expressions question2
# 416/3298: Arithmetic Expressions question1
# 417/3298: SELECT-DISTINCT question6
# 418/3298: SELECT-FROM question5
# 419/3298: SELECT-FROM question4
# 420/3298: SELECT-FROM question3
# 421/3298: SELECT-FROM question2
# 422/3298: SELECT-FROM question1
# 423/3298: Multiple Table question4
# 424/3298: Multiple Table question3
# 425/3298: Multiple Table question2
# 426/3298: Multiple Table question1
# 427/3298: Pattern Matching question5
# 428/3298: Pattern Matching question4
# 429/3298: Pattern Matching question3
# 430/3298: Pattern Matching question2
# 431/3298: Pattern Matching question1
# 432/3298: SELECT-FROM-WHERE question5
# 433/3298: SELECT-FROM-WHERE question4
# 434/3298: SELECT-FROM-WHERE question3
# 435/3298: SELECT-FROM-WHERE question2
# 436/3298: SELECT-FROM-WHERE question1
# 437/3298: Arithmetic Expressions question5
# 438/3298: Arithmetic Expressions question4
# 439/3298: Group-By & Having question4
# 440/3298: Group-By & Having question3
# 441/3298: Group-By & Having question2
# 442/3298: Group-By & Having question1
# 443/3298: Aggregate Functions question5
# 444/3298: Aggregate Functions question4
# 445/3298: Aggregate Functions question3
# 446/3298: Aggregate Functions question2
# 447/3298: Aggregate Functions question1
# 448/3298: Set Operations question1
# 449/3298: Order-By question4
# 450/3298: Order-By question3
# 451/3298: Order-By question2
# 452/3298: Order-By question1
# 453/3298: Multiple Table question5
# 454/3298: SELECT-FROM-WHERE question9
# 455/3298: SELECT-FROM-WHERE question8
# 456/3298: SELECT-FROM-WHERE question7
# 457/3298: SELECT-FROM-WHERE question6
# 458/3298: Sub-Queries question5
# 459/3298: Sub-Queries question4
# 460/3298: Sub-Queries question3
# 461/3298: Sub-Queries question2
# 462/3298: Sub-Queries question1
# 463/3298: Group-By & Having question5
# 464/3298: Set Operations question3
# 465/3298: Set Operations question2
# 466/3298: Set Operations question5
# 467/3298: Set Operations question4
# 468/3298: Arithmetic-expressions query execution 1
# 469/3298: Subqueries query execution 1
# 470/3298: Group-by-having query execution 1
# 471/3298: Aggregate-functions query execution 1
# 472/3298: Order-by query execution 1
# 473/3298: Pattern-matching query execution 1
# 474/3298: Select-from query execution 1
# 475/3298: Multiple-table-queries execution 1
# 476/3298: Select-from-where query execution 1
# 477/3298: Group-by-having query execution 4
# 478/3298: Group-by-having query execution 3
# 479/3298: Group-by-having query execution 2
# 480/3298: Aggregate-functions query execution 4
# 481/3298: Aggregate-functions query execution 3
# 482/3298: Aggregate-functions query execution 2
# 483/3298: Order-by query execution 4
# 484/3298: Order-by query execution 3
# 485/3298: Order-by query execution 2
# 486/3298: Pattern-matching query execution 4
# 487/3298: Pattern-matching query execution 3
# 488/3298: Pattern-matching query execution 2
# 489/3298: Select-from query execution 4
# 490/3298: Select-from query execution 3
# 491/3298: Select-from query execution 2
# 492/3298: Multiple-table-queries execution 4
# 493/3298: Multiple-table-queries execution 3
# 494/3298: Multiple-table-queries execution 2
# 495/3298: Select-from-where query execution 4
# 496/3298: Select-from-where query execution 3
# 497/3298: Select-from-where query execution 2
# 498/3298: Arithmetic-expressions query execution 4
# 499/3298: Arithmetic-expressions query execution 3
# 500/3298: Arithmetic-expressions query execution 2
# 501/3298: Subqueries query execution 4
# 502/3298: Subqueries query execution 3
# 503/3298: Subqueries query execution 2
# 504/3298: Join query execution 1
# 505/3298: Join query execution 4
# 506/3298: Join query execution 3
# 507/3298: Join query execution 2
# 508/3298: Arithmetic-expressions query execution 6
# 509/3298: Arithmetic-expressions query execution 5
# 510/3298: Join question1
# 511/3298: Join question2
# 512/3298: LEFT-JOIN question2
# 513/3298: LEFT-JOIN question1
# 514/3298: Inner-join query execution 1
# 515/3298: Left-join query execution 1
# 516/3298: Left-join query execution 4
# 517/3298: Left-join query execution 3
# 518/3298: Left-join query execution 2
# 519/3298: Inner-join query execution 4
# 520/3298: Inner-join query execution 3
# 521/3298: Inner-join query execution 2
# 522/3298: Converting Milliseconds to Hours-Minutes- and Seconds
# 523/3298: Seconds to Minutes Conversion
# 524/3298: Seconds to Minutes Conversion
# 525/3298: Converting Milliseconds to Hours-Minutes- and Seconds
# 526/3298: Converting Milliseconds to Hours-Minutes- and Seconds.
# 527/3298: Seconds to Minutes Conversion
# 528/3298: Vending Machine With Quarters-Dimes- and Nickels
# 529/3298: Vending Machine With Dollars and Quarters
# 530/3298: Vending Machine With Quarters-Dimes- and Nickels
# 531/3298: Vending Machine With Dollars and Quarters
# 532/3298: Creating an array that Contains the Numbers of Times Each Element of One Array Appears in Another Array
# 533/3298: Printing the Total Number of Times Elements of One Array Appear in Another Array
# 534/3298: Printing Common Elements in Two Arrays
# 535/3298: Determining When to Buy a New Phone (Case 1)
# 536/3298: Determining When to Buy a New Phone (Case 2)
# 537/3298: Printing Consecutive Numbers Starting from Zero (Case 1)
# 538/3298: Printing Consecutive Numbers Starting from Zero (Case 2)
# 539/3298: Pythagorean Theorem (Case 1)
# 540/3298: Pythagorean Theorem (Case 2)
# 541/3298: Finding the Smallest Divisor of a Positive Number
# 542/3298: Finding the Largest Divisor of a Positive Number
# 543/3298: Accessing String Characters (Case 2)
# 544/3298: Accessing String Characters (Case 1)
# 545/3298: The Class for Representing a Bank Account (Case 1)
# 546/3298: The Class for Representing a Bank Account (Case 2)
# 547/3298: The Class for Representing a TV (Case 1)
# 548/3298: The Class for Representing a TV (Case 2)
# 549/3298: The Class for Representing a Loan (Case 2)
# 550/3298: The Class for Representing a Loan (Case 1)
# 551/3298: Creating a List of Words from a File
# 552/3298: Comparing the List of Words from Two Files
# 553/3298: Creating an Array of Odd Numbers
# 554/3298: Creating an Array of User Inputs
# 555/3298: Increment/Decrement Operators (Case 1)
# 556/3298: Increment/Decrement Operators (Case 2)
# 557/3298: Increment/Decrement Operators (Case 3)
# 558/3298: String Concatenation (Case 1)
# 559/3298: String Concatenation (Case 2)
# 560/3298: Determining When a Customer Could Rent a Car (Case 3)
# 561/3298: Determining When a Customer Could Rent a Car (Case 1)
# 562/3298: Determining When a Customer Could Rent a Car (Case 2)
# 563/3298: String Comparison (Case 1)
# 564/3298: String Comparison (Case 2)
# 565/3298: Calculating the Average of the Values in the Array
# 566/3298: Calculating the Sum of the Values in an Array
# 567/3298: Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 1)
# 568/3298: Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 2)
# 569/3298: Calculating the Winning Percentage of a Sports Team (Case 2)
# 570/3298: Calculating the Winning Percentage of a Sports Team (Case 1)
# 571/3298: Calculating the Winning Percentage of a Sports Team (Case 3)
# 572/3298: Updating an Element in the Array (Case 1)
# 573/3298: Updating an Element in the Array (Case 2)
# 574/3298: Updating an Element in the Array (Case 3)
# 575/3298: Modifying an Array (Case 2)
# 576/3298: Modifying an Array (Case 1)
# 577/3298: Printing Name Initials
# 578/3298: Printing Full Name with Middle Initial
# 579/3298: Printing Name in APA Style
# 580/3298: Warning the User about the Changes in the Temperature
# 581/3298: Warning the User about the Changes in the Temperature and Humidity
# 582/3298: Determining the Smallest of the Three Integers
# 583/3298: Determining the Largest of the Three Integers
# 584/3298: Printing Table of Medal Winner Counts with Row and Column Totals
# 585/3298: Printing Table of Medal Winner Counts with Row Totals
# 586/3298: Vending Machine With Quarters-Dimes- and Nickels
# 587/3298: Vending Machine With Dollars and Quarters
# 588/3298: Celsius To Fahrenheit Conversion
# 589/3298: Fahrenheit to Celsius Conversion
# 590/3298: Determining When All Three Boolean Variables Are Equal
# 591/3298: Determining When at Least One of the Three Boolean Variables is True
# 592/3298: Determining When at Least One of the Three Boolean Variables is False
# 593/3298: Converting the Letter Grade of a Student to Its Numeric Range
# 594/3298: Determining the Letter Grade Of a Student
# 595/3298: The Class for Representing a Point in the Euclidean Plane (Case 1)
# 596/3298: The Class for Representing a Point in the Euclidean Plane (Case 2)
# 597/3298: Printing the Squares of Numbers Within a Specified Range (Case 2)
# 598/3298: Printing the Squares of Numbers Within a Specified Range (Case 3)
# 599/3298: Printing the Squares of Numbers Within a Specified Range (Case 1)
# 600/3298: Calculating the Wage of an Employee at the Customer Service Call Center
# 601/3298: Calculating the Employees Wage Based on the Hours That the Employee Has Worked and an Hourly Pay Rate
# 602/3298: Counting the Number of Valid and Banned Product Codes (Case 1)
# 603/3298: Counting the Number of Valid and Banned Product Codes (Case 2)
# 604/3298: Determining Whether One is a Teenager (Case 1)
# 605/3298: Determining Whether One is a Teenager (Case 2)
# 606/3298: Printing A Right Triangle Star Pattern
# 607/3298: Printing an Inverted Right Triangle Star Pattern
# 608/3298: Point Class Hierarchy (Case 1)
# 609/3298: Point Class Hierarchy (Case 2)
# 610/3298: Animal Class Hierarchy (Case 1)
# 611/3298:  Animal Class Hierarchy (Case 2)
# 612/3298: Finding the Number of Days Above the Average Temperature
# 613/3298: Displaying the Days That are Above 32 Degrees Fahrenheit
# 614/3298: Reporting File Information (Case 1)
# 615/3298: Reporting File Information (Case 2)
# 616/3298: Calculating the Average of Floating-Point Numbers
# 617/3298: Calculating the Average of the Input Integers that are an Even Number
# 618/3298: Calculating the Average of Input Integers
# 619/3298: Determining When a Student Fails a Course (Case 2)
# 620/3298: Determining When a Student Fails a Course (Case 1)
# 621/3298: Determining When a Student Fails a Course (Case 3)
# 622/3298: Reversing the Digits of an Integer
# 623/3298: Printing Digits of an Integer from Right to Left
# 624/3298: The Digit Sum of an Integer
# 625/3298: Finding Adjacent Consecutive Numbers in a Sequence of Integers
# 626/3298: Finding Adjacent Numbers in Ascending Order in a Sequence of Numbers
# 627/3298: Finding Adjacent Duplicates in a Sequence of Numbers
# 628/3298: Rotating the Array Values to the Right by One Position
# 629/3298: Rotating the List Values to the Right by Two Position
# 630/3298: Rotating the Array Values to the Left by One Position
# 631/3298: Rotating the Array Values to the Left by Two Position
# 632/3298: Calculating and Rounding Up Body Mass Index (BMI) To the Nearest Integer
# 633/3298: Calculating Body Mass Index (BMI)
# 634/3298: Updating Two-Dimensional Array (Case 1)
# 635/3298: Updating Two-Dimensional Array (Case 3)
# 636/3298: Updating Two-Dimensional Array (Case 2)
# 637/3298: Determining the Sign of an Integer
# 638/3298: Determining Whether an Integer is Even or Odd
# 639/3298: Receiving Input Integers Until a Certain Condition is Met (Case 2)
# 640/3298: Receiving Input Integers Until a Certain Condition is Met (Case 3)
# 641/3298: Receiving Input Integers Until a Certain Condition is Met (Case 4)
# 642/3298: Receiving Input Integers Until a Certain Condition is Met (Case 1)
# 643/3298: String With Escape Characters (Case 1)
# 644/3298: String With Escape Characters (Case 2)
# 645/3298: String With Escape Characters (Case 3)
# 646/3298: Determining the Weather Condition (Case 1)
# 647/3298: Determining the Weather Condition (Case 4)
# 648/3298: Determining the Weather Condition (Case 2)
# 649/3298: Determining the Weather Condition (Case 3)
# 650/3298: Determining the Average Ratings of each Respondent and Average Ratings Given to Each Soda in the Survey
# 651/3298: Determining the Average Rating for Each Soda in The Survey
# 652/3298: Determining the Maximum Rating for Each Soda in The Survey
# 653/3298: Printing Consecutive Numbers Within a Specified Range (Case 2)
# 654/3298: Printing Consecutive Numbers Within a Specified Range (Case 1)
# 655/3298: Converting Milliseconds to Hours-Minutes- and Seconds
# 656/3298: Seconds to Minutes Conversion
# 657/3298: Finding the Minimum Value in an Array
# 658/3298: Finding the Maximum Value in an Array
# 659/3298: Printing A Sequence of Repeated Numbers (Case 1)
# 660/3298: Printing A Sequence of Repeated Numbers (Case 2)
# 661/3298: Reporting the Total Hours Each Employee Worked (Case 2)
# 662/3298: Reporting the Total Hours Each Employee Worked (Case 1)
# 663/3298: Herencia de Persona y Empleado
# 664/3298: Informacion de Herencia de Persona y Empleado
# 665/3298: Mostrando los Dias que Estan por Sobre 32 Grados Fahrenheit
# 666/3298: Mostrando los Dias que Estan por Sobre el Promedio de Temperatura
# 667/3298: Concatenando Caracteres de Dos Strings (Caso 2).
# 668/3298: Concatenando Caracteres de Dos Strings (Caso 1)
# 669/3298: Imprimir Tabla de Conteo de Medallas con Totales por Fila
# 670/3298: Imprimir Tabla de Conteo de Medallas con Totales por Fila y por Columna
# 671/3298: Determinando Si Uno Es Adolescente (Caso 2)
# 672/3298: Determinando Si Uno Es Adolescente (Caso 1)
# 673/3298: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 1)
# 674/3298: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 2)
# 675/3298: Informe de Informacion del Archivo (Caso 1)
# 676/3298: Informar Informacion del Archivo (Caso 2)
# 677/3298: Contando las Ocurrencias de un String en Otro (Caso 2).
# 678/3298: Contando las Ocurrencias de un String en Otro (Caso 1)
# 679/3298: Calculo del Indice de Masa Corporal (IMC)
# 680/3298: Calculo y Redondeo del Indice de Masa Corporal (IMC) al Entero Mas Cercano.
# 681/3298: La Clase para Representar un Prestamo (Caso 1)
# 682/3298: La Clase para Representar un Prestamo (Caso 2)
# 683/3298: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 1)
# 684/3298: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 2)
# 685/3298: Determinando Cuando Comprar un Nuevo Telefono (Caso 2)
# 686/3298: Determinando Cuando Comprar un Nuevo Telefono (Caso 1)
# 687/3298: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 2)
# 688/3298: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 1)
# 689/3298: Creando un Diccionario de Pares Caracteres-Palabras
# 690/3298: Creando un Diccionario de Pares Caracteres-Frecuencia
# 691/3298: Desplazando los Valores de la Lista a la Izquierda Una Posicion
# 692/3298: Desplazando los Valores de la Lista a la Derecha Dos Posiciones
# 693/3298: Desplazando los Valores de la Lista a la Derecha una Posicion
# 694/3298: Desplazando los Valores de la Lista a la Izquierda Dos Posiciones
# 695/3298: Pasar Valores
# 696/3298: Pasar Valores
# 697/3298: Maquina Expendedora Con Dolares y Monedas de Veinticinco
# 698/3298: Maquina Expendedora Con Monedas de diferentes centavos
# 699/3298: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo
# 700/3298: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo Invertido
# 701/3298: Encontrar el Divisor Mas Pequeno de un Numero Positivo
# 702/3298: Encontrar el Mayor Divisor de un Numero Positivo
# 703/3298: testing_um2_student_average_arun_ch
# 704/3298: JSON ITERATION 1
# 705/3298: Calculando el Porcentaje de Victorias de un Equipo (Caso 1)
# 706/3298: Calculando el Porcentaje de Victorias de un Equipo (Caso 3)
# 707/3298: Calculando el Porcentaje de Victorias de un Equipo (Caso 2)
# 708/3298: Advertir al Usuario sobre los Cambios en la Temperatura y Humedad.
# 709/3298: Advertir al Usuario sobre los Cambios en la Temperatura
# 710/3298: Funcion con Multiples Parametros Llamando Otra
# 711/3298: Funcion con Multiples Parametros
# 712/3298: Pythagorean Theorem (Case 2)
# 713/3298: Pythagorean Theorem (Case 1)
# 714/3298: testing_um2_student_average_arun_ch
# 715/3298: testing_um2_student_average_arun_ex
# 716/3298: testing_um2_arun_java_SLR_weat_ex
# 717/3298: testing_um2_arun_java_SLR_weat_ch
# 718/3298: PrintFileContent
# 719/3298: CopyFileTo
# 720/3298: Calcular promedio de dos numeros enteros (ES)
# 721/3298: Calcular factura mensual (ES)
# 722/3298: Calcular los segundos en n dias (ES)
# 723/3298: Condicion: es impar (ES)
# 724/3298: Contar Mayusculas (ES)
# 725/3298: Mayusculas o Minusculas (ES)
# 726/3298: Contar no digitos (ES)
# 727/3298: Todo Esponjoso (ES)
# 728/3298: Indice Menor (ES)
# 729/3298: Primer Par (ES)
# 730/3298: Triangulo Ascii (ES)
# 731/3298: Contar Digitos (ES)
# 732/3298: Factor menor (ES)
# 733/3298: Contar Pasos Collatz (ES)
# 734/3298: Solo Dos Verdaderos (p2-4-ES)
# 735/3298: Solo Uno Verdadero (p1-4-ES)
# 736/3298: Listas de enteros pares (ES)
# 737/3298: Encontrar el indice de el string mas largo (ES)
# 738/3298: Intercambiar primero y ultimo
# 739/3298: Contar el numero de valores que estan por encima del promedio (ES)
# 740/3298: Suma digital (ES)
# 741/3298: Programa usual primero (CC)
# 742/3298: Ciclo for anidado
# 743/3298: Calculo rebanadas de pizza (ES)
# 744/3298: Condicion: es adolescente (ES)
# 745/3298: Dia siguiente
# 746/3298: Maximo de tres enteros (ES)
# 747/3298: Calculo galletas necesarias (ES)
# 748/3298: Calcular su suma y producto
# 749/3298: Practicar el uso de la biblioteca math y comprobar el tipo de una variable
# 750/3298: Practicar la manipulación de variables y verificar sus tipos
# 751/3298: Practicar ciclos while anidados
# 752/3298: Practicar el uso de ciclos while y for anidados
# 753/3298: Practicar herencia de clases
# 754/3298: Manipulación de diccionarios
# 755/3298: Cálculos con diccionarios
# 756/3298: Valores y referencias en listas
# 757/3298: Practicar la búsqueda del índice del elemento mínimo
# 758/3298: Practicar la búsqueda del índice de los elementos mínimo y máximo
# 759/3298: Construir un programa que cree una estructura de pila (Stack)
# 760/3298: Construir una función que use una estructura de cola (Queue)
# 761/3298: Construir una función que recorra una lista enlazada
# 762/3298: Construir una función que verifique el tamaño de una lista enlazada
# 763/3298: Construir una función que ordene un arreglo numérico usando Merge Sort
# 764/3298: Practicar el algoritmo de ordenación rápida (Quick Sort)
# 765/3298: Construir una función de recorrido inorder (inorden)
# 766/3298: Imprimir hola mundo
# 767/3298: Crear una función que imprima hola mundo
# 768/3298: Crear una función que reciba un número, le sume dos y lo devuelva
# 769/3298: Crear una función que devuelva el mayor de dos números
# 770/3298: Practicar el orden de líneas para obtener el número correcto
# 771/3298: Crear un programa con un ciclo while
# 772/3298: Crear un programa que compare un valor en un ciclo
# 773/3298: Crear y llamar a una función
# 774/3298: Crear múltiples funciones y llamadas de función anidadas
# 775/3298: Crear una función recursiva
# 776/3298: Crear una clase y utilizarla
# 777/3298: Crear una función y usar el operador módulo
# 778/3298: Iterar sobre una lista
# 779/3298: Practicar indexación de listas
# 780/3298: Practicar el corte de cadenas (slicing)
# 781/3298: Iterar sobre un diccionario
# 782/3298: Acceder a los valores de un diccionario
# 783/3298: Convertir una lista de tuplas en un diccionario
# 784/3298: Iterar sobre elementos (items) de un diccionario
# 785/3298: Usar expresiones booleanas como parámetros de una función
# 786/3298: Practicar sentencias if...elif...else
# 787/3298: Practicar leer un archivo e imprimir su contenido
# 788/3298: Practicar el manejo de excepciones
# 789/3298: Practicar sentencias if anidadas
# 790/3298: Practicar el uso de comparaciones
# 791/3298: Practicar indexación y modificación de listas
# 792/3298: Practicar la asignación de variables
# 793/3298: Crear una compuerta XOR usando sentencias if...elif
# 794/3298: Practicar iterar sobre una lista y usar módulo
# 795/3298: Practicar métodos de cadenas
# 796/3298: Practicar el manejo de excepciones
# 797/3298: Crear una clase y usar sus métodos
# 798/3298: Construir un programa que trabaje con listas
# 799/3298: Construir un problema con ciclos anidados
# 800/3298: Construir un programa que genere combinaciones únicas de 3 dígitos
# 801/3298: Construir un programa que genere combinaciones únicas de 3 dígitos
# 802/3298: Construir un programa con múltiples sentencias if-elif
# 803/3298: Construir un programa con múltiples sentencias if-elif
# 804/3298: Construir un programa con múltiples sentencias if-elif
# 805/3298: Frecuencia de letras
# 806/3298: Frecuencia de letras
# 807/3298: Crear una función que verifique si una cadena es un palíndromo o no
# 808/3298: Crear una función que verifique si una cadena es un palíndromo o no
# 809/3298: Crear una función que verifique si una cadena es un palíndromo o no
# 810/3298: Construir una función que determine si una cadena dada como parámetro es un palíndromo
# 811/3298: Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 812/3298: Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 813/3298: Invertir la lista
# 814/3298: Invertir la lista
# 815/3298: Invertir la lista
# 816/3298: Invertir la lista
# 817/3298: Invertir la lista
# 818/3298: Invertir la lista
# 819/3298: Invertir la lista
# 820/3298: Invertir la lista
# 821/3298: Verificar si la suma de dos enteros es igual al tercer entero
# 822/3298: Verificar si la suma de dos enteros es igual al tercer entero
# 823/3298: Actualizar elementos en una nueva lista
# 824/3298: Actualizar elementos necesarios en una nueva lista
# 825/3298: Actualizar los elementos en una nueva lista
# 826/3298: Actualizar los elementos en una nueva lista
# 827/3298: Actualizar elementos necesarios en una nueva lista
# 828/3298: Actualizar elementos necesarios en una nueva lista
# 829/3298: Cálculo de potencias
# 830/3298: Cálculo de potencias
# 831/3298: Calcular una potencia
# 832/3298: Calcular una potencia
# 833/3298: Calcular una potencia
# 834/3298: Calcular una potencia
# 835/3298: Eliminar duplicados de una lista
# 836/3298: Eliminar duplicados de una lista
# 837/3298: Reorganizar la lista
# 838/3298: Reorganizar la lista
# 839/3298: Reorganizar la lista
# 840/3298: Reorganizar la lista
# 841/3298: Practicar la lectura de archivos e imprimir el tercer elemento de cada línea
# 842/3298: Binary Search Algorithm Slideshow
# 843/3298: Binary Search recurrence slideshow
# 844/3298: BST Search Slideshow
# 845/3298: BST Insert Slideshow
# 846/3298: BST deletemax Slideshow
# 847/3298: BST remove Slideshow
# 848/3298: PosetCON
# 849/3298: Binary Search Proficiency Exercise
# 850/3298: BST Search Proficiency Exercise
# 851/3298: BST Question Summary
# 852/3298: Self-organizing List Move-to-front Proficiency Exercise
# 853/3298: Insertion Sort Slideshow
# 854/3298: Insertion Sort Worst Case Slideshow
# 855/3298: Insertion Sort Best Case Slideshow
# 856/3298: Insertion Sort Average Case Slideshow
# 857/3298: Bubble Sort Slideshow 1
# 858/3298: Bubble Sort Slideshow 2
# 859/3298: Bubble Sort Analysis Slideshow
# 860/3298: Selection Sort Slideshow 1
# 861/3298: Selection Sort Slideshow 2
# 862/3298: Selection Sort Analysis Slideshow
# 863/3298: Exchange Sort Analysis Slideshow
# 864/3298: Shellsort Slideshow 1
# 865/3298: Shellsort Slideshow 2
# 866/3298: Shellsort Slideshow 3
# 867/3298: Shellsort Slideshow 4
# 868/3298: Shellsort Slideshow 5
# 869/3298: Shellsort Slideshow 6
# 870/3298: Merging Slideshow
# 871/3298: Mergesort Analysis Slideshow
# 872/3298: Mergesort Implementation Slideshow 1
# 873/3298: Mergesort Implementation Slideshow 2
# 874/3298: Quicksort Partition Slideshow
# 875/3298: Quicksort Partition Analysis Slideshow
# 876/3298: Quicksort Worst Case Analysis Slideshow
# 877/3298: Quicksort Best Case Analysis Slideshow
# 878/3298: Quicksort Average Case Analysis Slideshow
# 879/3298: Heapsort Slideshow
# 880/3298: Heapsort Analysis Slideshow
# 881/3298: Binsort Slideshow 1
# 882/3298: Binsort Slideshow 2
# 883/3298: Radix Sort Analysis Slideshow
# 884/3298: Sorting Lower Bound Slideshow
# 885/3298: Selection Sort Pointer Swap
# 886/3298: Sorting Terminology and Notation Slideshow 1
# 887/3298: Sorting Problem
# 888/3298: Pair to Sorting Reduction Slideshow
# 889/3298: Sorting to Pairing Reduction Slideshow
# 890/3298: Record Comparison Summary Exercise
# 891/3298: Sorting Intro Summary
# 892/3298: Insertion Sort Proficiency Exercise
# 893/3298: Insertion Sort Summary Exercise
# 894/3298: Bubble Sort Proficiency Exercise
# 895/3298: Bubble Sort Summary Exercise
# 896/3298: Selection Sort Proficiency Exercise
# 897/3298: Selection Sort Summary Exercise
# 898/3298: Inversions Proficiency Exercise
# 899/3298: Exchange Sorting Summary Exercise
# 900/3298: Shellsort Sublist Proficency Exercise
# 901/3298: Shellsort Series Exercise
# 902/3298: Shellsort Summary Exercise
# 903/3298: Mergesort Merging Proficiency Exercise
# 904/3298: Mergesort Summary Exercise
# 905/3298: Quicksort Pivot Proficiency Exercise
# 906/3298: Quicksort Partition Proficiency Exercise
# 907/3298: Quicksort Summary Exercise
# 908/3298: Heapsort RemoveMax Proficiency Exercise
# 909/3298: Heapsort Summary Exercise
# 910/3298: Radix Sort Proficiency Exercise
# 911/3298: Radix Sort Summary Exercise
# 912/3298: Sort Comparison Summary Exercise
# 913/3298: Lower Bounds Summary Exercise
# 914/3298: Sorting Chapter Summary Exercise
# 915/3298: JLinkedListUtil Challenge
# 916/3298: JLinkedListUtil
# 917/3298:  Recursively calculate the power of a number Challenge
# 918/3298:  Recursively calculate the power of a number
# 919/3298: Recursively calculate the sum of all numbers from 1 to n Challenge
# 920/3298: Recursively calculate the sum of all numbers from 1 to n
# 921/3298: q_java_q_py_slinkedlist1
# 922/3298: q_java_q_py_dlinkedlist1
# 923/3298: Merge LinkList - NFB
# 924/3298: (Recursion) Power calculation - NFB
# 925/3298: (Recursion) Sum from 1 to n - NFB
# 926/3298: Recursive addition of characters - NFB
# 927/3298: Traverse LinkedList - NFB
# 928/3298: LinkedList repeated two lists - NFB
# 929/3298: Compare Two LinkedList - NFB
# 930/3298: Compare Two LinkedList
# 931/3298: Linked List 1
# 932/3298: Use Recursion to calculate power
# 933/3298: Use Recursion to calculate total sum of all numbers from 1 to N.
# 934/3298: PCRS C3-PL Reverse dictionary
# 935/3298: PCRS C3-PL Recursive counting
# 936/3298: PCRS C3-PL Bracket validation
# 937/3298: PCRS C3-PL  Find N Letters
# 938/3298: PCRS C3-PL  Event Class
# 939/3298: PCRS C3-PL  Total Slices
# 940/3298: PCRS C3-PL  List Insert
# 941/3298: PCRS C3-PL  Reverse Lookup
# 942/3298: PCRS C3-PL  Realestate Class
# 943/3298: PCRS C3-PL  Ipod Class
# 944/3298: PCRS C3-PL  Rectangle Class
# 945/3298: PCRS C3-PL  Special List Class
# 946/3298: PCRS C3-PL  Can Pay With Two Coins
# 947/3298: PCRS C3-PL  Add Underscores
# 948/3298: PCRS C3-PL  Class Day Calendar
# 949/3298: PCRS C3-PL  Double
# 950/3298: PCRS C3-PL  Our Maximum
# 951/3298: PCRS C3-PL  Max Of Min
# 952/3298: PCRS C3-PL  Caculate Tax
# 953/3298: PCRS C3-PL  Same Abs
# 954/3298: PCRS C3-PL  Upper Lower
# 955/3298: PCRS C3-PL  Overdue Fees
# 956/3298: PCRS C3-PL  Different Types
# 957/3298: PCRS C3-PL  Every Second Line
# 958/3298: PCRS C3-PL  Get Words
# 959/3298: PCRS C3-PL  Context To Next Words
# 960/3298: PCRS C3-PL  Calendar Event3
# 961/3298: PCRS C3-PL  User Class1
# 962/3298: PCRS C3-PL  User Day
# 963/3298: PCRS C3-PL  Adjacent Match
# 964/3298: PCRS C3-PL  Duplicate Cut
# 965/3298: PCRS C3-PL  Student By Degree
# 966/3298: PCRS C3-PL  Has Last Token
# 967/3298: PCRS C3-PL  Context Not Unique Hashtags
# 968/3298: PCRS C3-PL  Non Intersecting
# 969/3298: PCRS C3-PL  Eligible
# 970/3298: PCRS C3-PL  Return Indices
# 971/3298: PCRS C3-PL  Reorganize
# 972/3298: PCRS C3-PL  Reorder By Hashtag
# 973/3298: PCRS C3-PL  Valid
# 974/3298: PCRS C3-PL  Valid Dna
# 975/3298: PCRS C3-PL  Item Catalog Class
# 976/3298: PCRS C3-PL  Somecode
# 977/3298: PCRS C3-PL  My Max
# 978/3298: PCRS C3-PL  Compute Sum
# 979/3298: PCRS C3-PL  Unique Integer
# 980/3298: PCRS C3-PL  Compute Product
# 981/3298: PCRS C3-PL  Hello World
# 982/3298: PCRS C3-PL  Hello World Name
# 983/3298: PCRS C3-PL  Shift Char
# 984/3298: PCRS C3-PL  Unshift Char
# 985/3298: PCRS C3-PL  A Before B
# 986/3298: PCRS C3-PL  Less Than Ten
# 987/3298: PCRS C3-PL  Positive Less Than Ten
# 988/3298: PCRS C3-PL  In Between
# 989/3298: PCRS C3-PL  Sum Twenty
# 990/3298: PCRS C3-PL  Exactly One Positive
# 991/3298: PCRS C3-PL  Exactly One Positive2
# 992/3298: PCRS C3-PL  Is Prime
# 993/3298: PCRS C3-PL  Max In Group
# 994/3298: PCRS C3-PL  Counta
# 995/3298: PCRS C3-PL  Countx
# 996/3298: PCRS C3-PL  Replace1
# 997/3298: PCRS C3-PL  Replacec
# 998/3298: PCRS C3-PL  Replacex
# 999/3298: PCRS C3-PL  Replace Between Index
# 1000/3298: PCRS C3-PL  Is In
# 1001/3298: PCRS C3-PL  Is Not In
# 1002/3298: PCRS C3-PL  Dna Pairs
# 1003/3298: PCRS C3-PL  Dna Base Pairs
# 1004/3298: PCRS C3-PL  Count Genes
# 1005/3298: PCRS C3-PL  Between Two Genes
# 1006/3298: PCRS C3-PL  Sum List
# 1007/3298: PCRS C3-PL  List Average
# 1008/3298: PCRS C3-PL  Max In List
# 1009/3298: PCRS C3-PL  Greater Than Ten
# 1010/3298: PCRS C3-PL  Sum Greater Than N
# 1011/3298: PCRS C3-PL  Return Max Index
# 1012/3298: PCRS C3-PL  Longest String
# 1013/3298: PCRS C3-PL  Count Longer
# 1014/3298: PCRS C3-PL  Num Above Average
# 1015/3298: PCRS C3-PL  Count Number Seven
# 1016/3298: PCRS C3-PL  Count Nm
# 1017/3298: PCRS C3-PL  Count Nmmn
# 1018/3298: PCRS C3-PL  Count Nums
# 1019/3298: PCRS C3-PL  Num Greater At Index
# 1020/3298: PCRS C3-PL  Is Sorted
# 1021/3298: PCRS C3-PL  Postfix
# 1022/3298: PCRS C3-PL  Closed Interval
# 1023/3298: PCRS C3-PL  Merge Sort
# 1024/3298: PCRS C3-PL  Recurse Converge
# 1025/3298: PCRS C3-PL  Alert Weekend
# 1026/3298: PCRS C3-PL  Positive Two Digits
# 1027/3298: PCRS C3-PL  Two Params True One
# 1028/3298: PCRS C3-PL  Negative If Zero
# 1029/3298: PCRS C3-PL  Continent
# 1030/3298: PCRS C3-PL  Avocados
# 1031/3298: PCRS C3-PL  Two Params True
# 1032/3298: PCRS C3-PL Simple int comparison
# 1033/3298: PCRS C3-PL Is char half alphabet
# 1034/3298: PCRS C3-PL Is char lowercase
# 1035/3298:  PCRS C3-PL Is teenager
# 1036/3298: PCRS C3-PL If can drink
# 1037/3298: PCRS C3-PL Is candyshop open
# 1038/3298: PCRS C3-PL Within five
# 1039/3298: PCRS C3-PL  Loan
# 1040/3298: PCRS C3-PL  Utilties
# 1041/3298: PCRS C3-PL  List Insert
# 1042/3298: Busqueda Inversa de Telefono (ES)
# 1043/3298: PCRS C3-PL  Realestate Class
# 1044/3298: PCRS C3-PL  Ipod Class
# 1045/3298: PCRS C3-PL  Rectangle Class
# 1046/3298: PCRS C3-PL  Special List Class
# 1047/3298: PCRS C3-PL  Can Pay With Two Coins
# 1048/3298: Agregar guiones bajos a string (ES)
# 1049/3298: PCRS C3-PL  Class Day Calendar
# 1050/3298: PCRS C3-PL  Double
# 1051/3298: PCRS C3-PL  Our Maximum
# 1052/3298: Funcion maximo de los minimos valores (ES)
# 1053/3298: Funcion calculo impuesto (ES)
# 1054/3298: PCRS C3-PL  Same Abs
# 1055/3298: PCRS C3-PL  Different Types
# 1056/3298: Cada segunda linea en archivo (ES)
# 1057/3298: PCRS C3-PL  Calendar Event3
# 1058/3298: PCRS C3-PL  User Class1
# 1059/3298: PCRS C3-PL  User Day
# 1060/3298: PCRS C3-PL  Duplicate Cut
# 1061/3298: PCRS C3-PL  Has Last Token
# 1062/3298: PCRS C3-PL  Context Not Unique Hashtags
# 1063/3298: PCRS C3-PL  Non Intersecting
# 1064/3298: PCRS C3-PL  Return Indices
# 1065/3298: Reorganizar diccionario (ES)
# 1066/3298: PCRS C3-PL  Item Catalog Class
# 1067/3298: PCRS C3-PL  Somecode
# ...
# 2728/3298: Move Tester
# 2729/3298: Copy Demo
# 2730/3298: Counter Demo
# 2731/3298: Hello Printer
# 2732/3298: Operations with Variables
# 2733/3298: All Variables Together
# 2734/3298: Initializing Variables
# 2735/3298: Size of Variables
# 2736/3298: Boolean Variables
# 2737/3298: Ctring Variables
# 2738/3298: Character Numbers ASCII
# 2739/3298: Char Variables
# 2740/3298: Float and Double Variables
# 2741/3298: Variable Types
# 2742/3298: Change the Value of a Variable
# 2743/3298: Using Variables
# 2744/3298: Using End of Line Statement
# 2745/3298: Multiline cout
# 2746/3298: Simple cout
# 2747/3298: Cash Register Tester (Constant Field)
# 2748/3298: Class (Cash Register)
# 2749/3298: Division
# 2750/3298: Earthquake
# 2751/3298: String (replace)
# 2752/3298: Using float
# 2753/3298: Using Double
# 2754/3298: String (equals)
# 2755/3298: Strings (equalsIgnoreCase)
# 2756/3298: Converting between Class and Interface Types
# 2757/3298: Interface Polymorphism
# 2758/3298: Measure
# 2759/3298: Overriding Object Methods
# 2760/3298: Tic-Tac-Toe
# 2761/3298: Bank
# 2762/3298: Grade Book
# 2763/3298: ArrayList Tester
# 2764/3298: Enhanced For Loop
# 2765/3298: Enhanced For Loop Demo
# 2766/3298: Class (Bank Account This)
# 2767/3298: This Reference
# 2768/3298: Cash Register Tester
# 2769/3298: Bank Account Tester
# 2770/3298: Counter Demo
# 2771/3298: Copy Demo
# 2772/3298: Accessor Mutator Demo
# 2773/3298: Constructor Demo
# 2774/3298: Method Demo
# 2775/3298: Comparing Strings
# 2776/3298: String Equals
# 2777/3298: Test Null
# 2778/3298: Testing for null
# 2779/3298: Object Equality
# 2780/3298: Boolean Operations (Greater equal)
# 2781/3298: Boolean Operations (Less equal)
# 2782/3298: Boolean Operations (Not equal)
# 2783/3298: Boolean Operations (Not)
# 2784/3298: Boolean Operations (OR)
# 2785/3298: String Concat
# 2786/3298: Strings (Concatenation)
# 2787/3298: Strings (parse)
# 2788/3298: Strings (replace)
# 2789/3298: Strings (charAt)
# 2790/3298: Using Math Class (ceil)
# 2791/3298: Using Math Class (abs)
# 2792/3298: Pre Decrement
# 2793/3298: Post Decrement
# 2794/3298: Post Increment
# 2795/3298: Compound Assignment
# 2796/3298: Combining Assignment and Arithmetic
# 2797/3298: Decrement
# 2798/3298: Simple Variable Test
# 2799/3298: println Test
# 2800/3298: int Variables 4
# 2801/3298: int Variable 1
# 2802/3298: Print Tester
# 2803/3298: Variable Demo
# 2804/3298: Hello Printer
# 2805/3298: check_file2
# 2806/3298: count_occur
# 2807/3298: pointer_seq_file
# 2808/3298: pointer_seq_file2
# 2809/3298: create_seq_file
# 2810/3298: read_seq_file
# 2811/3298: update_credit_prog
# 2812/3298: pass_file
# 2813/3298: structs1
# 2814/3298: rand_access_file
# 2815/3298: write_info_rand_file
# 2816/3298: IS12:: helloworld.c (1.1)
# 2817/3298: IS12:: printing.c (2)
# 2818/3298: IS12:: printing1.c (2.1)
# 2819/3298: IS12:: printing2.c (2.2)
# 2820/3298: IS12:: calculating1.c (2.3)
# 2821/3298: IS12:: calculating2.c (2.4)
# 2822/3298: IS12:: variables.c (3.1)
# 2823/3298: IS12:: exchange_kiosk.c (3.11)
# 2824/3298: IS12:: better_kiosk.c (3.2)
# 2825/3298: IS12:: capital.c (3.3)
# 2826/3298: IS12:: fahr_input.c (3.4)
# 2827/3298: IS12:: countdown1.c (4.1)
# 2828/3298: IS12:: countdown2.c (4.2)
# 2829/3298: IS12:: capitalyears.c (4.3)
# 2830/3298: IS12:: factorial.c (4.4)
# 2831/3298: IS12:: accumulator.c (4.7)
# 2832/3298: IS12:: apples_kids.c (4.8)
# 2833/3298: IS12:: max2.c (5.1)
# 2834/3298: IS12:: max1.c (5.2)
# 2835/3298: IS12:: rate2.c (5.3)
# 2836/3298: IS12:: maxloop.c (5.4)
# 2837/3298: IS12:: max3.c (5.5)
# 2838/3298: IS12:: line_count.c (6.4)
# 2839/3298: IS12:: better_copycat.c (6.5)
# 2840/3298: IS12:: copycat.c (6.6)
# 2841/3298: IS12:: arraysum.c (9.1)
# 2842/3298: IS12:: arraymax.c (9.2)
# 2843/3298: IS12:: arraymin.c (9.3)
# 2844/3298: IS12:: babyweighting.c (9.4)
# 2845/3298: IS12:: digcount.c (10.1)
# 2846/3298: IS12:: sumarfunc.c (10.2)
# 2847/3298: IS12:: power.c (10.3)
# 2848/3298: IS12:: longestline.c (12.2)
# 2849/3298: IS12:: patternsearch.c (12.3)
# 2850/3298: IS12:: str2int.c (12.4)
# 2851/3298: IS12:: goodswap.c (14.1)
# 2852/3298: IS12:: strcomp.c (14.2)
# 2853/3298: IS12:: battleship.c (15.1)
# 2854/3298: IS12:: yearday.c (15.2)
# 2855/3298: IS12:: printback.c (15.3)
# 2856/3298: IS12:: betterbattle.c (15.4)
# 2857/3298: IS12:: recfactorial.c (24.1)
# 2858/3298: IS12:: recpower.c (24.2)
# 2859/3298: IS12:: insummax.c (111.1)
# 2860/3298: IS12:: parampass.c (111.2)
# 2861/3298: IS12:: palindrome.c (111.3)
# 2862/3298: IS12:: qpa.c (117.1)
# 2863/3298: IS12:: rate3.c (117.2)
# 2864/3298: IS12:: encrypt.c (117.3)
# 2865/3298: IS12:: qpa_or.c (117.4)
# 2866/3298: IS12:: qpa_and.c (117.5)
# 2867/3298: IS12:: av_line_while.c (118.1)
# 2868/3298: IS12:: av_line_for.c (118.2)
# 2869/3298: IS12:: f2c_for.c (118.3)
# 2870/3298: IS12:: abcounting.c (118.4)
# 2871/3298: IS12:: abcounting_case.c (118.5)
# 2872/3298: IS12:: wc.c (118.6)
# 2873/3298: IS12:: nondigits.c (118.7)
# 2874/3298: IS12:: arrayio.c (119.1)
# 2875/3298: IS12:: arrayiofor.c (119.2)
# 2876/3298: IfElse_Structure
# 2877/3298: private
# 2878/3298: fig02_01.c
# 2879/3298: fig02_03.c
# 2880/3298: fig02_04.c
# 2881/3298: fig02_05.c
# 2882/3298: fig02_13.c
# 2883/3298: fig03_06.c
# 2884/3298: fig03_08.c
# 2885/3298: fig03_10.c
# 2886/3298: fig03_13.c
# 2887/3298: fig04_01.c
# 2888/3298: fig04_02.c
# 2889/3298: fig04_06.c
# 2890/3298: fig04_07.c
# 2891/3298: fig04_09.c
# 2892/3298: fig04_11.c
# 2893/3298: fig04_12.c
# 2894/3298: fig05_03.c
# 2895/3298: fig05_04.c
# 2896/3298: fig05_07.c
# 2897/3298: fig05_08.c
# 2898/3298: fig05_09.c
# 2899/3298: fig05_10.c
# 2900/3298: fig05_12.c
# 2901/3298: fig05_14.c
# 2902/3298: fig05_15.c
# 2903/3298: fig06_03.c
# 2904/3298: fig06_04.c
# 2905/3298: fig06_05.c
# 2906/3298: fig06_06.c
# 2907/3298: fig06_07.c
# 2908/3298: fig06_08.c
# 2909/3298: fig06_09.c
# 2910/3298: fig06_10.c
# 2911/3298: fig06_11.c
# 2912/3298: fig06_12.c
# 2913/3298: fig06_13.c
# 2914/3298: fig06_14.c
# 2915/3298: fig06_15.c
# 2916/3298: fig06_16.c
# 2917/3298: fig06_18.c
# 2918/3298: fig06_19.c
# 2919/3298: fig06_21.c
# 2920/3298: fig06_22.c
# 2921/3298: fig07_04.c
# 2922/3298: fig07_06.c
# 2923/3298: fig07_07.c
# 2924/3298: fig07_10.c
# 2925/3298: fig07_11.c
# 2926/3298: fig07_12.c
# 2927/3298: fig07_13.c
# 2928/3298: fig07_14.c
# 2929/3298: Table Creation
# 2930/3298: fig07_15.c
# 2931/3298: Primary Key (1)
# 2932/3298: fig07_16.c
# 2933/3298: Primary Key and Unique Key
# 2934/3298: fig07_17.c
# 2935/3298: Foriegn Key
# 2936/3298: fig07_20.cpp
# 2937/3298: Table Drop
# 2938/3298: fig07_21.c
# 2939/3298: Column Addition
# 2940/3298: fig07_24.c
# 2941/3298: Column Drop
# 2942/3298: fig07_26.c
# 2943/3298: Inserting Data (1)
# 2944/3298: fig07_28.c
# 2945/3298: Deleting Data
# 2946/3298: Binary_Expressions
# 2947/3298: Selecting One Attribute
# 2948/3298: precedence_expression
# 2949/3298: Selecting Multiple Attributes
# 2950/3298: precedence_expr
# 2951/3298: Selecting All Attributes
# 2952/3298: complex_expr
# 2953/3298: Skipping Duplicates
# 2954/3298: IncDec_Oper
# 2955/3298: Aggregate Functions (1)
# 2956/3298: compound_assign
# 2957/3298: Selection Condition
# 2958/3298: casting_num
# 2959/3298: Comparison Condition (1)
# 2960/3298: 1stprogram
# 2961/3298: Comparison Condition (2)
# 2962/3298: printf
# 2963/3298: Comparison Condition (3)
# 2964/3298: input_print
# 2965/3298: Multiple Table Selection (1)
# 2966/3298: decimal_value
# 2967/3298: Multiple Comparisons (1)
# 2968/3298: avg_score
# 2969/3298: Check Constraint (1)
# 2970/3298: CH3_printf1
# 2971/3298: Check Constraint (2)
# 2972/3298: CH3_printf2
# 2973/3298: Assertion Creation (1)
# 2974/3298: CH3_printf3
# 2975/3298: Inserting Data (2)
# 2976/3298: Inserting Data (3)
# 2977/3298: Coin_Values
# 2978/3298: Inserting Data (4)
# 2979/3298: IncDec
# 2980/3298: Updating Data (2)
# 2981/3298: If
# 2982/3298: Updating Data (3)
# 2983/3298: while_structure
# 2984/3298: Updating Data (1)
# 2985/3298: Sentinel_value
# 2986/3298: Updating with condition
# 2987/3298: Sales
# 2988/3298: Updating with subquery
# 2989/3298: Payroll
# 2990/3298: Deleting with Condition (1)
# 2991/3298: Cwhile_counter
# 2992/3298: Deleting with Condition (2)
# 2993/3298: Whileloop
# 2994/3298: Arithmetic Expression
# 2995/3298: ForLoop
# 2996/3298: Multiple Comparisons (2)
# 2997/3298: ForLoop2
# 2998/3298: Range Test (1)
# 2999/3298: ForStatement
# 3000/3298: Range Test (2)
# 3001/3298: Usage
# 3002/3298: Multiple Table Selection (2)
# 3003/3298: WhileStatement
# 3004/3298: String Operation
# 3005/3298: BreakStatement
# 3006/3298: Alphabetic Order
# 3007/3298: Continue
# 3008/3298: Combining Query Results (1)
# 3009/3298: SwitchStatement
# 3010/3298: Combining Query Results (2)
# 3011/3298: SwitchStatement2
# 3012/3298: Combining Query Results (3)
# 3013/3298: IF2
# 3014/3298: Aggregate Functions (2)
# 3015/3298: Rand
# 3016/3298: Aggregate Functions (3)
# 3017/3298: Srand
# 3018/3298: Aggregate Functions (4)
# 3019/3298: rand function
# 3020/3298: Grouped Queries
# 3021/3298: defined function
# 3022/3298: Grouped Queries with Condition
# 3023/3298: Multiple Return
# 3024/3298: Checking Null Values
# 3025/3298: Assign Return
# 3026/3298: Nested Subqueries (1)
# 3027/3298: Do Switch Function
# 3028/3298: Nested Subqueries (2)
# 3029/3298: Defined Function2
# 3030/3298: Comparing Subquery Results (1)
# 3031/3298: No Argument Functions
# 3032/3298: Comparing Subquery Results (2)
# 3033/3298: Function CallByValue
# 3034/3298: Aggregating Subquery
# 3035/3298: Call By Reference
# 3036/3298: Derived Relations
# 3037/3298: Call By Reference2
# 3038/3298: View Creation (1)
# 3039/3298: Block Scope
# 3040/3298: View Creation (2)
# 3041/3298: Recursion
# 3042/3298: Grouping and aggregating (1)
# 3043/3298: calculate_Functions.c
# 3044/3298: Grouping and aggregating (2)
# 3045/3298: calculate_Main.c
# 3046/3298: Grouping and aggregating (3)
# 3047/3298: One Dim Arrays
# 3048/3298: Assertion Creation (2)
# 3049/3298: Retrieving data from view
# 3050/3298: Static Arrays
# 3051/3298: Aggregating Derived Relations
# 3052/3298: Using Arrays
# 3053/3298: Primary Key (2)
# 3054/3298: Encryption Program
# 3055/3298: Variable Declaration
# 3056/3298: comparison operators
# 3057/3298: Using Const
# 3058/3298: Variable Initialization
# 3059/3298: boolean operators
# 3060/3298: Using 2D Arrays
# 3061/3298: HelloWorld
# 3062/3298: if-else-if
# 3063/3298: BubbleSort
# 3064/3298: Object Creation and Method Calls
# 3065/3298: Exceptions
# 3066/3298: SortAlgorithm
# 3067/3298: Rectangle
# 3068/3298: Multiple Variables
# 3069/3298: InsertSortAlgo
# 3070/3298: Bicycle
# 3071/3298: Multiple Variables 2
# 3072/3298: BubbleSortAlgo
# 3073/3298: Funcion mismo valor absoluto (ES)
# 3074/3298: If with complex condition
# 3075/3298: CallbyValue
# 3076/3298: Primitive Data Types
# 3077/3298: If Statement
# 3078/3298: CallbyReference
# 3079/3298: Type Casting
# 3080/3298: Else Clause
# 3081/3298: deferencing
# 3082/3298: Constants
# 3083/3298: Nested if
# 3084/3298: PointerNotation
# 3085/3298: Constant2
# 3086/3298: Using &&
# 3087/3298: ArraysSubscript
# 3088/3298: Arithmetic Operations
# 3089/3298: Using ||
# 3090/3298: PointerArrays
# 3091/3298: Increment
# 3092/3298: Switch Statement
# 3093/3298: PointerArrays2
# 3094/3298: Math Functions
# 3095/3298: Free Flow Switch
# 3096/3298: ArrayAddresses
# 3097/3298: Operator
# 3098/3298: Nested Switch
# 3099/3298: ArrayPointers
# 3100/3298: Creating String
# 3101/3298: Switch with Enum
# 3102/3298: NonConstant
# 3103/3298: Substring
# 3104/3298: Sum using While
# 3105/3298: NonConstPointer
# 3106/3298: String Length
# 3107/3298: While with double
# 3108/3298: ConstPointer
# 3109/3298: Decision If
# 3110/3298: Nested For Loop
# 3111/3298: ConstPointer2
# 3112/3298: If Else
# 3113/3298: Print Out a Diamond
# 3114/3298: BubbleSortPF
# 3115/3298: String Comparison
# 3116/3298: Infinite For
# 3117/3298: PrintAddress
# 3118/3298: Logical Operators
# 3119/3298: For with Multiple Variables 2
# 3120/3298: Boolean Declaration
# 3121/3298: For with Multiple Variables
# 3122/3298: CopyString
# 3123/3298: Boolean Expression
# 3124/3298: For with Multiple Variables 3
# 3125/3298: CreateFile
# 3126/3298: Boolean Operators
# 3127/3298: For omitting elements
# 3128/3298: ReadFromFile
# 3129/3298: While
# 3130/3298: For-Each 2
# 3131/3298: DoWhile
# 3132/3298: For-Each with ArrayList
# 3133/3298: atof_atoi_atol
# 3134/3298: For Loop
# 3135/3298: For-Each
# 3136/3298: strtod
# 3137/3298: Nested Loops
# 3138/3298: For-each with char array
# 3139/3298: gets_puts
# 3140/3298: Nested Loops2
# 3141/3298: Multidimensional Array Iteration
# 3142/3298: Array Declaration
# 3143/3298: For-each with break
# 3144/3298: strcy_strncpy
# 3145/3298: Using an Array1
# 3146/3298: relational operators
# 3147/3298: strcat_strncat
# 3148/3298: Using an Array2
# 3149/3298: String Example
# 3150/3298: strcmp_strncmp
# 3151/3298: Create ArrayList
# 3152/3298: switch
# 3153/3298: strlen
# 3154/3298: ArrayList Demo
# 3155/3298: Polymorphism and Inheritance 1
# 3156/3298: search_func
# 3157/3298: Wrapper Classes
# 3158/3298: Casting subclass
# 3159/3298: strtok
# 3160/3298: Create 2D Array
# 3161/3298: Polymorphism and Inheritance 2
# 3162/3298: upper_lower_case
# 3163/3298: Use 2D Array
# 3164/3298: A Dog is also a Pet
# 3165/3298: string_to_integer
# 3166/3298: Interface
# 3167/3298: Inheritance and Constructors 1
# 3168/3298: string_compare
# 3169/3298: MultiInterfaces
# 3170/3298: Simple Inheritance
# 3171/3298: tokenize1
# 3172/3298: Inheritance
# 3173/3298: search_occur
# 3174/3298: Override
# 3175/3298: word_count
# 3176/3298: find_string
# 3177/3298: defined_func1
# 3178/3298: defined_func2
# 3179/3298: string_lib_func1
# 3180/3298: fgetc_fputc
# 3181/3298: check_file
# 3182/3298: Objects 3 (Rectangle)
# 3183/3298: Objects 4 (String)
# 3184/3298: Objects 5 (String)
# 3185/3298: Class 1 (BankAccount)
# 3186/3298: Class 2 (BankAccount)
# 3187/3298: Class 3 (BankAccount)
# 3188/3298: Class 4 (CashRegister)
# 3189/3298: Class 5 (Point)
# 3190/3298: Using int
# 3191/3298: Using double
# 3192/3298: Using double and Math class
# 3193/3298: Using float
# 3194/3298: Converting String to int
# 3195/3298: Converting String to double
# 3196/3298: Constants 1
# 3197/3298: Constants 2
# 3198/3298: Operations with int
# 3199/3298: Using Math class 1
# 3200/3298: Using Math class 2
# 3201/3298: Modulus Operator
# 3202/3298: Increment Operator
# 3203/3298: Strings 1
# 3204/3298: Strings 2
# 3205/3298: Strings 3
# 3206/3298: Strings 4
# 3207/3298: Strings 5
# 3208/3298: Strings 6
# 3209/3298: if-else 1
# 3210/3298: if-else 2
# 3211/3298: if-else 3
# 3212/3298: if-else 4
# 3213/3298: if-else 5
# 3214/3298: Using boolean
# 3215/3298: Comparing Strings
# 3216/3298: Boolean Operations (AND)
# 3217/3298: Comparisons
# 3218/3298: Comparisons 2
# 3219/3298: Switch 1
# 3220/3298: Switch 2
# 3221/3298: Switch 3
# 3222/3298: Loop While 1
# 3223/3298: Loop While 2
# 3224/3298: Loop While 3
# 3225/3298: Problem 1
# 3226/3298: Loop While 5
# 3227/3298: Loop Do-While 1
# 3228/3298: Loop Do-While 2
# 3229/3298: Loop Do-While 3
# 3230/3298: Loop Do-While 4
# 3231/3298: Problem 2
# 3232/3298: Problem 3
# 3233/3298: Loop For 1
# 3234/3298: Loop For 2
# 3235/3298: Loop For 3
# 3236/3298: Loop For 4
# 3237/3298: Loop For 5
# 3238/3298: Nested Loops 1
# 3239/3298: Problem 4
# 3240/3298: Nested Loops 3
# 3241/3298: Problem 5
# 3242/3298: Problem 6
# 3243/3298: Arrays 3
# 3244/3298: Arrays 4
# 3245/3298: Arrays 5
# 3246/3298: ArrayList 1
# 3247/3298: ArrayList 2
# 3248/3298: ArrayList 3
# 3249/3298: Wrapper Classes 1
# 3250/3298: Wrapper Classes 2
# 3251/3298: Wrapper Classes 3
# 3252/3298: 2D Arrays 1
# 3253/3298: 2D Arrays 2
# 3254/3298: Problem 7
# 3255/3298: 2D Arrays 4
# 3256/3298: ArrayList 4
# 3257/3298: ArrayList 5
# 3258/3298: Wrapper Classes 4
# 3259/3298: Interfaces 1
# 3260/3298: Interfaces 2
# 3261/3298: Interfaces 3
# 3262/3298: Interfaces 4
# 3263/3298: Interfaces 5
# 3264/3298: Inheritance 1
# 3265/3298: Inheritance 2
# 3266/3298: Inheritance 3
# 3267/3298: Inheritance 4
# 3268/3298: Inheritance 5
# 3269/3298: Inheritance 6
# 3270/3298: Exceptions 1
# 3271/3298: Exceptions 2
# 3272/3298: Exceptions 3
# 3273/3298: Exceptions 4
# 3274/3298: Exceptions 5
# 3275/3298: Constants in Math class
# 3276/3298: Constants in CashRegister class 1
# 3277/3298: Constants in CashRegister class 2
# 3278/3298: int Variables 1
# 3279/3298: int Variables 2
# 3280/3298: int Variables 3
# 3281/3298: int Variables 4
# 3282/3298: String Variables
# 3283/3298: Objects 1 (Rectangle)
# 3284/3298: Objects 2 (Rectangle)
# 3285/3298: fig04_05.c
# 3286/3298: Calculate_profit
# 3287/3298: Array of Char
# 3288/3298: CharReferencing
# 3289/3298: character_functions
# 3290/3298: getchar()
# 3291/3298: ascII_char
# 3292/3298: IS12:: f2c_table.c (4.5)
# 3293/3298: IS12:: nicer_f2c_table.c (4.6)
# 3294/3298: IS12:: capitaltable.c (4.9)
# 3295/3298: IS12:: count_char.c (6.1)
# 3296/3298: IS12:: char_codes.c (6.2)
# 3297/3298: IS12:: starchart.c (12.1)

# %%
# ------- RESTORE ITEMS -------
import os
import requests
import json

api_token = open('api_token.txt').read().strip()
items = os.listdir('items')

for index, id in enumerate(items):
    if not id.endswith('.json'):
        continue
    item = json.load(open(f'items/{id}'))
    response = requests.patch(
        f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id.replace('.json', '')}",
        json=item,
        headers={'api-token': api_token}
    )
    print(f'[{index}/{len(items)}:{response.status_code}] restored item id:', id.replace('.json', ''))
# Out:
# [1/3298:200] restored item id: 69cd72927afb2475509e5eb7
# [63/3298:200] restored item id: 69cd728e7afb2475509e5e3b
# [126/3298:200] restored item id: 69cd72a67afb2475509e6131
# [166/3298:200] restored item id: 69cd72887afb2475509e5d75
# [197/3298:200] restored item id: 69cd72987afb2475509e5f8b
# [201/3298:200] restored item id: 69cd729a7afb2475509e5fc7
# [230/3298:200] restored item id: 69cd72b17afb2475509e62a1
# [259/3298:200] restored item id: 69cd729c7afb2475509e5ff9
# [296/3298:200] restored item id: 69cd728e7afb2475509e5e35
# [302/3298:200] restored item id: 69cd72a97afb2475509e618b
# [318/3298:200] restored item id: 69cd72ae7afb2475509e622f
# [366/3298:200] restored item id: 69cd72907afb2475509e5e8b
# [388/3298:200] restored item id: 69cd72b37afb2475509e62d3
# [399/3298:200] restored item id: 69cd72917afb2475509e5e8d
# [450/3298:200] restored item id: 69cd72ae7afb2475509e6241
# [461/3298:200] restored item id: 69cd72897afb2475509e5d91
# [463/3298:200] restored item id: 69cd72907afb2475509e5e71
# [474/3298:200] restored item id: 69cd72887afb2475509e5d81
# [550/3298:200] restored item id: 69cd72997afb2475509e5fad
# [569/3298:200] restored item id: 69cd729e7afb2475509e6055
# [602/3298:200] restored item id: 69cd729e7afb2475509e6043
# [612/3298:200] restored item id: 69cd729a7afb2475509e5fd1
# [675/3298:200] restored item id: 69cd72907afb2475509e5e7f
# [683/3298:200] restored item id: 69cd728a7afb2475509e5dc3
# [685/3298:200] restored item id: 69cd72a47afb2475509e610d
# [705/3298:200] restored item id: 69cd728e7afb2475509e5e43
# [735/3298:200] restored item id: 69cd72977afb2475509e5f51
# [781/3298:200] restored item id: 69cd72947afb2475509e5f05
# [829/3298:200] restored item id: 69cd72a87afb2475509e616f
# [897/3298:200] restored item id: 69cd728f7afb2475509e5e5f
# [912/3298:200] restored item id: 69cd72947afb2475509e5efd
# [925/3298:200] restored item id: 69cd72af7afb2475509e6245
# [979/3298:200] restored item id: 69cd72b37afb2475509e62d5
# [999/3298:200] restored item id: 69cd729a7afb2475509e5fcf
# [1012/3298:200] restored item id: 69cd729b7afb2475509e5fe3
# [1023/3298:200] restored item id: 69cd728d7afb2475509e5e1b
# [1035/3298:200] restored item id: 69cd72927afb2475509e5eb1
# [1117/3298:200] restored item id: 69cd72927afb2475509e5ec7
# [1144/3298:200] restored item id: 69cd729b7afb2475509e5fdb
# [1149/3298:200] restored item id: 69cd729a7afb2475509e5fb7
# [1160/3298:200] restored item id: 69cd72a67afb2475509e6137
# [1165/3298:200] restored item id: 69cd729b7afb2475509e5fd9
# [1241/3298:200] restored item id: 69cd729a7afb2475509e5fc1
# [1244/3298:200] restored item id: 69cd728d7afb2475509e5e15
# [1320/3298:200] restored item id: 69cd728e7afb2475509e5e45
# [1336/3298:200] restored item id: 69cd72ab7afb2475509e61c9
# [1367/3298:200] restored item id: 69cd72ab7afb2475509e61cb
# [1382/3298:200] restored item id: 69cd72997afb2475509e5fa5
# [1412/3298:200] restored item id: 69cd72b47afb2475509e62f1
# [1428/3298:200] restored item id: 69cd72977afb2475509e5f6f
# [1434/3298:200] restored item id: 69cd729e7afb2475509e604b
# [1453/3298:200] restored item id: 69cd72a47afb2475509e60f9
# [1462/3298:200] restored item id: 69cd728c7afb2475509e5df7
# [1467/3298:200] restored item id: 69cd728a7afb2475509e5da9
# [1506/3298:200] restored item id: 69cd72a47afb2475509e6105
# [1533/3298:200] restored item id: 69cd728a7afb2475509e5dbd
# [1540/3298:200] restored item id: 69cd72b27afb2475509e62a5
# [1553/3298:200] restored item id: 69cd72ab7afb2475509e61c5
# [1559/3298:200] restored item id: 69cd72937afb2475509e5ee1
# [1673/3298:200] restored item id: 69cd72a37afb2475509e60e9
# [1726/3298:200] restored item id: 69cd72ad7afb2475509e6215
# [1771/3298:200] restored item id: 69cd729a7afb2475509e5fbb
# [1781/3298:200] restored item id: 69cd72ae7afb2475509e622b
# [1791/3298:200] restored item id: 69cd72a97afb2475509e618f
# [1794/3298:200] restored item id: 69cd72967afb2475509e5f33
# [1814/3298:200] restored item id: 69cd728b7afb2475509e5dc9
# [1816/3298:200] restored item id: 69cd728d7afb2475509e5e21
# [1990/3298:200] restored item id: 69cd72967afb2475509e5f3d
# [2007/3298:200] restored item id: 69cd728e7afb2475509e5e3f
# [2018/3298:200] restored item id: 69cd72897afb2475509e5da3
# [2063/3298:200] restored item id: 69cd72af7afb2475509e625f
# [2073/3298:200] restored item id: 69cd72ad7afb2475509e6223
# [2145/3298:200] restored item id: 69cd729c7afb2475509e600b
# [2168/3298:200] restored item id: 69cd72a27afb2475509e60bb
# [2241/3298:200] restored item id: 69cd72a77afb2475509e6165
# [2268/3298:200] restored item id: 69cd72937afb2475509e5ed9
# [2290/3298:200] restored item id: 69cd728c7afb2475509e5dfb
# [2321/3298:200] restored item id: 69cd72b37afb2475509e62cf
# [2434/3298:200] restored item id: 69cd72887afb2475509e5d85
# [2442/3298:200] restored item id: 69cd72997afb2475509e5fb1
# [2448/3298:200] restored item id: 69cd72897afb2475509e5d95
# [2461/3298:200] restored item id: 69cd72b17afb2475509e6289
# [2474/3298:200] restored item id: 69cd72b47afb2475509e62e5
# [2493/3298:200] restored item id: 69cd729a7afb2475509e5fc5
# [2563/3298:200] restored item id: 69cd72997afb2475509e5f8f
# [2574/3298:200] restored item id: 69cd729b7afb2475509e5fdf
# [2601/3298:200] restored item id: 69cd729f7afb2475509e6063
# [2604/3298:200] restored item id: 69cd72aa7afb2475509e61b9
# [2620/3298:200] restored item id: 69cd729b7afb2475509e5ff1
# [2697/3298:200] restored item id: 69cd728d7afb2475509e5e1f
# [2711/3298:200] restored item id: 69cd729b7afb2475509e5fe7
# [2730/3298:200] restored item id: 69cd72917afb2475509e5e8f
# [2814/3298:200] restored item id: 69cd729f7afb2475509e606d
# [2823/3298:200] restored item id: 69cd728e7afb2475509e5e37
# [2884/3298:200] restored item id: 69cd72927afb2475509e5ebb
# [2890/3298:200] restored item id: 69cd72a97afb2475509e619f
# [2903/3298:200] restored item id: 69cd728c7afb2475509e5dfd
# [2947/3298:200] restored item id: 69cd72977afb2475509e5f65
# [2969/3298:200] restored item id: 69cd72997afb2475509e5faf
# [3000/3298:200] restored item id: 69cd72b17afb2475509e6299
# [3006/3298:200] restored item id: 69cd72987afb2475509e5f7d
# [3013/3298:200] restored item id: 69cd72967afb2475509e5f4d
# [3025/3298:200] restored item id: 69cd728b7afb2475509e5dd5
# [3050/3298:200] restored item id: 69cd72a47afb2475509e6101
# [3065/3298:200] restored item id: 69cd72a57afb2475509e6111
# [3116/3298:200] restored item id: 69cd72a77afb2475509e614d
# [3178/3298:200] restored item id: 69cd72997afb2475509e5fa1
# [3235/3298:200] restored item id: 69cd72897afb2475509e5d8b
# [3258/3298:200] restored item id: 69cd72a77afb2475509e6163
# [3263/3298:200] restored item id: 69cd72a57afb2475509e611f

# %%
# # merge all items into a single file

# import os
# import json

# items = []
# for index, id in enumerate(os.listdir('items')):
#     if not id.endswith('.json'):
#         continue
#     items.append(json.load(open(f'items/{id}')))
# json.dump(items, open('items.json', 'w'), indent=2)
