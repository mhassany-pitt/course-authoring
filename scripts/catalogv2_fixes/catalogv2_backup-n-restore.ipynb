# %%
# # ------- BACKUP ITEMS -------
# import requests
# import json

# catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()
# for index, item in enumerate(catalog):
#     print(f'{index}/{len(catalog)}:', item['identity']['title'])
#     item = requests.get(f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}").json()
#     del item['updated_at']
#     json.dump(item, open(f"items/{item['id']}.json", 'w'), indent=2)

# %%
# ------- RESTORE ITEMS -------
import os
import requests
import json

api_token = open('api_token.txt').read().strip()
items = os.listdir('items')

for index, id in enumerate(items):
    if not id.endswith('.json'):
        continue
    item = json.load(open(f'items/{id}'))
    response = requests.patch(
        f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id.replace('.json', '')}",
        json=item,
        headers={'api-token': api_token}
    )
    print(f'[{index}/{len(items)}:{response.status_code}] restored item id:', id.replace('.json', ''))
# Out:
# [0/3298:200] restored item id: 69923553fbbb65899e0a1e77
# {"id":"69923553fbbb65899e0a1e77","user_email":"moh70@pitt.edu","status":"public","listed_at":"2026-02-15T00:00:00.000Z","tags":[],"identity":{"id":"horstmann/codecheck-python-Producing2DArrays-7","title":"codecheck-python-Producing2DArrays-7","type":"FreeCodingProblems"},"links":{"demo_url":"https://codecheck.io/files/horstmann/codecheck-python-Producing2DArrays-7"},"attribution":{"created_at":"2026-01-01T00:00:00.000Z","provider":"CodeCheck","publisher":"Cay Horstmann","authors":[{"name":"Cay Horstmann","affiliation":"San José State University"}]},"languages":{"content_language":"en","programming_languages":["Python"]},"content":{"prompt":"Given a two-dimensional array a, return a list whose [i][j] element is the average of the neighbors of a[i][j] in the N, E, S, W direction. ","source_code":"\r\n# Given a two-dimensional array a, return a two-dimensional array whose \r\n# [i][j] element is the average of the neighbors of a[i][j] \r\n# in the N, E, S, W direction. You may assume that there\r\n# are elements in all directions. \r\n\r\ndef averageElements(arr, i, j):\r\n   # Your code here...\n"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"CayHorstmann-keywords":{"concepts":["Two-Dimensional Arrays","Producing 2D Arrays"],"note":"extracted from the SPLICE.SLCItem.keywords field"}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"SPLICE","url":"https://codecheck.io/files/horstmann/codecheck-python-Producing2DArrays-7"},{"protocol":"LTI 1.1","url":"https://codecheck.io/lti/problem/files/horstmann/codecheck-python-Producing2DArrays-7"}],"rights":{"license":"CC BY-NC-ND 4.0","license_url":"https://creativecommons.org/licenses/by-nc-nd/4.0/","usage_notes":""},"uses":[],"created_at":"2026-02-15T21:06:27.439Z","updated_at":"2026-05-19T22:12:57.475Z","paws_id":3067}
# [1/3298:200] restored item id: 69cd72927afb2475509e5eb7
# {"id":"69cd72927afb2475509e5eb7","paws_id":4340,"user_email":"moh70@pitt.edu","status":"public","created_at":"2025-12-31T06:03:59.919Z","updated_at":"2026-05-19T22:12:57.532Z","listed_at":"2025-09-10T22:18:56.000Z","tags":[],"identity":{"id":"Vending Machine With Quarters-Dimes- and Nickels__68bdb308f6cc3d7a9cc0974e-68bdb308f6cc3d7a9cc0974c-1","title":"Vending Machine With Quarters-Dimes- and Nickels","type":"CodeCompletionProblem"},"links":{"demo_url":"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/artihmetic_vending_machine__68bdb308f6cc3d7a9cc0974e?index=1"},"attribution":{"created_at":"2025-09-10T22:18:56.000Z","provider":"PCEX","publisher":"","authors":[{"name":"Mohammad Hassany","affiliation":"University of Pittsburgh"}]},"languages":{"content_language":"en","programming_languages":["Java"]},"content":{"prompt":"Suppose we have a vending machine that gives change. A customer selects an item for purchase and inserts a bill into the vending machine. The vending machine dispenses the purchased item and gives change. We will assume that all item prices are multiples of 5 cents, and the machine gives all change in quarters, dimes, and nickels. Construct a program that computes how many quarters, dimes, and nickels to return to the customer.","source_code":"import java.util.Scanner;\npublic class VendingMachine2\n{\n\tpublic static void main(String[] args)\n\t{\n\t\t//Step 1: Define the constants that we need for this program\n\t\tfinal int PENNIES_PER_DOLLAR = 100;\n\t\tfinal int PENNIES_PER_QUARTER = 25;\n\t\tfinal int PENNIES_PER_DIME = 10;\n\t\tfinal int PENNIES_PER_NICKEL = 5;\n\t\t//Step 2: Read the bill value and item price\n\t\tScanner scan = new Scanner(System.in);\n\t\tSystem.out.println(\"Enter bill value in dollars (1 = $1 bill, 5 = $5 bill, etc.): \");\n\t\tint billValue = scan.nextInt();\n\t\tSystem.out.println(\"Enter item price in pennies: \");\n\t\tint itemPrice = scan.nextInt();\n\t\tscan.close();\n\t\t//Step 3: Compute the change due\n\t\tint changeDue = PENNIES_PER_DOLLAR * billValue - itemPrice;\n\t\t//Step 4: Compute the number of quarters in the change due and update the change due after taking away the quarters\n\t\tint quarters = changeDue / PENNIES_PER_QUARTER;\n\t\tchangeDue = changeDue % PENNIES_PER_QUARTER;\n\t\t//Step 5: Compute the number of dimes in the remaining change due and update the change due after taking away the dimes\n\t\tint dimes = changeDue / PENNIES_PER_DIME;\n\t\tchangeDue = changeDue % PENNIES_PER_DIME;\n\t\t//Step 6: Compute the number of nickels in the remaining change due\n\t\tint nickels = changeDue / PENNIES_PER_NICKEL;\n\t\t//Step 7: Display the result\n\t\tSystem.out.println(\"Your change consists of:\"); \n\t\tSystem.out.println(quarters + \" quarters\");\n\t\tSystem.out.println(dimes + \" dimes\"); \n\t\tSystem.out.println(nickels + \" nickels\");\n\t}\n}"},"classification":{"topics":[],"difficulty":""},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"SPLICE","url":"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/artihmetic_vending_machine__68bdb308f6cc3d7a9cc0974e?index=1"},{"protocol":"HTML","url":"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/artihmetic_vending_machine__68bdb308f6cc3d7a9cc0974e?index=1"},{"protocol":"PITT","url":"https://acos.cs.vt.edu/pitt/acos-pcex/acos-pcex-examples/artihmetic_vending_machine__68bdb308f6cc3d7a9cc0974e?index=1"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=467","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=467","context_name":"Java: CS 007 | CS007 - Java Programming (Fall 2025) > Variables and Primitive Data Types","used_at":"2025-09-03T17:58:29.000Z","used_by":"Mohammad Hassany - "},{"context_id":"cid=468","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo ...
# [2/3298:200] restored item id: 6954bccff9187b06cf8375a5
# {"id":"6954bccff9187b06cf8375a5","user_email":"moh70@pitt.edu","status":"public","listed_at":"2015-02-15T14:55:45.000Z","updated_at":"2026-05-19T22:12:57.592Z","tags":["TODO:add-prompt"],"identity":{"id":"ae_switch_demo2","title":"Switch Demo 2","type":"CodeVisualization"},"links":{"demo_url":"https://acos.cs.vt.edu/pitt/jsvee/jsvee-java/ae?example-id=ae_switch_demo2&grp=demo&usr=demo&sid=-1&cid=-1"},"attribution":{"created_at":"2015-02-15T14:55:45.000Z","provider":"JSVEE","publisher":"","authors":[{"name":"Roya Hosseini","affiliation":"University of Pittsburgh"}]},"languages":{"content_language":"en","programming_languages":["Java"]},"content":{"prompt":"","source_code":"public class SwitchDemoFallThrough {\n\n public static void main(String[] args) {\n  ArrayList<String> futureMonths = new ArrayList<String>();\n\n  int month = 3;\n\n  switch (month) {\n    case 1:  futureMonths.add(\"January\");\n    case 2:  futureMonths.add(\"February\");\n    case 3:  futureMonths.add(\"March\");\n    case 4:  futureMonths.add(\"April\");\n    case 5:  futureMonths.add(\"May\");\n    case 6:  futureMonths.add(\"June\");\n    case 7:  futureMonths.add(\"July\");\n    case 8:  futureMonths.add(\"August\");\n    case 9:  futureMonths.add(\"September\");\n    case 10: futureMonths.add(\"October\");\n    case 11: futureMonths.add(\"November\");\n    case 12: futureMonths.add(\"December\");\n    break;\n    default: break;\n  }\n\n  if (futureMonths.isEmpty()) {\n    System.out.println(\"Invalid month number\");\n  } else {\n    System.out.println(futureMonths.size() + \" upcoming months.\");\n  }\n }\n}"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"parser":{"concepts":["ActualMethodParameter","java.util.ArrayList.add","java.util.ArrayList","ObjectMethodInvocation","IfElseStatement","VoidDataType","SimpleAssignmentExpression","StringLiteral","FormalMethodParameter","java.util.ArrayList.size","MethodDefinition","ClassDefinition","java.lang.System.out.println","GenericObjectCreationStatement","StaticMethodSpecifier","PublicClassSpecifier","BreakStatement","DefaultClause","PublicMethodSpecifier","CaseClause","StringAddition","StringDataType","IntDataType","SwitchStatement"],"note":"","created_at":null,"updated_at":null}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://acos.cs.vt.edu/pitt/jsvee/jsvee-java/ae?example-id=ae_switch_demo2"},{"protocol":"SPLICE","url":"https://acos.cs.vt.edu/html/jsvee/jsvee-java/ae_switch_demo2"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=13","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=13","context_name":"Java: INFSCI 0017 | Revised Java Course [clone] - Animated Examples > Switch","used_at":"2014-09-09T15:38:38.000Z","used_by":"Administrator - University of Pittsburgh"},{"context_id":"cid=21","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=21","context_name":"Java: INFSCI 0017 2 | Demo Course 2 > Switch","used_at":"2015-04-15T13:10:54.000Z","used_by":"Roya Hosseini - University of Pittsburgh"},{"context_id":"cid=29","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=29","context_name":"Java: INFSCI 0017 | mg-gs-demo > Switch","used_at":"2015-09-14T11:10:25.000Z","used_by":"Roya Hosseini - University of Pittsburgh"},{"context_id":"cid=31","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=31","context_name":"Java: INFSCI 0017 | roya-clone-test-java > Switch","used_at":"2015-12-08T17:16:50.000Z","used_by":"Roya Hosseini - University of Pittsburgh"},{"context_id":"cid=32","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=32","context_name":"Java: INFSCI 0017 | Revised  ...
# [3/3298:200] restored item id: 6954bccff9187b06cf837459
# {"id":"6954bccff9187b06cf837459","user_email":"moh70@pitt.edu","status":"public","listed_at":"2016-09-16T14:07:44.000Z","updated_at":"2026-05-19T22:12:57.649Z","tags":[],"identity":{"id":"Bicycle","title":"DEPRECATED_Bicycle","type":"BehaviorExample"},"links":{"demo_url":"https://acos.cs.vt.edu/html/annotated/acos-annex-java/Bicycle"},"attribution":{"created_at":"2016-09-16T14:07:44.000Z","provider":"AnnEx","publisher":"","authors":[{"name":"Unknown","affiliation":""}]},"languages":{"content_language":"en","programming_languages":["Java"]},"content":{"prompt":"","source_code":"//Sun Java Tutorial, Learning the Java Language>> Classes and Objects\r\n\r\n\n\r\n\npublic class Bicycle {\r\n\r\n\n\t\r\n\r\n\n    // the Bicycle class has three fields\r\n\r\n\n    private int cadence;\r\n\r\n\n    private int gear;\r\n\r\n\n    private int speed;\r\n\r\n\n\t\r\n\r\n\n    // the Bicycle class has one constructor\r\n\r\n\n    public Bicycle(int startCadence, int startSpeed, int startGear) {\r\n\r\n\n        gear = startGear;\r\n\r\n\n        cadence = startCadence;\r\n\r\n\n        speed = startSpeed;\r\n\r\n\n    }\r\n\r\n\n\t\r\n\r\n\n    // the Bicycle class has four methods\r\n\r\n\n    public void setCadence(int newValue) {\r\n\r\n\n        cadence = newValue;\r\n\r\n\n    }\r\n\r\n\n\t\r\n\r\n\n    public void setGear(int newValue) {\r\n\r\n\n        gear = newValue;\r\n\r\n\n    }\r\n\r\n\n\t\r\n\r\n\n    public void applyBrake(int decrement) {\r\n\r\n\n        speed = speed - decrement;\r\n\r\n\n    }\r\n\r\n\n\t\r\n\r\n\n    public void speedUp(int increment) {\r\n\r\n\n        speed = speed + increment;\r\n\r\n\n    }\r\n\r\n\n\t\r\n\r\n\n}\r\n"},"classification":{"topics":[],"difficulty":""},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"SPLICE","url":"https://acos.cs.vt.edu/html/annotated/acos-annex-java/Bicycle"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[],"created_at":"2025-12-31T06:04:00.132Z","paws_id":1592}
# [4/3298:200] restored item id: 6954bccff9187b06cf8371d5
# {"id":"6954bccff9187b06cf8371d5","user_email":"moh70@pitt.edu","status":"public","listed_at":"2019-09-11T12:44:20.000Z","updated_at":"2026-05-19T22:12:57.702Z","tags":["TODO:add-prompt"],"identity":{"id":"q_py___gt__1","title":"Greater Than 1","type":"PredictingFinalResult"},"links":{"demo_url":"https://adapt2.sis.pitt.edu/quizpet/displayQuiz.jsp?rdfID=q_py___gt__1&sub=q_py___gt__1&act=q_topic_classes_objects"},"attribution":{"created_at":"2019-09-11T12:44:20.000Z","provider":"QuizPET","publisher":"","authors":[{"name":"Michelle Wang","affiliation":""}]},"languages":{"content_language":"en","programming_languages":["Python"]},"content":{"prompt":"","source_code":"class A(object):\n    def __gt__(self, other):\n        print(\"A __eq__ called\")\n        return self.value > other.value\nclass B(object):\n    def __gt__(self, other):\n        print(\"B __eq__ called\")\n        return self.value > other.value\na = A()\na.value = 3\nb = B()\nb.value = 4\nprint(a > b)\nprint(b > a)"},"classification":{"topics":[],"difficulty":""},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://adapt2.sis.pitt.edu/quizpet/displayQuiz.jsp?rdfID=q_py___gt__1&sub=q_py___gt__1&act=q_topic_classes_objects"},{"protocol":"HTML","url":"https://adapt2.sis.pitt.edu/quizpet/displayQuiz.jsp?rdfID=q_py___gt__1&sub=q_py___gt__1&act=q_topic_classes_objects"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=375","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=375","context_name":"Python: PYTHON001 | University of Alberta Python Course > Rich Comparison Methods","used_at":"2019-07-03T11:34:57.000Z","used_by":"Michelle, Wang - University of Alberta"},{"context_id":"cid=379","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=379","context_name":"Python: PYTHON001 | University of Alberta Python Fall 2019 > Classes and objects","used_at":"2019-09-14T21:22:08.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=391","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=391","context_name":"Python: PYTHON001 | University of Alberta Python Course, Fall 2020 > Rich Comparison Methods","used_at":"2020-07-03T01:07:51.000Z","used_by":"Carrie, Demmans - University of Alberta"}],"created_at":"2025-12-31T06:04:00.075Z","paws_id":2429}
# [5/3298:200] restored item id: 6954bccff9187b06cf836ef2
# {"id":"6954bccff9187b06cf836ef2","user_email":"moh70@pitt.edu","status":"public","listed_at":"2025-04-03T08:00:00.000Z","updated_at":"2026-05-19T22:12:57.749Z","tags":[],"identity":{"id":"py_is_teenager_if_es","title":" PCRS C3-PL Is teenager","type":"FreeCodingProblems"},"links":{"demo_url":"https://pcrs.utm.utoronto.ca/mgrids/problems/python/206/embed?act=PCRS&sub=py_is_teenager_if_es"},"attribution":{"created_at":"2025-04-03T08:00:00.000Z","provider":"PCRS","publisher":"","authors":[{"name":"Jordan Barria-Pineda","affiliation":"University of Pittsburgh"}]},"languages":{"content_language":"es","programming_languages":["Python"]},"content":{"prompt":"Generalmente se considera que una persona es un adolescente entre las edades de 13 y 18 años. Escriba una función que determine si la edad dada es a la vez adolescente y no un número primo. (Pista: sólo 13 y 17 son primos en ese rango).","source_code":"[student_code]\r\ndef adolescenteNoPrimo(edad):\r\n    return\r\n[/student_code]"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"alice_edu_py_ontology jordan":{"concepts":["NestedIfChecking"],"note":"","created_at":null,"updated_at":null},"alice_edu_py_ontology llm":{"concepts":["DefiningSimpleFunction","IfChecking","BooleanLiteral","IntegerLiteral","ComparisonExpression","LogicalExpression","CallingSimpleFunction"],"note":"","created_at":null,"updated_at":null},"alice_edu_py_ontology llm mod":{"concepts":["IfElseChecking"],"note":"","created_at":null,"updated_at":null}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://pcrs.utm.utoronto.ca/mgrids/problems/python/206/embed?act=PCRS&sub=py_is_teenager_if_es"},{"protocol":"HTML","url":"https://pcrs.utm.utoronto.ca/mgrids/problems/python/206/embed?act=PCRS&sub=py_is_teenager_if_es"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[],"created_at":"2025-12-31T06:03:59.977Z","paws_id":4411}
# [6/3298:200] restored item id: 6954bccff9187b06cf836e84
# {"id":"6954bccff9187b06cf836e84","user_email":"moh70@pitt.edu","status":"public","listed_at":"2025-04-03T08:00:00.000Z","updated_at":"2026-05-19T22:12:57.813Z","tags":[],"identity":{"id":"py_countA","title":"PCRS C3-PL  Counta","type":"FreeCodingProblems"},"links":{"demo_url":"https://pcrs.utm.utoronto.ca/mgrids/problems/python/125/embed?act=PCRS&sub=py_countA"},"attribution":{"created_at":"2025-04-03T08:00:00.000Z","provider":"PCRS","publisher":"","authors":[{"name":"Jordan Barria-Pineda","affiliation":"University of Pittsburgh"}]},"languages":{"content_language":"en","programming_languages":["Python"]},"content":{"prompt":"Write a function that takes a string and returns the number of \"a\"s.countA(\"This is a string\") -> 1countA(\"Oranges are not apples\") -> 3countA(\"To be or not to be\") -> 0","source_code":"[student_code]\ndef countA(s):\n    #your code here\n[/student_code]"},"classification":{"topics":[],"difficulty":""},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://pcrs.utm.utoronto.ca/mgrids/problems/python/125/embed?act=PCRS&sub=py_countA"},{"protocol":"HTML","url":"https://pcrs.utm.utoronto.ca/mgrids/problems/python/125/embed?act=PCRS&sub=py_countA"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=454","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=454","context_name":"Python: CMU15110 | CMU 15-110 Principles of Computing (Python) - All content > Strings","used_at":"2025-03-27T12:46:05.000Z","used_by":"Jordan Barria, Jordan Barria - University Of Pittsburgh"},{"context_id":"cid=462","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=462","context_name":"Python: SandboxPython | Sandbox Python Course > Strings","used_at":"2025-06-14T00:28:07.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"}],"created_at":"2025-12-31T06:03:59.965Z","paws_id":3653}
# [7/3298:200] restored item id: 6954bccff9187b06cf8373bb
# {"id":"6954bccff9187b06cf8373bb","user_email":"moh70@pitt.edu","status":"public","listed_at":"2016-09-16T14:07:46.000Z","updated_at":"2026-05-19T22:12:57.890Z","tags":["TODO:add-prompt"],"identity":{"id":"ae_python_function","title":"ae_python_function","type":"CodeVisualization"},"links":{"demo_url":"https://acos.cs.vt.edu/pitt/jsvee/jsvee-python/ae?example-id=ae_python_function&grp=demo&usr=demo&sid=-1&cid=-1"},"attribution":{"created_at":"2016-09-16T14:07:46.000Z","provider":"JSVEE","publisher":"","authors":[{"name":"Sirkiä Teemu","affiliation":"Aalto University"}]},"languages":{"content_language":"en","programming_languages":["Python"]},"content":{"prompt":"","source_code":"def calculate_area(width, height):\n  print(\"Dimensions are:\", width, height)\n  result = width * height\n  return height\n\ndef main():\n  side1 = 12\n  side2 = 10\n  area = calculate_area(side1, side2)\n  print(\"Area is:\", area)\n  print(\"Area is:\", calculate_area(2+3, 7+2))\n\nmain()"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"alice_edu_py_ontology expert":{"concepts":["Multiplication","Addition","AssigningValueVariable","CallingLibraryFunction","Printing","CallingFunctionCallingFunction","DefiningSimpleFunction","NestedFunctionCall","CreatingString","DefiningFunctionCallingFunction"],"note":"","created_at":null,"updated_at":null},"parser":{"concepts":["Call","arg","Assign","Add","Return","Mult","Str","Int","FunctionDef"],"note":"","created_at":null,"updated_at":null},"unspecified":{"concepts":["arg","Call","Assign","Return","FunctionDef","Int","Add","Mult","Str"],"note":"","created_at":null,"updated_at":null},"Rafaella added 09.03.2025 alice_edu_py_ontology":{"concepts":["Addition","AssigningValueVariable","CallingFunctionCallingFunction","CallingLibraryFunction","CreatingString","DefiningFunctionCallingFunction","DefiningSimpleFunction","Multiplication","NestedFunctionCall","Printing"],"note":"","created_at":null,"updated_at":null}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://acos.cs.vt.edu/pitt/jsvee/jsvee-python/ae?example-id=ae_python_function"},{"protocol":"SPLICE","url":"https://acos.cs.vt.edu/html/jsvee/jsvee-python/ae_python_function"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=396","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=396","context_name":"Python: PYTHON001 | Widener University Python Course (Fall 2020) > Functions","used_at":"2020-08-16T23:39:01.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=403","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=403","context_name":"Python: PYTHON001 | Aalto Python Fall 2020 > Functions","used_at":"2020-09-04T17:46:26.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=404","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=404","context_name":"Python: PYTHON001 | Aalto Python Fall 2020 (PCEX-Ex,PCEX-Ch) > Functions","used_at":"2020-09-07T18:36:47.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=407","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=407","context_name":"Python: PYTHON001 | Widener University Python Course (Spring 2021) > Functions","used_at":"2021-01-26T22:51:01.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=410","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=410","context_name":"Python: PYTHON001 | Utrecht Python Spring 2021 > Functions","used_at":"2021-02-16T21:53:05.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=411","context_url":"htt ...
# [8/3298:200] restored item id: 69cd72af7afb2475509e6259
# {"id":"69cd72af7afb2475509e6259","paws_id":null,"user_email":"moh70@pitt.edu","status":"public","created_at":"2026-02-15T22:33:57.330Z","updated_at":"2026-05-19T22:12:57.960Z","listed_at":"2026-02-15T22:33:57.328Z","tags":[],"identity":{"id":"c_dinamicka_alokacija_varijable_malloc__6952d68f136f190edb6d4936-6952b4f4136f190edb6d3389-0","title":"c_dinamicka_alokacija_varijable_malloc","type":"CodeConstruction"},"links":{"demo_url":"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/Dinamicka_alokacija_obicnih_varijabli__6952d68f136f190edb6d4936?index=1"},"attribution":{"created_at":"2026-01-01T00:00:00Z","provider":"PCEX","publisher":"PAWS Lab - WEAT","authors":[{"name":"Amina Hromic","affiliation":"Univerzitet u Sarajevu"}]},"languages":{"content_language":"bs","programming_languages":["C"]},"content":{"prompt":"Napisati C program koji dinamički alocira memoriju za jednu cjelobrojnu varijablu. Program treba omogućiti korisniku da unese cijeli broj, smjesti ga u dinamički alociranu memoriju, ispiše unesenu vrijednost na ekran, te na kraju pravilno oslobodi zauzetu memoriju. Potrebno je provjeriti da li je alokacija memorije uspješno izvršena prije korištenja pokazivača.","source_code":"#include <stdio.h>\r\n#include <stdlib.h>\r\n\r\nint main() {\r\n    int *x;\r\n\r\n    /* dinamicka alokacija jedne int varijable */\r\n    x = (int *)malloc(sizeof(int));\r\n\r\n    if (x == NULL) {\r\n        printf(\"Alokacija nije uspjela.\\n\");\r\n        return 1;\r\n    }\r\n\r\n    printf(\"Unesite cijeli broj: \");\r\n    scanf(\"%d\", x);\r\n\r\n    printf(\"Uneseni broj je: %d\\n\", *x);\r\n\r\n    /* oslobadjanje memorije */\r\n    free(x);\r\n\r\n    return 0;\r\n}\r\n"},"classification":{"topics":[],"difficulty":""},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"SPLICE","url":"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/Dinamicka_alokacija_obicnih_varijabli__6952d68f136f190edb6d4936?index=1"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[]}
# [9/3298:200] restored item id: 6954bccff9187b06cf836db7
# {"id":"6954bccff9187b06cf836db7","user_email":"moh70@pitt.edu","status":"public","listed_at":"2025-05-12T15:19:48.000Z","updated_at":"2026-05-19T22:12:58.033Z","tags":[],"identity":{"id":"ps_python_nested_ifs_es","title":"Practicar sentencias if anidadas","type":"ParsonsProblem"},"links":{"demo_url":"https://adapt2.sis.pitt.edu/acos/pitt/jsparsons/jsparsons-python/ps?example-id=ps_python_nested_ifs_es&grp=demo&usr=demo&sid=-1&cid=-1"},"attribution":{"created_at":"2025-05-12T15:19:48.000Z","provider":"jsParsons","publisher":"","authors":[{"name":"Kamil Akhuseyinoglu","affiliation":"University of Pittsburgh"}]},"languages":{"content_language":"es","programming_languages":["Python"]},"content":{"prompt":"Construye un programa que imprima una oracion dependiendo de la hora del dia. Noche se considera antes de las 7 a.m., manana es desde las 7 a.m. hasta el mediodia, tarde hasta las 5 p.m. y el resto se considera noche.","source_code":"if am_o_pm == \"am\":\n\tif hora < 7:\n\t\tprint(\"Todavia es de noche\")\n\telse:\n\t\tprint(\"Es de manana\")\nelif am_o_pm == \"pm\":\n\tif hora <= 5:\n\t\tprint(\"Es de tarde\")\n\telse:\n\t\tprint(\"Es de noche\")\n"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"alice_edu_py_ontology expert":{"concepts":["CallingLibraryFunction","BooleanEvaluating","Printing","IfElifChecking","NestedIfChecking"],"note":"","created_at":null,"updated_at":null},"parser":{"concepts":["LtE","Int","Lt","Call","Str","Eq","If"],"note":"","created_at":null,"updated_at":null},"unspecified":{"concepts":["Call","Eq","Int","Str","Lt","If","LtE"],"note":"","created_at":null,"updated_at":null},"Rafaella added 09.03.2025 alice_edu_py_ontology":{"concepts":["BooleanEvaluating","CallingLibraryFunction","IfElifChecking","NestedIfChecking","Printing"],"note":"","created_at":null,"updated_at":null}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://adapt2.sis.pitt.edu/acos/pitt/jsparsons/jsparsons-python/ps?example-id=ps_python_nested_ifs_es"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=457","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=457","context_name":"Python: PythonES | Programacion en Python en Espanol > Condicionales","used_at":"2025-03-30T22:04:51.000Z","used_by":"Jordan Barria, Jordan Barria - University Of Pittsburgh"},{"context_id":"cid=461","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=461","context_name":"Python: INFO063-25 | INTRODUCCION A LA PROGRAMACION > Condicionales","used_at":"2025-05-25T23:03:06.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=463","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=463","context_name":"Python: UTFSM-Progra | Programacion UTFSM > Condicionales","used_at":"2025-06-17T01:16:04.000Z","used_by":"Jordan Barria, Jordan Barria - University Of Pittsburgh"},{"context_id":"cid=464","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=464","context_name":"Python: UTFSM-Progra | Test Jordan Thesis Python ES > Condicionales","used_at":"2025-07-10T18:56:02.000Z","used_by":"Jordan Barria, Jordan Barria - University Of Pittsburgh"}],"created_at":"2025-12-31T06:03:59.944Z","paws_id":3922}
# [10/3298:200] restored item id: 6954bccff9187b06cf83779d
# {"id":"6954bccff9187b06cf83779d","user_email":"moh70@pitt.edu","status":"public","listed_at":"1970-01-01T00:00:00.000Z","updated_at":"2026-05-19T22:12:58.112Z","tags":["TODO:add-prompt"],"identity":{"id":"jOperator1","title":"Modulus Operator","type":"PredictingFinalResult"},"links":{"demo_url":"https://pawscomp2.sis.pitt.edu/quizjet/displayQuiz.jsp?rdfID=joperator1&act=Arithmetic_Operations&sub=jOperator1&svc=progvis"},"attribution":{"created_at":"1970-01-01T00:00:00.000Z","provider":"QuizJET","publisher":"","authors":[{"name":"Sharon Hsiao","affiliation":"University of Pittsburgh"}]},"languages":{"content_language":"en","programming_languages":["Java"]},"content":{"prompt":"","source_code":"public class Tester {\n  public static void main(String[] args) {      \n   \n      int result = 2 % 3;\n   \n  }\n}"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"expert":{"concepts":["Arithmetic Expressions","IntDataType","ModulusExpression","SimpleAssignmentExpression","SimpleVariable","VariableInitializationStatement"],"note":"","created_at":null,"updated_at":null},"unspecified":{"concepts":["Arithmetic Expressions"],"note":"","created_at":null,"updated_at":null},"java ontology v2":{"concepts":["PublicMethodSpecifier","VariableInitializationStatement","SimpleVariable","ClassDefinition","SimpleAssignmentExpression","ModulusExpression","IntDataType","FormalMethodParameter","StaticMethodSpecifier","PublicClassSpecifier","VoidDataType","MethodDefinition"],"note":"","created_at":null,"updated_at":null}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://pawscomp2.sis.pitt.edu/quizjet/displayQuiz.jsp?rdfID=joperator1&act=Arithmetic_Operations&sub=jOperator1&svc=progvis"},{"protocol":"HTML","url":"https://pawscomp2.sis.pitt.edu/quizjet/displayQuiz.jsp?rdfID=joperator1&act=Arithmetic_Operations&sub=jOperator1&svc=progvis"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=1","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=1","context_name":"Java: INFSCI 0017 | Introduction to Java Programming > Arithmetic Operations","used_at":"2013-05-23T12:19:44.000Z","used_by":"Administrator - University of Pittsburgh"},{"context_id":"cid=3","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=3","context_name":"Java: STUDY2013 | Lab Study 2013 - 2014 > Variables and Operations","used_at":"2013-12-07T14:35:37.000Z","used_by":"Roya Hosseini - University of Pittsburgh"},{"context_id":"cid=10","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=10","context_name":"Java: STUDY2013 | Lab Study 2013 - 2014 [cloned on 8/21/2014 at 10:55:44 PM] > Variables and Operations","used_at":"2014-08-21T22:55:46.000Z","used_by":"Administrator - University of Pittsburgh"},{"context_id":"cid=11","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=11","context_name":"Java: INFSCI 0017 | Revised Java Course [clone] > Arithmetic Operations","used_at":"2014-08-30T12:57:33.000Z","used_by":"Administrator - University of Pittsburgh"},{"context_id":"cid=13","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=13","context_name":"Java: INFSCI 0017 | Revised Java Course [clone] - Animated Examples > Arithmetic Operations","used_at":"2014-09-09T15:38:38.000Z","used_by":"Administrator - University of Pittsburgh"},{"context_id":"cid=17","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=17","context_name":"Java: INFSCI 0017 | Introduction to Java Programming (Fall 2014-ae) > Arithmetic Operations","used_at":"2014-09-11T11:50:18.000Z","used_by":"Administrator - University of Pittsburgh"},{"context_id":"cid=19","context ...
# [11/3298:200] restored item id: 69923550fbbb65899e0a1e1b
# {"id":"69923550fbbb65899e0a1e1b","user_email":"moh70@pitt.edu","status":"public","listed_at":"2026-02-15T00:00:00.000Z","tags":[],"identity":{"id":"horstmann/codecheck-python-MaximumandMinimum-3","title":"codecheck-python-MaximumandMinimum-3","type":"FreeCodingProblems"},"links":{"demo_url":"https://codecheck.io/files/horstmann/codecheck-python-MaximumandMinimum-3"},"attribution":{"created_at":"2026-01-01T00:00:00.000Z","provider":"CodeCheck","publisher":"Cay Horstmann","authors":[{"name":"Cay Horstmann","affiliation":"San José State University"}]},"languages":{"content_language":"en","programming_languages":["Python"]},"content":{"prompt":"Given a list of integers, return the difference of the positions of the first and the last occurrence of the largest element. ","source_code":"\r\n# Given a list of integers, return the difference of the positions \r\n# of the first and the last occurrence of the largest element.\r\n# You may assume that the largest element occurs at least once. \r\n# You may also assume that the given list contains at least one \r\n# element. Do not use builtins min, max, find, or index.\r\n\r\ndef positionDifferenceFirstLastLargest(arr):\r\n   # Your code here...\n"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"CayHorstmann-keywords":{"concepts":["Lists - Simple Exercises","Maximum and Minimum"],"note":"extracted from the SPLICE.SLCItem.keywords field"}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"SPLICE","url":"https://codecheck.io/files/horstmann/codecheck-python-MaximumandMinimum-3"},{"protocol":"LTI 1.1","url":"https://codecheck.io/lti/problem/files/horstmann/codecheck-python-MaximumandMinimum-3"}],"rights":{"license":"CC BY-NC-ND 4.0","license_url":"https://creativecommons.org/licenses/by-nc-nd/4.0/","usage_notes":""},"uses":[],"created_at":"2026-02-15T21:06:24.864Z","updated_at":"2026-05-19T22:12:58.185Z","paws_id":2970}
# [12/3298:200] restored item id: 69cd729f7afb2475509e6077
# {"id":"69cd729f7afb2475509e6077","paws_id":null,"user_email":"moh70@pitt.edu","status":"public","created_at":"2026-02-15T22:34:05.548Z","updated_at":"2026-05-19T22:12:58.247Z","listed_at":"2026-02-15T22:34:05.547Z","tags":[],"identity":{"id":"c_funkcija_stepenuj__6910b1521b622a00857decff-69106c421b622a00857deba2-2","title":"c_funkcija_stepenuj","type":"CodeCompletionProblem"},"links":{"demo_url":"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/Funkcije_i_izrazi__6910b1521b622a00857decff?index=2"},"attribution":{"created_at":"2026-01-01T00:00:00Z","provider":"PCEX","publisher":"PAWS Lab - WEAT","authors":[{"name":"Mubina Kamberovic","affiliation":"Univerzitet u Sarajevu"}]},"languages":{"content_language":"bs","programming_languages":["C"]},"content":{"prompt":"Napisati program koji koristi funkciju stepenuj za izračunavanje stepena cijelog broja. Ispisati vrijednosti stepenovanja brojeva 2 i -3 za stepene n = 0, 1, 2, 3 i 4.","source_code":"#include <stdio.h>\r\n\r\nint stepenuj(int, int); /* prototip funkcije */\r\n\r\nint main() {\r\n\tint i, x, y;\r\n\t\r\n\tprintf(\"stepen 2^stepen (-3)^stepen\\n\");\r\n\tfor(i = 0; i < 5; ++i) {\r\n\t\tx = stepenuj(2, i);\r\n\t\ty = stepenuj(-3, i);\r\n\t\tprintf(\"%4d %6d %10d\\n\", i, x, y);\r\n\t}\r\n\t\r\n\treturn 0;\r\n}\r\n\r\n/* stepenuj bazu na n, gdje je n >= 0 */\r\nint stepenuj(int baza, int n) {\r\n\tint i, p = 1;\r\n\t\r\n\tfor(i = 0; i < n; i++) p = p * baza;\r\n\t\r\n\treturn p;\r\n}\r\n"},"classification":{"topics":[],"difficulty":""},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"SPLICE","url":"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/Funkcije_i_izrazi__6910b1521b622a00857decff?index=2"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[]}
# [13/3298:200] restored item id: 6954bccff9187b06cf8374e0
# {"id":"6954bccff9187b06cf8374e0","user_email":"moh70@pitt.edu","status":"public","listed_at":"2015-10-15T10:28:47.000Z","updated_at":"2026-05-19T22:12:58.315Z","tags":[],"identity":{"id":"ps_python_try_adding","title":"Try adding","type":"ParsonsProblem"},"links":{"demo_url":"https://adapt2.sis.pitt.edu/acos/pitt/jsparsons/jsparsons-python/ps?example-id=ps_python_try_adding&grp=demo&usr=demo&sid=-1&cid=-1"},"attribution":{"created_at":"2015-10-15T10:28:47.000Z","provider":"jsParsons","publisher":"","authors":[{"name":"Haaranen Lassi","affiliation":"Aalto University"}]},"languages":{"content_language":"en","programming_languages":["Python"]},"content":{"prompt":"Construct a function that adds two numbers together and handles non-numeric input.","source_code":"def add_two_numbers(a,b):\n\ttry:\n\t\treturn a + b\n\texcept TypeError:\n\t\tprint(\"Can only add numbers together.\")"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"alice_edu_py_ontology expert":{"concepts":["Addition","CallingLibraryFunction","HandlingSpecificError","Printing","DefiningSimpleFunction"],"note":"","created_at":null,"updated_at":null},"parser":{"concepts":["Attribute","List","Add","Call","Str","Assign"],"note":"","created_at":null,"updated_at":null},"unspecified":{"concepts":["Call","Assign","List","Attribute","Add","Str"],"note":"","created_at":null,"updated_at":null},"Rafaella added 09.03.2025 alice_edu_py_ontology":{"concepts":["Addition","CallingLibraryFunction","DefiningSimpleFunction","HandlingSpecificError","Printing"],"note":"","created_at":null,"updated_at":null}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":"https://adapt2.sis.pitt.edu/acos/pitt/jsparsons/jsparsons-python/ps?example-id=ps_python_try_adding"}],"rights":{"license":"MIT","license_url":"","usage_notes":""},"uses":[{"context_id":"cid=23","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=23","context_name":"Python: PYTHON001 | Python Course (v1) > Exceptions","used_at":"2015-05-11T10:25:58.000Z","used_by":"Python Admin - University of Pittsburgh"},{"context_id":"cid=344","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=344","context_name":"Python: PYTHON001 | PythonCourseV1Clones > Exceptions","used_at":"2017-05-22T17:58:24.000Z","used_by":"Roya Hosseini - University of Pittsburgh"},{"context_id":"cid=346","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=346","context_name":"Python: PYTHON001 | Python Course (Program Construction) > Exception handling","used_at":"2017-09-10T13:11:43.000Z","used_by":"Roya Hosseini - University of Pittsburgh"},{"context_id":"cid=365","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=365","context_name":"Python: PYTHON001 | Python Course (AE-QP-PCEX-Parsons) > Exception handling","used_at":"2018-09-25T15:11:21.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=372","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=372","context_name":"Python: PYTHON001 | Python Course (CTAT-T3-AE-QP-PCEX-Parsons) > Exception handling","used_at":"2019-05-07T02:44:53.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=373","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=373","context_name":"Python: INFSCI 0019 | Python for Data Management & Analytics > Exception handling","used_at":"2019-05-12T00:16:14.000Z","used_by":"Kamil Akhuseyinoglu - University Of Pittsburgh"},{"context_id":"cid=375","context_url":"https://adapt2.sis.pitt.edu/um-vis-dev2/index.html?usr=demo&grp=adl&sid=adl&cid=375","context_name":"Python: PYTHON001 | University of Alberta Python Course > Exce ...
# [14/3298:200] restored item id: 69cd72a97afb2475509e6193
# {"id":"69cd72a97afb2475509e6193","paws_id":2035,"user_email":"moh70@pitt.edu","status":"public","created_at":"2025-12-31T06:04:00.101Z","updated_at":"2026-05-19T22:12:58.395Z","listed_at":"2017-10-25T22:29:41.000Z","tags":[],"identity":{"id":"py_work_hours","title":"Reporting the Total Hours Each Employee Worked ","type":"CodeConstruction"},"links":{"demo_url":"https://pawscomp2.sis.pitt.edu/pcex/index.html?lang=PYTHON&set=py_work_hours"},"attribution":{"created_at":"2017-10-25T22:29:41.000Z","provider":"PCEX","publisher":"","authors":[{"name":"Roya Hosseini","affiliation":"University of Pittsburgh"}]},"languages":{"content_language":"en","programming_languages":["Python"]},"content":{"prompt":"Suppose we have an input file that contains information about how many hours each employee of a company has worked. The file looks like the following (Employee's name, Hours):\\nErica 7.5 8.5 10.25 8 8.5\\nErin 10.5 11.5 12 11 10.75\\nSimone 8 8 8\\n...\\nConstruct a program that reads this file and calculates the total number of hours worked by each individual. Make sure that the program handles each specific exception that could occur. ","source_code":"#Step 1: Define the function\ndef report_work_hours(file_name):\n    #Step 1.1: Enclose the code that might throw an exception within the try block\n    try :\n        #Step 1.1.1: Open the file and process each line in the file        \n        myfile = open( file_name, \"r\")\n        for line in myfile:\n            tokens = line.split()\n            name = tokens[0]\n            total = 0.0;\n            for i in range(1, len(tokens)) :\n                try :\n                    total += float(tokens[i])\n                except ValueError:\n                    print(\"Error in the hour.\")\n            print(\"Total hours worked by \" + name  + \" = \" + str(total))\n        #Step 1.1.2: Close the file\n        myfile.close()\n    #Step 1.2: Handle all possible exceptions that may be thrown in the try block \n    except FileNotFoundError:\n        print(\"File not found\")\n    except IOError:\n        print(\"Problem with the file!\")\n#Step 2: Call the function\nname = input(\"Enter the full path of a file: \")\nreport_work_hours(name)"},"classification":{"topics":[],"difficulty":"","knowledge_components":{"alice_edu_py_ontology expert":{"concepts":["ClosingFile","SingleForLoopIteration","TransformingToFloatType","FindingLength","AssigningValueVariable","Addition","HandlingInput","NestedForLoopIteration","ReadingLine","CallingLibraryFunction","TransformingToStringType","ChangingValueVariable","HandlingSpecificError","SplittingString","Printing","DefiningSimpleFunction","OpeningFile","Concatenation","ForLoopWithListIndexing","ForLoopWith","NestedFunctionCall","CreatingString","CallingSimpleFunction"],"note":"","created_at":null,"updated_at":null},"parser":{"concepts":["Index","Float","For","Int","Attribute","AugAssign","ExceptHandler","Add","Call","Str","arg","Try","Assign","FunctionDef"],"note":"","created_at":null,"updated_at":null},"unspecified":{"concepts":["arg","ExceptHandler","For","Call","Assign","Float","Try","FunctionDef","Int","Attribute","Add","AugAssign","Index","Str"],"note":"","created_at":null,"updated_at":null},"Rafaella added 09.03.2025 alice_edu_py_ontology":{"concepts":["Addition","AssigningValueVariable","CallingLibraryFunction","CallingSimpleFunction","ChangingValueVariable","ClosingFile","Concatenation","CreatingString","DefiningSimpleFunction","FindingLength","ForLoopWith","ForLoopWithListIndexing","HandlingInput","HandlingSpecificError","NestedForLoopIteration","NestedFunctionCall","OpeningFile","Printing","ReadingLine","SingleForLoopIteration","SplittingString","TransformingToFloatType","TransformingToStringType"],"note":"","created_at":null,"updated_at":null}}},"pedagogy":{"learning_objectives":[],"instructional_role":"","prerequisites":{"topics":[],"concepts":[],"item_ids":[]}},"interaction":{"interaction_type":""},"delivery":[{"protocol":"PITT","url":" ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#      11     continue
#      12 item = json.load(open(f'items/{id}'))
# ---> 13 response = requests.patch(
#      14     f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id.replace('.json', '')}",
#      15     json=item,
#      16     headers={'api-token': api_token}
#      17 )
#      18 print(f'[{index}/{len(items)}:{response.status_code}] restored item id:', id.replace('.json', ''))
#      19 print(response.text)
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/requests/api.py:145, in patch(url, data, **kwargs)
#     133 def patch(url, data=None, **kwargs):
#     134     r"""Sends a PATCH request.
#     135
#     136     :param url: URL for the new :class:`Request` object.
#    (...)    142     :rtype: requests.Response
#     143     """
# --> 145     return request("patch", url, data=data, **kwargs)
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/Projects/paws/course-authoring/.venv/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# # merge all items into a single file

# import os
# import json

# items = []
# for index, id in enumerate(os.listdir('items')):
#     if not id.endswith('.json'):
#         continue
#     items.append(json.load(open(f'items/{id}')))
# json.dump(items, open('items.json', 'w'), indent=2)
