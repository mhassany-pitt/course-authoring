# %%
# ------- BACKUP ITEMS -------
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()
for index, item in enumerate(catalog):
    print(f'{index}/{len(catalog)}:', item['identity']['title'])
    item = requests.get(f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}").json()
    json.dump(item, open(f"items/{item['id']}.json", 'w'), indent=2)
# Out:
# 0/3361: Advertir al Usuario sobre los Cambios en la Temperatura y Humedad.
# 1/3361: Advertir al Usuario sobre los Cambios en la Temperatura
# 2/3361: py_nested_if_temperature_es
# 3/3361: Encontrar el Mayor Divisor de un Numero Positivo
# 4/3361: Encontrar el Divisor Mas Pequeno de un Numero Positivo
# 5/3361: py_divisor_es
# 6/3361: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo Invertido
# 7/3361: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo
# 8/3361: py_star_patterns_es
# 9/3361: Maquina Expendedora Con Monedas de 25, 10, y 5 centavos
# 10/3361: Maquina Expendedora Con Dolares y Monedas de Veinticinco
# 11/3361: py_vending_machine_es
# 12/3361: Determinando Cuando Comprar un Nuevo Telefono (Caso 2)
# 13/3361: Determinando Cuando Comprar un Nuevo Telefono (Caso 1)
# 14/3361: py_phone_age_es
# 15/3361: Pasar Valores
# 16/3361: Pasar Valores
# 17/3361: py_references_passing_values_llm_es
# 18/3361: Desplazando los Valores de la Lista a la Derecha Dos Posiciones
# 19/3361: Desplazando los Valores de la Lista a la Derecha una Posicion
# 20/3361: Desplazando los Valores de la Lista a la Izquierda Dos Posiciones
# 21/3361: Desplazando los Valores de la Lista a la Izquierda Una Posicion
# 22/3361: py_list_rotate_llm_es
# 23/3361: Creando un Diccionario de Pares Caracteres-Palabras
# 24/3361: Creando un Diccionario de Pares Caracteres-Frecuencia
# 25/3361: py_char_dict_llm_es
# 26/3361: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 2)
# 27/3361: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 1)
# 28/3361: py_work_hours_es
# 29/3361: La Clase para Representar un Prestamo (Caso 2)
# 30/3361: La Clase para Representar un Prestamo (Caso 1)
# 31/3361: objects_classes_loan_es
# 32/3361: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 2)
# 33/3361: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 1)
# 34/3361: py_check_product_code_es
# 35/3361: Calculando el Porcentaje de Victorias de un Equipo (Caso 3)
# 36/3361: Calculando el Porcentaje de Victorias de un Equipo (Caso 2)
# 37/3361: Calculando el Porcentaje de Victorias de un Equipo (Caso 1)
# 38/3361: py_win_percentage_es
# 39/3361: Funcion con Multiples Parametros Llamando Otra
# 40/3361: Funcion con Multiples Parametros
# 41/3361: py_functions_multiple_parameters_es
# 42/3361: Calculo y Redondeo del Indice de Masa Corporal (IMC) al Entero Mas Cercano.
# 43/3361: Calculo del Indice de Masa Corporal (IMC)
# 44/3361: py_bmi_calculator_llm_es
# 45/3361: Contando las Ocurrencias de un String en Otro (Caso 2).
# 46/3361: Contando las Ocurrencias de un String en Otro (Caso 1)
# 47/3361: py_str_count_llm_es
# 48/3361: Informar Informacion del Archivo (Caso 2)
# 49/3361: Informe de Informacion del Archivo (Caso 1)
# 50/3361: py_file_input_stat_es
# 51/3361: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 2)
# 52/3361: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 1)
# 53/3361: py_student_score_es
# 54/3361: Determinando Si Uno Es Adolescente (Caso 2)
# 55/3361: Determinando Si Uno Es Adolescente (Caso 1)
# 56/3361: py_check_age_es
# 57/3361: Imprimir Tabla de Conteo de Medallas con Totales por Fila y por Columna
# 58/3361: Imprimir Tabla de Conteo de Medallas con Totales por Fila
# 59/3361: py_print_medals_es
# 60/3361: Concatenando Caracteres de Dos Strings (Caso 2).
# 61/3361: Concatenando Caracteres de Dos Strings (Caso 1)
# 62/3361: py_concat_char_two_str_llm_es
# 63/3361: Mostrando los Dias que Estan por Sobre 32 Grados Fahrenheit
# 64/3361: Mostrando los Dias que Estan por Sobre el Promedio de Temperatura
# 65/3361: py_temperature_es
# 66/3361: Informacion de Herencia de Persona y Empleado
# 67/3361: Herencia de Persona y Empleado
# 68/3361: py_classes_inheritance_es
# 69/3361: Linked List Operations - Size 2
# 70/3361: Linked List Implementation
# 71/3361: Linked List Operations - Size 1
# 72/3361: Linked List Implementation - 1
# 73/3361: Linked List Operations - Contains
# 74/3361: Linked List Implementation
# 75/3361: Linked List Implementation - 2
# 76/3361: Queue Class - Check if Element Exists
# 77/3361: Queue
# 78/3361: Binary Search - 1
# 79/3361: Binary Search
# 80/3361: Binary Search - 2
# 81/3361: Binary Search - Recursive
# 82/3361: c_mjeseci
# 83/3361: c_pritisak
# 84/3361: c_max_number
# 85/3361: c_grading
# 86/3361: Kontrola toka programa
# 87/3361: c_faktorijeli (while petlja)
# 88/3361: c_ispis_unazad (while petlja)
# 89/3361: While petlja
# 90/3361: c_puni_kvadrat
# 91/3361: c_faktorijeli (for petlja)
# 92/3361: c_ispis_unazad (for petlja)
# 93/3361: For petlja
# 94/3361: c_decimalni_ispis
# 95/3361: c_ispisi_sa_sirinom_preciznosti_i_vodecim_nulama
# 96/3361: c_ispisi_sa_sirinom_i_preciznosti
# 97/3361: c_ispisi
# 98/3361: Formatirani ispisi
# 99/3361: c_hello_world_redovi
# 100/3361: c_hello_world
# 101/3361: Uvod
# 102/3361: c_ostatak_pri_dijeljenju
# 103/3361: c_dijeljenje
# 104/3361: c_polovine
# 105/3361: c_farenhajt_celzijus_konverzija
# 106/3361: c_celzijus_farenhajt_konverzija
# 107/3361: Izrazi
# 108/3361: c_selection_sort
# 109/3361: Selection sort
# 110/3361: c_prebacivanje_u_drugi_niz
# 111/3361: c_unos_niza_s_prekidom
# 112/3361: c_unos_niza_while
# 113/3361: Unos i prebacivanje elemenata niza
# 114/3361: c_ispis_sporedna_dijagonala
# 115/3361: c_ispis_glavna_dijagonala
# 116/3361: c_max_array
# 117/3361: c_min_array
# 118/3361: c_unos_matrice
# 119/3361: Unos i obrada nizova i matrica
# 120/3361: c_funkcija_suma_kolicnika
# 121/3361: c_funkcija_stepenuj
# 122/3361: c_kubiraj
# 123/3361: c_funkcija_pozdrav
# 124/3361: Funkcije i izrazi
# 125/3361: c_funkcija_djeljiv_sa
# 126/3361: c_funkcija_djelitelji
# 127/3361: c_funkcija_djeljiv_sa_3
# 128/3361: Funkcije i djeljivost
# 129/3361: c_proizvod_elemenata_na_dijagonalama_neparan
# 130/3361: c_proizvod_elemenata_na_dijagonalama
# 131/3361: c_ispis_ispod_sporedne_dijagonale
# 132/3361: c_elementi_ispod_glavne_dijagonale
# 133/3361: c_ispis_iznad_glavne_dijagonale
# 134/3361: Rad sa dijagonalama matrica
# 135/3361: c_mnozenje_reda_iznad
# 136/3361: c_dijeljenje_reda
# 137/3361: c_sabiranje_kolona
# 138/3361: Aritmeticke operacije nad redovima i kolonama matrice
# 139/3361: c_max_elementi_kolona
# 140/3361: c_srednja_vrijednost_matrice
# 141/3361: c_zbir_elemenata_u_redovima
# 142/3361: c_zbir_elemenata_u_kolonama
# 143/3361: Operacije nad elementima matrice
# 144/3361: c_zamjena_kolona_dva_mjesta_dalje
# 145/3361: c_zamjena_redova
# 146/3361: c_zamjena_dvije_kolone
# 147/3361: c_zamjena_dva_reda
# 148/3361: Zamjena redova i kolona
# 149/3361: c_pokazivaci_min_max
# 150/3361: c_zamjena_pomocu_pokazivaca
# 151/3361: Pokazivaci kao parametri u funkcijama
# 152/3361: c_pokazivaci_dodjela_i_ispis
# 153/3361: c_vrijednosti_u_pokazivacima
# 154/3361: c_vrijednosti_u_pokazivacima_int
# 155/3361: Adrese i dodjela vrijednosti pokazivacima
# 156/3361: c_promjena_vrijednosti_preko_pokazivaca_2
# 157/3361: c_promjena_vrijednosti_preko_pokazivaca
# 158/3361: c_pokazivaci_dereferenciranje_int
# 159/3361: Dereferenciranje pokazivaca
# 160/3361: c_pokazivaci_pomjeranje_kroz_niz_i_manipulacija
# 161/3361: c_pokazivaci_manipulacija_clanova_niza
# 162/3361: c_pokazivaci_pomjeranje_kroz_niz
# 163/3361: Pokazivacka aritmetika
# 164/3361: c_unos_broja_i_karaktera
# 165/3361: c_unos_karaktera_getchar
# 166/3361: c_unos_karaktera_za_karakterom
# 167/3361: Unos karaktera
# 168/3361: c_trazenje_karaktera_u_stringu
# 169/3361: c_niz_karaktera_brojanje_samoglasnika
# 170/3361: c_unos_niza_karaktera
# 171/3361: Nizovi karaktera
# 172/3361: c_trazenje_karaktera_u_stringu_pokazivaci
# 173/3361: c_pokazivaci_na_karaktere_brojanje_samoglasnika
# 174/3361: Pokazivaci na karaktere
# 175/3361: c_brojanje_rijeci_s_velikim_pocetnim_slovom
# 176/3361: c_brojanje_rijeci_alfanumericki
# 177/3361: c_brojanje_rijeci_razmaci
# 178/3361: Detektovanje granica unutar stringa
# 179/3361: c_zamjena_svakog_drugog_znaka
# 180/3361: c_pretvaranje_broja_u_slovo
# 181/3361: Mijenjanje karaktera u stringu
# 182/3361: c_izbacivanje_samoglasnika
# 183/3361: c_izbacivanje_svakog_ntog_karaktera
# 184/3361: c_izbacivanje_nte_rijeci
# 185/3361: Brisanje dijelova stringa
# 186/3361: c_spajanje_dva_stringa
# 187/3361: c_ubacivanje_rijeci
# 188/3361: Ubacivanje karaktera u string
# 189/3361: c_funkcija_nadji_rijec
# 190/3361: c_funkcija_uporedi_stringove
# 191/3361: c_funkcija_prebroji_znak
# 192/3361: Slanje stringova u funkcije
# 193/3361: c_funkcija_ukloni_razmake
# 194/3361: c_funkcija_podstring
# 195/3361: Vracanje pokazivaca na karaktere iz funkcija
# 196/3361: c_datoteke_brojanje_rijeci_s_velikim_pocetnim_slovom
# 197/3361: c_datoteke_brojanje_redova_rijeci_znakova
# 198/3361: Citanje sadrzaja tekstualnih datoteka karakter po karakter
# 199/3361: c_upis_stringa_u_datoteku
# 200/3361: c_kopiranje_karaktera_u_datoteku
# 201/3361: Upis u tekstualne datoteke karakter po karakter
# 202/3361: c_formatirane_datoteke_citanje_brojeva_i_stringa
# 203/3361: c_formatirane_datoteke_citanje_broja_i_stringa
# 204/3361: Citanje sadrzaja formatiranih tekstualnih datoteka
# 205/3361: c_formatirane_datoteke_upis_sa_decimalama
# 206/3361: c_formatirane_datoteke_upis_broja_i_stringa
# 207/3361: Upis u formatirane tekstualne datoteke
# 208/3361: c_makro_max_broj
# 209/3361: c_makro_kvadrat_broja
# 210/3361: Makro naredbe
# 211/3361: c_upis_reda_na_kraj_datoteke
# 212/3361: c_upis_broja_karaktera_na_kraj_datoteke
# 213/3361: c_upis_na_kraj_datoteke
# 214/3361: Izmjena tekstualnih datoteka
# 215/3361: c_dinamicka_alokacija_varijable_malloc
# 216/3361: Unos i ispis struktura old
# 217/3361: c_citanje_iz_txt_challenge
# 218/3361: c_citanje_struktura_iz_datoteka
# 219/3361: Citanje struktura iz tekstualnih datoteka
# 220/3361: c_citanje_iz_bin_datoteke_challenge
# 221/3361: c_citanje_iz_bin_datoteke
# 222/3361: c_citanje_podatka_iz_bin_datoteke
# 223/3361: Citanje iz binarnih datoteka
# 224/3361: c_pisanje_u_datoteke_challenge
# 225/3361: c_pisanje_u_datoteke
# 226/3361: Unos struktura u tekstualne datoteke
# 227/3361: c_pisanje_u_binarne_datoteke_challenge
# 228/3361: c_pisanje_u_binarne_datoteke
# 229/3361: c_pisanje_podatka_u_binarnu_datoteku
# 230/3361: Pisanje u binarne datoteke
# 231/3361: c_citanja_izmjena_koristenjem_kursora_challenge
# 232/3361: c_citanje_izmjena_datoteka_koristenjem_kursora
# 233/3361: Rad s kursorom u tekstualnim datotekama
# 234/3361: c_izmjena_binarnih_datoteka_challenge
# 235/3361: c_izmjena_binarnih_datoteka
# 236/3361: Append i read-update mod za binarne datoteke
# 237/3361: c_strukture_i_nizovi_challenge
# 238/3361: c_strukture_i_nizovi
# 239/3361: c_strukture_i_nizovi_pokazivaci
# 240/3361: Nizovi u strukturama i nizovi struktura
# 241/3361: c_strukture_unos_ispis_studenta_challenge
# 242/3361: c_strukture
# 243/3361: c_unos_i_ispis_datuma
# 244/3361: c_unos_i_ispis_proizvoda
# 245/3361: Unos i ispis struktura
# 246/3361: c_strukture_funkcija_pravougaonik
# 247/3361: c_strukture_funkcije_sredina_tacaka
# 248/3361: Funkcije i strukture
# 249/3361: c_strukture_funkcija_pravougaonik_pokazivaci
# 250/3361: c_strukture_s_pokazivacima
# 251/3361: c_strukture_funkcije_sredina_tacaka_s_pokazivacima
# 252/3361: Funkcije i strukture s pokazivacima
# 253/3361: c_dinamicka_alokacija_varijabli_challenge
# 254/3361: c_dinamicka_alokacija_varijable_calloc
# 255/3361: c_dinamicka_alokacija_varijable_malloc
# 256/3361: Dinamicka alokacija obicnih varijabli
# 257/3361: c_dinamicka_alokacija_nizova_challenge
# 258/3361: c_dinamicka_alokacija_niza_calloc
# 259/3361: c_dinamicka_alokacija_niza_malloc
# 260/3361: Dinamicka alokacija nizova
# 261/3361: codecheck-python-StringsNumbersInStrings-1
# 262/3361: codecheck-python-StringsNumbersInStrings-3
# 263/3361: codecheck-python-StringsNumbersInStrings-2
# 264/3361: codecheck-python-LoopingOvertheEntireArray-12
# 265/3361: codecheck-python-LoopingOvertheEntireArray-9
# 266/3361: codecheck-python-LoopingOvertheEntireArray-1
# 267/3361: codecheck-python-LoopingOvertheEntireArray-11
# 268/3361: codecheck-python-LoopingOvertheEntireArray-3
# 269/3361: codecheck-python-LoopingOvertheEntireArray-4
# 270/3361: codecheck-python-LoopingOvertheEntireArray-5
# 271/3361: codecheck-python-LoopingOvertheEntireArray-13
# 272/3361: codecheck-python-LoopingOvertheEntireArray-6
# 273/3361: codecheck-python-LoopingOvertheEntireArray-2
# 274/3361: codecheck-python-LoopingOvertheEntireArray-10
# 275/3361: codecheck-python-LoopingOvertheEntireArray-8
# 276/3361: codecheck-python-LoopingOvertheEntireArray-7
# 277/3361: codecheck-python-StringWords-1
# 278/3361: codecheck-python-StringWords-3
# 279/3361: codecheck-python-StringWords-4
# 280/3361: codecheck-python-StringWords-2
# 281/3361: codecheck-python-MaximumandMinimum-1
# 282/3361: codecheck-python-MaximumandMinimum-3
# 283/3361: codecheck-python-MaximumandMinimum-4
# 284/3361: codecheck-python-MaximumandMinimum-5
# 285/3361: codecheck-python-MaximumandMinimum-6
# 286/3361: codecheck-python-MaximumandMinimum-2
# 287/3361: codecheck-python-MaximumandMinimum-7
# 288/3361: codecheck-python-ComplexLoops-1
# 289/3361: codecheck-python-ComplexLoops-3
# 290/3361: codecheck-python-ComplexLoops-4
# 291/3361: codecheck-python-ComplexLoops-5
# 292/3361: codecheck-python-ComplexLoops-6
# 293/3361: codecheck-python-ComplexLoops-2
# 294/3361: codecheck-python-LoopingoverNeighbors-1
# 295/3361: codecheck-python-LoopingoverNeighbors-3
# 296/3361: codecheck-python-LoopingoverNeighbors-4
# 297/3361: codecheck-python-LoopingoverNeighbors-5
# 298/3361: codecheck-python-LoopingoverNeighbors-2
# 299/3361: codecheck-python-StringsNoLoops-1
# 300/3361: codecheck-python-StringsNoLoops-3
# 301/3361: codecheck-python-StringsNoLoops-4
# 302/3361: codecheck-python-StringsNoLoops-5
# 303/3361: codecheck-python-StringsNoLoops-2
# 304/3361: codecheck-python-ArraysNoLoops-1
# 305/3361: codecheck-python-ArraysNoLoops-3
# 306/3361: codecheck-python-ArraysNoLoops-4
# 307/3361: codecheck-python-ArraysNoLoops-2
# 308/3361: codecheck-python-SumsAveragesProducts-14
# 309/3361: codecheck-python-SumsAveragesProducts-12
# 310/3361: codecheck-python-SumsAveragesProducts-9
# 311/3361: codecheck-python-SumsAveragesProducts-1
# 312/3361: codecheck-python-SumsAveragesProducts-11
# 313/3361: codecheck-python-SumsAveragesProducts-3
# 314/3361: codecheck-python-SumsAveragesProducts-4
# 315/3361: codecheck-python-SumsAveragesProducts-5
# 316/3361: codecheck-python-SumsAveragesProducts-13
# 317/3361: codecheck-python-SumsAveragesProducts-6
# 318/3361: codecheck-python-SumsAveragesProducts-2
# 319/3361: codecheck-python-SumsAveragesProducts-10
# 320/3361: codecheck-python-SumsAveragesProducts-8
# 321/3361: codecheck-python-SumsAveragesProducts-7
# 322/3361: codecheck-python-Producing2DArrays-1
# 323/3361: codecheck-python-Producing2DArrays-3
# 324/3361: codecheck-python-Producing2DArrays-4
# 325/3361: codecheck-python-Producing2DArrays-5
# 326/3361: codecheck-python-Producing2DArrays-6
# 327/3361: codecheck-python-Producing2DArrays-2
# 328/3361: codecheck-python-Producing2DArrays-7
# 329/3361: codecheck-python-OtherStringOperations-9
# 330/3361: codecheck-python-OtherStringOperations-1
# 331/3361: codecheck-python-OtherStringOperations-3
# 332/3361: codecheck-python-OtherStringOperations-4
# 333/3361: codecheck-python-OtherStringOperations-5
# 334/3361: codecheck-python-OtherStringOperations-6
# 335/3361: codecheck-python-OtherStringOperations-2
# 336/3361: codecheck-python-OtherStringOperations-8
# 337/3361: codecheck-python-OtherStringOperations-7
# 338/3361: codecheck-python-FunctionsWithDecisions-9
# 339/3361: codecheck-python-FunctionsWithDecisions-1
# 340/3361: codecheck-python-FunctionsWithDecisions-3
# 341/3361: codecheck-python-FunctionsWithDecisions-4
# 342/3361: codecheck-python-FunctionsWithDecisions-5
# 343/3361: codecheck-python-FunctionsWithDecisions-6
# 344/3361: codecheck-python-FunctionsWithDecisions-2
# 345/3361: codecheck-python-FunctionsWithDecisions-8
# 346/3361: codecheck-python-FunctionsWithDecisions-7
# 347/3361: codecheck-python-TwoAnswers-1
# 348/3361: codecheck-python-TwoAnswers-3
# 349/3361: codecheck-python-TwoAnswers-4
# 350/3361: codecheck-python-TwoAnswers-5
# 351/3361: codecheck-python-TwoAnswers-2
# 352/3361: codecheck-python-FillingArrays-1
# 353/3361: codecheck-python-FillingArrays-3
# 354/3361: codecheck-python-FillingArrays-4
# 355/3361: codecheck-python-FillingArrays-5
# 356/3361: codecheck-python-FillingArrays-2
# 357/3361: codecheck-python-Branches-12
# 358/3361: codecheck-python-Branches-9
# 359/3361: codecheck-python-Branches-1
# 360/3361: codecheck-python-Branches-11
# 361/3361: codecheck-python-Branches-3
# 362/3361: codecheck-python-Branches-4
# 363/3361: codecheck-python-Branches-5
# 364/3361: codecheck-python-Branches-13
# 365/3361: codecheck-python-Branches-6
# 366/3361: codecheck-python-Branches-2
# 367/3361: codecheck-python-Branches-10
# 368/3361: codecheck-python-Branches-8
# 369/3361: codecheck-python-Branches-7
# 370/3361: codecheck-python-MovingorRemovingElements-1
# 371/3361: codecheck-python-MovingorRemovingElements-3
# 372/3361: codecheck-python-MovingorRemovingElements-4
# 373/3361: codecheck-python-MovingorRemovingElements-5
# 374/3361: codecheck-python-MovingorRemovingElements-6
# 375/3361: codecheck-python-MovingorRemovingElements-2
# 376/3361: codecheck-python-LoopsAlongaRoworColumn-9
# 377/3361: codecheck-python-LoopsAlongaRoworColumn-1
# 378/3361: codecheck-python-LoopsAlongaRoworColumn-11
# 379/3361: codecheck-python-LoopsAlongaRoworColumn-3
# 380/3361: codecheck-python-LoopsAlongaRoworColumn-4
# 381/3361: codecheck-python-LoopsAlongaRoworColumn-5
# 382/3361: codecheck-python-LoopsAlongaRoworColumn-6
# 383/3361: codecheck-python-LoopsAlongaRoworColumn-2
# 384/3361: codecheck-python-LoopsAlongaRoworColumn-10
# 385/3361: codecheck-python-LoopsAlongaRoworColumn-8
# 386/3361: codecheck-python-LoopsAlongaRoworColumn-7
# 387/3361: codecheck-python-FindingElements-1
# 388/3361: codecheck-python-FindingElements-3
# 389/3361: codecheck-python-FindingElements-4
# 390/3361: codecheck-python-FindingElements-5
# 391/3361: codecheck-python-FindingElements-6
# 392/3361: codecheck-python-FindingElements-2
# 393/3361: codecheck-python-DoubleLoops-1
# 394/3361: codecheck-python-DoubleLoops-3
# 395/3361: codecheck-python-DoubleLoops-4
# 396/3361: codecheck-python-DoubleLoops-5
# 397/3361: codecheck-python-DoubleLoops-6
# 398/3361: codecheck-python-DoubleLoops-2
# 399/3361: codecheck-python-DoubleLoops-8
# 400/3361: codecheck-python-DoubleLoops-7
# 401/3361: codecheck-python-StringsFindingSubstrings-1
# 402/3361: codecheck-python-StringsFindingSubstrings-3
# 403/3361: codecheck-python-StringsFindingSubstrings-4
# 404/3361: codecheck-python-StringsFindingSubstrings-5
# 405/3361: codecheck-python-StringsFindingSubstrings-2
# 406/3361: codecheck-python-2DArraysNoLoops-1
# 407/3361: codecheck-python-2DArraysNoLoops-3
# 408/3361: codecheck-python-2DArraysNoLoops-4
# 409/3361: codecheck-python-2DArraysNoLoops-5
# 410/3361: codecheck-python-2DArraysNoLoops-6
# 411/3361: codecheck-python-2DArraysNoLoops-2
# 412/3361: codecheck-python-2DArraysNoLoops-8
# 413/3361: codecheck-python-2DArraysNoLoops-7
# 414/3361: codecheck-python-StringsComparingStrings-1
# 415/3361: codecheck-python-StringsComparingStrings-3
# 416/3361: codecheck-python-StringsComparingStrings-2
# 417/3361: codecheck-python-CountingElements-9
# 418/3361: codecheck-python-CountingElements-1
# 419/3361: codecheck-python-CountingElements-3
# 420/3361: codecheck-python-CountingElements-4
# 421/3361: codecheck-python-CountingElements-5
# 422/3361: codecheck-python-CountingElements-6
# 423/3361: codecheck-python-CountingElements-2
# 424/3361: codecheck-python-CountingElements-10
# 425/3361: codecheck-python-CountingElements-8
# 426/3361: codecheck-python-CountingElements-7
# 427/3361: Sub-Queries question5
# 428/3361: Sub-Queries question4
# 429/3361: Sub-Queries question3
# 430/3361: Sub-Queries question2
# 431/3361: Sub-Queries question1
# 432/3361: Group-By & Having question5
# 433/3361: Group-By & Having question4
# 434/3361: Group-By & Having question3
# 435/3361: Group-By & Having question2
# 436/3361: Group-By & Having question1
# 437/3361: Aggregate Functions question5
# 438/3361: Aggregate Functions question4
# 439/3361: Aggregate Functions question3
# 440/3361: Aggregate Functions question2
# 441/3361: Aggregate Functions question1
# 442/3361: Set Operations question1
# 443/3361: Order-By question4
# 444/3361: Order-By question3
# 445/3361: Order-By question2
# 446/3361: Order-By question1
# 447/3361: Multiple Table question5
# 448/3361: Multiple Table question4
# 449/3361: Multiple Table question3
# 450/3361: Multiple Table question2
# 451/3361: Multiple Table question1
# 452/3361: Pattern Matching question5
# 453/3361: Pattern Matching question4
# 454/3361: Pattern Matching question3
# 455/3361: Pattern Matching question2
# 456/3361: Pattern Matching question1
# 457/3361: SELECT-FROM-WHERE question5
# 458/3361: SELECT-FROM-WHERE question4
# 459/3361: SELECT-FROM-WHERE question3
# 460/3361: SELECT-FROM-WHERE question2
# 461/3361: SELECT-FROM-WHERE question1
# 462/3361: Arithmetic Expressions question5
# 463/3361: Arithmetic Expressions question4
# 464/3361: Arithmetic Expressions question3
# 465/3361: Arithmetic Expressions question2
# 466/3361: Arithmetic Expressions question1
# 467/3361: SELECT-DISTINCT question6
# 468/3361: SELECT-FROM question5
# 469/3361: SELECT-FROM question4
# 470/3361: SELECT-FROM question3
# 471/3361: SELECT-FROM question2
# 472/3361: SELECT-FROM question1
# 473/3361: SELECT-FROM-WHERE question6
# 474/3361: SELECT-FROM-WHERE question9
# 475/3361: SELECT-FROM-WHERE question8
# 476/3361: SELECT-FROM-WHERE question7
# 477/3361: Arithmetic Expressions question3
# 478/3361: Arithmetic Expressions question2
# 479/3361: Arithmetic Expressions question1
# 480/3361: SELECT-DISTINCT question6
# 481/3361: SELECT-FROM question5
# 482/3361: SELECT-FROM question4
# 483/3361: SELECT-FROM question3
# 484/3361: SELECT-FROM question2
# 485/3361: SELECT-FROM question1
# 486/3361: Multiple Table question4
# 487/3361: Multiple Table question3
# 488/3361: Multiple Table question2
# 489/3361: Multiple Table question1
# 490/3361: Pattern Matching question5
# 491/3361: Pattern Matching question4
# 492/3361: Pattern Matching question3
# 493/3361: Pattern Matching question2
# 494/3361: Pattern Matching question1
# 495/3361: SELECT-FROM-WHERE question5
# 496/3361: SELECT-FROM-WHERE question4
# 497/3361: SELECT-FROM-WHERE question3
# 498/3361: SELECT-FROM-WHERE question2
# 499/3361: SELECT-FROM-WHERE question1
# 500/3361: Arithmetic Expressions question5
# 501/3361: Arithmetic Expressions question4
# 502/3361: Group-By & Having question4
# 503/3361: Group-By & Having question3
# 504/3361: Group-By & Having question2
# 505/3361: Group-By & Having question1
# 506/3361: Aggregate Functions question5
# 507/3361: Aggregate Functions question4
# 508/3361: Aggregate Functions question3
# 509/3361: Aggregate Functions question2
# 510/3361: Aggregate Functions question1
# 511/3361: Set Operations question1
# 512/3361: Order-By question4
# 513/3361: Order-By question3
# 514/3361: Order-By question2
# 515/3361: Order-By question1
# 516/3361: Multiple Table question5
# 517/3361: SELECT-FROM-WHERE question9
# 518/3361: SELECT-FROM-WHERE question8
# 519/3361: SELECT-FROM-WHERE question7
# 520/3361: SELECT-FROM-WHERE question6
# 521/3361: Sub-Queries question5
# 522/3361: Sub-Queries question4
# 523/3361: Sub-Queries question3
# 524/3361: Sub-Queries question2
# 525/3361: Sub-Queries question1
# 526/3361: Group-By & Having question5
# 527/3361: Set Operations question3
# 528/3361: Set Operations question2
# 529/3361: Set Operations question5
# 530/3361: Set Operations question4
# 531/3361: Arithmetic-expressions query execution 1
# 532/3361: Subqueries query execution 1
# 533/3361: Group-by-having query execution 1
# 534/3361: Aggregate-functions query execution 1
# 535/3361: Order-by query execution 1
# 536/3361: Pattern-matching query execution 1
# 537/3361: Select-from query execution 1
# 538/3361: Multiple-table-queries execution 1
# 539/3361: Select-from-where query execution 1
# 540/3361: Group-by-having query execution 4
# 541/3361: Group-by-having query execution 3
# 542/3361: Group-by-having query execution 2
# 543/3361: Aggregate-functions query execution 4
# 544/3361: Aggregate-functions query execution 3
# 545/3361: Aggregate-functions query execution 2
# 546/3361: Order-by query execution 4
# 547/3361: Order-by query execution 3
# 548/3361: Order-by query execution 2
# 549/3361: Pattern-matching query execution 4
# 550/3361: Pattern-matching query execution 3
# 551/3361: Pattern-matching query execution 2
# 552/3361: Select-from query execution 4
# 553/3361: Select-from query execution 3
# 554/3361: Select-from query execution 2
# 555/3361: Multiple-table-queries execution 4
# 556/3361: Multiple-table-queries execution 3
# 557/3361: Multiple-table-queries execution 2
# 558/3361: Select-from-where query execution 4
# 559/3361: Select-from-where query execution 3
# 560/3361: Select-from-where query execution 2
# 561/3361: Arithmetic-expressions query execution 4
# 562/3361: Arithmetic-expressions query execution 3
# 563/3361: Arithmetic-expressions query execution 2
# 564/3361: Subqueries query execution 4
# 565/3361: Subqueries query execution 3
# 566/3361: Subqueries query execution 2
# 567/3361: Join query execution 1
# 568/3361: Join query execution 4
# 569/3361: Join query execution 3
# 570/3361: Join query execution 2
# 571/3361: Arithmetic-expressions query execution 6
# 572/3361: Arithmetic-expressions query execution 5
# 573/3361: Join question1
# 574/3361: Join question2
# 575/3361: LEFT-JOIN question2
# 576/3361: LEFT-JOIN question1
# 577/3361: Inner-join query execution 1
# 578/3361: Left-join query execution 1
# 579/3361: Left-join query execution 4
# 580/3361: Left-join query execution 3
# 581/3361: Left-join query execution 2
# 582/3361: Inner-join query execution 4
# 583/3361: Inner-join query execution 3
# 584/3361: Inner-join query execution 2
# 585/3361: Seconds to Minutes Conversion
# 586/3361: Converting Milliseconds to Hours-Minutes- and Seconds
# 587/3361: Seconds to Minutes Conversion
# 588/3361: Converting Milliseconds to Hours-Minutes- and Seconds
# 589/3361: Seconds to Minutes Conversion
# 590/3361: Converting Milliseconds to Hours-Minutes- and Seconds.
# 591/3361: Vending Machine With Dollars and Quarters
# 592/3361: Vending Machine With Quarters-Dimes- and Nickels
# 593/3361: Vending Machine With Dollars and Quarters
# 594/3361: Vending Machine With Quarters-Dimes- and Nickels
# 595/3361: Printing Common Elements in Two Arrays
# 596/3361: Printing the Total Number of Times Elements of One Array Appear in Another Array
# 597/3361: Creating an array that Contains the Numbers of Times Each Element of One Array Appears in Another Array
# 598/3361: Determining When to Buy a New Phone (Case 1)
# 599/3361: Determining When to Buy a New Phone (Case 2)
# 600/3361: Printing Consecutive Numbers Starting from Zero (Case 1)
# 601/3361: Printing Consecutive Numbers Starting from Zero (Case 2)
# 602/3361: Pythagorean Theorem (Case 1)
# 603/3361: Pythagorean Theorem (Case 2)
# 604/3361: Finding the Smallest Divisor of a Positive Number
# 605/3361: Finding the Largest Divisor of a Positive Number
# 606/3361: Accessing String Characters (Case 1)
# 607/3361: Accessing String Characters (Case 2)
# 608/3361: The Class for Representing a Bank Account (Case 1)
# 609/3361: The Class for Representing a Bank Account (Case 2)
# 610/3361: The Class for Representing a TV (Case 1)
# 611/3361: The Class for Representing a TV (Case 2)
# 612/3361: The Class for Representing a Loan (Case 1)
# 613/3361: The Class for Representing a Loan (Case 2)
# 614/3361: Creating a List of Words from a File
# 615/3361: Comparing the List of Words from Two Files
# 616/3361: Creating an Array of Odd Numbers
# 617/3361: Creating an Array of User Inputs
# 618/3361: Increment/Decrement Operators (Case 1)
# 619/3361: Increment/Decrement Operators (Case 2)
# 620/3361: Increment/Decrement Operators (Case 3)
# 621/3361: String Concatenation (Case 1)
# 622/3361: String Concatenation (Case 2)
# 623/3361: Determining When a Customer Could Rent a Car (Case 1)
# 624/3361: Determining When a Customer Could Rent a Car (Case 2)
# 625/3361: Determining When a Customer Could Rent a Car (Case 3)
# 626/3361: String Comparison (Case 1)
# 627/3361: String Comparison (Case 2)
# 628/3361: Calculating the Sum of the Values in an Array
# 629/3361: Calculating the Average of the Values in the Array
# 630/3361: Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 1)
# 631/3361: Printing Sequence of Numbers with a Gap Between Adjacent Values (Case 2)
# 632/3361: Calculating the Winning Percentage of a Sports Team (Case 1)
# 633/3361: Calculating the Winning Percentage of a Sports Team (Case 2)
# 634/3361: Calculating the Winning Percentage of a Sports Team (Case 3)
# 635/3361: Updating an Element in the Array (Case 1)
# 636/3361: Updating an Element in the Array (Case 2)
# 637/3361: Updating an Element in the Array (Case 3)
# 638/3361: Modifying an Array (Case 1)
# 639/3361: Modifying an Array (Case 2)
# 640/3361: Printing Name Initials
# 641/3361: Printing Full Name with Middle Initial
# 642/3361: Printing Name in APA Style
# 643/3361: Warning the User about the Changes in the Temperature
# 644/3361: Warning the User about the Changes in the Temperature and Humidity
# 645/3361: Determining the Smallest of the Three Integers
# 646/3361: Determining the Largest of the Three Integers
# 647/3361: Printing Table of Medal Winner Counts with Row Totals
# 648/3361: Printing Table of Medal Winner Counts with Row and Column Totals
# 649/3361: Vending Machine With Dollars and Quarters
# 650/3361: Vending Machine With Quarters-Dimes- and Nickels
# 651/3361: Celsius To Fahrenheit Conversion
# 652/3361: Fahrenheit to Celsius Conversion
# 653/3361: Determining When at Least One of the Three Boolean Variables is True
# 654/3361: Determining When at Least One of the Three Boolean Variables is False
# 655/3361: Determining When All Three Boolean Variables Are Equal
# 656/3361: Determining the Letter Grade Of a Student
# 657/3361: Converting the Letter Grade of a Student to Its Numeric Range
# 658/3361: The Class for Representing a Point in the Euclidean Plane (Case 1)
# 659/3361: The Class for Representing a Point in the Euclidean Plane (Case 2)
# 660/3361: Printing the Squares of Numbers Within a Specified Range (Case 1)
# 661/3361: Printing the Squares of Numbers Within a Specified Range (Case 2)
# 662/3361: Printing the Squares of Numbers Within a Specified Range (Case 3)
# 663/3361: Calculating the Employees Wage Based on the Hours That the Employee Has Worked and an Hourly Pay Rate
# 664/3361: Calculating the Wage of an Employee at the Customer Service Call Center
# 665/3361: Counting the Number of Valid and Banned Product Codes (Case 1)
# 666/3361: Counting the Number of Valid and Banned Product Codes (Case 2)
# 667/3361: Determining Whether One is a Teenager (Case 1)
# 668/3361: Determining Whether One is a Teenager (Case 2)
# 669/3361: Printing A Right Triangle Star Pattern
# 670/3361: Printing an Inverted Right Triangle Star Pattern
# 671/3361: Point Class Hierarchy (Case 1)
# 672/3361: Point Class Hierarchy (Case 2)
# 673/3361: Animal Class Hierarchy (Case 1)
# 674/3361:  Animal Class Hierarchy (Case 2)
# 675/3361: Finding the Number of Days Above the Average Temperature
# 676/3361: Displaying the Days That are Above 32 Degrees Fahrenheit
# 677/3361: Reporting File Information (Case 1)
# 678/3361: Reporting File Information (Case 2)
# 679/3361: Calculating the Average of Input Integers
# 680/3361: Calculating the Average of the Input Integers that are an Even Number
# 681/3361: Calculating the Average of Floating-Point Numbers
# 682/3361: Determining When a Student Fails a Course (Case 1)
# 683/3361: Determining When a Student Fails a Course (Case 2)
# 684/3361: Determining When a Student Fails a Course (Case 3)
# 685/3361: Printing Digits of an Integer from Right to Left
# 686/3361: The Digit Sum of an Integer
# 687/3361: Reversing the Digits of an Integer
# 688/3361: Finding Adjacent Duplicates in a Sequence of Numbers
# 689/3361: Finding Adjacent Consecutive Numbers in a Sequence of Integers
# 690/3361: Finding Adjacent Numbers in Ascending Order in a Sequence of Numbers
# 691/3361: Rotating the Array Values to the Left by One Position
# 692/3361: Rotating the Array Values to the Left by Two Position
# 693/3361: Rotating the Array Values to the Right by One Position
# 694/3361: Rotating the List Values to the Right by Two Position
# 695/3361: Calculating Body Mass Index (BMI)
# 696/3361: Calculating and Rounding Up Body Mass Index (BMI) To the Nearest Integer
# 697/3361: Updating Two-Dimensional Array (Case 1)
# 698/3361: Updating Two-Dimensional Array (Case 2)
# 699/3361: Updating Two-Dimensional Array (Case 3)
# 700/3361: Determining the Sign of an Integer
# 701/3361: Determining Whether an Integer is Even or Odd
# 702/3361: Receiving Input Integers Until a Certain Condition is Met (Case 1)
# 703/3361: Receiving Input Integers Until a Certain Condition is Met (Case 2)
# 704/3361: Receiving Input Integers Until a Certain Condition is Met (Case 3)
# 705/3361: Receiving Input Integers Until a Certain Condition is Met (Case 4)
# 706/3361: String With Escape Characters (Case 1)
# 707/3361: String With Escape Characters (Case 2)
# 708/3361: String With Escape Characters (Case 3)
# 709/3361: Determining the Weather Condition (Case 1)
# 710/3361: Determining the Weather Condition (Case 2)
# 711/3361: Determining the Weather Condition (Case 3)
# 712/3361: Determining the Weather Condition (Case 4)
# 713/3361: Determining the Maximum Rating for Each Soda in The Survey
# 714/3361: Determining the Average Rating for Each Soda in The Survey
# 715/3361: Determining the Average Ratings of each Respondent and Average Ratings Given to Each Soda in the Survey
# 716/3361: Printing Consecutive Numbers Within a Specified Range (Case 1)
# 717/3361: Printing Consecutive Numbers Within a Specified Range (Case 2)
# 718/3361: Seconds to Minutes Conversion
# 719/3361: Converting Milliseconds to Hours-Minutes- and Seconds
# 720/3361: Finding the Minimum Value in an Array
# 721/3361: Finding the Maximum Value in an Array
# 722/3361: Printing A Sequence of Repeated Numbers (Case 1)
# 723/3361: Printing A Sequence of Repeated Numbers (Case 2)
# 724/3361: Reporting the Total Hours Each Employee Worked (Case 1)
# 725/3361: Reporting the Total Hours Each Employee Worked (Case 2)
# 726/3361: Herencia de Persona y Empleado
# 727/3361: Informacion de Herencia de Persona y Empleado
# 728/3361: Mostrando los Dias que Estan por Sobre el Promedio de Temperatura
# 729/3361: Mostrando los Dias que Estan por Sobre 32 Grados Fahrenheit
# 730/3361: Concatenando Caracteres de Dos Strings (Caso 1)
# 731/3361: Concatenando Caracteres de Dos Strings (Caso 2).
# 732/3361: Imprimir Tabla de Conteo de Medallas con Totales por Fila
# 733/3361: Imprimir Tabla de Conteo de Medallas con Totales por Fila y por Columna
# 734/3361: Determinando Si Uno Es Adolescente (Caso 1)
# 735/3361: Determinando Si Uno Es Adolescente (Caso 2)
# 736/3361: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 1)
# 737/3361: Creando un Diccionario de Pares Estudiante-Puntajes (Caso 2)
# 738/3361: Informe de Informacion del Archivo (Caso 1)
# 739/3361: Informar Informacion del Archivo (Caso 2)
# 740/3361: Contando las Ocurrencias de un String en Otro (Caso 1)
# 741/3361: Contando las Ocurrencias de un String en Otro (Caso 2).
# 742/3361: Calculo del Indice de Masa Corporal (IMC)
# 743/3361: Calculo y Redondeo del Indice de Masa Corporal (IMC) al Entero Mas Cercano.
# 744/3361: La Clase para Representar un Prestamo (Caso 1)
# 745/3361: La Clase para Representar un Prestamo (Caso 2)
# 746/3361: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 1)
# 747/3361: Informe de las Horas Totales Trabajadas por Cada Empleado (Caso 2)
# 748/3361: Determinando Cuando Comprar un Nuevo Telefono (Caso 1)
# 749/3361: Determinando Cuando Comprar un Nuevo Telefono (Caso 2)
# 750/3361: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 1)
# 751/3361: Contando el Numero de Codigos de Producto Validos y Prohibidos (Caso 2)
# 752/3361: Creando un Diccionario de Pares Caracteres-Frecuencia
# 753/3361: Creando un Diccionario de Pares Caracteres-Palabras
# 754/3361: Desplazando los Valores de la Lista a la Izquierda Una Posicion
# 755/3361: Desplazando los Valores de la Lista a la Izquierda Dos Posiciones
# 756/3361: Desplazando los Valores de la Lista a la Derecha una Posicion
# 757/3361: Desplazando los Valores de la Lista a la Derecha Dos Posiciones
# 758/3361: Pasar Valores
# 759/3361: Pasar Valores
# 760/3361: Maquina Expendedora Con Dolares y Monedas de Veinticinco
# 761/3361: Maquina Expendedora Con Monedas de diferentes centavos
# 762/3361: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo
# 763/3361: Imprimir un Patron de Estrellas en Forma de Triangulo Rectangulo Invertido
# 764/3361: Encontrar el Divisor Mas Pequeno de un Numero Positivo
# 765/3361: Encontrar el Mayor Divisor de un Numero Positivo
# 766/3361: testing_um2_student_average_arun_ch
# 767/3361: JSON ITERATION 1
# 768/3361: Calculando el Porcentaje de Victorias de un Equipo (Caso 1)
# 769/3361: Calculando el Porcentaje de Victorias de un Equipo (Caso 2)
# 770/3361: Calculando el Porcentaje de Victorias de un Equipo (Caso 3)
# 771/3361: Advertir al Usuario sobre los Cambios en la Temperatura
# 772/3361: Advertir al Usuario sobre los Cambios en la Temperatura y Humedad.
# 773/3361: Funcion con Multiples Parametros
# 774/3361: Funcion con Multiples Parametros Llamando Otra
# 775/3361: Pythagorean Theorem (Case 1)
# 776/3361: Pythagorean Theorem (Case 2)
# 777/3361: testing_um2_student_average_arun_ch
# 778/3361: testing_um2_student_average_arun_ex
# 779/3361: testing_um2_arun_java_SLR_weat_ex
# 780/3361: testing_um2_arun_java_SLR_weat_ch
# 781/3361: CopyFileTo
# 782/3361: PrintFileContent
# 783/3361: Calcular promedio de dos numeros enteros (ES)
# 784/3361: Calcular factura mensual (ES)
# 785/3361: Calcular los segundos en n dias (ES)
# 786/3361: Condicion: es impar (ES)
# 787/3361: Contar Mayusculas (ES)
# 788/3361: Mayusculas o Minusculas (ES)
# 789/3361: Contar no digitos (ES)
# 790/3361: Todo Esponjoso (ES)
# 791/3361: Indice Menor (ES)
# 792/3361: Primer Par (ES)
# 793/3361: Triangulo Ascii (ES)
# 794/3361: Contar Digitos (ES)
# 795/3361: Factor menor (ES)
# 796/3361: Contar Pasos Collatz (ES)
# 797/3361: Solo Dos Verdaderos (p2-4-ES)
# 798/3361: Solo Uno Verdadero (p1-4-ES)
# 799/3361: Listas de enteros pares (ES)
# 800/3361: Encontrar el indice de el string mas largo (ES)
# 801/3361: Intercambiar primero y ultimo
# 802/3361: Contar el numero de valores que estan por encima del promedio (ES)
# 803/3361: Suma digital (ES)
# 804/3361: Programa usual primero (CC)
# 805/3361: Ciclo for anidado
# 806/3361: Calculo rebanadas de pizza (ES)
# 807/3361: Condicion: es adolescente (ES)
# 808/3361: Dia siguiente
# 809/3361: Maximo de tres enteros (ES)
# 810/3361: Calculo galletas necesarias (ES)
# 811/3361: Calcular su suma y producto
# 812/3361: Practicar el uso de la biblioteca math y comprobar el tipo de una variable
# 813/3361: Practicar la manipulación de variables y verificar sus tipos
# 814/3361: Practicar ciclos while anidados
# 815/3361: Practicar el uso de ciclos while y for anidados
# 816/3361: Practicar herencia de clases
# 817/3361: Manipulación de diccionarios
# 818/3361: Cálculos con diccionarios
# 819/3361: Valores y referencias en listas
# 820/3361: Practicar la búsqueda del índice del elemento mínimo
# 821/3361: Practicar la búsqueda del índice de los elementos mínimo y máximo
# 822/3361: Construir un programa que cree una estructura de pila (Stack)
# 823/3361: Construir una función que use una estructura de cola (Queue)
# 824/3361: Construir una función que recorra una lista enlazada
# 825/3361: Construir una función que verifique el tamaño de una lista enlazada
# 826/3361: Construir una función que ordene un arreglo numérico usando Merge Sort
# 827/3361: Practicar el algoritmo de ordenación rápida (Quick Sort)
# 828/3361: Construir una función de recorrido inorder (inorden)
# 829/3361: Imprimir hola mundo
# 830/3361: Crear una función que imprima hola mundo
# 831/3361: Crear una función que reciba un número, le sume dos y lo devuelva
# 832/3361: Crear una función que devuelva el mayor de dos números
# 833/3361: Practicar el orden de líneas para obtener el número correcto
# 834/3361: Crear un programa con un ciclo while
# 835/3361: Crear un programa que compare un valor en un ciclo
# 836/3361: Crear y llamar a una función
# 837/3361: Crear múltiples funciones y llamadas de función anidadas
# 838/3361: Crear una función recursiva
# 839/3361: Crear una clase y utilizarla
# 840/3361: Crear una función y usar el operador módulo
# 841/3361: Iterar sobre una lista
# 842/3361: Practicar indexación de listas
# 843/3361: Practicar el corte de cadenas (slicing)
# 844/3361: Iterar sobre un diccionario
# 845/3361: Acceder a los valores de un diccionario
# 846/3361: Convertir una lista de tuplas en un diccionario
# 847/3361: Iterar sobre elementos (items) de un diccionario
# 848/3361: Usar expresiones booleanas como parámetros de una función
# 849/3361: Practicar sentencias if...elif...else
# 850/3361: Practicar leer un archivo e imprimir su contenido
# 851/3361: Practicar el manejo de excepciones
# 852/3361: Practicar sentencias if anidadas
# 853/3361: Practicar el uso de comparaciones
# 854/3361: Practicar indexación y modificación de listas
# 855/3361: Practicar la asignación de variables
# 856/3361: Crear una compuerta XOR usando sentencias if...elif
# 857/3361: Practicar iterar sobre una lista y usar módulo
# 858/3361: Practicar métodos de cadenas
# 859/3361: Practicar el manejo de excepciones
# 860/3361: Crear una clase y usar sus métodos
# 861/3361: Construir un programa que trabaje con listas
# 862/3361: Construir un problema con ciclos anidados
# 863/3361: Construir un programa que genere combinaciones únicas de 3 dígitos
# 864/3361: Construir un programa que genere combinaciones únicas de 3 dígitos
# 865/3361: Construir un programa con múltiples sentencias if-elif
# 866/3361: Construir un programa con múltiples sentencias if-elif
# 867/3361: Construir un programa con múltiples sentencias if-elif
# 868/3361: Frecuencia de letras
# 869/3361: Frecuencia de letras
# 870/3361: Crear una función que verifique si una cadena es un palíndromo o no
# 871/3361: Crear una función que verifique si una cadena es un palíndromo o no
# 872/3361: Crear una función que verifique si una cadena es un palíndromo o no
# 873/3361: Construir una función que determine si una cadena dada como parámetro es un palíndromo
# 874/3361: Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 875/3361: Construir una función que devuelva una lista de restos (módulos) del valor de entrada
# 876/3361: Invertir la lista
# 877/3361: Invertir la lista
# 878/3361: Invertir la lista
# 879/3361: Invertir la lista
# 880/3361: Invertir la lista
# 881/3361: Invertir la lista
# 882/3361: Invertir la lista
# 883/3361: Invertir la lista
# 884/3361: Verificar si la suma de dos enteros es igual al tercer entero
# 885/3361: Verificar si la suma de dos enteros es igual al tercer entero
# 886/3361: Actualizar elementos en una nueva lista
# 887/3361: Actualizar elementos necesarios en una nueva lista
# 888/3361: Actualizar los elementos en una nueva lista
# 889/3361: Actualizar los elementos en una nueva lista
# 890/3361: Actualizar elementos necesarios en una nueva lista
# 891/3361: Actualizar elementos necesarios en una nueva lista
# 892/3361: Cálculo de potencias
# 893/3361: Cálculo de potencias
# 894/3361: Calcular una potencia
# 895/3361: Calcular una potencia
# 896/3361: Calcular una potencia
# 897/3361: Calcular una potencia
# 898/3361: Eliminar duplicados de una lista
# 899/3361: Eliminar duplicados de una lista
# 900/3361: Reorganizar la lista
# 901/3361: Reorganizar la lista
# 902/3361: Reorganizar la lista
# 903/3361: Reorganizar la lista
# 904/3361: Practicar la lectura de archivos e imprimir el tercer elemento de cada línea
# 905/3361: Binary Search Algorithm Slideshow
# 906/3361: Binary Search recurrence slideshow
# 907/3361: BST Search Slideshow
# 908/3361: BST Insert Slideshow
# 909/3361: BST deletemax Slideshow
# 910/3361: BST remove Slideshow
# 911/3361: PosetCON
# 912/3361: Binary Search Proficiency Exercise
# 913/3361: BST Search Proficiency Exercise
# 914/3361: BST Question Summary
# 915/3361: Self-organizing List Move-to-front Proficiency Exercise
# 916/3361: Insertion Sort Slideshow
# 917/3361: Insertion Sort Worst Case Slideshow
# 918/3361: Insertion Sort Best Case Slideshow
# 919/3361: Insertion Sort Average Case Slideshow
# 920/3361: Bubble Sort Slideshow 1
# 921/3361: Bubble Sort Slideshow 2
# 922/3361: Bubble Sort Analysis Slideshow
# 923/3361: Selection Sort Slideshow 1
# 924/3361: Selection Sort Slideshow 2
# 925/3361: Selection Sort Analysis Slideshow
# 926/3361: Exchange Sort Analysis Slideshow
# 927/3361: Shellsort Slideshow 1
# 928/3361: Shellsort Slideshow 2
# 929/3361: Shellsort Slideshow 3
# 930/3361: Shellsort Slideshow 4
# 931/3361: Shellsort Slideshow 5
# 932/3361: Shellsort Slideshow 6
# 933/3361: Merging Slideshow
# 934/3361: Mergesort Analysis Slideshow
# 935/3361: Mergesort Implementation Slideshow 1
# 936/3361: Mergesort Implementation Slideshow 2
# 937/3361: Quicksort Partition Slideshow
# 938/3361: Quicksort Partition Analysis Slideshow
# 939/3361: Quicksort Worst Case Analysis Slideshow
# 940/3361: Quicksort Best Case Analysis Slideshow
# 941/3361: Quicksort Average Case Analysis Slideshow
# 942/3361: Heapsort Slideshow
# 943/3361: Heapsort Analysis Slideshow
# 944/3361: Binsort Slideshow 1
# 945/3361: Binsort Slideshow 2
# 946/3361: Radix Sort Analysis Slideshow
# 947/3361: Sorting Lower Bound Slideshow
# 948/3361: Selection Sort Pointer Swap
# 949/3361: Sorting Terminology and Notation Slideshow 1
# 950/3361: Sorting Problem
# 951/3361: Pair to Sorting Reduction Slideshow
# 952/3361: Sorting to Pairing Reduction Slideshow
# 953/3361: Record Comparison Summary Exercise
# 954/3361: Sorting Intro Summary
# 955/3361: Insertion Sort Proficiency Exercise
# 956/3361: Insertion Sort Summary Exercise
# 957/3361: Bubble Sort Proficiency Exercise
# 958/3361: Bubble Sort Summary Exercise
# 959/3361: Selection Sort Proficiency Exercise
# 960/3361: Selection Sort Summary Exercise
# 961/3361: Inversions Proficiency Exercise
# 962/3361: Exchange Sorting Summary Exercise
# 963/3361: Shellsort Sublist Proficency Exercise
# 964/3361: Shellsort Series Exercise
# 965/3361: Shellsort Summary Exercise
# 966/3361: Mergesort Merging Proficiency Exercise
# 967/3361: Mergesort Summary Exercise
# 968/3361: Quicksort Pivot Proficiency Exercise
# 969/3361: Quicksort Partition Proficiency Exercise
# 970/3361: Quicksort Summary Exercise
# 971/3361: Heapsort RemoveMax Proficiency Exercise
# 972/3361: Heapsort Summary Exercise
# 973/3361: Radix Sort Proficiency Exercise
# 974/3361: Radix Sort Summary Exercise
# 975/3361: Sort Comparison Summary Exercise
# 976/3361: Lower Bounds Summary Exercise
# 977/3361: Sorting Chapter Summary Exercise
# 978/3361: JLinkedListUtil Challenge
# 979/3361: JLinkedListUtil
# 980/3361:  Recursively calculate the power of a number Challenge
# 981/3361:  Recursively calculate the power of a number
# 982/3361: Recursively calculate the sum of all numbers from 1 to n Challenge
# 983/3361: Recursively calculate the sum of all numbers from 1 to n
# 984/3361: q_java_q_py_slinkedlist1
# 985/3361: q_java_q_py_dlinkedlist1
# 986/3361: Merge LinkList - NFB
# 987/3361: (Recursion) Power calculation - NFB
# 988/3361: (Recursion) Sum from 1 to n - NFB
# 989/3361: Recursive addition of characters - NFB
# 990/3361: Traverse LinkedList - NFB
# 991/3361: LinkedList repeated two lists - NFB
# 992/3361: Compare Two LinkedList - NFB
# 993/3361: Compare Two LinkedList
# 994/3361: Linked List 1
# 995/3361: Use Recursion to calculate power
# 996/3361: Use Recursion to calculate total sum of all numbers from 1 to N.
# 997/3361: PCRS C3-PL Reverse dictionary
# 998/3361: PCRS C3-PL Recursive counting
# 999/3361: PCRS C3-PL Bracket validation
# 1000/3361: PCRS C3-PL  Find N Letters
# 1001/3361: PCRS C3-PL  Event Class
# 1002/3361: PCRS C3-PL  Total Slices
# 1003/3361: PCRS C3-PL  List Insert
# 1004/3361: PCRS C3-PL  Reverse Lookup
# 1005/3361: PCRS C3-PL  Realestate Class
# 1006/3361: PCRS C3-PL  Ipod Class
# 1007/3361: PCRS C3-PL  Rectangle Class
# 1008/3361: PCRS C3-PL  Special List Class
# 1009/3361: PCRS C3-PL  Can Pay With Two Coins
# 1010/3361: PCRS C3-PL  Add Underscores
# 1011/3361: PCRS C3-PL  Class Day Calendar
# 1012/3361: PCRS C3-PL  Double
# 1013/3361: PCRS C3-PL  Our Maximum
# 1014/3361: PCRS C3-PL  Max Of Min
# 1015/3361: PCRS C3-PL  Caculate Tax
# 1016/3361: PCRS C3-PL  Same Abs
# 1017/3361: PCRS C3-PL  Upper Lower
# 1018/3361: PCRS C3-PL  Overdue Fees
# 1019/3361: PCRS C3-PL  Different Types
# 1020/3361: PCRS C3-PL  Every Second Line
# 1021/3361: PCRS C3-PL  Get Words
# 1022/3361: PCRS C3-PL  Context To Next Words
# 1023/3361: PCRS C3-PL  Calendar Event3
# 1024/3361: PCRS C3-PL  User Class1
# 1025/3361: PCRS C3-PL  User Day
# 1026/3361: PCRS C3-PL  Adjacent Match
# 1027/3361: PCRS C3-PL  Duplicate Cut
# 1028/3361: PCRS C3-PL  Student By Degree
# 1029/3361: PCRS C3-PL  Has Last Token
# 1030/3361: PCRS C3-PL  Context Not Unique Hashtags
# 1031/3361: PCRS C3-PL  Non Intersecting
# 1032/3361: PCRS C3-PL  Eligible
# 1033/3361: PCRS C3-PL  Return Indices
# ...
# 2791/3361: Move Tester
# 2792/3361: Copy Demo
# 2793/3361: Counter Demo
# 2794/3361: Hello Printer
# 2795/3361: Operations with Variables
# 2796/3361: All Variables Together
# 2797/3361: Initializing Variables
# 2798/3361: Size of Variables
# 2799/3361: Boolean Variables
# 2800/3361: Ctring Variables
# 2801/3361: Character Numbers ASCII
# 2802/3361: Char Variables
# 2803/3361: Float and Double Variables
# 2804/3361: Variable Types
# 2805/3361: Change the Value of a Variable
# 2806/3361: Using Variables
# 2807/3361: Using End of Line Statement
# 2808/3361: Multiline cout
# 2809/3361: Simple cout
# 2810/3361: Cash Register Tester (Constant Field)
# 2811/3361: Class (Cash Register)
# 2812/3361: Division
# 2813/3361: Earthquake
# 2814/3361: String (replace)
# 2815/3361: Using float
# 2816/3361: Using Double
# 2817/3361: String (equals)
# 2818/3361: Strings (equalsIgnoreCase)
# 2819/3361: Converting between Class and Interface Types
# 2820/3361: Interface Polymorphism
# 2821/3361: Measure
# 2822/3361: Overriding Object Methods
# 2823/3361: Tic-Tac-Toe
# 2824/3361: Bank
# 2825/3361: Grade Book
# 2826/3361: ArrayList Tester
# 2827/3361: Enhanced For Loop
# 2828/3361: Enhanced For Loop Demo
# 2829/3361: Class (Bank Account This)
# 2830/3361: This Reference
# 2831/3361: Cash Register Tester
# 2832/3361: Bank Account Tester
# 2833/3361: Counter Demo
# 2834/3361: Copy Demo
# 2835/3361: Accessor Mutator Demo
# 2836/3361: Constructor Demo
# 2837/3361: Method Demo
# 2838/3361: Comparing Strings
# 2839/3361: String Equals
# 2840/3361: Test Null
# 2841/3361: Testing for null
# 2842/3361: Object Equality
# 2843/3361: Boolean Operations (Greater equal)
# 2844/3361: Boolean Operations (Less equal)
# 2845/3361: Boolean Operations (Not equal)
# 2846/3361: Boolean Operations (Not)
# 2847/3361: Boolean Operations (OR)
# 2848/3361: String Concat
# 2849/3361: Strings (Concatenation)
# 2850/3361: Strings (parse)
# 2851/3361: Strings (replace)
# 2852/3361: Strings (charAt)
# 2853/3361: Using Math Class (ceil)
# 2854/3361: Using Math Class (abs)
# 2855/3361: Pre Decrement
# 2856/3361: Post Decrement
# 2857/3361: Post Increment
# 2858/3361: Compound Assignment
# 2859/3361: Combining Assignment and Arithmetic
# 2860/3361: Decrement
# 2861/3361: Simple Variable Test
# 2862/3361: println Test
# 2863/3361: int Variables 4
# 2864/3361: int Variable 1
# 2865/3361: Print Tester
# 2866/3361: Variable Demo
# 2867/3361: Hello Printer
# 2868/3361: check_file2
# 2869/3361: count_occur
# 2870/3361: pointer_seq_file
# 2871/3361: pointer_seq_file2
# 2872/3361: create_seq_file
# 2873/3361: read_seq_file
# 2874/3361: update_credit_prog
# 2875/3361: pass_file
# 2876/3361: structs1
# 2877/3361: rand_access_file
# 2878/3361: write_info_rand_file
# 2879/3361: IS12:: helloworld.c (1.1)
# 2880/3361: IS12:: printing.c (2)
# 2881/3361: IS12:: printing1.c (2.1)
# 2882/3361: IS12:: printing2.c (2.2)
# 2883/3361: IS12:: calculating1.c (2.3)
# 2884/3361: IS12:: calculating2.c (2.4)
# 2885/3361: IS12:: variables.c (3.1)
# 2886/3361: IS12:: exchange_kiosk.c (3.11)
# 2887/3361: IS12:: better_kiosk.c (3.2)
# 2888/3361: IS12:: capital.c (3.3)
# 2889/3361: IS12:: fahr_input.c (3.4)
# 2890/3361: IS12:: countdown1.c (4.1)
# 2891/3361: IS12:: countdown2.c (4.2)
# 2892/3361: IS12:: capitalyears.c (4.3)
# 2893/3361: IS12:: factorial.c (4.4)
# 2894/3361: IS12:: accumulator.c (4.7)
# 2895/3361: IS12:: apples_kids.c (4.8)
# 2896/3361: IS12:: max2.c (5.1)
# 2897/3361: IS12:: max1.c (5.2)
# 2898/3361: IS12:: rate2.c (5.3)
# 2899/3361: IS12:: maxloop.c (5.4)
# 2900/3361: IS12:: max3.c (5.5)
# 2901/3361: IS12:: line_count.c (6.4)
# 2902/3361: IS12:: better_copycat.c (6.5)
# 2903/3361: IS12:: copycat.c (6.6)
# 2904/3361: IS12:: arraysum.c (9.1)
# 2905/3361: IS12:: arraymax.c (9.2)
# 2906/3361: IS12:: arraymin.c (9.3)
# 2907/3361: IS12:: babyweighting.c (9.4)
# 2908/3361: IS12:: digcount.c (10.1)
# 2909/3361: IS12:: sumarfunc.c (10.2)
# 2910/3361: IS12:: power.c (10.3)
# 2911/3361: IS12:: longestline.c (12.2)
# 2912/3361: IS12:: patternsearch.c (12.3)
# 2913/3361: IS12:: str2int.c (12.4)
# 2914/3361: IS12:: goodswap.c (14.1)
# 2915/3361: IS12:: strcomp.c (14.2)
# 2916/3361: IS12:: battleship.c (15.1)
# 2917/3361: IS12:: yearday.c (15.2)
# 2918/3361: IS12:: printback.c (15.3)
# 2919/3361: IS12:: betterbattle.c (15.4)
# 2920/3361: IS12:: recfactorial.c (24.1)
# 2921/3361: IS12:: recpower.c (24.2)
# 2922/3361: IS12:: insummax.c (111.1)
# 2923/3361: IS12:: parampass.c (111.2)
# 2924/3361: IS12:: palindrome.c (111.3)
# 2925/3361: IS12:: qpa.c (117.1)
# 2926/3361: IS12:: rate3.c (117.2)
# 2927/3361: IS12:: encrypt.c (117.3)
# 2928/3361: IS12:: qpa_or.c (117.4)
# 2929/3361: IS12:: qpa_and.c (117.5)
# 2930/3361: IS12:: av_line_while.c (118.1)
# 2931/3361: IS12:: av_line_for.c (118.2)
# 2932/3361: IS12:: f2c_for.c (118.3)
# 2933/3361: IS12:: abcounting.c (118.4)
# 2934/3361: IS12:: abcounting_case.c (118.5)
# 2935/3361: IS12:: wc.c (118.6)
# 2936/3361: IS12:: nondigits.c (118.7)
# 2937/3361: IS12:: arrayio.c (119.1)
# 2938/3361: IS12:: arrayiofor.c (119.2)
# 2939/3361: IfElse_Structure
# 2940/3361: private
# 2941/3361: fig02_01.c
# 2942/3361: fig02_03.c
# 2943/3361: fig02_04.c
# 2944/3361: fig02_05.c
# 2945/3361: fig02_13.c
# 2946/3361: fig03_06.c
# 2947/3361: fig03_08.c
# 2948/3361: fig03_10.c
# 2949/3361: fig03_13.c
# 2950/3361: fig04_01.c
# 2951/3361: fig04_02.c
# 2952/3361: fig04_06.c
# 2953/3361: fig04_07.c
# 2954/3361: fig04_09.c
# 2955/3361: fig04_11.c
# 2956/3361: fig04_12.c
# 2957/3361: fig05_03.c
# 2958/3361: fig05_04.c
# 2959/3361: fig05_07.c
# 2960/3361: fig05_08.c
# 2961/3361: fig05_09.c
# 2962/3361: fig05_10.c
# 2963/3361: fig05_12.c
# 2964/3361: fig05_14.c
# 2965/3361: fig05_15.c
# 2966/3361: fig06_03.c
# 2967/3361: fig06_04.c
# 2968/3361: fig06_05.c
# 2969/3361: fig06_06.c
# 2970/3361: fig06_07.c
# 2971/3361: fig06_08.c
# 2972/3361: fig06_09.c
# 2973/3361: fig06_10.c
# 2974/3361: fig06_11.c
# 2975/3361: fig06_12.c
# 2976/3361: fig06_13.c
# 2977/3361: fig06_14.c
# 2978/3361: fig06_15.c
# 2979/3361: fig06_16.c
# 2980/3361: fig06_18.c
# 2981/3361: fig06_19.c
# 2982/3361: fig06_21.c
# 2983/3361: fig06_22.c
# 2984/3361: fig07_04.c
# 2985/3361: fig07_06.c
# 2986/3361: fig07_07.c
# 2987/3361: fig07_10.c
# 2988/3361: fig07_11.c
# 2989/3361: fig07_12.c
# 2990/3361: fig07_13.c
# 2991/3361: fig07_14.c
# 2992/3361: Table Creation
# 2993/3361: fig07_15.c
# 2994/3361: Primary Key (1)
# 2995/3361: fig07_16.c
# 2996/3361: Primary Key and Unique Key
# 2997/3361: fig07_17.c
# 2998/3361: Foriegn Key
# 2999/3361: fig07_20.cpp
# 3000/3361: Table Drop
# 3001/3361: fig07_21.c
# 3002/3361: Column Addition
# 3003/3361: fig07_24.c
# 3004/3361: Column Drop
# 3005/3361: fig07_26.c
# 3006/3361: Inserting Data (1)
# 3007/3361: fig07_28.c
# 3008/3361: Deleting Data
# 3009/3361: Binary_Expressions
# 3010/3361: Selecting One Attribute
# 3011/3361: precedence_expression
# 3012/3361: Selecting Multiple Attributes
# 3013/3361: precedence_expr
# 3014/3361: Selecting All Attributes
# 3015/3361: complex_expr
# 3016/3361: Skipping Duplicates
# 3017/3361: IncDec_Oper
# 3018/3361: Aggregate Functions (1)
# 3019/3361: compound_assign
# 3020/3361: Selection Condition
# 3021/3361: casting_num
# 3022/3361: Comparison Condition (1)
# 3023/3361: 1stprogram
# 3024/3361: Comparison Condition (2)
# 3025/3361: printf
# 3026/3361: Comparison Condition (3)
# 3027/3361: input_print
# 3028/3361: Multiple Table Selection (1)
# 3029/3361: decimal_value
# 3030/3361: Multiple Comparisons (1)
# 3031/3361: avg_score
# 3032/3361: Check Constraint (1)
# 3033/3361: CH3_printf1
# 3034/3361: Check Constraint (2)
# 3035/3361: CH3_printf2
# 3036/3361: Assertion Creation (1)
# 3037/3361: CH3_printf3
# 3038/3361: Inserting Data (2)
# 3039/3361: Inserting Data (3)
# 3040/3361: Coin_Values
# 3041/3361: Inserting Data (4)
# 3042/3361: IncDec
# 3043/3361: Updating Data (2)
# 3044/3361: If
# 3045/3361: Updating Data (3)
# 3046/3361: while_structure
# 3047/3361: Updating Data (1)
# 3048/3361: Sentinel_value
# 3049/3361: Updating with condition
# 3050/3361: Sales
# 3051/3361: Updating with subquery
# 3052/3361: Payroll
# 3053/3361: Deleting with Condition (1)
# 3054/3361: Cwhile_counter
# 3055/3361: Deleting with Condition (2)
# 3056/3361: Whileloop
# 3057/3361: Arithmetic Expression
# 3058/3361: ForLoop
# 3059/3361: Multiple Comparisons (2)
# 3060/3361: ForLoop2
# 3061/3361: Range Test (1)
# 3062/3361: ForStatement
# 3063/3361: Range Test (2)
# 3064/3361: Usage
# 3065/3361: Multiple Table Selection (2)
# 3066/3361: WhileStatement
# 3067/3361: String Operation
# 3068/3361: BreakStatement
# 3069/3361: Alphabetic Order
# 3070/3361: Continue
# 3071/3361: Combining Query Results (1)
# 3072/3361: SwitchStatement
# 3073/3361: Combining Query Results (2)
# 3074/3361: SwitchStatement2
# 3075/3361: Combining Query Results (3)
# 3076/3361: IF2
# 3077/3361: Aggregate Functions (2)
# 3078/3361: Rand
# 3079/3361: Aggregate Functions (3)
# 3080/3361: Srand
# 3081/3361: Aggregate Functions (4)
# 3082/3361: rand function
# 3083/3361: Grouped Queries
# 3084/3361: defined function
# 3085/3361: Grouped Queries with Condition
# 3086/3361: Multiple Return
# 3087/3361: Checking Null Values
# 3088/3361: Assign Return
# 3089/3361: Nested Subqueries (1)
# 3090/3361: Do Switch Function
# 3091/3361: Nested Subqueries (2)
# 3092/3361: Defined Function2
# 3093/3361: Comparing Subquery Results (1)
# 3094/3361: No Argument Functions
# 3095/3361: Comparing Subquery Results (2)
# 3096/3361: Function CallByValue
# 3097/3361: Aggregating Subquery
# 3098/3361: Call By Reference
# 3099/3361: Derived Relations
# 3100/3361: Call By Reference2
# 3101/3361: View Creation (1)
# 3102/3361: Block Scope
# 3103/3361: View Creation (2)
# 3104/3361: Recursion
# 3105/3361: Grouping and aggregating (1)
# 3106/3361: calculate_Functions.c
# 3107/3361: Grouping and aggregating (2)
# 3108/3361: calculate_Main.c
# 3109/3361: Grouping and aggregating (3)
# 3110/3361: One Dim Arrays
# 3111/3361: Assertion Creation (2)
# 3112/3361: Retrieving data from view
# 3113/3361: Static Arrays
# 3114/3361: Aggregating Derived Relations
# 3115/3361: Using Arrays
# 3116/3361: Primary Key (2)
# 3117/3361: Encryption Program
# 3118/3361: Variable Declaration
# 3119/3361: comparison operators
# 3120/3361: Using Const
# 3121/3361: Variable Initialization
# 3122/3361: boolean operators
# 3123/3361: Using 2D Arrays
# 3124/3361: HelloWorld
# 3125/3361: if-else-if
# 3126/3361: BubbleSort
# 3127/3361: Object Creation and Method Calls
# 3128/3361: Exceptions
# 3129/3361: SortAlgorithm
# 3130/3361: Rectangle
# 3131/3361: Multiple Variables
# 3132/3361: InsertSortAlgo
# 3133/3361: Bicycle
# 3134/3361: Multiple Variables 2
# 3135/3361: BubbleSortAlgo
# 3136/3361: Funcion mismo valor absoluto (ES)
# 3137/3361: If with complex condition
# 3138/3361: CallbyValue
# 3139/3361: Primitive Data Types
# 3140/3361: If Statement
# 3141/3361: CallbyReference
# 3142/3361: Type Casting
# 3143/3361: Else Clause
# 3144/3361: deferencing
# 3145/3361: Constants
# 3146/3361: Nested if
# 3147/3361: PointerNotation
# 3148/3361: Constant2
# 3149/3361: Using &&
# 3150/3361: ArraysSubscript
# 3151/3361: Arithmetic Operations
# 3152/3361: Using ||
# 3153/3361: PointerArrays
# 3154/3361: Increment
# 3155/3361: Switch Statement
# 3156/3361: PointerArrays2
# 3157/3361: Math Functions
# 3158/3361: Free Flow Switch
# 3159/3361: ArrayAddresses
# 3160/3361: Operator
# 3161/3361: Nested Switch
# 3162/3361: ArrayPointers
# 3163/3361: Creating String
# 3164/3361: Switch with Enum
# 3165/3361: NonConstant
# 3166/3361: Substring
# 3167/3361: Sum using While
# 3168/3361: NonConstPointer
# 3169/3361: String Length
# 3170/3361: While with double
# 3171/3361: ConstPointer
# 3172/3361: Decision If
# 3173/3361: Nested For Loop
# 3174/3361: ConstPointer2
# 3175/3361: If Else
# 3176/3361: Print Out a Diamond
# 3177/3361: BubbleSortPF
# 3178/3361: String Comparison
# 3179/3361: Infinite For
# 3180/3361: PrintAddress
# 3181/3361: Logical Operators
# 3182/3361: For with Multiple Variables 2
# 3183/3361: Boolean Declaration
# 3184/3361: For with Multiple Variables
# 3185/3361: CopyString
# 3186/3361: Boolean Expression
# 3187/3361: For with Multiple Variables 3
# 3188/3361: CreateFile
# 3189/3361: Boolean Operators
# 3190/3361: For omitting elements
# 3191/3361: ReadFromFile
# 3192/3361: While
# 3193/3361: For-Each 2
# 3194/3361: DoWhile
# 3195/3361: For-Each with ArrayList
# 3196/3361: atof_atoi_atol
# 3197/3361: For Loop
# 3198/3361: For-Each
# 3199/3361: strtod
# 3200/3361: Nested Loops
# 3201/3361: For-each with char array
# 3202/3361: gets_puts
# 3203/3361: Nested Loops2
# 3204/3361: Multidimensional Array Iteration
# 3205/3361: Array Declaration
# 3206/3361: For-each with break
# 3207/3361: strcy_strncpy
# 3208/3361: Using an Array1
# 3209/3361: relational operators
# 3210/3361: strcat_strncat
# 3211/3361: Using an Array2
# 3212/3361: String Example
# 3213/3361: strcmp_strncmp
# 3214/3361: Create ArrayList
# 3215/3361: switch
# 3216/3361: strlen
# 3217/3361: ArrayList Demo
# 3218/3361: Polymorphism and Inheritance 1
# 3219/3361: search_func
# 3220/3361: Wrapper Classes
# 3221/3361: Casting subclass
# 3222/3361: strtok
# 3223/3361: Create 2D Array
# 3224/3361: Polymorphism and Inheritance 2
# 3225/3361: upper_lower_case
# 3226/3361: Use 2D Array
# 3227/3361: A Dog is also a Pet
# 3228/3361: string_to_integer
# 3229/3361: Interface
# 3230/3361: Inheritance and Constructors 1
# 3231/3361: string_compare
# 3232/3361: MultiInterfaces
# 3233/3361: Simple Inheritance
# 3234/3361: tokenize1
# 3235/3361: Inheritance
# 3236/3361: search_occur
# 3237/3361: Override
# 3238/3361: word_count
# 3239/3361: find_string
# 3240/3361: defined_func1
# 3241/3361: defined_func2
# 3242/3361: string_lib_func1
# 3243/3361: fgetc_fputc
# 3244/3361: check_file
# 3245/3361: Objects 3 (Rectangle)
# 3246/3361: Objects 4 (String)
# 3247/3361: Objects 5 (String)
# 3248/3361: Class 1 (BankAccount)
# 3249/3361: Class 2 (BankAccount)
# 3250/3361: Class 3 (BankAccount)
# 3251/3361: Class 4 (CashRegister)
# 3252/3361: Class 5 (Point)
# 3253/3361: Using int
# 3254/3361: Using double
# 3255/3361: Using double and Math class
# 3256/3361: Using float
# 3257/3361: Converting String to int
# 3258/3361: Converting String to double
# 3259/3361: Constants 1
# 3260/3361: Constants 2
# 3261/3361: Operations with int
# 3262/3361: Using Math class 1
# 3263/3361: Using Math class 2
# 3264/3361: Modulus Operator
# 3265/3361: Increment Operator
# 3266/3361: Strings 1
# 3267/3361: Strings 2
# 3268/3361: Strings 3
# 3269/3361: Strings 4
# 3270/3361: Strings 5
# 3271/3361: Strings 6
# 3272/3361: if-else 1
# 3273/3361: if-else 2
# 3274/3361: if-else 3
# 3275/3361: if-else 4
# 3276/3361: if-else 5
# 3277/3361: Using boolean
# 3278/3361: Comparing Strings
# 3279/3361: Boolean Operations (AND)
# 3280/3361: Comparisons
# 3281/3361: Comparisons 2
# 3282/3361: Switch 1
# 3283/3361: Switch 2
# 3284/3361: Switch 3
# 3285/3361: Loop While 1
# 3286/3361: Loop While 2
# 3287/3361: Loop While 3
# 3288/3361: Problem 1
# 3289/3361: Loop While 5
# 3290/3361: Loop Do-While 1
# 3291/3361: Loop Do-While 2
# 3292/3361: Loop Do-While 3
# 3293/3361: Loop Do-While 4
# 3294/3361: Problem 2
# 3295/3361: Problem 3
# 3296/3361: Loop For 1
# 3297/3361: Loop For 2
# 3298/3361: Loop For 3
# 3299/3361: Loop For 4
# 3300/3361: Loop For 5
# 3301/3361: Nested Loops 1
# 3302/3361: Problem 4
# 3303/3361: Nested Loops 3
# 3304/3361: Problem 5
# 3305/3361: Problem 6
# 3306/3361: Arrays 3
# 3307/3361: Arrays 4
# 3308/3361: Arrays 5
# 3309/3361: ArrayList 1
# 3310/3361: ArrayList 2
# 3311/3361: ArrayList 3
# 3312/3361: Wrapper Classes 1
# 3313/3361: Wrapper Classes 2
# 3314/3361: Wrapper Classes 3
# 3315/3361: 2D Arrays 1
# 3316/3361: 2D Arrays 2
# 3317/3361: Problem 7
# 3318/3361: 2D Arrays 4
# 3319/3361: ArrayList 4
# 3320/3361: ArrayList 5
# 3321/3361: Wrapper Classes 4
# 3322/3361: Interfaces 1
# 3323/3361: Interfaces 2
# 3324/3361: Interfaces 3
# 3325/3361: Interfaces 4
# 3326/3361: Interfaces 5
# 3327/3361: Inheritance 1
# 3328/3361: Inheritance 2
# 3329/3361: Inheritance 3
# 3330/3361: Inheritance 4
# 3331/3361: Inheritance 5
# 3332/3361: Inheritance 6
# 3333/3361: Exceptions 1
# 3334/3361: Exceptions 2
# 3335/3361: Exceptions 3
# 3336/3361: Exceptions 4
# 3337/3361: Exceptions 5
# 3338/3361: Constants in Math class
# 3339/3361: Constants in CashRegister class 1
# 3340/3361: Constants in CashRegister class 2
# 3341/3361: int Variables 1
# 3342/3361: int Variables 2
# 3343/3361: int Variables 3
# 3344/3361: int Variables 4
# 3345/3361: String Variables
# 3346/3361: Objects 1 (Rectangle)
# 3347/3361: Objects 2 (Rectangle)
# 3348/3361: fig04_05.c
# 3349/3361: Calculate_profit
# 3350/3361: Array of Char
# 3351/3361: CharReferencing
# 3352/3361: character_functions
# 3353/3361: getchar()
# 3354/3361: ascII_char
# 3355/3361: IS12:: f2c_table.c (4.5)
# 3356/3361: IS12:: nicer_f2c_table.c (4.6)
# 3357/3361: IS12:: capitaltable.c (4.9)
# 3358/3361: IS12:: count_char.c (6.1)
# 3359/3361: IS12:: char_codes.c (6.2)
# 3360/3361: IS12:: starchart.c (12.1)

# %%
# # ------- RESTORE ITEMS -------
# import os
# import requests
# import json

# api_token = open('api_token.txt').read().strip()
# items = os.listdir('items')

# for index, id in enumerate(items):
#     if not id.endswith('.json'):
#         continue
#     item = json.load(open(f'items/{id}'))
#     response = requests.patch(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id.replace('.json', '')}",
#         json=item,
#         headers={'api-token': api_token}
#     )
#     print(f'[{index}/{len(items)}:{response.status_code}] restored item id:', id.replace('.json', ''))

# %%
# # merge all items into a single file

# import os
# import json

# items = []
# for index, id in enumerate(os.listdir('items')):
#     if not id.endswith('.json'):
#         continue
#     items.append(json.load(open(f'items/{id}')))
# json.dump(items, open('items.json', 'w'), indent=2)
