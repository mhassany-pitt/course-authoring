# %%
# import requests
# import json

# codechecks = json.load(open('codecheck-python.json'))

# api_token = open('api_token.txt').read().strip()
# for index, codecheck in enumerate(codechecks):
#     item = {
#         "status": "public",
#         "listed_at": "2026-02-15T00:00:00.000Z",
#         "tags": [],
#         "identity": {
#             "id": codecheck['persistentID'].replace('https://codecheck.io/files/', ''),
#             "title": codecheck['persistentID'].replace('https://codecheck.io/files/horstmann/', ''),
#             "type": "FreeCodingProblems"
#         },
#         "links": {
#             "demo_url": codecheck['iframe_url']
#         },
#         "attribution": {
#             "created_at": "2026-01-01T00:00:00.000Z",
#             "provider": "CodeCheck",
#             "publisher": "Cay Horstmann",
#             "authors": [
#                 {
#                     "name": codecheck['author'],
#                     "affiliation": codecheck['institution']
#                 }
#             ]
#         },
#         "languages": {
#             "content_language": codecheck['natural_language'][0],
#             "programming_languages": [codecheck['programming_language']]
#         },
#         "content": {
#             "prompt": codecheck['description'],
#             "source_code": ""
#         },
#         "classification": {
#             "topics": [],
#             "difficulty": "",
#             "knowledge_components": {
#                 "CayHorstmann-keywords": {
#                     "concepts": codecheck["keywords"],
#                     "note": "extracted from the SPLICE.SLCItem.keywords field"
#                 }
#             }
#         },
#         "pedagogy": {
#             "learning_objectives": [],
#             "instructional_role": "",
#             "prerequisites": {"topics": [],"concepts": [],"item_ids": []}
#         },
#         "interaction": {"interaction_type": ""},
#         "delivery": [
#             { "format": protocol, "url": codecheck['protocol_url'][i] }
#             for i, protocol in enumerate(codecheck['protocol'])
#         ],
#         "rights": {
#             "license": "CC BY-NC-ND 4.0",
#             "license_url": "https://creativecommons.org/licenses/by-nc-nd/4.0/",
#             "usage_notes": ""
#         },
#         "uses": [],
#     }
#     response = requests.post(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/",
#         json=item,
#         headers={'api-token': api_token, 'api-user-email': "moh70@pitt.edu"}
#     )
#     print(f'{index}/{len(codechecks)}:[{response.status_code}]', item['identity']['title'])
# Out:
# 0/166:[201] codecheck-python-StringsNumbersInStrings-1
# 1/166:[201] codecheck-python-StringsNumbersInStrings-3
# 2/166:[201] codecheck-python-StringsNumbersInStrings-2
# 3/166:[201] codecheck-python-LoopingOvertheEntireArray-12
# 4/166:[201] codecheck-python-LoopingOvertheEntireArray-9
# 5/166:[201] codecheck-python-LoopingOvertheEntireArray-1
# 6/166:[201] codecheck-python-LoopingOvertheEntireArray-11
# 7/166:[201] codecheck-python-LoopingOvertheEntireArray-3
# 8/166:[201] codecheck-python-LoopingOvertheEntireArray-4
# 9/166:[201] codecheck-python-LoopingOvertheEntireArray-5
# 10/166:[201] codecheck-python-LoopingOvertheEntireArray-13
# 11/166:[201] codecheck-python-LoopingOvertheEntireArray-6
# 12/166:[201] codecheck-python-LoopingOvertheEntireArray-2
# 13/166:[201] codecheck-python-LoopingOvertheEntireArray-10
# 14/166:[201] codecheck-python-LoopingOvertheEntireArray-8
# 15/166:[201] codecheck-python-LoopingOvertheEntireArray-7
# 16/166:[201] codecheck-python-StringWords-1
# ...
