# %%
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()

# %%
# api_token = open('api_token.txt').read().strip()
# for index, item in enumerate(catalog):
#     if item['attribution']['provider'] != 'CodeCheck':
#         continue
#     if 'source_code' in item["content"] and len(item["content"]["source_code"]) > 0:
#         continue
#     if item['status'] != 'public':
#         continue

#     html_content = requests.get(item['links']['demo_url']).text
#     html_content = html_content[html_content.find('//<![CDATA[')+11:html_content.find('// ]]>')]
#     html_content = html_content.strip().replace('horstmann_codecheck.setup.push(', '')[:-1]
#     code = json.loads(html_content)['requiredFiles']["prog.py"]["editors"][0]
#     item = requests.get(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}",
#         headers={'api-token': api_token}
#     ).json()
#     item["content"]["source_code"] = code
#     response = requests.patch(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{item['id']}",
#         json=item,
#         headers={'api-token': api_token}
#     )
#     print(f'{index}/{len(catalog)}:[{response.status_code}]', item['identity']['title'])
# Out:
# 0/3100:[200] codecheck-python-StringsNumbersInStrings-1
# 1/3100:[200] codecheck-python-StringsNumbersInStrings-3
# 2/3100:[200] codecheck-python-StringsNumbersInStrings-2
# 3/3100:[200] codecheck-python-LoopingOvertheEntireArray-12
# 4/3100:[200] codecheck-python-LoopingOvertheEntireArray-9
# 5/3100:[200] codecheck-python-LoopingOvertheEntireArray-1
# 6/3100:[200] codecheck-python-LoopingOvertheEntireArray-11
# 7/3100:[200] codecheck-python-LoopingOvertheEntireArray-3
# 8/3100:[200] codecheck-python-LoopingOvertheEntireArray-4
# 9/3100:[200] codecheck-python-LoopingOvertheEntireArray-5
# 10/3100:[200] codecheck-python-LoopingOvertheEntireArray-13
# 11/3100:[200] codecheck-python-LoopingOvertheEntireArray-6
# 12/3100:[200] codecheck-python-LoopingOvertheEntireArray-2
# 13/3100:[200] codecheck-python-LoopingOvertheEntireArray-10
# 14/3100:[200] codecheck-python-LoopingOvertheEntireArray-8
# 15/3100:[200] codecheck-python-LoopingOvertheEntireArray-7
# ...
