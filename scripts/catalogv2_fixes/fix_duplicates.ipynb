# %%
dup_pawsIds = [2004,2005,2006,2007,2301,2302,2303,2304,2305,2306,2307,2308,2309,2310,2311,2312,2313,2314,2315,2316,2317,2318,2319,2320,2321,2322,2323,2324,2325,2326,2327,2328,2329,2330,2331,2332,2333,2334,2335,2336,2337,2338,2339,2340,2341,2342,2343,2344,2345,2346,2347,2348,2349,2350,2410,2411,2412,2413,2701,2702,3409,3410,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397]

# %%
import requests
import json

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()

# %%
catalog = [item for item in catalog if item['paws_id'] in dup_pawsIds]

# %%
catalog = sorted(catalog, key=lambda x: x['paws_id'])

# %%
to_delIds = [item['id'] for item in catalog if item['content']['prompt'] is None]

# %%
# api_token = open('api_token.txt').read().strip()
# for index, id in enumerate(to_delIds):
#     response = requests.delete(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id}",
#         headers={'api-token': api_token}
#     )
#     print(f'{index}/{len(to_delIds)} -- {id} | status_code:', response.status_code)
# Out:
# 0/108 -- 6954bccff9187b06cf8377f1 | status_code: 200
# 1/108 -- 6954bccff9187b06cf8377f2 | status_code: 200
# 2/108 -- 6954bccff9187b06cf8377f3 | status_code: 200
# 3/108 -- 6954bccff9187b06cf8377f4 | status_code: 200
# 4/108 -- 6954bccff9187b06cf8377f5 | status_code: 200
# 5/108 -- 6954bccff9187b06cf8377f6 | status_code: 200
# 6/108 -- 6954bccff9187b06cf8377f7 | status_code: 200
# 7/108 -- 6954bccff9187b06cf8377f8 | status_code: 200
# 8/108 -- 6954bccff9187b06cf8377f9 | status_code: 200
# 9/108 -- 6954bccff9187b06cf8377fa | status_code: 200
# 10/108 -- 6954bccff9187b06cf8377fb | status_code: 200
# 11/108 -- 6954bccff9187b06cf8377fc | status_code: 200
# 12/108 -- 6954bccff9187b06cf8377fd | status_code: 200
# 13/108 -- 6954bccff9187b06cf8377fe | status_code: 200
# 14/108 -- 6954bccff9187b06cf8377ff | status_code: 200
# 15/108 -- 6954bccff9187b06cf837800 | status_code: 200
# 16/108 -- 6954bccff9187b06cf837801 | status_code: 200
# 17/108 -- 6954bccff9187b06cf837802 | status_code: 200
# ...
