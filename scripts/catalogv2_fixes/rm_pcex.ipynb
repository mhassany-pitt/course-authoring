# %%
# import os
# import json
# import requests

# api_token = open('api_token.txt').read().strip()
# to_delIds = []

# for file in os.listdir('./items'):
#     if not file.endswith('.json'):
#         continue
#     item = json.load(open(os.path.join('./items', file)))
#     if item['attribution']['provider'] == 'PCEX':
#         to_delIds.append(item['id'])
        
# for index, id in enumerate(to_delIds):
#     response = requests.delete(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id}",
#         headers={'api-token': api_token}
#     )
#     print(f'{index}/{len(to_delIds)} -- {id} | status_code:', response.status_code)
#     if response.status_code == 200:
#         os.remove(os.path.join('./items', f'{id}.json'))
# Out:
# 0/971 -- 6954bccff9187b06cf83728a | status_code: 200
# 1/971 -- 6954bccff9187b06cf836cee | status_code: 200
# 2/971 -- 69ccaa7b52280355ab1ee330 | status_code: 200
# 3/971 -- 6954bccff9187b06cf837265 | status_code: 200
# 4/971 -- 6954bccff9187b06cf836d2e | status_code: 200
# 5/971 -- 699249df7e3947753a7664c2 | status_code: 404
# 6/971 -- 699249dc7e3947753a766456 | status_code: 404
# 7/971 -- 69ccaa7e52280355ab1ee3ba | status_code: 200
# 8/971 -- 699249db7e3947753a766446 | status_code: 404
# 9/971 -- 699249d77e3947753a7663b0 | status_code: 404
# 10/971 -- 69cca9a852280355ab1ee27f | status_code: 200
# 11/971 -- 6954bccff9187b06cf8372bf | status_code: 200
# 12/971 -- 69ccaa7f52280355ab1ee3e2 | status_code: 200
# 13/971 -- 6954bccff9187b06cf836cad | status_code: 200
# 14/971 -- 6954bccff9187b06cf836d6d | status_code: 200
# 15/971 -- 6954bccff9187b06cf836d38 | status_code: 200
# 16/971 -- 699249d67e3947753a766378 | status_code: 404
# 17/971 -- 69ccaa7b52280355ab1ee326 | status_code: 200
# ...
