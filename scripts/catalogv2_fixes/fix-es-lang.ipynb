# %%
# import requests
# import json

# ids = [line.split('|')[1] for line in open('fix-es-lang.txt').read().split('\n')]

# api_token = open('api_token.txt').read().strip()
# for index, id in enumerate(ids):
#     item = requests.get(f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{id}").json()
#     item['languages']['content_language'] = 'es'
#     response = requests.patch(
#         f"http://adapt2.sis.pitt.edu/next.course-authoring/api/slc-items-api/{id}",
#         json=item,
#         headers={'api-token': api_token}
#     )
#     print(f'{index}/{len(ids)}:', id, ' -- status_code:', response.status_code)
# Out:
# 0/195: 6954bccff9187b06cf836f2f  -- status_code: 200
# 1/195: 6954bccff9187b06cf836f28  -- status_code: 200
# 2/195: 6954bccff9187b06cf836f25  -- status_code: 200
# 3/195: 6954bccff9187b06cf836f20  -- status_code: 200
# 4/195: 6954bccff9187b06cf836f1f  -- status_code: 200
# 5/195: 6954bccff9187b06cf836f19  -- status_code: 200
# 6/195: 6954bccff9187b06cf836f16  -- status_code: 200
# 7/195: 6954bccff9187b06cf836f15  -- status_code: 200
# 8/195: 6954bccff9187b06cf836f14  -- status_code: 200
# 9/195: 6954bccff9187b06cf836f13  -- status_code: 200
# 10/195: 6954bccff9187b06cf836f11  -- status_code: 200
# 11/195: 6954bccff9187b06cf836f10  -- status_code: 200
# 12/195: 6954bccff9187b06cf836f0f  -- status_code: 200
# 13/195: 6954bccff9187b06cf836f0e  -- status_code: 200
# 14/195: 6954bccff9187b06cf836f0d  -- status_code: 200
# 15/195: 6954bccff9187b06cf836f0c  -- status_code: 200
# 16/195: 6954bccff9187b06cf836f0b  -- status_code: 200
# 17/195: 6954bccff9187b06cf836f0a  -- status_code: 200
# ...
