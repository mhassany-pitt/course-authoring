# %%
import requests

catalog = requests.get("http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2").json()

# %%
import os
import json

os.makedirs("paws-catalog", exist_ok=True)

for index, item in enumerate(catalog):
    if os.path.exists(f"paws-catalog/{item['id']}.json"):
        print(f"{index}/{len(catalog)} {item['id']} already exists, skipping.")
        continue
    
    item = requests.get(f"http://adapt2.sis.pitt.edu/next.course-authoring/api/catalog-v2/{item['id']}").json()
    with open(f"paws-catalog/{item['id']}.json", "w") as f:
        json.dump(item, f, indent=2)
    print(f"{index}/{len(catalog)} {item['id']} downloaded.")
# Out:
# 0/2934 6988ea3a3be3b366adec6dc7 already exists, skipping.
# 1/2934 6988ea3a3be3b366adec6dc5 already exists, skipping.
# 2/2934 6988ea393be3b366adec6dc3 already exists, skipping.
# 3/2934 6988ea393be3b366adec6dc1 already exists, skipping.
# 4/2934 6988ea393be3b366adec6dbf already exists, skipping.
# 5/2934 6988ea383be3b366adec6dbd already exists, skipping.
# 6/2934 6988ea383be3b366adec6dbb already exists, skipping.
# 7/2934 6988ea383be3b366adec6db9 already exists, skipping.
# 8/2934 6988ea373be3b366adec6db7 already exists, skipping.
# 9/2934 6988ea373be3b366adec6db5 already exists, skipping.
# 10/2934 6988ea363be3b366adec6db3 already exists, skipping.
# 11/2934 6988ea363be3b366adec6db1 already exists, skipping.
# 12/2934 6988ea333be3b366adec6daf already exists, skipping.
# 13/2934 6988ea323be3b366adec6dad already exists, skipping.
# 14/2934 6988ea323be3b366adec6dab already exists, skipping.
# 15/2934 6988ea323be3b366adec6da9 already exists, skipping.
# 16/2934 6988ea313be3b366adec6da7 already exists, skipping.
# 17/2934 6988ea313be3b366adec6da5 already exists, skipping.
# 18/2934 6988ea313be3b366adec6da3 already exists, skipping.
# 19/2934 6988ea313be3b366adec6da1 already exists, skipping.
# 20/2934 6988ea303be3b366adec6d9f already exists, skipping.
# 21/2934 6988ea303be3b366adec6d9d already exists, skipping.
# 22/2934 6988ea303be3b366adec6d9b already exists, skipping.
# 23/2934 6988ea2f3be3b366adec6d99 already exists, skipping.
# 24/2934 6988ea2f3be3b366adec6d97 already exists, skipping.
# 25/2934 6988ea2f3be3b366adec6d95 already exists, skipping.
# 26/2934 6988ea2e3be3b366adec6d93 already exists, skipping.
# 27/2934 6988ea2e3be3b366adec6d91 already exists, skipping.
# 28/2934 6988ea2e3be3b366adec6d8f already exists, skipping.
# 29/2934 6988ea2d3be3b366adec6d8d already exists, skipping.
# 30/2934 6988ea2d3be3b366adec6d8b already exists, skipping.
# 31/2934 6988ea2d3be3b366adec6d89 already exists, skipping.
# 32/2934 6988ea2c3be3b366adec6d87 already exists, skipping.
# 33/2934 6988ea2c3be3b366adec6d85 already exists, skipping.
# 34/2934 6988ea2c3be3b366adec6d83 already exists, skipping.
# 35/2934 6988ea2b3be3b366adec6d81 already exists, skipping.
# 36/2934 6988ea2b3be3b366adec6d7f already exists, skipping.
# 37/2934 6988ea2b3be3b366adec6d7d already exists, skipping.
# 38/2934 6988ea2a3be3b366adec6d7b already exists, skipping.
# 39/2934 6988ea2a3be3b366adec6d79 already exists, skipping.
# 2904/2934 6954bccff9187b06cf8377e0 already exists, skipping.
# 2905/2934 6954bccff9187b06cf8377e1 already exists, skipping.
# 2906/2934 6954bccff9187b06cf8377e2 already exists, skipping.
# 2907/2934 6954bccff9187b06cf8377e3 already exists, skipping.
# 2908/2934 6954bccff9187b06cf8377e4 already exists, skipping.
# 2909/2934 6954bccff9187b06cf8377e5 already exists, skipping.
# 2910/2934 6954bccff9187b06cf8377e6 already exists, skipping.
# 2911/2934 6954bccff9187b06cf8377e7 already exists, skipping.
# 2912/2934 6954bccff9187b06cf8377e8 already exists, skipping.
# 2913/2934 6954bccff9187b06cf8377e9 already exists, skipping.
# 2914/2934 6954bccff9187b06cf8377ea already exists, skipping.
# 2915/2934 6954bccff9187b06cf8377eb already exists, skipping.
# 2916/2934 6954bccff9187b06cf8377ec already exists, skipping.
# 2917/2934 6954bccff9187b06cf8377ed already exists, skipping.
# 2918/2934 6954bccff9187b06cf8377ee already exists, skipping.
# 2919/2934 6954bccff9187b06cf8377ef already exists, skipping.
# 2920/2934 6954bccff9187b06cf8377f0 already exists, skipping.
# 2921/2934 6954bccff9187b06cf83781f already exists, skipping.
# 2922/2934 6954bccff9187b06cf837820 already exists, skipping.
# 2923/2934 6954bccff9187b06cf837821 already exists, skipping.
# 2924/2934 6954bccff9187b06cf837822 already exists, skipping.
# 2925/2934 6954bccff9187b06cf837823 already exists, skipping.
# 2926/2934 6954bccff9187b06cf837824 already exists, skipping.
# 2927/2934 6954bccff9187b06cf837825 already exists, skipping.
# 2928/2934 6954bccff9187b06cf837826 already exists, skipping.
# 2929/2934 6954bccff9187b06cf837827 already exists, skipping.
# 2930/2934 6954bccff9187b06cf837828 already exists, skipping.
# 2931/2934 6954bccff9187b06cf837829 already exists, skipping.
# 2932/2934 6954bccff9187b06cf83782a already exists, skipping.
# 2933/2934 6954bccff9187b06cf83782b already exists, skipping.

# %%
normalized_keywords = {
  "advanced oop": ["object-oriented programming"],
  "aggregate functions": ["aggregate functions"],
  "aliasing": ["aliasing"],
  "arithmetic expressions": ["arithmetic expressions"],
  "arithmetic operations": ["arithmetic operations"],
  "arithmetic": ["arithmetic operators"],
  "arraylist": ["arraylist"],
  "arraylists": ["arraylist"],
  "arrays and arraylists": ["arrays", "arraylist"],
  "arrays and two-dim arrays": ["arrays", "2d arrays"],
  "arrays": ["arrays"],
  "basic operators": ["operators"],
  "boolean expressions": ["boolean expressions"],
  "boolean logic": ["boolean logic"],
  "ciclos for": ["for loop"],
  "ciclos while": ["while loop"],
  "ciclos": ["loops"],
  "clases y objetos": ["classes", "objects"],
  "classes & objects": ["classes", "objects"],
  "classes and objects": ["classes", "objects"],
  "classes": ["classes"],
  "classes/objects": ["classes", "objects"],
  "comparison": ["comparison operators"],
  "condicionales": ["conditionals"],
  "conditional": ["conditionals"],
  "conditionals": ["conditionals"],
  "constants": ["constants"],
  "constructors/overload/inheritance": ["constructors", "overloading", "inheritance"],
  "constructors/overloading": ["constructors", "overloading"],
  "control structures": ["control flow"],
  "data types": ["data types"],
  "decision structures": ["conditionals"],
  "decisions and boolean expressions": ["boolean expressions"],
  "decisions": ["conditionals"],
  "demo unit": [],
  "derived relations and views": ["views"],
  "diccionarios": ["dictionaries"],
  "dictionaries": ["dictionaries"],
  "dictionary": ["dictionary"],
  "do while": ["do-while loop"],
  "excepciones": ["exceptions"],
  "exception handling": ["exception handling"],
  "exceptions": ["exceptions"],
  "exceptions/file handling/methods/classes-objects": ["exceptions", "file i/o", "methods", "classes", "objects"],
  "expresiones booleanas": ["boolean expressions"],
  "file handling": ["file i/o"],
  "file processing": ["file i/o"],
  "for loops and while loops": ["loops"],
  "for loops": ["for loop"],
  "funciones": ["functions"],
  "functions": ["functions"],
  "general constraints": ["constraints"],
  "group-by and having": ["group by having"],
  "group-by": ["group by"],
  "halfweek 1 - back to programming": [],
  "halfweek 10 and 11 - trees": ["trees"],
  "halfweek 2 - hands-on python": [],
  "halfweek 3 - algorithm analysis": ["algorithm analysis"],
  "halfweek 4 - data structures and classes": ["data structures", "classes"],
  "halfweek 5 - exception handling": ["exception handling"],
  "halfweek 6 - queues": ["queues"],
  "halfweek 7 - linked lists": ["linked list"],
  "halfweek 8 - search-recursion-sorting": ["search", "recursion", "sorting"],
  "halfweek 9 - sorting": ["sorting"],
  "if else": ["if-else statement"],
  "if statement": ["if statement"],
  "if-else and switch": ["control flow"],
  "if-else": ["if-else statement"],
  "if": ["if statement"],
  "inheritance": ["inheritance"],
  "input": ["input"],
  "interfaces": ["interfaces"],
  "json - aggregate": ["json-aggregate"],
  "json - conditions": ["json-conditions"],
  "json - iterate": ["json-iterate"],
  "json processing": ["json"],
  "json processing/statistics": ["json"],
  "key constraints": [],
  "lab 1 - variables and operations": ["variables"],
  "lab 2 - strings": ["string"],
  "lab 5 - nested loops": ["nested loops"],
  "lecture 1": [],
  "lecture 11": [],
  "lecture 12": [],
  "lecture 3": [],
  "lecture 4": [],
  "lecture 5": [],
  "lecture 6": [],
  "lecture 7": [],
  "lecture 8": [],
  "left join": ["left join"],
  "linked lists (feedback)": ["linked list"],
  "linked lists": ["linked list"],
  "list": ["list"],
  "listas en 2d": ["2d list"],
  "listas": ["list"],
  "lists": ["list"],
  "logical operations": ["logical operators"],
  "logical operators": ["logical operators"],
  "loop for and nested loops": ["nested loops"],
  "loops (for & while)": ["loops"],
  "loops / arrays / exceptions": ["loops"],
  "loops do-while": ["do-while loop"],
  "loops for": ["for loop"],
  "loops while": ["while loop"],
  "loops": ["loops"],
  "main task": [],
  "manejo de archivos/texto": ["file i/o"],
  "math class": ["math"],
  "methods": ["methods"],
  "module 1- arithmetic operators": ["arithmetic operators"],
  "module 1- variables and data types": ["variables","data types"],
  "module 2- objects and classes": ["classes", "objects"],
  "module 2- string operations": ["string operations"],
  "module 3a - boolean expressions": ["boolean expressions"],
  "module 3a- exception handling": ["exception handling"],
  "module 3b- if else conditions": ["if-else statement"],
  "module 3c- inheritance": ["inheritance"],
  "module 4 - arrays": ["arrays"],
  "module 4: arraylist": ["arraylist"],
  "module 4a- while and do..while loops": ["while loop"],
  "module 4b- for loops": ["for loop"],
  "module 4c- nested loops": ["nested loops"],
  "multiple table queries": ["joins"],
  "nested loops": ["nested loops"],
  "null-values": ["null"],
  "numbers": ["numeric types"],
  "object": ["object"],
  "objects and classes": ["classes", "objects"],
  "objects": ["objects"],
  "operators": ["operators"],
  "optional (boolean expressions)": ["boolean expressions"],
  "optional (classes & objects)": ["classes", "objects"],
  "optional (data types)": ["data types"],
  "optional (dictionaries)": ["dictionaries"],
  "optional (exceptions)": ["exceptions"],
  "optional (file handling)": ["file i/o"],
  "optional (functions)": ["functions"],
  "optional (if-else)": ["if-else statement"],
  "optional (lists)": ["list"],
  "optional (loops (for & while))": ["loops"],
  "optional (nested loops)": ["nested loops"],
  "optional (stacks)": ["stack"],
  "optional (strings)": ["strings"],
  "optional (values & references)": ["value vs reference"],
  "optional (variables & operations)": ["variables","operators"],
  "order-by": ["order by"],
  "others": [],
  "output formatting": ["string formatting"],
  "overload/arrays": ["overloading"],
  "pandas - data selection": ["pandas"],
  "pandas - groupby": ["pandas"],
  "pandas - statistics": ["pandas"],
  "pattern matching": ["pattern matching"],
  "preliminary topics": [],
  "primitive data type": ["primitive data types"],
  "primitive data types": ["primitive data types"],
  "procesamiento de texto y archivos": ["file i/o"],
  "queues and stacks": ["queues", "stacks"],
  "queues": ["queue"],
  "recursion (feedback)": ["recursion"],
  "recursion": ["recursion"],
  "recursion/searching/sorting": ["recursion"],
  "rich comparison methods": [],
  "search": ["search algorithms"],
  "searching": ["search algorithms"],
  "select-from-where": ["select"],
  "select-from": ["select"],
  "set operations": ["set operations"],
  "simple input": ["input"],
  "sorting": ["sorting algorithms"],
  "stacks and queues": ["stacks", "queues"],
  "stacks": ["stack"],
  "statistics": ["statistics"],
  "string class": ["string"],
  "strings and decision structures": ["strings", "conditionals"],
  "strings": ["strings"],
  "sub-queries": ["subqueries"],
  "subproblems": [],
  "switch": ["switch statement"],
  "table creation": ["create table"],
  "table deletion and alteration": ["ddl"],
  "test unit": [],
  "topic 1 - 174 review": [],
  "topic 1": [],
  "topic 10 - binary search, trees": ["binary search", "trees"],
  "topic 10": [],
  "topic 2 - algorithm analysis": ["algorithm analysis"],
  "topic 3 - data structures, stacks, classes": ["data structures", "stacks", "classes"],
  "topic 4 - exceptions & exception handling": ["exception handling"],
  "topic 5 - queues": ["queue"],
  "topic 6 - linked lists": ["linked list"],
  "topic 6": [],
  "topic 7 - doubly linked lists": ["doubly linked list"],
  "topic 7": [],
  "topic 8 - search, recursion, sorting": ["search algorithms", "recursion", "sorting algorithms"],
  "topic 8": [],
  "topic 9 - swapping variables": ["swap"],
  "topic 9": [],
  "topic1": [],
  "topic2": [],
  "trees": ["trees"],
  "tuple deletion": ["tuple"],
  "tuple insertion": ["tuple"],
  "tuple update": ["tuple"],
  "tuples": ["tuples"],
  "two-dimensional arrays": ["2d arrays"],
  "two-dimensional lists": ["2d list"],
  "unit 1": [],
  "unit1": [],
  "values & references": ["value vs reference"],
  "values and references": ["value vs reference"],
  "values, references and aliasing": ["aliasing"],
  "variables & operations": ["variables", "operators"],
  "variables and datatypes": ["variables", "data types"],
  "variables and operations": ["variables", "operators"],
  "variables and primitive data types": ["primitive data types"],
  "variables and types": ["variables", "data types"],
  "variables y operaciones": ["variables", "operators"],
  "variables": ["variables"],
  "while loops": ["while loop"],
  "wrapper classes": ["wrapper classes"],
}

# %%
import re
import itertools

items = []

providers_list = ["WebEx","QuizJET","QuizPET","jsParsons","JSVEE","DBQA", "AnnEx"]
author_affs = {
  "alex simeone": "University of Pittsburgh",
  "andres pacheco": "",
  "andrew mowrey": "",
  "andrzej dubiel": "",
  "angela zack": "University of Pittsburgh",
  "annette rico": "",
  "arun balajiee lekshmi narayanan": "University of Pittsburgh",
  "aslam mogri": "Robert Morris University ",
  "banks christopher": "",
  "chris jackson": "",
  "cross patrick": "Indiana University of Pennsylvania ",
  "daniel guerra": "University of Pittsburgh",
  "darby hoffman": "",
  "david nawn": "University of Pittsburgh ",
  "detar derek": "Indiana University of Pennsylvania ",
  "dobosh joshua": "",
  "eric napolitan": "University of Pittsburgh",
  "eric riemer": "University of Pittsburgh",
  "gentile jeffrey": "",
  "haaranen lassi": "Aalto Finland",
  "hardik vasa": "University of Pittsburgh",
  "hasan mashrique": "University of Memphis",
  "hung chau": "University of Pittsburgh",
  "isaac alpizar-chacon": "Utrecht University",
  "james bowman": "University of Pittsburgh",
  "john moan": "",
  "jordan barria-pineda": "University of Pittsburgh",
  "joshua sawyers": "University of Pittsburgh",
  "kamil akhuseyinoglu": "University of Pittsburgh",
  "kerns troy": "Indiana University of Pennsylvania ",
  "kieth yackovich": "Indiana University of Pennsylvania ",
  "kitchens kenyetta": "Indiana University of Pennsylvania ",
  "laney jesse": "University of Pittsburgh",
  "larry werner": "University of Pittsburgh",
  "megan patton": "Pittsburgh Public Schools ",
  "michael logoyda": "University of Pittsburgh ",
  "mohammad hassany": "University of Pittsburgh",
  "natalya goreva": "Indiana University of Pennsylvania",
  "oliver gladys": "University of Pittsburgh",
  "patric campbell": "University of Pittsburgh",
  "peter brusilovsky": "University of Pittsburgh",
  "rafael araujo": "University of Pittsburgh",
  "roya hosseini": "University of Pittsburgh",
  "rully hendrawan": "University of Pittsburgh",
  "ryan johnston": "University of Pittsburgh",
  "sergey sosnovsky": "University of Pittsburgh",
  "sharon hsiao": "University of Pittsburgh",
  "sirkiä teemu": "Aalto Finland",
  "stephen plumby": "University of Pittsburgh",
  "yun huang": "University of Pittsburgh"
}

def fix_url(url):
    # print("before:", url)
    url = url.replace('https://acos.cs.vt.edu/pitt/', 'https://acos.cs.vt.edu/html/')\
        .replace('http://adapt2.sis.pitt.edu/acos/pitt/', 'https://acos.cs.vt.edu/html/')\
        .replace('/ae?example-id=', '/')\
        .replace('/ps?example-id=', '/')
    if url.startswith('https://acos.cs.vt.edu/html/'):
        url = '&'.join([seg for seg in url.split('&') if not seg.startswith(('grp=', 'usr=', 'sid=', 'cid='))])
    # print("after:", url)
    return url

def get_description(item):
    type = item["identity"]["type"]
    provider = item["attribution"]["provider"]
    prompt = item["content"]["prompt"]
    
    if provider in ['QuizJET', 'QuizPET'] and type == 'Question':
        type = 'PredictingFinalResult'
    elif provider == 'jsParsons':
        type = 'ParsonsProblem'
    elif provider == 'SQL-KnoT':
        type = 'FreeCodingProblems'
    elif provider == 'WebEx' and prompt:
        type = 'CodeConstruction'
    elif provider == 'WebEx' and not prompt:
        type = 'BehaviorExample'
    elif provider == 'JSVEE':
        type = 'CodeVisualization'
        
    return (
        f'{item["languages"]["programming_languages"][0]} {type} for demonstrating {item["identity"]["title"]}'
    )

for filename in os.listdir("paws-catalog"):
    if not filename.endswith(".json"):
        continue
    
    with open(f"paws-catalog/{filename}", "r") as f:
        item = json.load(f)
        
    if item["attribution"]["provider"] not in providers_list:
        continue
    
    url = [delivery["url"] for delivery in item["delivery"]][0]
    iframe_url = item["links"]["demo_url"]
        
    # fix the url for JSVEE and jsParsons items
    if item["attribution"]["provider"] in ['JSVEE','jsParsons']:
        url = fix_url(url)
        iframe_url = fix_url(iframe_url)
    
    # WebEx in ACOS should be named AnnEx
    platform_name = item["attribution"]["provider"]
    if platform_name == "WebEx" and 'https://acos.cs.vt.edu/html/annotated/' in url:
        platform_name = "AnnEx"
        
    # set protocol based on provider
    protocol = []
    if item["attribution"]["provider"] == 'DBQA':
        protocol = ["LTI 1.1"]
    elif item["attribution"]["provider"] in ['QuizJET','QuizPET','WebEx']:
        protocol = ["html"]
    elif item["attribution"]["provider"] in ['jsParsons','JSVEE','AnnEx']:
        protocol = ["SPLICE"]

    items.append({
        "__id":item["id"],
        "catalog_type":"SLCItem",
        "persistentID":url,
        "platform_name":platform_name,
        "title":item["identity"]["title"],
        "description":item["content"]["prompt"] if item["content"]["prompt"] else get_description(item),
        "license":item["rights"]["license"],
        "author":[author["name"] for author in item["attribution"]["authors"]],
        "institution":list(set([author_affs.get(author["name"].lower(), author["affiliation"]) for author in item["attribution"]["authors"]])),
        "keywords":sorted(list(set(itertools.chain.from_iterable([
            normalized_keywords[use['context_name'].rsplit(' > ')[1].strip().lower()]
            for use in item['uses']
            if 'context_name' in use and ' > ' in use['context_name']
        ])))),
        "features":[],
        "programming_language":item["languages"]["programming_languages"],
        "natural_language":[item["languages"]["content_language"]],
        "iframe_url":iframe_url,
        "protocol":protocol,
        "protocol_url":[url]
    })

# %%
import re
pcex_hub = requests.get("http://adapt2.sis.pitt.edu/pcex-authoring/api/hub?key=").json()

pcex_affiliations = {
  "adityajoshi5@gmail.com": "Utrecht University",
  "ahromic1@etf.unsa.ba": "Elektrotehnički fakultet Univerziteta u Sarajevu",
  "akm@dmi.uns.ac.rs": "Departman za matematiku i informatiku",
  "arl122@pitt.edu": "University of Pittsburgh",
  "boban.vesin@usn.no": "Universitetet i Sørøst-Norge",
  "i.alpizarchacon@uu.nl": "Utrecht University",
  "jab464@pitt.edu": "University of Pittsburgh",
  "mbarsky@pitt.edu": "University of Pittsburgh",
  "mcburton@pitt.edu": "University of Pittsburgh",
  "mkamberovi1@etf.unsa.ba": "Elektrotehnički fakultet Univerziteta u Sarajevu",
  "moh70@pitt.edu": "University of Pittsburgh",
  "rafaellasalencar@gmail.com": "University of Pittsburgh"
}

bosnian_ids = '68b896c02da757ceaee7ff41,68b9b83afce5207cc0b4d0f6,68b9be49fce5207cc0b4d140,68d1a96763fa732f4df66957,68d4450963fa732f4df67320,68d56ea863fa732f4df6775b,6910afee1b622a00857decdc,6910b0d21b622a00857decf5,6910b1521b622a00857decff,6910b19a1b622a00857ded0b,692364eae28428298e4ba75c,692365b9e28428298e4ba8b7,69236607e28428298e4ba8c1,69236a65e28428298e4bab80,693480c7e28428298e556a5c,69348d69e28428298e557133,693552f9e28428298e55e310,69355d5de28428298e55e8a6,693b00d77c5007b9c2231262,693b2fab80e2aaa929a2579d,693b360480e2aaa929a25bd8,693c50a7e6aa8ff1d74e2d13,693c7f92443e2801de617111,693da3e8443e2801de625e29,693dab82443e2801de62624f,693dd520443e2801de627aa0,693ddc65443e2801de627ec7,69444a4db71cfad9382176c5,694450b9b71cfad938217b32,69458765b71cfad9382240a3,694591f5b71cfad938224778,694eb4bd136f190edb6ac071,694ec54a136f190edb6aca59,694f41c8136f190edb6b1622,694f41e6136f190edb6b1628,6951b817136f190edb6c9736,6951b894136f190edb6c98a6,6951d3d8136f190edb6ca847,6951e616136f190edb6cb3d2,69523e43136f190edb6cea34,6952b141136f190edb6d321e,6952bd0d136f190edb6d396e,6952bda1136f190edb6d397c,6952d68f136f190edb6d4936,6952fa18136f190edb6d5e8a'.split(',')

def clean(name):
    name = re.sub(r'__([a-f0-9]{24})-([a-f0-9]{24})-([0-9]{1,2})$', '', name)
    return re.sub(r'__([a-f0-9]{24})$', '', name).strip()

os.makedirs("pcex-authoring", exist_ok=True)
for item in pcex_hub:
    if item['id'] in ['69432fa7b71cfad93820cdaa']:
        continue
    
    if os.path.exists(f"pcex-authoring/{item['id']}.json"):
        activity = json.load(open(f"pcex-authoring/{item['id']}.json", "r"))
    else:
        print(f"downloading activity {item['id']}")
        activity = requests.get(f"http://adapt2.sis.pitt.edu/pcex-authoring/api/hub/{item['id']}?_t=1769895252087").json()
        with open(f"pcex-authoring/{item['id']}.json", "w") as f:
            json.dump(activity, f, indent=2)
            print(f"activity {item['id']} downloaded and saved.")
    
    activity = activity[0]
    item_nameid = activity['activityName'].replace(' ', '_').replace('.', '_').replace('(', '').replace(')', '')
    if item['id'] not in item_nameid:
        item_nameid += f"__{item['id']}"
    url = f"https://acos.cs.vt.edu/html/acos-pcex/acos-pcex-examples/{item_nameid}"
    
    lang = "en"
    if item['id'] in bosnian_ids:
        lang = "bs"
    elif clean(activity['activityName']).endswith("_es"):
        lang = "es"

    items.append({
        "__id":item["id"],
        "catalog_type":"SLCItem",
        "persistentID":url,
        "platform_name":"PCEX",
        "title":clean(activity['activityName']),
        "description":"PCEX Set of activities for "+clean(activity['activityName']),
        "license":"MIT",
        "author":item['author']['fullname'],
        "institution":pcex_affiliations[item['author']['email']],
        "keywords":[],
        "features":[],
        "programming_language":activity['activityGoals'][0]['language'],
        "natural_language":lang,
        "iframe_url":url,
        "protocol":["SPLICE"],
        "protocol_url":[url]
    })
    
    for index, goal in enumerate(activity['activityGoals']):
        items.append({
            "__id":item["id"],
            "catalog_type":"SLCItem",
            "persistentID":url+f"?index={index}",
            "platform_name":"PCEX",
            "title":clean(goal["name"]),
            "description":goal["goalDescription"],
            "license":"MIT",
            "author":item['author']['fullname'],
            "institution":pcex_affiliations[item['author']['email']],
            "keywords":[],
            "features":[],
            "programming_language":goal['language'],
            "natural_language":lang,
            "iframe_url":url+f"?index={index}",
            "protocol":["SPLICE"],
            "protocol_url":[url+f"?index={index}"]
        })

# %%
def no_id(item):
    item = json.loads(json.dumps(item))  # deep copy
    del item["__id"]
    return item
    
with open("paws-catalog-SLCItem-all.json", "w") as f:
    json.dump([no_id(item) for item in items], f, indent=2) 
    
for provider in [*providers_list, "PCEX"]:
    with open(f"paws-catalog-SLCItem-{provider}.json", "w") as f:
        json.dump([no_id(item) for item in items if item["platform_name"] == provider], f, indent=2)

# %%
# import requests

# for index, item in enumerate(items):
#     req = requests.get(item['iframe_url'])
#     print(f"{index}/{len(items)} - {req.status_code}: {item['iframe_url']}")

# %%
json.dump([
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "DBQA",
    "url": "https://codesmell.org/dbqa",
    "description": "Web tool that steps through SQL SELECT query evaluation, highlighting the active clause and showing intermediate results. Used to teach how queries execute; supports LMS/LTI integration.",
    "contact_email": "hardtr@uwec.edu"
  },
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "jsParsons",
    "url": "https://github.com/acos-server/acos-jsparsons",
    "description": "ACOS content package that delivers Parsons problems (code reordering puzzles). Provides shared JS components and deployment scaffolding for building and serving Parsons-style programming exercises.",
    "contact_email": "lassi.haaranen@aalto.fi"
  },
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "JSVEE",
    "url": "https://github.com/Aalto-LeTech/jsvee",
    "description": "JavaScript library for creating step-by-step program execution visualizations. Offers reusable operations and extensibility for language-specific visual execution content.",
    "contact_email": "teemu.sirkia@aalto.fi"
  },
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "PCEX",
    "url": "http://adapt2.sis.pitt.edu/wiki/PCEX",
    "description": "Interactive worked-example system for learning code construction. Breaks solutions into subgoal steps with on-demand explanations and checks, supporting self-paced study of programming patterns.",
    "contact_email": "moh70@pitt.edu"
  },
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "QuizJET",
    "url": "http://adapt2.sis.pitt.edu/wiki/QuizJET",
    "description": "Parameterized Java quiz engine that generates variants, executes reference code to compute correct answers, checks responses, and logs performance for practice and adaptive support.",
    "contact_email": "moh70@pitt.edu"
  },
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "QuizPET",
    "url": "http://adapt2.sis.pitt.edu/wiki/QuizPET",
    "description": "Parameterized Python quiz tool focused on code behavior/semantics. Generates instances, runs code to derive answers, grades responses, and records results for targeted practice.",
    "contact_email": "moh70@pitt.edu"
  },
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "WebEx",
    "url": "http://adapt2.sis.pitt.edu/wiki/WebEx",
    "description": "Annotated example viewer for programming code. Learners inspect instructor comments line-by-line, opening explanations as needed to support comprehension and example-based learning.",
    "contact_email": "moh70@pitt.edu"
  },
  {
    "catalog_type": "SLCToolsCatalog",
    "platform_name": "AnnEx",
    "url": "https://github.com/mhassany-pitt/acos-annotated",
    "description": "Repository of WebEx-style annotated programming examples packaged for reuse (often via ACOS). Provides curated example sets across languages for embedding into courses or adaptive platforms.",
    "contact_email": "moh70@pitt.edu"
  }
], open("paws-catalog-SLCToolsCatalog-all.json", "w"), indent=2)
